# %%
# %load_ext autoreload
# %autoreload 2

# %%
import datetime
from dotenv import load_dotenv
import json
from lib.utils import black_print
import openai
import polars as pl
from pydantic import BaseModel

load_dotenv()

df = (
    pl.read_parquet("./data/corbt/connections-games/*.parquet")
    .sort("createdAt")
    .cast({"id": pl.Int64})
    .rename({"startingBoard": "starting_board"})
)
df
# Out:
# shape: (600, 5)
# ┌─────┬────────────────────────┬────────────────────────┬──────────────────┬───────────────────────┐
# │ id  ┆ board                  ┆ createdAt              ┆ name             ┆ starting_board        │
# │ --- ┆ ---                    ┆ ---                    ┆ ---              ┆ ---                   │
# │ i64 ┆ str                    ┆ datetime[μs, UTC]      ┆ str              ┆ str                   │
# ╞═════╪════════════════════════╪════════════════════════╪══════════════════╪═══════════════════════╡
# │ 1   ┆ {"WET WEATHER":        ┆ 2023-06-12 00:00:00    ┆ Connections #1   ┆ [["SNOW", "LEVEL",    │
# │     ┆ {"level": 0, "…        ┆ UTC                    ┆                  ┆ "SHIFT", "K…          │
# │ 2   ┆ {"FOOTWEAR": {"level": ┆ 2023-06-13 00:00:00    ┆ Connections #2   ┆ [["PUMP", "FOOT",     │
# │     ┆ 0, "mem…               ┆ UTC                    ┆                  ┆ "TIME", "SEA…         │
# │ 3   ┆ {"FACIAL FEATURES":    ┆ 2023-06-14 00:00:00    ┆ Connections #3   ┆ [["AMIGO", "MOUTH",   │
# │     ┆ {"level": …            ┆ UTC                    ┆                  ┆ "LAB", "ST…           │
# │ 4   ┆ {"SNEAKER BRANDS":     ┆ 2023-06-15 00:00:00    ┆ Connections #4   ┆ [["DUST", "CATS",     │
# │     ┆ {"level": 0…           ┆ UTC                    ┆                  ┆ "SPIDER", "C…         │
# │ 5   ┆ {"STREAMING SERVICES": ┆ 2023-06-16 00:00:00    ┆ Connections #5   ┆ [["MUSTARD",          │
# │     ┆ {"level…               ┆ UTC                    ┆                  ┆ "TARTAR", "PLUM",…    │
# │ …   ┆ …                      ┆ …                      ┆ …                ┆ …                     │
# │ 596 ┆ {"SMALL AMOUNT OF FOOD ┆ 2025-01-27 00:00:00    ┆ Connections #596 ┆ [["OLIVE",            │
# │     ┆ TO TRY"…               ┆ UTC                    ┆                  ┆ "TYPEWRITER", "EXTR…  │
# │ 597 ┆ {"FUNNY PERSON":       ┆ 2025-01-28 00:00:00    ┆ Connections #597 ┆ [["DEMON", "LAUGH",   │
# │     ┆ {"level": 0, …         ┆ UTC                    ┆                  ┆ "JOKER", "…           │
# │ 598 ┆ {"OWNED": {"level": 0, ┆ 2025-01-29 00:00:00    ┆ Connections #598 ┆ [["WICKED",           │
# │     ┆ "member…               ┆ UTC                    ┆                  ┆ "GINGERBREAD", "FU…   │
# │ 599 ┆ {"INTANGIBLE QUALITY": ┆ 2025-01-30 00:00:00    ┆ Connections #599 ┆ [["HALO", "RIGATONI", │
# │     ┆ {"level…               ┆ UTC                    ┆                  ┆ "AIR", "…             │
# │ 600 ┆ {"STORAGE CONTAINER":  ┆ 2025-01-31 00:00:00    ┆ Connections #600 ┆ [["SNOOT", "BREAST",  │
# │     ┆ {"level"…              ┆ UTC                    ┆                  ┆ "FREE", "…            │
# └─────┴────────────────────────┴────────────────────────┴──────────────────┴───────────────────────┘

# %%
class ConnectionGroup(BaseModel):
    level: int
    members: list[str]


class ConnectionGame(BaseModel):
    board: dict[str, ConnectionGroup]
    starting_board: list[list[str]]
    createdAt: datetime.datetime
    id: int
    name: str


games: list[ConnectionGame] = [
    ConnectionGame(
        board={
            group_name: ConnectionGroup(
                level=group_contents["level"],
                members=group_contents["members"],
            )
            for group_name, group_contents in json.loads(d["board"]).items()
        },
        starting_board=json.loads(d["starting_board"]),
        createdAt=d["createdAt"],
        id=d["id"],
        name=d["name"],
    )
    for d in df.to_dicts()
]
games
# Out:
# [ConnectionGame(board={'WET WEATHER': ConnectionGroup(level=0, members=['HAIL', 'RAIN', 'SLEET', 'SNOW']), 'NBA TEAMS': ConnectionGroup(level=1, members=['BUCKS', 'HEAT', 'JAZZ', 'NETS']), 'KEYBOARD KEYS': ConnectionGroup(level=2, members=['OPTION', 'RETURN', 'SHIFT', 'TAB']), 'PALINDROMES': ConnectionGroup(level=3, members=['KAYAK', 'LEVEL', 'MOM', 'RACECAR'])}, starting_board=[['SNOW', 'LEVEL', 'SHIFT', 'KAYAK'], ['HEAT', 'TAB', 'BUCKS', 'RETURN'], ['JAZZ', 'HAIL', 'OPTION', 'RAIN'], ['SLEET', 'RACECAR', 'MOM', 'NETS']], createdAt=datetime.datetime(2023, 6, 12, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=1, name='Connections #1'),
#  ConnectionGame(board={'FOOTWEAR': ConnectionGroup(level=0, members=['BOOT', 'LOAFER', 'PUMP', 'SNEAKER']), 'UNITS OF LENGTH': ConnectionGroup(level=1, members=['FOOT', 'LEAGUE', 'MILE', 'YARD']), 'MAGAZINES': ConnectionGroup(level=2, members=['ESSENCE', 'PEOPLE', 'TIME', 'US']), 'LETTER HOMOPHONES': ConnectionGroup(level=3, members=['ARE', 'QUEUE', 'SEA', 'WHY'])}, starting_board=[['PUMP', 'FOOT', 'TIME', 'SEA'], ['LEAGUE', 'LOAFER', 'WHY', 'US'], ['BOOT', 'YARD', 'PEOPLE', 'ARE'], ['MILE', 'SNEAKER', 'QUEUE', 'ESSENCE']], createdAt=datetime.datetime(2023, 6, 13, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=2, name='Connections #2'),
#  ConnectionGame(board={'FACIAL FEATURES': ConnectionGroup(level=0, members=['CHEEK', 'EYE', 'MOUTH', 'NOSE']), 'SYNONYMS FOR EAT': ConnectionGroup(level=1, members=['CHOW', 'GOBBLE', 'SCARF', 'WOLF']), 'DOG BREEDS, INFORMALLY': ConnectionGroup(level=2, members=['LAB', 'PEKE', 'PIT', 'POM']), 'MEMBERS OF A TRIO': ConnectionGroup(level=3, members=['AMIGO', 'KING', 'STOOGE', 'TENOR'])}, starting_board=[['AMIGO', 'MOUTH', 'LAB', 'STOOGE'], ['WOLF', 'KING', 'NOSE', 'CHOW'], ['TENOR', 'POM', 'SCARF', 'EYE'], ['PIT', 'GOBBLE', 'PEKE', 'CHEEK']], createdAt=datetime.datetime(2023, 6, 14, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=3, name='Connections #3'),
#  ConnectionGame(board={'SNEAKER BRANDS': ConnectionGroup(level=0, members=['ADIDAS', 'NIKE', 'PUMA', 'REEBOK']), 'MUSICALS BEGINNING WITH “C”': ConnectionGroup(level=1, members=['CABARET', 'CAROUSEL', 'CATS', 'CHICAGO']), 'CLEANING VERBS': ConnectionGroup(level=2, members=['DUST', 'MOP', 'SWEEP', 'VACUUM']), '___ MAN SUPERHEROES': ConnectionGroup(level=3, members=['BAT', 'IRON', 'SPIDER', 'SUPER'])}, starting_board=[['DUST', 'CATS', 'SPIDER', 'CAROUSEL'], ['PUMA', 'IRON', 'NIKE', 'MOP'], ['CHICAGO', 'SWEEP', 'SUPER', 'BAT'], ['REEBOK', 'CABARET', 'VACUUM', 'ADIDAS']], createdAt=datetime.datetime(2023, 6, 15, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=4, name='Connections #4'),
#  ConnectionGame(board={'STREAMING SERVICES': ConnectionGroup(level=0, members=['HULU', 'NETFLIX', 'PEACOCK', 'PRIME']), 'CONDIMENTS': ConnectionGroup(level=1, members=['KETCHUP', 'MAYO', 'RELISH', 'TARTAR']), 'SYNONYMS FOR SAD': ConnectionGroup(level=2, members=['BLUE', 'DOWN', 'GLUM', 'LOW']), 'CLUE CHARACTERS': ConnectionGroup(level=3, members=['GREEN', 'MUSTARD', 'PLUM', 'SCARLET'])}, starting_board=[['MUSTARD', 'TARTAR', 'PLUM', 'BLUE'], ['GREEN', 'PRIME', 'GLUM', 'RELISH'], ['DOWN', 'PEACOCK', 'KETCHUP', 'LOW'], ['HULU', 'SCARLET', 'MAYO', 'NETFLIX']], createdAt=datetime.datetime(2023, 6, 16, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=5, name='Connections #5'),
#  ConnectionGame(board={'MONOPOLY SQUARES': ConnectionGroup(level=0, members=['BOARDWALK', 'CHANCE', 'GO', 'JAIL']), 'SHADES OF BLUE': ConnectionGroup(level=1, members=['BABY', 'MIDNIGHT', 'POWDER', 'ROYAL']), 'RAPPERS': ConnectionGroup(level=2, members=['COMMON', 'FUTURE', 'ICE CUBE', 'Q-TIP']), 'MEMBERS OF A SEPTET': ConnectionGroup(level=3, members=['SEA', 'SIN', 'SISTER', 'WONDER'])}, starting_board=[['WONDER', 'FUTURE', 'BABY', 'GO'], ['SIN', 'CHANCE', 'ROYAL', 'ICE CUBE'], ['MIDNIGHT', 'JAIL', 'SEA', 'POWDER'], ['Q-TIP', 'SISTER', 'BOARDWALK', 'COMMON']], createdAt=datetime.datetime(2023, 6, 17, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=6, name='Connections #6'),
#  ConnectionGame(board={'LEG PARTS': ConnectionGroup(level=0, members=['ANKLE', 'KNEE', 'SHIN', 'THIGH']), 'BABY ANIMALS': ConnectionGroup(level=1, members=['CALF', 'CUB', 'JOEY', 'KID']), 'SLANG FOR TOILET': ConnectionGroup(level=2, members=['CAN', 'HEAD', 'JOHN', 'THRONE']), '___ FISH THAT AREN’T FISH': ConnectionGroup(level=3, members=['CRAY', 'JELLY', 'SILVER', 'STAR'])}, starting_board=[['JOHN', 'CUB', 'STAR', 'SILVER'], ['KNEE', 'THRONE', 'JOEY', 'JELLY'], ['CALF', 'ANKLE', 'CRAY', 'HEAD'], ['SHIN', 'CAN', 'KID', 'THIGH']], createdAt=datetime.datetime(2023, 6, 18, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=7, name='Connections #7'),
#  ConnectionGame(board={'BOARD GAMES': ConnectionGroup(level=0, members=['BACKGAMMON', 'CHECKERS', 'CHESS', 'GO']), 'MATTRESS SIZES': ConnectionGroup(level=1, members=['FULL', 'KING', 'QUEEN', 'TWIN']), 'THINGS THAT ARE RED': ConnectionGroup(level=2, members=['CHERRY', 'FIRE TRUCK', 'RUBY', 'STOP SIGN']), 'THINGS WITH KEYS': ConnectionGroup(level=3, members=['CRYPTOGRAPHY', 'FLORIDA', 'LOCKSMITH', 'PIANO'])}, starting_board=[['LOCKSMITH', 'FIRE TRUCK', 'KING', 'PIANO'], ['CHESS', 'RUBY', 'FLORIDA', 'TWIN'], ['CHERRY', 'QUEEN', 'STOP SIGN', 'GO'], ['CHECKERS', 'CRYPTOGRAPHY', 'FULL', 'BACKGAMMON']], createdAt=datetime.datetime(2023, 6, 19, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=8, name='Connections #8'),
#  ConnectionGame(board={'SPORTS': ConnectionGroup(level=0, members=['CRICKET', 'FENCING', 'POLO', 'SQUASH']), 'TOPS': ConnectionGroup(level=1, members=['CAMI', 'HALTER', 'TANK', 'TEE']), 'VEGETABLES': ConnectionGroup(level=2, members=['BEET', 'CARROT', 'CORN', 'ONION']), 'INSECTS': ConnectionGroup(level=3, members=['ANT', 'BEETLE', 'MANTIS', 'TERMITE'])}, starting_board=[['SQUASH', 'TEE', 'CARROT', 'ANT'], ['TANK', 'CORN', 'CRICKET', 'MANTIS'], ['POLO', 'ONION', 'BEETLE', 'BEET'], ['CAMI', 'TERMITE', 'HALTER', 'FENCING']], createdAt=datetime.datetime(2023, 6, 20, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=9, name='Connections #9'),
#  ConnectionGame(board={'FRUIT': ConnectionGroup(level=0, members=['DATE', 'KIWI', 'LEMON', 'ORANGE']), 'COUNTRIES': ConnectionGroup(level=1, members=['CHAD', 'GEORGIA', 'JORDAN', 'TOGO']), 'BIRDS': ConnectionGroup(level=2, members=['CRANE', 'JAY', 'SWALLOW', 'TURKEY']), 'ZODIAC SYMBOLS': ConnectionGroup(level=3, members=['FISH', 'GOAT', 'SCALES', 'TWINS'])}, starting_board=[['TWINS', 'TURKEY', 'GOAT', 'KIWI'], ['SCALES', 'FISH', 'JORDAN', 'JAY'], ['ORANGE', 'GEORGIA', 'DATE', 'CRANE'], ['TOGO', 'SWALLOW', 'LEMON', 'CHAD']], createdAt=datetime.datetime(2023, 6, 21, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=10, name='Connections #10'),
#  ConnectionGame(board={'SPICES BEGINNING WITH “C”': ConnectionGroup(level=0, members=['CARDAMOM', 'CLOVE', 'CORIANDER', 'CUMIN']), 'TERMS OF ENDEARMENT': ConnectionGroup(level=1, members=['BOO', 'HONEY', 'SUGAR', 'SWEETIE']), 'THINGS WITH WINGS': ConnectionGroup(level=2, members=['AIRPLANE', 'ANGEL', 'BIRD', 'PEGASUS']), 'SPICE GIRLS': ConnectionGroup(level=3, members=['BABY', 'GINGER', 'POSH', 'SCARY'])}, starting_board=[['SUGAR', 'ANGEL', 'GINGER', 'BIRD'], ['BABY', 'CUMIN', 'BOO', 'SCARY'], ['SWEETIE', 'CORIANDER', 'AIRPLANE', 'CLOVE'], ['PEGASUS', 'HONEY', 'CARDAMOM', 'POSH']], createdAt=datetime.datetime(2023, 6, 22, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=11, name='Connections #11'),
#  ConnectionGame(board={'ANIMAL GROUP NAMES': ConnectionGroup(level=0, members=['FLOCK', 'PACK', 'POD', 'SCHOOL']), 'DEADLY SINS': ConnectionGroup(level=1, members=['ENVY', 'GREED', 'LUST', 'PRIDE']), 'SLOW ANIMALS': ConnectionGroup(level=2, members=['LORIS', 'SLOTH', 'SNAIL', 'TORTOISE']), 'TRIG FUNCTIONS': ConnectionGroup(level=3, members=['COT', 'SEC', 'SIN', 'TAN'])}, starting_board=[['LUST', 'PRIDE', 'TAN', 'SCHOOL'], ['SLOTH', 'SEC', 'PACK', 'COT'], ['SNAIL', 'GREED', 'SIN', 'FLOCK'], ['POD', 'LORIS', 'ENVY', 'TORTOISE']], createdAt=datetime.datetime(2023, 6, 23, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=12, name='Connections #12'),
#  ConnectionGame(board={'AIRLINES': ConnectionGroup(level=0, members=['FRONTIER', 'SPIRIT', 'UNITED', 'VIRGIN']), 'GREEK LETTERS': ConnectionGroup(level=1, members=['BETA', 'CHI', 'DELTA', 'IOTA']), 'SILENT “G”': ConnectionGroup(level=2, members=['GNAT', 'GNAW', 'GNOCCHI', 'GNOME']), 'HOMOPHONES': ConnectionGroup(level=3, members=['GNU', 'KNEW', 'NEW', 'NU'])}, starting_board=[['KNEW', 'GNOME', 'IOTA', 'FRONTIER'], ['DELTA', 'CHI', 'GNOCCHI', 'NEW'], ['SPIRIT', 'BETA', 'VIRGIN', 'GNAW'], ['NU', 'GNAT', 'UNITED', 'GNU']], createdAt=datetime.datetime(2023, 6, 24, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=13, name='Connections #13'),
#  ConnectionGame(board={'BEDS': ConnectionGroup(level=0, members=['BUNK', 'CANOPY', 'MURPHY', 'TRUNDLE']), 'FAMOUS BROTHERS': ConnectionGroup(level=1, members=['JONAS', 'MARX', 'WARNER', 'WRIGHT']), 'HONDAS': ConnectionGroup(level=2, members=['ACCORD', 'CIVIC', 'PASSPORT', 'PILOT']), 'VIDEO GAME CHARACTERS': ConnectionGroup(level=3, members=['CRASH', 'LINK', 'MARIO', 'SONIC'])}, starting_board=[['CANOPY', 'LINK', 'PASSPORT', 'MARX'], ['PILOT', 'SONIC', 'WRIGHT', 'ACCORD'], ['MURPHY', 'CRASH', 'CIVIC', 'BUNK'], ['MARIO', 'JONAS', 'TRUNDLE', 'WARNER']], createdAt=datetime.datetime(2023, 6, 25, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=14, name='Connections #14'),
#  ConnectionGame(board={'BIRD SOUNDS': ConnectionGroup(level=0, members=['CAW', 'CHIRP', 'CLUCK', 'TWEET']), 'COLORS': ConnectionGroup(level=1, members=['BROWN', 'PINK', 'TURQUOISE', 'VIOLET']), 'FISHING GEAR': ConnectionGroup(level=2, members=['LURE', 'REEL', 'ROD', 'TACKLE']), 'FICTIONAL PIRATES': ConnectionGroup(level=3, members=['HOOK', 'JONES', 'SILVER', 'SPARROW'])}, starting_board=[['SILVER', 'TWEET', 'ROD', 'SPARROW'], ['BROWN', 'TACKLE', 'HOOK', 'PINK'], ['CAW', 'JONES', 'VIOLET', 'REEL'], ['TURQUOISE', 'CHIRP', 'LURE', 'CLUCK']], createdAt=datetime.datetime(2023, 6, 26, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=15, name='Connections #15'),
#  ConnectionGame(board={'COFFEE DRINKS': ConnectionGroup(level=0, members=['AMERICANO', 'CAPPUCCINO', 'ESPRESSO', 'LATTE']), 'TREE NUTS': ConnectionGroup(level=1, members=['ALMOND', 'CASHEW', 'PECAN', 'WALNUT']), 'SHADES OF GREEN': ConnectionGroup(level=2, members=['EMERALD', 'FOREST', 'KELLY', 'OLIVE']), 'MR. ___': ConnectionGroup(level=3, members=['BEAN', 'CLEAN', 'FOX', 'PEANUT'])}, starting_board=[['BEAN', 'ESPRESSO', 'ALMOND', 'FOREST'], ['PECAN', 'CLEAN', 'KELLY', 'LATTE'], ['PEANUT', 'EMERALD', 'AMERICANO', 'FOX'], ['OLIVE', 'WALNUT', 'CAPPUCCINO', 'CASHEW']], createdAt=datetime.datetime(2023, 6, 27, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=16, name='Connections #16'),
#  ConnectionGame(board={'NECKWEAR': ConnectionGroup(level=0, members=['ASCOT', 'BOLO', 'SCARF', 'TIE']), 'SHIP DIRECTIONS': ConnectionGroup(level=1, members=['BOW', 'PORT', 'STARBOARD', 'STERN']), 'DETERGENTS': ConnectionGroup(level=2, members=['ALL', 'ERA', 'GAIN', 'TIDE']), '___ TRIANGLE': ConnectionGroup(level=3, members=['ACUTE', 'BERMUDA', 'LOVE', 'RIGHT'])}, starting_board=[['TIDE', 'BERMUDA', 'STERN', 'SCARF'], ['LOVE', 'ASCOT', 'GAIN', 'BOW'], ['RIGHT', 'ERA', 'PORT', 'BOLO'], ['ACUTE', 'TIE', 'ALL', 'STARBOARD']], createdAt=datetime.datetime(2023, 6, 28, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=17, name='Connections #17'),
#  ConnectionGame(board={'MUSCLES, INFORMALLY': ConnectionGroup(level=0, members=['LAT', 'PEC', 'QUAD', 'TRI']), 'AWARDS': ConnectionGroup(level=1, members=['CUP', 'MEDAL', 'RIBBON', 'TROPHY']), 'TITLE TV DOCTORS': ConnectionGroup(level=2, members=['GREY', 'HOUSE', 'HOWSER', 'QUINN']), 'NFL PLAYERS': ConnectionGroup(level=3, members=['BEAR', 'BILL', 'BROWN', 'COMMANDER'])}, starting_board=[['GREY', 'CUP', 'BILL', 'RIBBON'], ['QUAD', 'BEAR', 'HOUSE', 'LAT'], ['QUINN', 'TRI', 'MEDAL', 'COMMANDER'], ['BROWN', 'TROPHY', 'PEC', 'HOWSER']], createdAt=datetime.datetime(2023, 6, 29, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=18, name='Connections #18'),
#  ConnectionGame(board={'OFF-WHITE SHADES': ConnectionGroup(level=0, members=['CREAM', 'EGGSHELL', 'IVORY', 'VANILLA']), 'ANTI-VAMPIRE': ConnectionGroup(level=1, members=['CRUCIFIX', 'GARLIC', 'MIRROR', 'STAKE']), 'KINDS OF MEAT': ConnectionGroup(level=2, members=['BEEF', 'PORK', 'POULTRY', 'VENISON']), 'SYNONYMS FOR ARGUMENT': ConnectionGroup(level=3, members=['ROW', 'QUARREL', 'SPAT', 'TIFF'])}, starting_board=[['CREAM', 'GARLIC', 'PORK', 'ROW'], ['MIRROR', 'BEEF', 'SPAT', 'EGGSHELL'], ['POULTRY', 'STAKE', 'TIFF', 'VANILLA'], ['IVORY', 'QUARREL', 'VENISON', 'CRUCIFIX']], createdAt=datetime.datetime(2023, 6, 30, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=19, name='Connections #19'),
#  ConnectionGame(board={'GRAINS': ConnectionGroup(level=0, members=['BARLEY', 'OAT', 'RYE', 'SPELT']), 'ROYAL TITLES': ConnectionGroup(level=1, members=['BARON', 'EARL', 'KING', 'PRINCE']), 'UNIVERSITIES': ConnectionGroup(level=2, members=['BROWN', 'DUKE', 'HOWARD', 'RICE']), 'BEST DIRECTOR OSCAR WINNERS': ConnectionGroup(level=3, members=['BONG', 'FORD', 'LEE', 'STONE'])}, starting_board=[['KING', 'OAT', 'STONE', 'RICE'], ['BARLEY', 'BONG', 'DUKE', 'FORD'], ['BROWN', 'SPELT', 'LEE', 'EARL'], ['HOWARD', 'BARON', 'RYE', 'PRINCE']], createdAt=datetime.datetime(2023, 7, 1, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=20, name='Connections #20'),
#  ConnectionGame(board={'MUSIC GENRES': ConnectionGroup(level=0, members=['JAZZ', 'POP', 'PUNK', 'RAP']), 'WEB BROWSERS': ConnectionGroup(level=1, members=['CHROME', 'EDGE', 'OPERA', 'SAFARI']), '“LITTLE WOMEN” SISTERS': ConnectionGroup(level=2, members=['AMY', 'BETH', 'JO', 'MEG']), 'LIL ___ RAPPERS': ConnectionGroup(level=3, members=['BABY', 'JON', 'KIM', 'WAYNE'])}, starting_board=[['OPERA', 'BABY', 'WAYNE', 'JO'], ['POP', 'MEG', 'SAFARI', 'KIM'], ['RAP', 'CHROME', 'BETH', 'JAZZ'], ['PUNK', 'JON', 'AMY', 'EDGE']], createdAt=datetime.datetime(2023, 7, 2, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=21, name='Connections #21'),
#  ConnectionGame(board={'DOG BREEDS': ConnectionGroup(level=0, members=['BOXER', 'DALMATIAN', 'HUSKY', 'POODLE']), 'ANIMAL NOSES': ConnectionGroup(level=1, members=['BEAK', 'MUZZLE', 'SNOUT', 'TRUNK']), 'TRAFFIC SIGNS': ConnectionGroup(level=2, members=['DETOUR', 'SLOW', 'STOP', 'YIELD']), 'SOUND ___': ConnectionGroup(level=3, members=['ASLEEP', 'BARRIER', 'BITE', 'WAVE'])}, starting_board=[['BITE', 'STOP', 'TRUNK', 'BOXER'], ['WAVE', 'YIELD', 'MUZZLE', 'BARRIER'], ['DETOUR', 'HUSKY', 'SNOUT', 'ASLEEP'], ['DALMATIAN', 'BEAK', 'SLOW', 'POODLE']], createdAt=datetime.datetime(2023, 7, 3, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=22, name='Connections #22'),
#  ConnectionGame(board={'60’s BAND MEMBERS': ConnectionGroup(level=0, members=['BEACH BOY', 'BEATLE', 'BYRD', 'MONKEE']), 'DANCE FADS': ConnectionGroup(level=1, members=['DOUGIE', 'MACARENA', 'MASHED POTATO', 'TWIST']), 'MAGAZINES': ConnectionGroup(level=2, members=['FORTUNE', 'ROLLING STONE', 'VOGUE', 'WIRED']), 'THINGS WITH LINKS': ConnectionGroup(level=3, members=['CHAIN', 'GOLF COURSE', 'SAUSAGE', 'WEBSITE'])}, starting_board=[['BEACH BOY', 'TWIST', 'CHAIN', 'ROLLING STONE'], ['MASHED POTATO', 'WIRED', 'WEBSITE', 'BEATLE'], ['SAUSAGE', 'BYRD', 'DOUGIE', 'FORTUNE'], ['MACARENA', 'VOGUE', 'GOLF COURSE', 'MONKEE']], createdAt=datetime.datetime(2023, 7, 4, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=23, name='Connections #23'),
#  ConnectionGame(board={'CANDY BARS': ConnectionGroup(level=0, members=['BOUNTY', 'CRUNCH', 'HEATH', 'MILKY WAY']), 'VIDEO GAME CONSOLES': ConnectionGroup(level=1, members=['DREAMCAST', 'GENESIS', 'SWITCH', 'WII']), 'EAR PARTS': ConnectionGroup(level=2, members=['ANVIL', 'COCHLEA', 'HAMMER', 'STIRRUP']), 'BAND NAMES MINUS NUMBERS': ConnectionGroup(level=3, members=['BLINK', 'MAROON', 'SUM', 'U'])}, starting_board=[['MILKY WAY', 'GENESIS', 'HAMMER', 'SUM'], ['SWITCH', 'MAROON', 'BOUNTY', 'U'], ['ANVIL', 'CRUNCH', 'BLINK', 'STIRRUP'], ['HEATH', 'WII', 'COCHLEA', 'DREAMCAST']], createdAt=datetime.datetime(2023, 7, 5, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=24, name='Connections #24'),
#  ConnectionGame(board={'DESSERTS': ConnectionGroup(level=0, members=['CHEESECAKE', 'FLAN', 'MOUSSE', 'TIRAMISU']), 'MILD OATHS': ConnectionGroup(level=1, members=['DARN', 'FUDGE', 'HECK', 'SHOOT']), 'ANIMALS WITH TUSKS': ConnectionGroup(level=2, members=['ELEPHANT', 'HIPPO', 'NARWHAL', 'WARTHOG']), 'MUSTACHES': ConnectionGroup(level=3, members=['HANDLEBAR', 'HORSESHOE', 'PENCIL', 'WALRUS'])}, starting_board=[['MOUSSE', 'WALRUS', 'FUDGE', 'HORSESHOE'], ['SHOOT', 'PENCIL', 'ELEPHANT', 'FLAN'], ['NARWHAL', 'HIPPO', 'HECK', 'HANDLEBAR'], ['TIRAMISU', 'DARN', 'WARTHOG', 'CHEESECAKE']], createdAt=datetime.datetime(2023, 7, 6, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=25, name='Connections #25'),
#  ConnectionGame(board={'EUROPEAN COUNTRIES': ConnectionGroup(level=0, members=['DENMARK', 'GREECE', 'POLAND', 'PORTUGAL']), 'SYNONYMS FOR IMITATE': ConnectionGroup(level=1, members=['COPY', 'ECHO', 'MIMIC', 'PARROT']), 'TOMS': ConnectionGroup(level=2, members=['CRUISE', 'HOLLAND', 'PETTY', 'WAITS']), 'WORDS SPELLED WITH ROMAN NUMERALS': ConnectionGroup(level=3, members=['DILL', 'LIVID', 'MILD', 'MIX'])}, starting_board=[['PETTY', 'PARROT', 'POLAND', 'CRUISE'], ['MIX', 'MIMIC', 'HOLLAND', 'GREECE'], ['ECHO', 'MILD', 'LIVID', 'COPY'], ['PORTUGAL', 'WAITS', 'DENMARK', 'DILL']], createdAt=datetime.datetime(2023, 7, 7, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=26, name='Connections #26'),
#  ConnectionGame(board={'HATS': ConnectionGroup(level=0, members=['BERET', 'BOWLER', 'FEDORA', 'FEZ']), 'ORGANS': ConnectionGroup(level=1, members=['HEART', 'KIDNEY', 'LIVER', 'LUNG']), 'PARTS OF A BOOK': ConnectionGroup(level=2, members=['COVER', 'JACKET', 'PAGE', 'SPINE']), 'JACK ___': ConnectionGroup(level=3, members=['ASS', 'KNIFE', 'POT', 'RABBIT'])}, starting_board=[['HEART', 'BERET', 'SPINE', 'POT'], ['ASS', 'KIDNEY', 'FEZ', 'JACKET'], ['BOWLER', 'RABBIT', 'LIVER', 'COVER'], ['LUNG', 'PAGE', 'FEDORA', 'KNIFE']], createdAt=datetime.datetime(2023, 7, 8, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=27, name='Connections #27'),
#  ConnectionGame(board={'SEVEN DWARFS': ConnectionGroup(level=0, members=['BASHFUL', 'DOC', 'GRUMPY', 'HAPPY']), 'FILE EXTENSIONS': ConnectionGroup(level=1, members=['GIF', 'PDF', 'TIFF', 'ZIP']), 'FLIGHTLESS BIRDS': ConnectionGroup(level=2, members=['EMU', 'KIWI', 'OSTRICH', 'PENGUIN']), 'TROPICAL FRUITS': ConnectionGroup(level=3, members=['BANANA', 'COCONUT', 'MANGO', 'PINEAPPLE'])}, starting_board=[['COCONUT', 'ZIP', 'PENGUIN', 'DOC'], ['KIWI', 'HAPPY', 'TIFF', 'BANANA'], ['EMU', 'GRUMPY', 'MANGO', 'GIF'], ['PDF', 'OSTRICH', 'BASHFUL', 'PINEAPPLE']], createdAt=datetime.datetime(2023, 7, 9, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=28, name='Connections #28'),
#  ConnectionGame(board={'WINGED INSECTS': ConnectionGroup(level=0, members=['FLY', 'GNAT', 'MOTH', 'WASP']), 'ARITHMETIC OPERATIONS': ConnectionGroup(level=1, members=['ADD', 'DIVIDE', 'MULTIPLY', 'SUBTRACT']), 'FISH': ConnectionGroup(level=2, members=['TANG', 'TETRA', 'SKATE', 'SOLE']), '___ CAT': ConnectionGroup(level=3, members=['ALLEY', 'COOL', 'COPY', 'LAP'])}, starting_board=[['SKATE', 'ADD', 'COPY', 'FLY'], ['ALLEY', 'TANG', 'MOTH', 'COOL'], ['DIVIDE', 'SOLE', 'LAP', 'SUBTRACT'], ['TETRA', 'GNAT', 'MULTIPLY', 'WASP']], createdAt=datetime.datetime(2023, 7, 10, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=29, name='Connections #29'),
#  ConnectionGame(board={'NFL PLAYERS': ConnectionGroup(level=0, members=['BRONCO', 'COWBOY', 'PACKER', 'RAVEN']), 'PASTA SHAPES': ConnectionGroup(level=1, members=['BOWTIE', 'ELBOW', 'SHELL', 'SPIRAL']), 'JOINTS': ConnectionGroup(level=2, members=['HIP', 'KNEE', 'SHOULDER', 'WRIST']), 'MOVIES WITH “!”': ConnectionGroup(level=3, members=['AIRPLANE', 'MOTHER', 'OKLAHOMA', 'THEM'])}, starting_board=[['SPIRAL', 'HIP', 'MOTHER', 'RAVEN'], ['ELBOW', 'AIRPLANE', 'KNEE', 'SHELL'], ['COWBOY', 'SHOULDER', 'OKLAHOMA', 'BOWTIE'], ['THEM', 'PACKER', 'WRIST', 'BRONCO']], createdAt=datetime.datetime(2023, 7, 11, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=30, name='Connections #30'),
#  ConnectionGame(board={'VEGETABLES THAT ARE ALSO FRUITS': ConnectionGroup(level=0, members=['CUCUMBER', 'EGGPLANT', 'PEPPER', 'TOMATO']), '3-D SHAPES': ConnectionGroup(level=1, members=['CONE', 'CUBE', 'PYRAMID', 'SPHERE']), 'WORDS WITH “i”': ConnectionGroup(level=2, members=['MAC', 'PAD', 'PHONE', 'POD']), 'WORDS WITH TWO PRONUNCIATIONS': ConnectionGroup(level=3, members=['JOB', 'LIMA', 'MOBILE', 'POLISH'])}, starting_board=[['PAD', 'LIMA', 'CONE', 'TOMATO'], ['POLISH', 'PEPPER', 'PHONE', 'PYRAMID'], ['CUBE', 'MOBILE', 'JOB', 'CUCUMBER'], ['EGGPLANT', 'MAC', 'SPHERE', 'POD']], createdAt=datetime.datetime(2023, 7, 12, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=31, name='Connections #31'),
#  ConnectionGame(board={'SHOE PARTS': ConnectionGroup(level=0, members=['HEEL', 'LACE', 'SOLE', 'TONGUE']), 'BOARD GAMES': ConnectionGroup(level=1, members=['CLUE', 'RISK', 'SORRY', 'TROUBLE']), 'FICTIONAL SPIES': ConnectionGroup(level=2, members=['BOND', 'HUNT', 'RYAN', 'SMART']), 'RUBBER ___': ConnectionGroup(level=3, members=['BAND', 'CEMENT', 'DUCKIE', 'SOUL'])}, starting_board=[['SOLE', 'TROUBLE', 'HUNT', 'CEMENT'], ['SMART', 'TONGUE', 'SOUL', 'BOND'], ['LACE', 'BAND', 'SORRY', 'RYAN'], ['CLUE', 'HEEL', 'DUCKIE', 'RISK']], createdAt=datetime.datetime(2023, 7, 13, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=32, name='Connections #32'),
#  ConnectionGame(board={'BOATS': ConnectionGroup(level=0, members=['FERRY', 'JUNK', 'TUG', 'YACHT']), 'SANDWICHES': ConnectionGroup(level=1, members=['CLUB', 'CUBAN', 'MELT', 'SUB']), 'CUTS OF BEEF': ConnectionGroup(level=2, members=['FLANK', 'LOIN', 'ROUND', 'SHANK']), 'NICKNAMES THAT ARE VERBS': ConnectionGroup(level=3, members=['CHUCK', 'JOSH', 'ROB', 'SUE'])}, starting_board=[['TUG', 'CHUCK', 'JUNK', 'CLUB'], ['SHANK', 'ROB', 'SUB', 'FLANK'], ['CUBAN', 'FERRY', 'LOIN', 'SUE'], ['JOSH', 'ROUND', 'MELT', 'YACHT']], createdAt=datetime.datetime(2023, 7, 14, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=33, name='Connections #33'),
#  ConnectionGame(board={'PLEASANT SMELLS': ConnectionGroup(level=0, members=['AROMA', 'BOUQUET', 'FRAGRANCE', 'SCENT']), 'MUSIC GENRES': ConnectionGroup(level=1, members=['BLUES', 'COUNTRY', 'FUNK', 'SOUL']), 'ROCK PAPER SCISSORS': ConnectionGroup(level=2, members=['PAPER', 'ROCK', 'SCISSORS', 'SHOOT']), 'MALE ANIMALS': ConnectionGroup(level=3, members=['BOAR', 'BUCK', 'BULL', 'JACK'])}, starting_board=[['ROCK', 'FUNK', 'BUCK', 'BOUQUET'], ['SHOOT', 'BULL', 'COUNTRY', 'JACK'], ['SOUL', 'SCENT', 'SCISSORS', 'BOAR'], ['FRAGRANCE', 'PAPER', 'BLUES', 'AROMA']], createdAt=datetime.datetime(2023, 7, 15, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=34, name='Connections #34'),
#  ConnectionGame(board={'U.S. COINS': ConnectionGroup(level=0, members=['DIME', 'NICKEL', 'PENNY', 'QUARTER']), 'METAL ELEMENTS': ConnectionGroup(level=1, members=['IRON', 'LEAD', 'TIN', 'ZINC']), 'LUCKY CHARMS MARSHMALLOWS': ConnectionGroup(level=2, members=['CLOVER', 'HORSESHOE', 'MOON', 'RAINBOW']), '___ AND ___': ConnectionGroup(level=3, members=['AGAIN', 'HALF', 'NECK', 'SO'])}, starting_board=[['NICKEL', 'HALF', 'HORSESHOE', 'TIN'], ['RAINBOW', 'QUARTER', 'NECK', 'LEAD'], ['PENNY', 'CLOVER', 'IRON', 'SO'], ['ZINC', 'AGAIN', 'DIME', 'MOON']], createdAt=datetime.datetime(2023, 7, 16, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=35, name='Connections #35'),
#  ConnectionGame(board={'MARSUPIALS': ConnectionGroup(level=0, members=['KANGAROO', 'KOALA', 'WALLABY', 'WOMBAT']), 'CHOCOLATE BARS': ConnectionGroup(level=1, members=['CHUNKY', 'CRUNCH', 'MARS', 'MOUNDS']), 'SLANG FOR MONEY': ConnectionGroup(level=2, members=['CHEDDAR', 'DOUGH', 'PAPER', 'STACKS']), 'NAKED ___': ConnectionGroup(level=3, members=['EYE', 'GUN', 'MOLE RAT', 'TRUTH'])}, starting_board=[['EYE', 'MARS', 'PAPER', 'TRUTH'], ['WOMBAT', 'GUN', 'MOLE RAT', 'CHUNKY'], ['CHEDDAR', 'CRUNCH', 'KANGAROO', 'DOUGH'], ['KOALA', 'STACKS', 'MOUNDS', 'WALLABY']], createdAt=datetime.datetime(2023, 7, 17, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=36, name='Connections #36'),
#  ConnectionGame(board={'MARINE MAMMALS': ConnectionGroup(level=0, members=['DOLPHIN', 'MANATEE', 'OTTER', 'SEAL']), 'BIKE PARTS': ConnectionGroup(level=1, members=['BRAKE', 'CHAIN', 'SADDLE', 'SPOKE']), 'SYNONYMS FOR SELL': ConnectionGroup(level=2, members=['HAWK', 'MOVE', 'PEDDLE', 'VEND']), 'COUNTRIES WHEN “A” IS ADDED': ConnectionGroup(level=3, members=['CHIN', 'CUB', 'MALT', 'TONG'])}, starting_board=[['SPOKE', 'MOVE', 'CUB', 'SEAL'], ['HAWK', 'CHAIN', 'DOLPHIN', 'CHIN'], ['SADDLE', 'PEDDLE', 'MALT', 'OTTER'], ['MANATEE', 'BRAKE', 'VEND', 'TONG']], createdAt=datetime.datetime(2023, 7, 18, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=37, name='Connections #37'),
#  ConnectionGame(board={'TREES': ConnectionGroup(level=0, members=['ASH', 'CEDAR', 'MAPLE', 'PINE']), 'LAND FORMATIONS': ConnectionGroup(level=1, members=['HILL', 'MOUNTAIN', 'PLATEAU', 'VALLEY']), 'BAGEL FLAVORS': ConnectionGroup(level=2, members=['EVERYTHING', 'ONION', 'PLAIN', 'POPPY']), 'STREETS ON SCREEN': ConnectionGroup(level=3, members=['ELM', 'FEAR', 'JUMP', 'SESAME'])}, starting_board=[['MOUNTAIN', 'ELM', 'ONION', 'JUMP'], ['PLAIN', 'VALLEY', 'MAPLE', 'POPPY'], ['PINE', 'SESAME', 'HILL', 'FEAR'], ['PLATEAU', 'ASH', 'EVERYTHING', 'CEDAR']], createdAt=datetime.datetime(2023, 7, 19, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=38, name='Connections #38'),
#  ConnectionGame(board={'TIMEKEEPING DEVICES': ConnectionGroup(level=0, members=['CLOCK', 'HOURGLASS', 'SUNDIAL', 'WATCH']), 'HAIRSTYLES': ConnectionGroup(level=1, members=['BOB', 'CROP', 'PIXIE', 'SHAG']), 'UNITS OF MEASURE': ConnectionGroup(level=2, members=['HERTZ', 'MOLE', 'NEWTON', 'SECOND']), 'DR. ___': ConnectionGroup(level=3, members=['EVIL', 'J', 'NO', 'PEPPER'])}, starting_board=[['PEPPER', 'MOLE', 'WATCH', 'BOB'], ['SECOND', 'EVIL', 'CROP', 'CLOCK'], ['NO', 'NEWTON', 'SUNDIAL', 'PIXIE'], ['HERTZ', 'HOURGLASS', 'SHAG', 'J']], createdAt=datetime.datetime(2023, 7, 20, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=39, name='Connections #39'),
#  ConnectionGame(board={'WOODWINDS': ConnectionGroup(level=0, members=['BASSOON', 'CLARINET', 'FLUTE', 'OBOE']), 'COVERINGS': ConnectionGroup(level=1, members=['CAP', 'COVER', 'LID', 'TOP']), 'SUNGLASSES': ConnectionGroup(level=2, members=['AVIATOR', 'CAT EYE', 'WAYFARER', 'WRAPAROUND']), 'SEALS': ConnectionGroup(level=3, members=['HARBOR', 'HARP', 'HOODED', 'MONK'])}, starting_board=[['AVIATOR', 'FLUTE', 'MONK', 'LID'], ['HARBOR', 'HARP', 'CLARINET', 'CAT EYE'], ['TOP', 'HOODED', 'BASSOON', 'COVER'], ['OBOE', 'WAYFARER', 'CAP', 'WRAPAROUND']], createdAt=datetime.datetime(2023, 7, 21, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=40, name='Connections #40'),
#  ConnectionGame(board={'BOTTLED WATER BRANDS': ConnectionGroup(level=0, members=['DASANI', 'EVIAN', 'FIJI', 'VOSS']), 'SLANG FOR COFFEE': ConnectionGroup(level=1, members=['BREW', 'JAVA', 'JOE', 'MUD']), 'ISLAND COUNTRIES': ConnectionGroup(level=2, members=['CUBA', 'JAPAN', 'MALTA', 'PALAU']), 'CEREAL MASCOTS': ConnectionGroup(level=3, members=['LUCKY', 'POP', 'SAM', 'TONY'])}, starting_board=[['FIJI', 'MUD', 'POP', 'PALAU'], ['JOE', 'SAM', 'JAPAN', 'BREW'], ['CUBA', 'VOSS', 'TONY', 'JAVA'], ['DASANI', 'MALTA', 'EVIAN', 'LUCKY']], createdAt=datetime.datetime(2023, 7, 22, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=41, name='Connections #41'),
#  ConnectionGame(board={'SCUBA GEAR': ConnectionGroup(level=0, members=['FINS', 'MASK', 'SNORKEL', 'TANK']), 'PUNCTUATION MARKS': ConnectionGroup(level=1, members=['COLON', 'COMMA', 'HYPHEN', 'PERIOD']), 'RUN QUICKLY': ConnectionGroup(level=2, members=['BOLT', 'DASH', 'RACE', 'SPRINT']), '___ CAT': ConnectionGroup(level=3, members=['DOJA', 'FAT', 'HOUSE', 'JUNGLE'])}, starting_board=[['DASH', 'MASK', 'JUNGLE', 'PERIOD'], ['HOUSE', 'HYPHEN', 'SNORKEL', 'BOLT'], ['FAT', 'TANK', 'COLON', 'RACE'], ['FINS', 'SPRINT', 'DOJA', 'COMMA']], createdAt=datetime.datetime(2023, 7, 23, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=42, name='Connections #42'),
#  ConnectionGame(board={'SYNONYMS FOR ANGRY': ConnectionGroup(level=0, members=['FURIOUS', 'INCENSED', 'IRATE', 'LIVID']), 'THINGS THAT ARE YELLOW': ConnectionGroup(level=1, members=['BANANA', 'CANARY', 'SCHOOL BUS', 'SUNFLOWER']), 'MARINE BIRDS': ConnectionGroup(level=2, members=['BOOBY', 'GULL', 'PELICAN', 'PUFFIN']), '___ BOYS': ConnectionGroup(level=3, members=['BEACH', 'BEASTIE', 'HARDY', 'LOST'])}, starting_board=[['CANARY', 'IRATE', 'LOST', 'SCHOOL BUS'], ['BEACH', 'GULL', 'FURIOUS', 'BOOBY'], ['BANANA', 'BEASTIE', 'SUNFLOWER', 'LIVID'], ['HARDY', 'PELICAN', 'INCENSED', 'PUFFIN']], createdAt=datetime.datetime(2023, 7, 24, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=43, name='Connections #43'),
#  ConnectionGame(board={'STATES OF MATTER': ConnectionGroup(level=0, members=['GAS', 'LIQUID', 'PLASMA', 'SOLID']), 'EDIT MENU COMMANDS': ConnectionGroup(level=1, members=['COPY', 'CUT', 'PASTE', 'UNDO']), 'DEFEAT BADLY': ConnectionGroup(level=2, members=['CRUSH', 'ROUT', 'SHELLAC', 'TRASH']), 'ANAGRAMS': ConnectionGroup(level=3, members=['LEAST', 'SLATE', 'STALE', 'TESLA'])}, starting_board=[['SOLID', 'PASTE', 'SLATE', 'TRASH'], ['TESLA', 'CUT', 'PLASMA', 'CRUSH'], ['GAS', 'SHELLAC', 'STALE', 'UNDO'], ['COPY', 'LIQUID', 'ROUT', 'LEAST']], createdAt=datetime.datetime(2023, 7, 25, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=44, name='Connections #44'),
#  ConnectionGame(board={'MODES OF TRANSPORTATION': ConnectionGroup(level=0, members=['BOAT', 'CAR', 'PLANE', 'TRAIN']), 'NBA PLAYERS': ConnectionGroup(level=1, members=['KING', 'MAGIC', 'SUN', 'THUNDER']), 'FAST FOOD CHAINS': ConnectionGroup(level=2, members=['CHECKERS', 'OUTBACK', 'SONIC', 'SUBWAY']), 'BAND NAMES MINUS COLORS': ConnectionGroup(level=3, members=['DAY', 'FLOYD', 'SABBATH', 'STRIPES'])}, starting_board=[['PLANE', 'SUN', 'DAY', 'THUNDER'], ['SONIC', 'BOAT', 'STRIPES', 'CHECKERS'], ['CAR', 'SUBWAY', 'FLOYD', 'TRAIN'], ['OUTBACK', 'KING', 'SABBATH', 'MAGIC']], createdAt=datetime.datetime(2023, 7, 26, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=45, name='Connections #45'),
#  ConnectionGame(board={'MOVIE TITLE CITIES': ConnectionGroup(level=0, members=['CHICAGO', 'MUNICH', 'PHILADELPHIA', 'RIO']), 'FASHION MAGAZINES': ConnectionGroup(level=1, members=['ALLURE', 'ELLE', 'GLAMOUR', 'W']), 'STORMS': ConnectionGroup(level=2, members=['BLIZZARD', 'CYCLONE', 'SQUALL', 'TORNADO']), 'COCKTAILS': ConnectionGroup(level=3, members=['COSMOPOLITAN', 'HURRICANE', 'MANHATTAN', 'SCREWDRIVER'])}, starting_board=[['HURRICANE', 'CYCLONE', 'CHICAGO', 'W'], ['MANHATTAN', 'GLAMOUR', 'TORNADO', 'PHILADELPHIA'], ['COSMOPOLITAN', 'SQUALL', 'ALLURE', 'SCREWDRIVER'], ['RIO', 'BLIZZARD', 'MUNICH', 'ELLE']], createdAt=datetime.datetime(2023, 7, 27, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=46, name='Connections #46'),
#  ConnectionGame(board={'BIOMES': ConnectionGroup(level=0, members=['DESERT', 'FOREST', 'GRASSLAND', 'TUNDRA']), 'LIZARDS': ConnectionGroup(level=1, members=['CHAMELEON', 'GECKO', 'IGUANA', 'MONITOR']), 'YOGA POSES': ConnectionGroup(level=2, members=['COBRA', 'LOTUS', 'TREE', 'WARRIOR']), 'DANCES WHEN DOUBLED': ConnectionGroup(level=3, members=['CAN', 'CHA', 'GO', 'NAE'])}, starting_board=[['TREE', 'GECKO', 'FOREST', 'GO'], ['MONITOR', 'DESERT', 'LOTUS', 'CAN'], ['IGUANA', 'CHA', 'TUNDRA', 'COBRA'], ['GRASSLAND', 'WARRIOR', 'NAE', 'CHAMELEON']], createdAt=datetime.datetime(2023, 7, 28, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=47, name='Connections #47'),
#  ConnectionGame(board={'FABRICS': ConnectionGroup(level=0, members=['CORDUROY', 'DENIM', 'LINEN', 'TWEED']), 'APPARITIONS': ConnectionGroup(level=1, members=['GHOST', 'PHANTOM', 'SPECTER', 'SPIRIT']), 'SYNONYMS FOR BOTHER': ConnectionGroup(level=2, members=['NEEDLE', 'POKE', 'RIB', 'TEASE']), 'DISNEY CHARACTERS': ConnectionGroup(level=3, members=['BEAST', 'GENIE', 'SCAR', 'STITCH'])}, starting_board=[['RIB', 'SPECTER', 'TWEED', 'SCAR'], ['SPIRIT', 'BEAST', 'NEEDLE', 'LINEN'], ['STITCH', 'POKE', 'DENIM', 'GENIE'], ['CORDUROY', 'GHOST', 'TEASE', 'PHANTOM']], createdAt=datetime.datetime(2023, 7, 29, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=48, name='Connections #48'),
#  ConnectionGame(board={'RELATIVES': ConnectionGroup(level=0, members=['AUNT', 'COUSIN', 'MOTHER', 'NEPHEW']), 'SYNONYMS FOR OFFBEAT': ConnectionGroup(level=1, members=['DAFFY', 'KOOKY', 'QUIRKY', 'WACKY']), 'DISNEY DUCKS': ConnectionGroup(level=2, members=['DAISY', 'DEWEY', 'DONALD', 'SCROOGE']), '___ CLOCK': ConnectionGroup(level=3, members=['ALARM', 'BIOLOGICAL', 'CUCKOO', 'GRANDFATHER'])}, starting_board=[['DAISY', 'AUNT', 'ALARM', 'QUIRKY'], ['SCROOGE', 'GRANDFATHER', 'KOOKY', 'BIOLOGICAL'], ['NEPHEW', 'DAFFY', 'CUCKOO', 'MOTHER'], ['DEWEY', 'WACKY', 'COUSIN', 'DONALD']], createdAt=datetime.datetime(2023, 7, 30, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=49, name='Connections #49'),
#  ConnectionGame(board={'UNITS OF LENGTH': ConnectionGroup(level=0, members=['FOOT', 'INCH', 'MILE', 'YARD']), 'TYPES OF PAINT': ConnectionGroup(level=1, members=['ACRYLIC', 'OIL', 'TEMPERA', 'WATERCOLOR']), 'DEEP-FRIED FOOD': ConnectionGroup(level=2, members=['FALAFEL', 'KATSU', 'SAMOSA', 'SCHNITZEL']), 'STARTS OF U.S. COINS': ConnectionGroup(level=3, members=['DIM', 'NICK', 'PEN', 'QUART'])}, starting_board=[['OIL', 'FOOT', 'SAMOSA', 'DIM'], ['QUART', 'KATSU', 'MILE', 'WATERCOLOR'], ['PEN', 'INCH', 'ACRYLIC', 'FALAFEL'], ['YARD', 'NICK', 'SCHNITZEL', 'TEMPERA']], createdAt=datetime.datetime(2023, 7, 31, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=50, name='Connections #50'),
#  ConnectionGame(board={'LONG SANDWICHES': ConnectionGroup(level=0, members=['HERO', 'HOAGIE', 'GRINDER', 'SUB']), 'DATING APPS': ConnectionGroup(level=1, members=['BUMBLE', 'HINGE', 'MATCH', 'TINDER']), 'VAMPIRE MOVIES': ConnectionGroup(level=2, members=['BLADE', 'LOST BOYS', 'NEAR DARK', 'TWILIGHT']), 'ADAMS': ConnectionGroup(level=3, members=['ANT', 'DRIVER', 'SCOTT', 'WEST'])}, starting_board=[['MATCH', 'HERO', 'BLADE', 'DRIVER'], ['GRINDER', 'SCOTT', 'HINGE', 'TWILIGHT'], ['WEST', 'TINDER', 'ANT', 'SUB'], ['BUMBLE', 'LOST BOYS', 'HOAGIE', 'NEAR DARK']], createdAt=datetime.datetime(2023, 8, 1, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=51, name='Connections #51'),
#  ConnectionGame(board={'COMPUTER EQUIPMENT': ConnectionGroup(level=0, members=['KEYBOARD', 'MONITOR', 'MOUSE', 'SPEAKER']), 'RODENTS': ConnectionGroup(level=1, members=['GERBIL', 'HAMSTER', 'RAT', 'VOLE']), 'MUSICAL INSTRUMENTS': ConnectionGroup(level=2, members=['HARP', 'HORN', 'ORGAN', 'TRIANGLE']), 'SYNONYMS FOR COMPLAIN': ConnectionGroup(level=3, members=['CARP', 'GRIPE', 'GROUSE', 'MOAN'])}, starting_board=[['RAT', 'HORN', 'SPEAKER', 'TRIANGLE'], ['CARP', 'HARP', 'ORGAN', 'VOLE'], ['GROUSE', 'HAMSTER', 'MOUSE', 'MONITOR'], ['KEYBOARD', 'MOAN', 'GERBIL', 'GRIPE']], createdAt=datetime.datetime(2023, 8, 2, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=52, name='Connections #52'),
#  ConnectionGame(board={'ANIMAL GROUP NAMES': ConnectionGroup(level=0, members=['COLONY', 'HERD', 'PRIDE', 'SWARM']), 'STONED': ConnectionGroup(level=1, members=['BAKED', 'BLAZED', 'HIGH', 'LIT']), 'AP CLASSES': ConnectionGroup(level=2, members=['BIO', 'CHEM', 'GOV', 'STATS']), 'TAXONOMY RANKS': ConnectionGroup(level=3, members=['CLASS', 'DOMAIN', 'FAMILY', 'ORDER'])}, starting_board=[['HIGH', 'PRIDE', 'CLASS', 'GOV'], ['ORDER', 'CHEM', 'LIT', 'FAMILY'], ['SWARM', 'DOMAIN', 'BIO', 'COLONY'], ['BAKED', 'STATS', 'HERD', 'BLAZED']], createdAt=datetime.datetime(2023, 8, 3, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=53, name='Connections #53'),
#  ConnectionGame(board={'PLACES FOR WORSHIP': ConnectionGroup(level=0, members=['ALTAR', 'RELIQUARY', 'SHRINE', 'TEMPLE']), 'CARTOON CATS': ConnectionGroup(level=1, members=['FELIX', 'GARFIELD', 'SYLVESTER', 'TOM']), 'PRESIDENTIAL FIRST NAMES': ConnectionGroup(level=2, members=['CALVIN', 'CHESTER', 'GROVER', 'HARRY']), '___ ROAD': ConnectionGroup(level=3, members=['ABBEY', 'HIGH', 'ROCKY', 'SILK'])}, starting_board=[['TOM', 'ROCKY', 'TEMPLE', 'HARRY'], ['HIGH', 'ALTAR', 'SYLVESTER', 'GROVER'], ['SILK', 'CALVIN', 'ABBEY', 'GARFIELD'], ['CHESTER', 'RELIQUARY', 'FELIX', 'SHRINE']], createdAt=datetime.datetime(2023, 8, 4, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=54, name='Connections #54'),
#  ConnectionGame(board={'CLASSIC TOYS': ConnectionGroup(level=0, members=['BLOCKS', 'DOLL', 'TOP', 'YO-YO']), 'WORDS WITH THREE G’S': ConnectionGroup(level=1, members=['BAGGAGE', 'EGGNOG', 'GIGGLE', 'LEGGINGS']), 'SHAKESPEARE CHARACTERS': ConnectionGroup(level=2, members=['DUNCAN', 'JULIET', 'PUCK', 'VIOLA']), '___ STICK': ConnectionGroup(level=3, members=['FISH', 'HOCKEY', 'MEMORY', 'SELFIE'])}, starting_board=[['VIOLA', 'TOP', 'GIGGLE', 'MEMORY'], ['EGGNOG', 'BLOCKS', 'SELFIE', 'PUCK'], ['DOLL', 'HOCKEY', 'DUNCAN', 'LEGGINGS'], ['JULIET', 'BAGGAGE', 'YO-YO', 'FISH']], createdAt=datetime.datetime(2023, 8, 5, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=55, name='Connections #55'),
#  ConnectionGame(board={'CLASSIC ARCADE GAMES': ConnectionGroup(level=0, members=['ASTEROIDS', 'BREAKOUT', 'FROGGER', 'PONG']), 'DANCES': ConnectionGroup(level=1, members=['HUSTLE', 'SALSA', 'SWING', 'TANGO']), 'TOUCHSCREEN GESTURES': ConnectionGroup(level=2, members=['PINCH', 'SPREAD', 'SWIPE', 'TAP']), 'RAPPERS MINUS NUMBERS': ConnectionGroup(level=3, members=['CENT', 'CHAINZ', 'PAC', 'SAVAGE'])}, starting_board=[['PINCH', 'SALSA', 'SAVAGE', 'BREAKOUT'], ['CENT', 'SWIPE', 'SWING', 'TAP'], ['ASTEROIDS', 'PAC', 'PONG', 'HUSTLE'], ['TANGO', 'SPREAD', 'CHAINZ', 'FROGGER']], createdAt=datetime.datetime(2023, 8, 6, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=56, name='Connections #56'),
#  ConnectionGame(board={'MOVIE GENRES': ConnectionGroup(level=0, members=['HORROR', 'MUSICAL', 'ROMANCE', 'WESTERN']), 'PATTERNS': ConnectionGroup(level=1, members=['HOUNDSTOOTH', 'PAISLEY', 'PLAID', 'STRIPES']), 'SYNONYMS FOR FALSEHOOD': ConnectionGroup(level=2, members=['FIB', 'FICTION', 'LIE', 'TALE']), 'CANDY PIECES': ConnectionGroup(level=3, members=['DOT', 'GOOBER', 'KISS', 'WHOPPER'])}, starting_board=[['KISS', 'ROMANCE', 'STRIPES', 'FICTION'], ['PAISLEY', 'HORROR', 'DOT', 'LIE'], ['MUSICAL', 'WHOPPER', 'PLAID', 'FIB'], ['GOOBER', 'TALE', 'WESTERN', 'HOUNDSTOOTH']], createdAt=datetime.datetime(2023, 8, 7, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=57, name='Connections #57'),
#  ConnectionGame(board={'ARACHNIDS': ConnectionGroup(level=0, members=['MITE', 'SCORPION', 'SPIDER', 'TICK']), 'FISH': ConnectionGroup(level=1, members=['CHAR', 'EEL', 'PERCH', 'SHARK']), 'SUPERHEROES': ConnectionGroup(level=2, members=['BLACK WIDOW', 'BLADE', 'FLASH', 'STORM']), 'MTV SHOWS': ConnectionGroup(level=3, members=['CATFISH', 'CRIBS', 'JACKASS', 'STATE'])}, starting_board=[['BLADE', 'CATFISH', 'TICK', 'CHAR'], ['STATE', 'EEL', 'STORM', 'FLASH'], ['BLACK WIDOW', 'JACKASS', 'PERCH', 'SCORPION'], ['MITE', 'SHARK', 'SPIDER', 'CRIBS']], createdAt=datetime.datetime(2023, 8, 8, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=58, name='Connections #58'),
#  ConnectionGame(board={'UNSPECIFIED QUANTITIES': ConnectionGroup(level=0, members=['FEW', 'HANDFUL', 'SEVERAL', 'SOME']), 'CELESTIAL OBJECTS': ConnectionGroup(level=1, members=['ASTEROID', 'COMET', 'MOON', 'PLANET']), 'NEWSPAPERS': ConnectionGroup(level=2, members=['GLOBE', 'JOURNAL', 'POST', 'SUN']), 'FRUIT HOMOPHONES': ConnectionGroup(level=3, members=['LYME', 'MELLON', 'PAIR', 'PLUMB'])}, starting_board=[['MOON', 'GLOBE', 'SOME', 'LYME'], ['FEW', 'PAIR', 'POST', 'COMET'], ['PLUMB', 'HANDFUL', 'SUN', 'PLANET'], ['JOURNAL', 'MELLON', 'ASTEROID', 'SEVERAL']], createdAt=datetime.datetime(2023, 8, 9, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=59, name='Connections #59'),
#  ConnectionGame(board={'HORROR FRANCHISES': ConnectionGroup(level=0, members=['PURGE', 'RING', 'SAW', 'SCREAM']), 'SPORTS VENUES': ConnectionGroup(level=1, members=['COURT', 'DIAMOND', 'FIELD', 'RINK']), 'MAKE HAPPY': ConnectionGroup(level=2, members=['CHARM', 'DELIGHT', 'PLEASE', 'TICKLE']), 'JEWELRY': ConnectionGroup(level=3, members=['ANKLET', 'BANGLE', 'BROOCH', 'PENDANT'])}, starting_board=[['DIAMOND', 'PENDANT', 'CHARM', 'SAW'], ['PLEASE', 'COURT', 'SCREAM', 'TICKLE'], ['BANGLE', 'RING', 'FIELD', 'DELIGHT'], ['PURGE', 'ANKLET', 'RINK', 'BROOCH']], createdAt=datetime.datetime(2023, 8, 10, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=60, name='Connections #60'),
#  ConnectionGame(board={'THEORETICAL PHYSICISTS': ConnectionGroup(level=0, members=['EINSTEIN', 'FEYNMAN', 'HAWKING', 'OPPENHEIMER']), 'TALENT': ConnectionGroup(level=1, members=['FACULTY', 'FLAIR', 'GENIUS', 'GIFT']), 'AUSTRALIAN TERMS': ConnectionGroup(level=2, members=['BARBIE', 'BUSH', 'CRIKEY', 'MATE']), '___ POINT': ConnectionGroup(level=3, members=['MATCH', 'MOOT', 'SELLING', 'WEST'])}, starting_board=[['BARBIE', 'OPPENHEIMER', 'MATCH', 'GENIUS'], ['WEST', 'BUSH', 'SELLING', 'HAWKING'], ['FACULTY', 'EINSTEIN', 'MATE', 'MOOT'], ['CRIKEY', 'GIFT', 'FEYNMAN', 'FLAIR']], createdAt=datetime.datetime(2023, 8, 11, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=61, name='Connections #61'),
#  ConnectionGame(board={'STATE ABBREVIATIONS': ConnectionGroup(level=0, members=['CO', 'MA', 'ME', 'PA']), 'MUSICAL NOTES': ConnectionGroup(level=1, members=['DO', 'FA', 'LA', 'TI']), 'GREEK LETTERS': ConnectionGroup(level=2, members=['MU', 'NU', 'PI', 'XI']), 'PERIODIC TABLE SYMBOLS': ConnectionGroup(level=3, members=['FE', 'HE', 'NA', 'NI'])}, starting_board=[['MA', 'LA', 'NA', 'NU'], ['PI', 'NI', 'TI', 'HE'], ['FA', 'XI', 'PA', 'FE'], ['DO', 'CO', 'MU', 'ME']], createdAt=datetime.datetime(2023, 8, 12, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=62, name='Connections #62'),
#  ConnectionGame(board={'FASTENING VERBS': ConnectionGroup(level=0, members=['BUCKLE', 'BUTTON', 'SNAP', 'ZIP']), 'SLANG FOR ZERO': ConnectionGroup(level=1, members=['JACK', 'NADA', 'NOTHING', 'SQUAT']), 'GYM EXERCISES': ConnectionGroup(level=2, members=['CURL', 'LUNGE', 'PLANK', 'PRESS']), '“CAPTAINS”': ConnectionGroup(level=3, members=['CRUNCH', 'KANGAROO', 'OBVIOUS', 'PLANET'])}, starting_board=[['JACK', 'PRESS', 'PLANET', 'BUTTON'], ['PLANK', 'SQUAT', 'SNAP', 'OBVIOUS'], ['CRUNCH', 'BUCKLE', 'NOTHING', 'CURL'], ['ZIP', 'KANGAROO', 'LUNGE', 'NADA']], createdAt=datetime.datetime(2023, 8, 13, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=63, name='Connections #63'),
#  ConnectionGame(board={'CLASSIC DOG NAMES': ConnectionGroup(level=0, members=['FIDO', 'LUCKY', 'ROVER', 'SPOT']), 'PERCEIVE': ConnectionGroup(level=1, members=['CATCH', 'NOTICE', 'OBSERVE', 'SEE']), 'FISHING TERMS': ConnectionGroup(level=2, members=['BAIT', 'CHUM', 'FLY', 'SINKER']), 'T-___': ConnectionGroup(level=3, members=['BONE', 'REX', 'SHIRT', 'STORM'])}, starting_board=[['CATCH', 'SPOT', 'BONE', 'LUCKY'], ['SEE', 'SHIRT', 'FLY', 'STORM'], ['CHUM', 'NOTICE', 'REX', 'BAIT'], ['FIDO', 'SINKER', 'OBSERVE', 'ROVER']], createdAt=datetime.datetime(2023, 8, 14, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=64, name='Connections #64'),
#  ConnectionGame(board={'STATES OF MATTER': ConnectionGroup(level=0, members=['GAS', 'LIQUID', 'PLASMA', 'SOLID']), 'ENERGY': ConnectionGroup(level=1, members=['JUICE', 'SPIRIT', 'STEAM', 'VIGOR']), 'CLASSICAL ELEMENTS': ConnectionGroup(level=2, members=['AIR', 'EARTH', 'FIRE', 'WATER']), 'THINGS WITH RINGS': ConnectionGroup(level=3, members=['CIRCUS', 'SATURN', 'TREE', 'WEDDING'])}, starting_board=[['JUICE', 'WATER', 'TREE', 'EARTH'], ['GAS', 'CIRCUS', 'STEAM', 'LIQUID'], ['SATURN', 'FIRE', 'SOLID', 'SPIRIT'], ['PLASMA', 'VIGOR', 'AIR', 'WEDDING']], createdAt=datetime.datetime(2023, 8, 15, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=65, name='Connections #65'),
#  ConnectionGame(board={'TIME PERIODS': ConnectionGroup(level=0, members=['CENTURY', 'DECADE', 'MILLENNIUM', 'YEAR']), 'BREAKFAST FOODS': ConnectionGroup(level=1, members=['CEREAL', 'OMELET', 'PANCAKE', 'WAFFLE']), 'PAINTERS': ConnectionGroup(level=2, members=['BACON', 'CLOSE', 'MUNCH', 'WHISTLER']), 'ONE IN A DOZEN': ConnectionGroup(level=3, members=['EGG', 'JUROR', 'MONTH', 'ROSE'])}, starting_board=[['ROSE', 'CLOSE', 'BACON', 'YEAR'], ['PANCAKE', 'MONTH', 'MUNCH', 'EGG'], ['DECADE', 'CEREAL', 'CENTURY', 'OMELET'], ['WHISTLER', 'MILLENNIUM', 'JUROR', 'WAFFLE']], createdAt=datetime.datetime(2023, 8, 16, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=66, name='Connections #66'),
#  ConnectionGame(board={'DESSERTS': ConnectionGroup(level=0, members=['CAKE', 'COBBLER', 'PIE', 'TART']), 'OCCUPATIONAL SURNAMES': ConnectionGroup(level=1, members=['FISHER', 'MASON', 'MILLER', 'SMITH']), 'ALTER DECEPTIVELY': ConnectionGroup(level=2, members=['DISTORT', 'DOCTOR', 'FUDGE', 'TWIST']), 'SQUARE ___': ConnectionGroup(level=3, members=['DANCE', 'MEAL', 'ONE', 'ROOT'])}, starting_board=[['FUDGE', 'MEAL', 'COBBLER', 'SMITH'], ['PIE', 'DOCTOR', 'ROOT', 'TWIST'], ['DANCE', 'ONE', 'FISHER', 'TART'], ['MASON', 'CAKE', 'DISTORT', 'MILLER']], createdAt=datetime.datetime(2023, 8, 17, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=67, name='Connections #67'),
#  ConnectionGame(board={'UNITS OF VOLUME': ConnectionGroup(level=0, members=['CUP', 'GALLON', 'PINT', 'QUART']), 'EXTREMELY': ConnectionGroup(level=1, members=['AWFUL', 'QUITE', 'SUPER', 'VERY']), 'WORLD CURRENCIES': ConnectionGroup(level=2, members=['RAND', 'REAL', 'STERLING', 'WON']), '___ CAKE': ConnectionGroup(level=3, members=['CARROT', 'COFFEE', 'POUND', 'SPONGE'])}, starting_board=[['PINT', 'REAL', 'CARROT', 'AWFUL'], ['SPONGE', 'CUP', 'WON', 'SUPER'], ['GALLON', 'COFFEE', 'VERY', 'POUND'], ['RAND', 'QUITE', 'QUART', 'STERLING']], createdAt=datetime.datetime(2023, 8, 18, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=68, name='Connections #68'),
#  ConnectionGame(board={'FRIEND': ConnectionGroup(level=0, members=['BUD', 'CHUM', 'MATE', 'PAL']), 'COOKWEAR': ConnectionGroup(level=1, members=['CROCK', 'POT', 'SKILLET', 'WOK']), 'SHOES': ConnectionGroup(level=2, members=['CLOG', 'PUMP', 'SLIDE', 'WEDGE']), 'SLANG FOR CANNABIS': ConnectionGroup(level=3, members=['GRASS', 'HERB', 'MARY JANE', 'WEED'])}, starting_board=[['BUD', 'PUMP', 'CROCK', 'HERB'], ['POT', 'MATE', 'WEDGE', 'GRASS'], ['WOK', 'MARY JANE', 'CHUM', 'SLIDE'], ['CLOG', 'PAL', 'SKILLET', 'WEED']], createdAt=datetime.datetime(2023, 8, 19, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=69, name='Connections #69'),
#  ConnectionGame(board={'CAMPING SUPPLIES': ConnectionGroup(level=0, members=['COOLER', 'LANTERN', 'SLEEPING BAG', 'TENT']), 'INSULT': ConnectionGroup(level=1, members=['BARB', 'DIG', 'DISS', 'JAB']), 'TINY': ConnectionGroup(level=2, members=['MINUTE', 'SLIGHT', 'SMALL', 'WEE']), 'HAPPY ___': ConnectionGroup(level=3, members=['CAMPER', 'HOUR', 'MEAL', 'MEDIUM'])}, starting_board=[['MINUTE', 'DIG', 'MEAL', 'COOLER'], ['HOUR', 'TENT', 'SLIGHT', 'MEDIUM'], ['SMALL', 'BARB', 'CAMPER', 'LANTERN'], ['JAB', 'SLEEPING BAG', 'DISS', 'WEE']], createdAt=datetime.datetime(2023, 8, 20, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=70, name='Connections #70'),
#  ConnectionGame(board={'U.S. MOUNTAIN STATES': ConnectionGroup(level=0, members=['ARIZONA', 'COLORADO', 'NEVADA', 'UTAH']), 'SODA BRANDS': ConnectionGroup(level=1, members=['CRUSH', 'MUG', 'SPRITE', 'SQUIRT']), 'CLASSIC ROCK BANDS': ConnectionGroup(level=2, members=['GENESIS', 'KANSAS', 'RUSH', 'YES']), 'TONY ___': ConnectionGroup(level=3, members=['HAWK', 'MONTANA', 'SOPRANO', 'STARK'])}, starting_board=[['CRUSH', 'UTAH', 'RUSH', 'HAWK'], ['MONTANA', 'MUG', 'ARIZONA', 'GENESIS'], ['SQUIRT', 'STARK', 'YES', 'COLORADO'], ['KANSAS', 'SPRITE', 'NEVADA', 'SOPRANO']], createdAt=datetime.datetime(2023, 8, 21, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=71, name='Connections #71'),
# ...
#  ConnectionGame(board={'BE CONTINGENT (ON)': ConnectionGroup(level=0, members=['DEPEND', 'HINGE', 'RELY', 'REST']), '“CALM DOWN”': ConnectionGroup(level=1, members=['CHILL', 'EASY', 'ENOUGH', 'RELAX']), 'INGREDIENTS IN AN OLD FASHIONED': ConnectionGroup(level=2, members=['BITTERS', 'ORANGE', 'RYE', 'SUGAR']), 'FEATURED IN THE MONTY HALL PROBLEM': ConnectionGroup(level=3, members=['CAR', 'DOOR', 'GOAT', 'HOST'])}, starting_board=[['SUGAR', 'GOAT', 'RELAX', 'ORANGE'], ['HOST', 'REST', 'DOOR', 'HINGE'], ['EASY', 'RYE', 'DEPEND', 'CAR'], ['RELY', 'CHILL', 'ENOUGH', 'BITTERS']], createdAt=datetime.datetime(2025, 1, 10, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=579, name='Connections #579'),
#  ConnectionGame(board={'DISPLAY OF ROWS AND COLUMNS': ConnectionGroup(level=0, members=['ARRAY', 'GRID', 'MATRIX', 'TABLE']), 'THINGS TO DO AT A WORK EVENT': ConnectionGroup(level=1, members=['CIRCULATE', 'CONVERSE', 'MINGLE', 'NETWORK']), 'OLYMPIC EVENTS INTRODUCED IN THE 21ST CENTURY': ConnectionGroup(level=2, members=['BREAKING', 'SURFING', 'TAEKWONDO', 'TRAMPOLINE']), '___ COURT': ConnectionGroup(level=3, members=['FOOD', 'KANGAROO', 'SUPREME', 'TENNIS'])}, starting_board=[['CONVERSE', 'SUPREME', 'FOOD', 'NETWORK'], ['SURFING', 'KANGAROO', 'TABLE', 'TENNIS'], ['MATRIX', 'BREAKING', 'TRAMPOLINE', 'GRID'], ['CIRCULATE', 'TAEKWONDO', 'ARRAY', 'MINGLE']], createdAt=datetime.datetime(2025, 1, 11, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=580, name='Connections #580'),
#  ConnectionGame(board={'FABRICATION': ConnectionGroup(level=0, members=['FAIRY TALE', 'FANTASY', 'FICTION', 'INVENTION']), 'WOO': ConnectionGroup(level=1, members=['CHARM', 'COURT', 'PURSUE', 'ROMANCE']), 'CLASSIC ATARI GAMES': ConnectionGroup(level=2, members=['ASTEROIDS', 'BREAKOUT', 'CENTIPEDE', 'DEFENDER']), 'THINGS FEATURING TAILS': ConnectionGroup(level=3, members=['COIN TOSS', 'COMETS', 'DRESS COAT', 'SONIC THE HEDGEHOG'])}, starting_board=[['COMETS', 'INVENTION', 'COIN TOSS', 'DEFENDER'], ['COURT', 'ASTEROIDS', 'FAIRY TALE', 'DRESS COAT'], ['FICTION', 'ROMANCE', 'SONIC THE HEDGEHOG', 'CENTIPEDE'], ['CHARM', 'FANTASY', 'BREAKOUT', 'PURSUE']], createdAt=datetime.datetime(2025, 1, 12, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=581, name='Connections #581'),
#  ConnectionGame(board={'TEACH': ConnectionGroup(level=0, members=['COACH', 'GUIDE', 'SCHOOL', 'TRAIN']), 'CACHE': ConnectionGroup(level=1, members=['BANK', 'POOL', 'RESERVE', 'STORE']), 'DRIVING INSTRUCTOR DIRECTIVES': ConnectionGroup(level=2, members=['BRAKE', 'PARK', 'SIGNAL', 'TURN']), '___WORM': ConnectionGroup(level=3, members=['BOOK', 'EARTH', 'GLOW', 'INCH'])}, starting_board=[['BANK', 'PARK', 'BOOK', 'STORE'], ['RESERVE', 'TRAIN', 'SCHOOL', 'POOL'], ['EARTH', 'SIGNAL', 'INCH', 'COACH'], ['TURN', 'GLOW', 'GUIDE', 'BRAKE']], createdAt=datetime.datetime(2025, 1, 13, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=582, name='Connections #582'),
#  ConnectionGame(board={'OPERATING': ConnectionGroup(level=0, members=['ACTIVE', 'FUNCTIONAL', 'RUNNING', 'WORKING']), 'TERM': ConnectionGroup(level=1, members=['MEETING', 'PERIOD', 'SESSION', 'SITTING']), 'THINGS IN A CAMERA KIT': ConnectionGroup(level=2, members=['BODY', 'FLASH', 'LENS', 'STRAP']), 'BIRD PLUS LETTER': ConnectionGroup(level=3, members=['CROWD', 'GULLY', 'PUFFING', 'SWANK'])}, starting_board=[['WORKING', 'SESSION', 'BODY', 'CROWD'], ['PUFFING', 'RUNNING', 'SWANK', 'FLASH'], ['SITTING', 'ACTIVE', 'GULLY', 'PERIOD'], ['STRAP', 'MEETING', 'FUNCTIONAL', 'LENS']], createdAt=datetime.datetime(2025, 1, 14, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=583, name='Connections #583'),
#  ConnectionGame(board={'MEANS': ConnectionGroup(level=0, members=['MECHANISM', 'MEDIUM', 'TOOL', 'VEHICLE']), 'LACKING': ConnectionGroup(level=1, members=['LOW', 'SHORT', 'SHY', 'TIGHT']), 'MARTINI SPECIFICATIONS': ConnectionGroup(level=2, members=['DIRTY', 'DRY', 'PERFECT', 'WET']), 'FICTIONAL MISTERS': ConnectionGroup(level=3, members=['BIG', 'PEANUT', 'ROBOT', 'TOAD'])}, starting_board=[['PEANUT', 'VEHICLE', 'DIRTY', 'ROBOT'], ['SHY', 'BIG', 'WET', 'TOAD'], ['MEDIUM', 'LOW', 'PERFECT', 'TOOL'], ['TIGHT', 'MECHANISM', 'DRY', 'SHORT']], createdAt=datetime.datetime(2025, 1, 15, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=584, name='Connections #584'),
#  ConnectionGame(board={'BUYING AND SELLING': ConnectionGroup(level=0, members=['BUSINESS', 'COMMERCE', 'MARKET', 'TRADE']), 'INSTALLED ON A WALL': ConnectionGroup(level=1, members=['BASEBOARD', 'OUTLET', 'SCONCE', 'SWITCH']), 'SPY': ConnectionGroup(level=2, members=['AGENT', 'ASSET', 'MOLE', 'PLANT']), '___ RAT TERMS': ConnectionGroup(level=3, members=['GYM', 'MALL', 'PACK', 'RUG'])}, starting_board=[['MARKET', 'SWITCH', 'PLANT', 'MALL'], ['TRADE', 'GYM', 'OUTLET', 'ASSET'], ['RUG', 'BUSINESS', 'MOLE', 'SCONCE'], ['PACK', 'AGENT', 'BASEBOARD', 'COMMERCE']], createdAt=datetime.datetime(2025, 1, 16, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=585, name='Connections #585'),
#  ConnectionGame(board={'FRANKFURTER': ConnectionGroup(level=0, members=['BANGER', 'BRAT', 'LINK', 'SAUSAGE']), 'STRIKE': ConnectionGroup(level=1, members=['BOP', 'HIT', 'KNOCK', 'TAP']), 'WEB BROWSERS': ConnectionGroup(level=2, members=['CHROME', 'EDGE', 'OPERA', 'SAFARI']), 'ENDING WITH BEER BRANDS': ConnectionGroup(level=3, members=['AUTOHARP', 'CONTRABASS', 'PEPPERONI', 'ROSEBUD'])}, starting_board=[['HIT', 'OPERA', 'BANGER', 'ROSEBUD'], ['PEPPERONI', 'BOP', 'EDGE', 'LINK'], ['TAP', 'CONTRABASS', 'BRAT', 'SAFARI'], ['AUTOHARP', 'CHROME', 'KNOCK', 'SAUSAGE']], createdAt=datetime.datetime(2025, 1, 17, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=586, name='Connections #586'),
#  ConnectionGame(board={'DESIRE': ConnectionGroup(level=0, members=['DRIVE', 'IMPULSE', 'ITCH', 'URGE']), 'BARB': ConnectionGroup(level=1, members=['SPINE', 'SPUR', 'STICKER', 'THORN']), 'INFO ON A RECORD': ConnectionGroup(level=2, members=['ALBUM', 'ARTIST', 'LABEL', 'TRACK']), 'TURN THE ___': ConnectionGroup(level=3, members=['CORNER', 'PAGE', 'TABLES', 'TIDE'])}, starting_board=[['LABEL', 'SPINE', 'PAGE', 'TIDE'], ['URGE', 'STICKER', 'TRACK', 'SPUR'], ['CORNER', 'ARTIST', 'DRIVE', 'TABLES'], ['ITCH', 'THORN', 'ALBUM', 'IMPULSE']], createdAt=datetime.datetime(2025, 1, 18, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=587, name='Connections #587'),
#  ConnectionGame(board={'FUND': ConnectionGroup(level=0, members=['KITTY', 'POOL', 'POT', 'PURSE']), 'COURT FILING': ConnectionGroup(level=1, members=['ACTION', 'CASE', 'CLAIM', 'SUIT']), 'LANDFORMS': ConnectionGroup(level=2, members=['BASIN', 'BLUFF', 'CAPE', 'PLAIN']), 'THEY HAVE RAYS': ConnectionGroup(level=3, members=['AQUARIUM', 'GEOMETRY', 'SUN', 'TAMPA BAY'])}, starting_board=[['SUN', 'POOL', 'ACTION', 'AQUARIUM'], ['CLAIM', 'GEOMETRY', 'BLUFF', 'SUIT'], ['CAPE', 'PURSE', 'TAMPA BAY', 'KITTY'], ['PLAIN', 'CASE', 'POT', 'BASIN']], createdAt=datetime.datetime(2025, 1, 19, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=588, name='Connections #588'),
#  ConnectionGame(board={'TAKE ON, AS A RESPONSIBILITY': ConnectionGroup(level=0, members=['ASSUME', 'BEAR', 'HANDLE', 'SHOULDER']), 'CURVATURE': ConnectionGroup(level=1, members=['ANGLE', 'BEND', 'CROOK', 'ELBOW']), 'ASSOCIATED WITH POPEYE': ConnectionGroup(level=2, members=['ANCHOR', 'FOREARM', 'PIPE', 'SPINACH']), '___ SHEET': ConnectionGroup(level=3, members=['BALANCE', 'CHEAT', 'COOKIE', 'FITTED'])}, starting_board=[['COOKIE', 'BEAR', 'SPINACH', 'SHOULDER'], ['CROOK', 'ANCHOR', 'ELBOW', 'CHEAT'], ['PIPE', 'HANDLE', 'BEND', 'FOREARM'], ['FITTED', 'ANGLE', 'ASSUME', 'BALANCE']], createdAt=datetime.datetime(2025, 1, 20, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=589, name='Connections #589'),
#  ConnectionGame(board={'PUTDOWN': ConnectionGroup(level=0, members=['BARB', 'CRACK', 'DIG', 'SLIGHT']), 'USED TO CLEAR SNOW': ConnectionGroup(level=1, members=['PLOW', 'SALT', 'SAND', 'SHOVEL']), 'FIGURINE': ConnectionGroup(level=2, members=['DOLL', 'FIGURE', 'MINIATURE', 'MODEL']), 'DOCTORS IN POP CULTURE': ConnectionGroup(level=3, members=['NO', 'OCTOPUS', 'PEPPER', 'WHO'])}, starting_board=[['MINIATURE', 'OCTOPUS', 'CRACK', 'PEPPER'], ['SLIGHT', 'SALT', 'DIG', 'SAND'], ['DOLL', 'WHO', 'SHOVEL', 'FIGURE'], ['PLOW', 'BARB', 'MODEL', 'NO']], createdAt=datetime.datetime(2025, 1, 21, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=590, name='Connections #590'),
#  ConnectionGame(board={'TYPES OF ACADEMIC COURSES': ConnectionGroup(level=0, members=['DISCUSSION', 'LAB', 'LECTURE', 'SEMINAR']), 'RESULTS OF SOME DIGGING': ConnectionGroup(level=1, members=['DITCH', 'HOLE', 'PIT', 'TRENCH']), 'ONES WEARING ROBES': ConnectionGroup(level=2, members=['BOXER', 'JUDGE', 'MONK', 'WIZARD']), '___ UP': ConnectionGroup(level=3, members=['BATTER', 'BOTTOMS', 'CHIN', 'LAWYER'])}, starting_board=[['BOXER', 'DITCH', 'BATTER', 'LAB'], ['CHIN', 'JUDGE', 'PIT', 'LAWYER'], ['LECTURE', 'HOLE', 'WIZARD', 'DISCUSSION'], ['TRENCH', 'BOTTOMS', 'SEMINAR', 'MONK']], createdAt=datetime.datetime(2025, 1, 22, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=591, name='Connections #591'),
#  ConnectionGame(board={'OUTDO': ConnectionGroup(level=0, members=['BETTER', 'ECLIPSE', 'SURPASS', 'TOP']), 'PICNIC ACCESSORIES': ConnectionGroup(level=1, members=['BASKET', 'BLANKET', 'COOLER', 'UTENSILS']), 'PARTS OF AN INDIANA JONES COSTUME': ConnectionGroup(level=2, members=['BOMBER', 'FEDORA', 'SATCHEL', 'WHIP']), 'RHYMES OF U.S. PRESIDENT NAMES': ConnectionGroup(level=3, members=['PAGAN', 'SMARTER', 'VIXEN', 'WIDEN'])}, starting_board=[['BETTER', 'BLANKET', 'SATCHEL', 'PAGAN'], ['WIDEN', 'COOLER', 'WHIP', 'SMARTER'], ['BASKET', 'ECLIPSE', 'BOMBER', 'UTENSILS'], ['TOP', 'FEDORA', 'SURPASS', 'VIXEN']], createdAt=datetime.datetime(2025, 1, 23, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=592, name='Connections #592'),
#  ConnectionGame(board={'RUDE THINGS TO DO': ConnectionGroup(level=0, members=['INTERRUPT', 'LITTER', 'POINT', 'STARE']), 'CONTEMPLATE': ConnectionGroup(level=1, members=['BROOD', 'MUSE', 'PONDER', 'REFLECT']), 'OCCUPATION': ConnectionGroup(level=2, members=['CRAFT', 'LINE', 'TRADE', 'WORK']), '___ PATCH': ConnectionGroup(level=3, members=['CABBAGE', 'NICOTINE', 'ROUGH', 'SOUL'])}, starting_board=[['LITTER', 'NICOTINE', 'ROUGH', 'TRADE'], ['CABBAGE', 'BROOD', 'LINE', 'POINT'], ['REFLECT', 'STARE', 'INTERRUPT', 'WORK'], ['CRAFT', 'MUSE', 'SOUL', 'PONDER']], createdAt=datetime.datetime(2025, 1, 24, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=593, name='Connections #593'),
#  ConnectionGame(board={'SCHOOL PERIODS': ConnectionGroup(level=0, members=['CLASS', 'HOMEROOM', 'LUNCH', 'RECESS']), 'FEATURES OF A SKI RESORT': ConnectionGroup(level=1, members=['LIFT', 'LODGE', 'MOGUL', 'SLOPE']), 'WORDS DERIVED FROM JAPANESE': ConnectionGroup(level=2, members=['EMOJI', 'GINKGO', 'KARAOKE', 'TYCOON']), 'WORDS AFTER THE PREFIX “TRI-”': ConnectionGroup(level=3, members=['ANGLE', 'CYCLE', 'DENT', 'POD'])}, starting_board=[['GINKGO', 'SLOPE', 'EMOJI', 'ANGLE'], ['DENT', 'TYCOON', 'RECESS', 'MOGUL'], ['LODGE', 'LUNCH', 'POD', 'KARAOKE'], ['CLASS', 'CYCLE', 'LIFT', 'HOMEROOM']], createdAt=datetime.datetime(2025, 1, 25, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=594, name='Connections #594'),
#  ConnectionGame(board={'WAYS TO GET FOOD': ConnectionGroup(level=0, members=['FARM', 'FISH', 'GATHER', 'HUNT']), 'KEEP APART': ConnectionGroup(level=1, members=['CLOISTER', 'SECLUDE', 'SEPARATE', 'SILO']), 'PARTS OF A BIG RIG': ConnectionGroup(level=2, members=['AXLES', 'HITCH', 'TRACTOR', 'TRAILER']), 'DANCE EVENTS PLUS A LETTER': ConnectionGroup(level=3, members=['BALLY', 'DISCOG', 'PROMO', 'RAVEN'])}, starting_board=[['RAVEN', 'SILO', 'HITCH', 'PROMO'], ['TRAILER', 'DISCOG', 'FISH', 'TRACTOR'], ['BALLY', 'FARM', 'CLOISTER', 'GATHER'], ['SEPARATE', 'HUNT', 'AXLES', 'SECLUDE']], createdAt=datetime.datetime(2025, 1, 26, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=595, name='Connections #595'),
#  ConnectionGame(board={'SMALL AMOUNT OF FOOD TO TRY': ConnectionGroup(level=0, members=['BITE', 'MOUTHFUL', 'SAMPLE', 'TASTE']), 'PROTECTIVE COVERINGS IN NATURE': ConnectionGroup(level=1, members=['BARK', 'SCALES', 'SHELL', 'SKIN']), '“EXTRA VIRGIN OLIVE OIL”': ConnectionGroup(level=2, members=['EXTRA', 'OIL', 'OLIVE', 'VIRGIN']), 'SEEN IN “THE SHINING”': ConnectionGroup(level=3, members=['AXE', 'HEDGE MAZE', 'TWINS', 'TYPEWRITER'])}, starting_board=[['OLIVE', 'TYPEWRITER', 'EXTRA', 'SAMPLE'], ['BARK', 'BITE', 'AXE', 'SCALES'], ['TWINS', 'OIL', 'SHELL', 'VIRGIN'], ['TASTE', 'HEDGE MAZE', 'SKIN', 'MOUTHFUL']], createdAt=datetime.datetime(2025, 1, 27, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=596, name='Connections #596'),
#  ConnectionGame(board={'FUNNY PERSON': ConnectionGroup(level=0, members=['CARD', 'CHARACTER', 'JOKER', 'LAUGH']), 'RESISTANCE TRAINING EQUIPMENT': ConnectionGroup(level=1, members=['BAND', 'BENCH', 'DUMBBELL', 'MAT']), 'CANDY BARS MINUS “S”': ConnectionGroup(level=2, members=['AIRHEAD', 'MAR', 'MOUND', 'SNICKER']), 'SPEED ___': ConnectionGroup(level=3, members=['BUMP', 'CHESS', 'DEMON', 'DIAL'])}, starting_board=[['DEMON', 'LAUGH', 'JOKER', 'AIRHEAD'], ['CARD', 'BAND', 'CHESS', 'DUMBBELL'], ['SNICKER', 'CHARACTER', 'MAT', 'MAR'], ['BUMP', 'MOUND', 'DIAL', 'BENCH']], createdAt=datetime.datetime(2025, 1, 28, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=597, name='Connections #597'),
#  ConnectionGame(board={'OWNED': ConnectionGroup(level=0, members=['BORE', 'HAD', 'HELD', 'POSSESSED']), 'THINGS YOU MIGHT DO IN YOUR SLEEP': ConnectionGroup(level=1, members=['DREAM', 'DROOL', 'SNORE', 'TALK']), '2024 PREQUELS/SEQUELS': ConnectionGroup(level=2, members=['ALIEN', 'GLADIATOR', 'VENOM', 'WICKED']), '___ HOUSE': ConnectionGroup(level=3, members=['FULL', 'GINGERBREAD', 'HAUNTED', 'WHITE'])}, starting_board=[['WICKED', 'GINGERBREAD', 'FULL', 'TALK'], ['POSSESSED', 'VENOM', 'ALIEN', 'DROOL'], ['HAUNTED', 'DREAM', 'SNORE', 'BORE'], ['HAD', 'GLADIATOR', 'WHITE', 'HELD']], createdAt=datetime.datetime(2025, 1, 29, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=598, name='Connections #598'),
#  ConnectionGame(board={'INTANGIBLE QUALITY': ConnectionGroup(level=0, members=['AIR', 'AURA', 'HALO', 'VIBE']), 'GAME DAY FARE': ConnectionGroup(level=1, members=['BEER', 'DIP', 'PIZZA', 'WINGS']), 'KEEP GOING ON ABOUT, WITH “ON”': ConnectionGroup(level=2, members=['DWELL', 'HARP', 'INSIST', 'LINGER']), 'STARTING WITH EUROPEAN CAPITALS': ConnectionGroup(level=3, members=['BERNIE', 'PARISH', 'RIGATONI', 'ROMEO'])}, starting_board=[['HALO', 'RIGATONI', 'AIR', 'WINGS'], ['ROMEO', 'HARP', 'DIP', 'DWELL'], ['PIZZA', 'PARISH', 'LINGER', 'VIBE'], ['BERNIE', 'AURA', 'BEER', 'INSIST']], createdAt=datetime.datetime(2025, 1, 30, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=599, name='Connections #599'),
#  ConnectionGame(board={'STORAGE CONTAINER': ConnectionGroup(level=0, members=['CASE', 'CHEST', 'CRATE', 'TRUNK']), 'SCHNOZZ': ConnectionGroup(level=1, members=['BEAK', 'HONKER', 'SNOOT', 'SNOUT']), 'AUTHORITIES ON A SUBJECT': ConnectionGroup(level=2, members=['CRITIC', 'EXPERT', 'SNOB', 'WONK']), 'STARTS OF SWIMMING STROKES': ConnectionGroup(level=3, members=['BACK', 'BREAST', 'BUTTER', 'FREE'])}, starting_board=[['SNOOT', 'BREAST', 'FREE', 'CHEST'], ['BUTTER', 'SNOB', 'BACK', 'EXPERT'], ['BEAK', 'TRUNK', 'CRITIC', 'CASE'], ['WONK', 'SNOUT', 'CRATE', 'HONKER']], createdAt=datetime.datetime(2025, 1, 31, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='UTC')), id=600, name='Connections #600')]

# %%
client = openai.AsyncOpenAI()
chat_completion = await client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Hello, world!",
        }
    ],
    model="gpt-4o-mini",
)
black_print(chat_completion)
# Out:
# ChatCompletion(
#     id="chatcmpl-AzWkMiS5O00MT92xtmHen3I6KxLSz",
#     choices=[
#         Choice(
#             finish_reason="stop",
#             index=0,
#             logprobs=None,
#             message=ChatCompletionMessage(
#                 content="Hello! How can I assist you today?",
#                 refusal=None,
#                 role="assistant",
#                 audio=None,
#                 function_call=None,
#                 tool_calls=None,
#             ),
#         )
#     ],
#     created=1739227250,
#     model="gpt-4o-mini-2024-07-18",
#     object="chat.completion",
#     service_tier="default",
#     system_fingerprint="fp_72ed7ab54c",
#     usage=CompletionUsage(
#         completion_tokens=10,
#         prompt_tokens=11,
#         total_tokens=21,
#         completion_tokens_details=CompletionTokensDetails(
#             accepted_prediction_tokens=0,
#             audio_tokens=0,
#             reasoning_tokens=0,
#             rejected_prediction_tokens=0,
#         ),
#         prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0),
#     ),
# )

# %%
# Prompts from https://github.com/lechmazur/nyt-connections
prompts = [
    "Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.",
    "Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.",
    "This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.",
]

for prompt in prompts:
    for game in games:
        content = (
            f"{prompt}\n\n{"\n".join(" ".join(row) for row in game.starting_board)}"
        )
        print(content)
        chat_completion = await client.chat.completions.create(
            messages=[
                {
                    "role": "user",
                    "content": content,
                }
            ],
            model="o3-mini",
        )
        black_print(chat_completion)
        assistant_content = chat_completion.choices[0].message.content
        assert assistant_content is not None
        assistant_content = assistant_content.strip()
        groups = [
            frozenset(word.strip() for word in line.split(","))
            for line in assistant_content.split("\n")
        ]
        print(groups)
        score = 0
        for group_name, group_contents in game.board.items():
            if set(group_contents.members) in groups:
                score += 1 / len(game.board)
        print(f"{game.name}: {score}")
        break
    break
# Out:
# Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.
#
# SNOW LEVEL SHIFT KAYAK
# HEAT TAB BUCKS RETURN
# JAZZ HAIL OPTION RAIN
# SLEET RACECAR MOM NETS
# ChatCompletion(
#     id="chatcmpl-AzWzS24kM1XfR8OfyKgqn8zuEzkkV",
#     choices=[
#         Choice(
#             finish_reason="stop",
#             index=0,
#             logprobs=None,
#             message=ChatCompletionMessage(
#                 content="SNOW, HAIL, RAIN, SLEET\nLEVEL, KAYAK, RACECAR, MOM\nSHIFT, TAB, RETURN, OPTION\nHEAT, BUCKS, JAZZ, NETS",
#                 refusal=None,
#                 role="assistant",
#                 audio=None,
#                 function_call=None,
#                 tool_calls=None,
#             ),
#         )
#     ],
#     created=1739228186,
#     model="o3-mini-2025-01-31",
#     object="chat.completion",
#     service_tier="default",
#     system_fingerprint="fp_8bcaa0ca21",
#     usage=CompletionUsage(
#         completion_tokens=1656,
#         prompt_tokens=106,
#         total_tokens=1762,
#         completion_tokens_details=CompletionTokensDetails(
#             accepted_prediction_tokens=0,
#             audio_tokens=0,
#             reasoning_tokens=1600,
#             rejected_prediction_tokens=0,
#         ),
#         prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0),
#     ),
# )
#
# [frozenset({'RAIN', 'HAIL', 'SNOW', 'SLEET'}), frozenset({'LEVEL', 'KAYAK', 'RACECAR', 'MOM'}), frozenset({'RETURN', 'OPTION', 'TAB', 'SHIFT'}), frozenset({'BUCKS', 'NETS', 'HEAT', 'JAZZ'})]
# Connections #1: 1.0

# %%
def do_two_lists_have_same_elements(list1, list2):
   #to lowercase
   list1 = [x.lower() for x in list1]
   list2 = [x.lower() for x in list2]
   if len(list1) != len(list2):
      return False
   return set(list1) == set(list2)


def run_eval(filep, all_extracted):
    used = set()
    scores = {}
    with open(filep, 'r') as file:
        lines = file.read().strip().split('\n')
        total_score = 0
        count = 0
        index = 0
        while index < len(lines):
            try:
                num = int(lines[index].strip())
                used.add(num)
                groups = lines[index + 1:index + 5]
                index += 5  # Move to the next section

                # Process groups
                processed = []
                for g in groups:
                    # Remove text after '//' if any
                    g = g.split('//')[0]
                    # Remove text after ' - ' if any
                    g = g.split(' - ')[0]
                    splitg = g.split(',')
                    stripped = [
                        x.strip().strip('\'"')
                        .replace('1. ', '')
                        .replace('2. ', '')
                        .replace('3. ', '')
                        .replace('4. ', '')
                        .replace('<eos>', '')
                        for x in splitg
                    ]
                    # Remove text in parentheses
                    stripped = [x.split('(')[0].strip() for x in stripped]
                    # Handle colon ':' splitting
                    stripped = [
                        max(x.split(':'), key=lambda part: part.count(','))
                        if ':' in x else x
                        for x in stripped
                    ]
                    # Remove text before period '.' if any
                    stripped = [
                        x.split('.', 1)[1].strip()
                        if '.' in x and len(x.split('.', 1)) > 1 else x
                        for x in stripped
                    ]
                    # Remove text after dash '-' if any
                    stripped = [x.split(' - ')[0].strip() for x in stripped]
                    processed.append(stripped[:4])

                # Now compute the score
                compared_to = all_extracted[num].split('\n')
                score = 0
                for f in range(0, 4):
                    description = compared_to[f * 6]
                    words = compared_to[f * 6 + 1:f * 6 + 5]

                    match_found = False
                    for res in processed:
                        if do_two_lists_have_same_elements(res, words):
                            match_found = True
                            break

                    if match_found:
                        score += 1 / 4

                scores[num] = score
                total_score += score
                count += 1

            except ValueError:
                # If we can't convert to int, move to the next line
                index += 1
                continue

        print("Total score = ", total_score)
        print("Total count = ", count)
        print("Percentage = ", round(total_score / count * 100.0, 2))
    return used, list(scores.values())

# %%
pl.read_csv("./data/eric27n/NYT-Connections/Connections_Data.csv").drop_nulls()
# Out:
# shape: (9_104, 7)
# ┌─────────┬─────────────┬───────┬───────────────────┬─────────────┬──────────────┬─────────────────┐
# │ Game ID ┆ Puzzle Date ┆ Word  ┆ Group Name        ┆ Group Level ┆ Starting Row ┆ Starting Column │
# │ ---     ┆ ---         ┆ ---   ┆ ---               ┆ ---         ┆ ---          ┆ ---             │
# │ i64     ┆ str         ┆ str   ┆ str               ┆ i64         ┆ i64          ┆ i64             │
# ╞═════════╪═════════════╪═══════╪═══════════════════╪═════════════╪══════════════╪═════════════════╡
# │ 1       ┆ 2023-06-12  ┆ SNOW  ┆ WET WEATHER       ┆ 0           ┆ 1            ┆ 1               │
# │ 1       ┆ 2023-06-12  ┆ LEVEL ┆ PALINDROMES       ┆ 3           ┆ 1            ┆ 2               │
# │ 1       ┆ 2023-06-12  ┆ SHIFT ┆ KEYBOARD KEYS     ┆ 2           ┆ 1            ┆ 3               │
# │ 1       ┆ 2023-06-12  ┆ KAYAK ┆ PALINDROMES       ┆ 3           ┆ 1            ┆ 4               │
# │ 1       ┆ 2023-06-12  ┆ HEAT  ┆ NBA TEAMS         ┆ 1           ┆ 2            ┆ 1               │
# │ …       ┆ …           ┆ …     ┆ …                 ┆ …           ┆ …            ┆ …               │
# │ 599     ┆ 2024-12-31  ┆ BLAST ┆ FUN TIME          ┆ 1           ┆ 3            ┆ 4               │
# │ 599     ┆ 2024-12-31  ┆ BOLT  ┆ MOVE QUICKLY      ┆ 0           ┆ 4            ┆ 1               │
# │ 599     ┆ 2024-12-31  ┆ KICK  ┆ FUN TIME          ┆ 1           ┆ 4            ┆ 2               │
# │ 599     ┆ 2024-12-31  ┆ TO    ┆ WORDS BEFORE AN   ┆ 2           ┆ 4            ┆ 3               │
# │         ┆             ┆       ┆ ADDRESSEE         ┆             ┆              ┆                 │
# │ 599     ┆ 2024-12-31  ┆ DASH  ┆ MOVE QUICKLY      ┆ 0           ┆ 4            ┆ 4               │
# └─────────┴─────────────┴───────┴───────────────────┴─────────────┴──────────────┴─────────────────┘

# %%
import json

data = json.load(open("./data/tm21cy/NYT-Connections/ConnectionsFinalDataset.json"))
data
# Out:
# [{'date': '2024/06/03',
#   'contest': 'NYT Connections 358 - June 3rd, 2024',
#   'words': ['LASER',
#    'PLUCK',
#    'THREAD',
#    'WAX',
#    'COIL',
#    'SPOOL',
#    'WIND',
#    'WRAP',
#    'HONEYCOMB',
#    'ORGANISM',
#    'SOLAR PANEL',
#    'SPREADSHEET',
#    'BALL',
#    'MOVIE',
#    'SCHOOL',
#    'VITAMIN'],
#   'answers': [{'answerDescription': 'REMOVE, AS BODY HAIR',
#     'words': ['LASER', 'PLUCK', 'THREAD', 'WAX']},
#    {'answerDescription': 'TWIST AROUND',
#     'words': ['COIL', 'SPOOL', 'WIND', 'WRAP']},
#    {'answerDescription': 'THINGS MADE OF CELLS',
#     'words': ['HONEYCOMB', 'ORGANISM', 'SOLAR PANEL', 'SPREADSHEET']},
#    {'answerDescription': 'B-___',
#     'words': ['BALL', 'MOVIE', 'SCHOOL', 'VITAMIN']}],
#   'difficulty': 3.3},
#  {'date': '2024/06/02',
#   'contest': 'NYT Connections 357 - June 2nd, 2024',
#   'words': ['FOLLOWERS',
#    'LEMMINGS',
#    'PUPPETS',
#    'SHEEP',
#    'EQUITY',
#    'OPTIONS',
#    'SHARES',
#    'STOCKS',
#    'BILLINGS',
#    'BUFFALO',
#    'MOBILE',
#    'PHOENIX',
#    'APARTMENT',
#    'INSULTS',
#    'LIKES',
#    'SHOVELS'],
#   'answers': [{'answerDescription': 'CONFORMISTS',
#     'words': ['FOLLOWERS', 'LEMMINGS', 'PUPPETS', 'SHEEP']},
#    {'answerDescription': 'COMPANY OWNERSHIP OFFERS',
#     'words': ['EQUITY', 'OPTIONS', 'SHARES', 'STOCKS']},
#    {'answerDescription': 'U.S. CITIES',
#     'words': ['BILLINGS', 'BUFFALO', 'MOBILE', 'PHOENIX']},
#    {'answerDescription': 'WHAT “DIGS” MIGHT MEAN',
#     'words': ['APARTMENT', 'INSULTS', 'LIKES', 'SHOVELS']}],
#   'difficulty': 2.8},
#  {'date': '2024/06/01',
#   'contest': 'NYT Connections 356 - June 1st, 2024',
#   'words': ['HURRY',
#    'NOW',
#    'PRONTO',
#    'STAT',
#    'CURRENT',
#    'DRIFT',
#    'TIDE',
#    'WAVE',
#    'CURL',
#    'FLY',
#    'PRESS',
#    'ROW',
#    'LOCK',
#    'MARKS',
#    'PANE',
#    'RUSTLE'],
#   'answers': [{'answerDescription': '“DON’T DELAY!”',
#     'words': ['HURRY', 'NOW', 'PRONTO', 'STAT']},
#    {'answerDescription': 'OCEAN PHENOMENA',
#     'words': ['CURRENT', 'DRIFT', 'TIDE', 'WAVE']},
#    {'answerDescription': 'DUMBBELL EXERCISES',
#     'words': ['CURL', 'FLY', 'PRESS', 'ROW']},
#    {'answerDescription': 'PHILOSOPHER HOMOPHONES',
#     'words': ['LOCK', 'MARKS', 'PANE', 'RUSTLE']}],
#   'difficulty': 2.8},
#  {'date': '2024/05/31',
#   'contest': 'NYT Connections 355 - May 31st, 2024',
#   'words': ['BODY',
#    'CANON',
#    'OEUVRE',
#    'WORKS',
#    'FUJI',
#    'HOOD',
#    'OLYMPUS',
#    'WHITNEY',
#    'INSERT',
#    'JACKET',
#    'RECORD',
#    'SLEEVE',
#    'HANDS',
#    'MARACA',
#    'POLAROID',
#    'SNOWGLOBE'],
#   'answers': [{'answerDescription': 'CORPUS',
#     'words': ['BODY', 'CANON', 'OEUVRE', 'WORKS']},
#    {'answerDescription': 'MOUNT ___',
#     'words': ['FUJI', 'HOOD', 'OLYMPUS', 'WHITNEY']},
#    {'answerDescription': 'COMPONENTS OF AN LP',
#     'words': ['INSERT', 'JACKET', 'RECORD', 'SLEEVE']},
#    {'answerDescription': 'THINGS PEOPLE SHAKE',
#     'words': ['HANDS', 'MARACA', 'POLAROID', 'SNOWGLOBE']}],
#   'difficulty': 3.0},
#  {'date': '2024/05/30',
#   'contest': 'NYT Connections 354 - May 30th, 2024',
#   'words': ['LOOT',
#    'RAID',
#    'ROB',
#    'SACK',
#    'CLOUT',
#    'PULL',
#    'SWAY',
#    'WEIGHT',
#    'BOB',
#    'CROP',
#    'FADE',
#    'SHAG',
#    'BOBBY',
#    'HAIR',
#    'PUSH',
#    'SAFETY'],
#   'answers': [{'answerDescription': 'PLUNDER',
#     'words': ['LOOT', 'RAID', 'ROB', 'SACK']},
#    {'answerDescription': 'INFLUENCE',
#     'words': ['CLOUT', 'PULL', 'SWAY', 'WEIGHT']},
#    {'answerDescription': 'HAIRSTYLES',
#     'words': ['BOB', 'CROP', 'FADE', 'SHAG']},
#    {'answerDescription': '___ PIN',
#     'words': ['BOBBY', 'HAIR', 'PUSH', 'SAFETY']}],
#   'difficulty': 3.5},
#  {'date': '2024/05/29',
#   'contest': 'NYT Connections 353 - May 29th, 2024',
#   'words': ['CHOW',
#    'EATS',
#    'FARE',
#    'GRUB',
#    'DIRECT',
#    'GUIDE',
#    'LEAD',
#    'STEER',
#    'BULLY',
#    'COW',
#    'DAUNT',
#    'RATTLE',
#    'BULL',
#    'FLEA',
#    'MEAT',
#    'STOCK'],
#   'answers': [{'answerDescription': 'FOOD',
#     'words': ['CHOW', 'EATS', 'FARE', 'GRUB']},
#    {'answerDescription': 'PILOT',
#     'words': ['DIRECT', 'GUIDE', 'LEAD', 'STEER']},
#    {'answerDescription': 'INTIMIDATE',
#     'words': ['BULLY', 'COW', 'DAUNT', 'RATTLE']},
#    {'answerDescription': '___ MARKET',
#     'words': ['BULL', 'FLEA', 'MEAT', 'STOCK']}],
#   'difficulty': 2.5},
#  {'date': '2024/05/28',
#   'contest': 'NYT Connections 352 - May 28th, 2024',
#   'words': ['EASY',
#    'FLEXIBLE',
#    'OPEN',
#    'RECEPTIVE',
#    'EVIL',
#    'LIVE',
#    'VEIL',
#    'VILE',
#    'AMAZING',
#    'BEGINNER',
#    'GENIUS',
#    'SOLID',
#    'LIT',
#    'SCENTED',
#    'WAXY',
#    'WICKED'],
#   'answers': [{'answerDescription': 'AMENABLE',
#     'words': ['EASY', 'FLEXIBLE', 'OPEN', 'RECEPTIVE']},
#    {'answerDescription': 'ANAGRAMS',
#     'words': ['EVIL', 'LIVE', 'VEIL', 'VILE']},
#    {'answerDescription': 'SPELLING BEE RANKS',
#     'words': ['AMAZING', 'BEGINNER', 'GENIUS', 'SOLID']},
#    {'answerDescription': 'ADJECTIVES FOR A CANDLE',
#     'words': ['LIT', 'SCENTED', 'WAXY', 'WICKED']}],
#   'difficulty': 2.8},
#  {'date': '2024/05/27',
#   'contest': 'NYT Connections 351 - May 27th, 2024',
#   'words': ['CHOICE',
#    'SAY',
#    'VOICE',
#    'VOTE',
#    'DOWN',
#    'HEEL',
#    'SHAKE',
#    'SPEAK',
#    'FLAT',
#    'NATURAL',
#    'QUARTER',
#    'WHOLE',
#    'PUMP',
#    'STEAM',
#    'TIRE',
#    'WAFFLE'],
#   'answers': [{'answerDescription': 'AGENCY IN DECISIONMAKING',
#     'words': ['CHOICE', 'SAY', 'VOICE', 'VOTE']},
#    {'answerDescription': 'DOG COMMANDS',
#     'words': ['DOWN', 'HEEL', 'SHAKE', 'SPEAK']},
#    {'answerDescription': 'KINDS OF NOTES',
#     'words': ['FLAT', 'NATURAL', 'QUARTER', 'WHOLE']},
#    {'answerDescription': '___ IRON',
#     'words': ['PUMP', 'STEAM', 'TIRE', 'WAFFLE']}],
#   'difficulty': 2.2},
#  {'date': '2024/05/26',
#   'contest': 'NYT Connections 350 - May 26th, 2024',
#   'words': ['GRIDDLE',
#    'KETTLE',
#    'PAN',
#    'POT',
#    'FRILL',
#    'FRINGE',
#    'RUFFLE',
#    'TRIM',
#    'LAY',
#    'PLACE',
#    'PUT',
#    'SET',
#    'GEEZ',
#    'SEIZE',
#    'TEASE',
#    'WISE'],
#   'answers': [{'answerDescription': 'FOUND ON A STOVE TOP',
#     'words': ['GRIDDLE', 'KETTLE', 'PAN', 'POT']},
#    {'answerDescription': 'ORNAMENTAL BORDER',
#     'words': ['FRILL', 'FRINGE', 'RUFFLE', 'TRIM']},
#    {'answerDescription': 'DEPOSIT, WITH “DOWN”',
#     'words': ['LAY', 'PLACE', 'PUT', 'SET']},
#    {'answerDescription': 'WORDS THAT SOUNDS LIKE PLURAL LETTERS',
#     'words': ['GEEZ', 'SEIZE', 'TEASE', 'WISE']}],
#   'difficulty': 4.0},
#  {'date': '2024/05/25',
#   'contest': 'NYT Connections 349 - May 25th, 2024',
#   'words': ['BANNER',
#    'BILLBOARD',
#    'POSTER',
#    'SIGN',
#    'FIRST',
#    'INITIAL',
#    'MAIDEN',
#    'PREMIER',
#    'BACK',
#    'CHAMPION',
#    'ENDORSE',
#    'SUPPORT',
#    'HERE',
#    'THEME',
#    'USE',
#    'WEE'],
#   'answers': [{'answerDescription': 'ADVERTISING FORMAT',
#     'words': ['BANNER', 'BILLBOARD', 'POSTER', 'SIGN']},
#    {'answerDescription': 'INAUGURAL',
#     'words': ['FIRST', 'INITIAL', 'MAIDEN', 'PREMIER']},
#    {'answerDescription': 'ADVOCATE FOR',
#     'words': ['BACK', 'CHAMPION', 'ENDORSE', 'SUPPORT']},
#    {'answerDescription': 'PRONOUN PLUS “E”',
#     'words': ['HERE', 'THEME', 'USE', 'WEE']}],
#   'difficulty': 1.6},
#  {'date': '2024/05/24',
#   'contest': 'NYT Connections 348 - May 24th, 2024',
#   'words': ['DRAIN',
#    'DUCT',
#    'PIPE',
#    'SEWER',
#    'CHEESE',
#    'CORN',
#    'SAP',
#    'SCHMALTZ',
#    'EGG',
#    'KNUCKLES',
#    'SMILE',
#    'WINDOW',
#    'CHUMP',
#    'CLIMATE',
#    'LOOSE',
#    'SEA'],
#   'answers': [{'answerDescription': 'CONDUITS FOR WATER REMOVAL',
#     'words': ['DRAIN', 'DUCT', 'PIPE', 'SEWER']},
#    {'answerDescription': 'FOOD PRODUCTS ASSOCIATED WITH SENTIMENTALITY',
#     'words': ['CHEESE', 'CORN', 'SAP', 'SCHMALTZ']},
#    {'answerDescription': 'THINGS TO CRACK',
#     'words': ['EGG', 'KNUCKLES', 'SMILE', 'WINDOW']},
#    {'answerDescription': '___ CHANGE',
#     'words': ['CHUMP', 'CLIMATE', 'LOOSE', 'SEA']}],
#   'difficulty': 3.0},
#  {'date': '2024/05/23',
#   'contest': 'NYT Connections 347 - May 23rd, 2024',
#   'words': ['EXPLOIT',
#    'LEVERAGE',
#    'MILK',
#    'USE',
#    'DONE',
#    'OVER',
#    'THROUGH',
#    'UP',
#    'CITY',
#    'COPY',
#    'CULTURE',
#    'SPORTS',
#    'HEYDAY',
#    'HIJINKS',
#    'SUPPER',
#    'YOGURT'],
#   'answers': [{'answerDescription': 'TAKE ADVANTAGE OF',
#     'words': ['EXPLOIT', 'LEVERAGE', 'MILK', 'USE']},
#    {'answerDescription': 'FINISHED, AS TIME',
#     'words': ['DONE', 'OVER', 'THROUGH', 'UP']},
#    {'answerDescription': 'NEWSPAPER DESKS',
#     'words': ['CITY', 'COPY', 'CULTURE', 'SPORTS']},
#    {'answerDescription': 'WORDS BEGINNING WITH GREETINGS',
#     'words': ['HEYDAY', 'HIJINKS', 'SUPPER', 'YOGURT']}],
#   'difficulty': 2.4},
#  {'date': '2024/05/22',
#   'contest': 'NYT Connections 346 - May 22nd, 2024',
#   'words': ['HEAD',
#    'KNEES',
#    'SHOULDERS',
#    'TOES',
#    'AUTO',
#    'RIDE',
#    'WHEELS',
#    'WHIP',
#    'PARES',
#    'PEELS',
#    'SHELLS',
#    'SHUCKS',
#    'BEES',
#    'CAFFEINE',
#    'GOSSIP',
#    'INTERCOMS'],
#   'answers': [{'answerDescription': 'BODY PARTS IN “HEAD, SHOULDERS, KNEES AND TOES”',
#     'words': ['HEAD', 'KNEES', 'SHOULDERS', 'TOES']},
#    {'answerDescription': 'CAR, INFORMALLY',
#     'words': ['AUTO', 'RIDE', 'WHEELS', 'WHIP']},
#    {'answerDescription': 'REMOVES THE COVERING OF',
#     'words': ['PARES', 'PEELS', 'SHELLS', 'SHUCKS']},
#    {'answerDescription': '“BUZZY” THINGS',
#     'words': ['BEES', 'CAFFEINE', 'GOSSIP', 'INTERCOMS']}],
#   'difficulty': 2.8},
#  {'date': '2024/05/21',
#   'contest': 'NYT Connections 345 - May 21st, 2024',
#   'words': ['BIT',
#    'DASH',
#    'PINCH',
#    'TOUCH',
#    'BUY',
#    'DEAL',
#    'STEAL',
#    'VALUE',
#    'BALL',
#    'CHALK',
#    'CUE',
#    'RACK',
#    'FACE',
#    'MAC',
#    'MATCH',
#    'POCKET'],
#   'answers': [{'answerDescription': 'SMIDGEN',
#     'words': ['BIT', 'DASH', 'PINCH', 'TOUCH']},
#    {'answerDescription': 'BARGAIN',
#     'words': ['BUY', 'DEAL', 'STEAL', 'VALUE']},
#    {'answerDescription': 'BILLIARDS EQUIPMENT',
#     'words': ['BALL', 'CHALK', 'CUE', 'RACK']},
#    {'answerDescription': '___BOOK (THAT’S NOT A BOOK)',
#     'words': ['FACE', 'MAC', 'MATCH', 'POCKET']}],
#   'difficulty': 3.3},
#  {'date': '2024/05/20',
#   'contest': 'NYT Connections 344 - May 20th, 2024',
#   'words': ['CHARM',
#    'HEX',
#    'MAGIC',
#    'SPELL',
#    'INSTRUMENT',
#    'PAWN',
#    'PUPPET',
#    'TOOL',
#    'CAPE',
#    'MASK',
#    'TIGHTS',
#    'UNDERWEAR',
#    'BAY',
#    'CARPENTER',
#    'SCOTT',
#    'WOO'],
#   'answers': [{'answerDescription': 'SORCERER’S OUTPUT',
#     'words': ['CHARM', 'HEX', 'MAGIC', 'SPELL']},
#    {'answerDescription': 'ONE BEING MANIPULATED',
#     'words': ['INSTRUMENT', 'PAWN', 'PUPPET', 'TOOL']},
#    {'answerDescription': 'CLASSIC SUPERHERO WEAR',
#     'words': ['CAPE', 'MASK', 'TIGHTS', 'UNDERWEAR']},
#    {'answerDescription': 'ACTION MOVIE DIRECTORS',
#     'words': ['BAY', 'CARPENTER', 'SCOTT', 'WOO']}],
#   'difficulty': 2.4},
#  {'date': '2024/05/19',
#   'contest': 'NYT Connections 343 - May 19th, 2024',
#   'words': ['FLUSH',
#    'LOADED',
#    'RICH',
#    'WEALTHY',
#    'CHOP',
#    'CUBE',
#    'DICE',
#    'MINCE',
#    'SQUARE',
#    'STRAIGHT',
#    'STUFFY',
#    'TRADITIONAL',
#    'BURY',
#    'CURRENT',
#    'LEACHY',
#    'PAIR'],
#   'answers': [{'answerDescription': 'AFFLUENT',
#     'words': ['FLUSH', 'LOADED', 'RICH', 'WEALTHY']},
#    {'answerDescription': 'CUT INTO PIECES',
#     'words': ['CHOP', 'CUBE', 'DICE', 'MINCE']},
#    {'answerDescription': 'OLD-FASHIONED',
#     'words': ['SQUARE', 'STRAIGHT', 'STUFFY', 'TRADITIONAL']},
#    {'answerDescription': 'FRUIT HOMOPHONES',
#     'words': ['BURY', 'CURRENT', 'LEACHY', 'PAIR']}],
#   'difficulty': 2.2},
#  {'date': '2024/05/18',
#   'contest': 'NYT Connections 342 - May 18th, 2024',
#   'words': ['BULLDOG',
#    'CATFISH',
#    'HORSEFLY',
#    'TURTLEDOVE',
#    'DOGLEG',
#    'HAIRPIN',
#    'SWITCHBACK',
#    'ZAG',
#    'CATEGORIES',
#    'CHARADES',
#    'FISHBOWL',
#    'WEREWOLF',
#    'CLOCK',
#    'MATTRESS',
#    'MOUSETRAP',
#    'TRAMPOLINE'],
#   'answers': [{'answerDescription': 'ANIMALS WHOSE NAMES ARE TWO ANIMALS',
#     'words': ['BULLDOG', 'CATFISH', 'HORSEFLY', 'TURTLEDOVE']},
#    {'answerDescription': 'SHARP TURNS',
#     'words': ['DOGLEG', 'HAIRPIN', 'SWITCHBACK', 'ZAG']},
#    {'answerDescription': 'CLASSIC PARTY GAMES',
#     'words': ['CATEGORIES', 'CHARADES', 'FISHBOWL', 'WEREWOLF']},
#    {'answerDescription': 'THINGS WITH SPRING/S',
#     'words': ['CLOCK', 'MATTRESS', 'MOUSETRAP', 'TRAMPOLINE']}],
#   'difficulty': 2.8},
#  {'date': '2024/05/17',
#   'contest': 'NYT Connections 341 - May 17th, 2024',
#   'words': ['BASE',
#    'DIRTY',
#    'LOW',
#    'VILE',
#    'CONTACT',
#    'MESSAGE',
#    'PING',
#    'TEXT',
#    'FRUIT',
#    'PITCHER',
#    'SKULL',
#    'TABLECLOTH',
#    'BATTER',
#    'CAN',
#    'GARDEN',
#    'PONG'],
#   'answers': [{'answerDescription': 'CORRUPT',
#     'words': ['BASE', 'DIRTY', 'LOW', 'VILE']},
#    {'answerDescription': 'REACH OUT TO',
#     'words': ['CONTACT', 'MESSAGE', 'PING', 'TEXT']},
#    {'answerDescription': 'CLASSIC STILL LIFE COMPONENTS',
#     'words': ['FRUIT', 'PITCHER', 'SKULL', 'TABLECLOTH']},
#    {'answerDescription': 'BEER ___',
#     'words': ['BATTER', 'CAN', 'GARDEN', 'PONG']}],
#   'difficulty': 3.2},
#  {'date': '2024/05/16',
#   'contest': 'NYT Connections 340 - May 16th, 2024',
#   'words': ['PIC',
#    'SHOT',
#    'SNAP',
#    'STILL',
#    'CINCH',
#    'ICE',
#    'LOCK',
#    'SECURE',
#    'BREEZE',
#    'COAST',
#    'GLIDE',
#    'SAIL',
#    'PICNIC',
#    'SECURITY',
#    'THROW',
#    'WET'],
#   'answers': [{'answerDescription': 'PHOTO',
#     'words': ['PIC', 'SHOT', 'SNAP', 'STILL']},
#    {'answerDescription': 'ASSURE, AS A VICTORY',
#     'words': ['CINCH', 'ICE', 'LOCK', 'SECURE']},
#    {'answerDescription': 'MOVE IN AN EFFORTLESS WAY',
#     'words': ['BREEZE', 'COAST', 'GLIDE', 'SAIL']},
#    {'answerDescription': '___ BLANKET',
#     'words': ['PICNIC', 'SECURITY', 'THROW', 'WET']}],
#   'difficulty': 3.6},
#  {'date': '2024/05/15',
#   'contest': 'NYT Connections 339 - May 15th, 2024',
#   'words': ['ACT',
#    'BILL',
#    'MEASURE',
#    'RESOLUTION',
#    'MEADOW',
#    'PLAIN',
#    'PRAIRIE',
#    'SAVANNA',
#    'DIRECT',
#    'FRANK',
#    'OPEN',
#    'STRAIGHT',
#    'AURA',
#    'BUCK',
#    'DOGE',
#    'HODA'],
#   'answers': [{'answerDescription': 'BIT OF LEGISLATION',
#     'words': ['ACT', 'BILL', 'MEASURE', 'RESOLUTION']},
#    {'answerDescription': 'GRASSLAND',
#     'words': ['MEADOW', 'PLAIN', 'PRAIRIE', 'SAVANNA']},
#    {'answerDescription': 'FORTHRIGHT',
#     'words': ['DIRECT', 'FRANK', 'OPEN', 'STRAIGHT']},
#    {'answerDescription': 'CAR COMPANIES MINUS LETTER',
#     'words': ['AURA', 'BUCK', 'DOGE', 'HODA']}],
#   'difficulty': 3.2},
#  {'date': '2024/05/14',
#   'contest': 'NYT Connections 338 - May 14th, 2024',
#   'words': ['DRAFT',
#    'OUTLINE',
#    'PLAN',
#    'SKETCH',
#    'DINE',
#    'FEAST',
#    'FEED',
#    'SUP',
#    'ELLA',
#    'ME',
#    'SUS',
#    'YO',
#    'FIT',
#    'JIM',
#    'PICKINGS',
#    'SHADY'],
#   'answers': [{'answerDescription': 'EARLY ITERATION',
#     'words': ['DRAFT', 'OUTLINE', 'PLAN', 'SKETCH']},
#    {'answerDescription': 'ENJOY A MEAL',
#     'words': ['DINE', 'FEAST', 'FEED', 'SUP']},
#    {'answerDescription': 'SPANISH PRONOUNS',
#     'words': ['ELLA', 'ME', 'SUS', 'YO']},
#    {'answerDescription': 'SLIM ___',
#     'words': ['FIT', 'JIM', 'PICKINGS', 'SHADY']}],
#   'difficulty': 2.8},
#  {'date': '2024/05/13',
#   'contest': 'NYT Connections 337 - May 13th, 2024',
#   'words': ['BRAND',
#    'COLLECTION',
#    'LABEL',
#    'LINE',
#    'DODGE',
#    'HIDE',
#    'HOP',
#    'TAG',
#    'BUNNY',
#    'DUCK',
#    'MARTIAN',
#    'PIG',
#    'GREECE',
#    'HARE',
#    'KATZ',
#    'MAIM'],
#   'answers': [{'answerDescription': "FASHION DESIGNER'S OUTPUT",
#     'words': ['BRAND', 'COLLECTION', 'LABEL', 'LINE']},
#    {'answerDescription': 'PLAYGROUND VERBS',
#     'words': ['DODGE', 'HIDE', 'HOP', 'TAG']},
#    {'answerDescription': 'LOONEY TUNES FIGURES',
#     'words': ['BUNNY', 'DUCK', 'MARTIAN', 'PIG']},
#    {'answerDescription': 'HOMOPHONES OF MUSICALS',
#     'words': ['GREECE', 'HARE', 'KATZ', 'MAIM']}],
#   'difficulty': 2.8},
#  {'date': '2024/05/12',
#   'contest': 'NYT Connections 336 - May 12th, 2024',
#   'words': ['KID',
#    'NEEDLE',
#    'RIB',
#    'TEASE',
#    'CHUCK',
#    'FLANK',
#    'LOIN',
#    'ROUND',
#    'MIA',
#    'OMG',
#    'PIN',
#    'RAM',
#    'LIBRE',
#    'MAMA',
#    'MULE',
#    'SLING'],
#   'answers': [{'answerDescription': 'PLAYFULLY POKE FUN AT',
#     'words': ['KID', 'NEEDLE', 'RIB', 'TEASE']},
#    {'answerDescription': 'CUTS OF BEEF',
#     'words': ['CHUCK', 'FLANK', 'LOIN', 'ROUND']},
#    {'answerDescription': 'ACRONYMS', 'words': ['MIA', 'OMG', 'PIN', 'RAM']},
#    {'answerDescription': 'COCKTAILS MINUS PLACE NAMES',
#     'words': ['LIBRE', 'MAMA', 'MULE', 'SLING']}],
#   'difficulty': 3.0},
#  {'date': '2024/05/11',
#   'contest': 'NYT Connections 335 - May 11th, 2024',
#   'words': ['HEADLINER',
#    'LEAD',
#    'PRINCIPAL',
#    'STAR',
#    'CROSS',
#    'GARLIC',
#    'SILVER',
#    'SUN',
#    'CRACKED',
#    'LAMPOON',
#    'MAD',
#    'ONION',
#    'MED',
#    'MUSIC',
#    'SANDWICH',
#    'SODA'],
#   'answers': [{'answerDescription': 'ONE WITH TOP BILLING',
#     'words': ['HEADLINER', 'LEAD', 'PRINCIPAL', 'STAR']},
#    {'answerDescription': 'VAMPIRE VULNERABILITIES',
#     'words': ['CROSS', 'GARLIC', 'SILVER', 'SUN']},
#    {'answerDescription': 'SATIRICAL PUBLICATIONS, FAMILIARLY',
#     'words': ['CRACKED', 'LAMPOON', 'MAD', 'ONION']},
#    {'answerDescription': 'CLUB ___',
#     'words': ['MED', 'MUSIC', 'SANDWICH', 'SODA']}],
#   'difficulty': 3.2},
#  {'date': '2024/05/10',
#   'contest': 'NYT Connections 334 - May 10th, 2024',
#   'words': ['BRASS',
#    'CHEEK',
#    'GALL',
#    'NERVE',
#    'COLLAR',
#    'HALTER',
#    'HARNESS',
#    'LEAD',
#    'CAROUSEL',
#    'GLOBE',
#    'RECORD',
#    'TOP',
#    'FERRY',
#    'MERCURY',
#    'NICKS',
#    'PLANT'],
#   'answers': [{'answerDescription': 'CHUTZPAH',
#     'words': ['BRASS', 'CHEEK', 'GALL', 'NERVE']},
#    {'answerDescription': 'ACCESSORIES FOR DOG WALKING',
#     'words': ['COLLAR', 'HALTER', 'HARNESS', 'LEAD']},
#    {'answerDescription': 'THINGS THAT SPIN',
#     'words': ['CAROUSEL', 'GLOBE', 'RECORD', 'TOP']},
#    {'answerDescription': 'LEAD SINGERS OF ’70S ROCK BANDS',
#     'words': ['FERRY', 'MERCURY', 'NICKS', 'PLANT']}],
#   'difficulty': 3.3},
#  {'date': '2024/05/09',
#   'contest': 'NYT Connections 333 - May 9th, 2024',
#   'words': ['CAP',
#    'CORK',
#    'LID',
#    'TAB',
#    'PERIOD',
#    'SPELL',
#    'STRETCH',
#    'TIME',
#    'CHECK',
#    'CONTAIN',
#    'CURB',
#    'LIMIT',
#    'BILL',
#    'EGG',
#    'FUR',
#    'VENOM'],
#   'answers': [{'answerDescription': 'CONTAINER CLOSURES',
#     'words': ['CAP', 'CORK', 'LID', 'TAB']},
#    {'answerDescription': 'DURATION',
#     'words': ['PERIOD', 'SPELL', 'STRETCH', 'TIME']},
#    {'answerDescription': 'REGULATE',
#     'words': ['CHECK', 'CONTAIN', 'CURB', 'LIMIT']},
#    {'answerDescription': 'TRADEMARKS OF A PLATYPUS',
#     'words': ['BILL', 'EGG', 'FUR', 'VENOM']}],
#   'difficulty': 3.3},
#  {'date': '2024/05/08',
#   'contest': 'NYT Connections 332 - May 8th, 2024',
#   'words': ['BRICK',
#    'CHERRY',
#    'ROSE',
#    'RUBY',
#    'DROP',
#    'SPLASH',
#    'SPOT',
#    'SPRINKLE',
#    'BEST',
#    'CREAM',
#    'PICK',
#    'TOP',
#    'BIRD',
#    'BUBBLE',
#    'MUD',
#    'SPONGE'],
#   'answers': [{'answerDescription': 'SHADES OF RED',
#     'words': ['BRICK', 'CHERRY', 'ROSE', 'RUBY']},
#    {'answerDescription': 'LITTLE BIT OF A BEVERAGE',
#     'words': ['DROP', 'SPLASH', 'SPOT', 'SPRINKLE']},
#    {'answerDescription': 'CHOICEST',
#     'words': ['BEST', 'CREAM', 'PICK', 'TOP']},
#    {'answerDescription': '___ BATH',
#     'words': ['BIRD', 'BUBBLE', 'MUD', 'SPONGE']}],
#   'difficulty': 2.3},
#  {'date': '2024/05/07',
#   'contest': 'NYT Connections 331 - May 7th, 2024',
#   'words': ['BUN',
#    'HERO',
#    'ROLL',
#    'WRAP',
#    'CHOPS',
#    'KISSER',
#    'TRAP',
#    'YAP',
#    'BOB',
#    'CLAP',
#    'SNAP',
#    'TAP',
#    'APPLAUSE',
#    'DRINKS',
#    'FUNDING',
#    'GOLF'],
#   'answers': [{'answerDescription': 'DELI BREAD OPTIONS',
#     'words': ['BUN', 'HERO', 'ROLL', 'WRAP']},
#    {'answerDescription': 'SLANG FOR MOUTH',
#     'words': ['CHOPS', 'KISSER', 'TRAP', 'YAP']},
#    {'answerDescription': 'KEEP RHYTHM WITH MUSIC',
#     'words': ['BOB', 'CLAP', 'SNAP', 'TAP']},
#    {'answerDescription': 'ROUND OF ___',
#     'words': ['APPLAUSE', 'DRINKS', 'FUNDING', 'GOLF']}],
#   'difficulty': 3.8},
#  {'date': '2024/05/06',
#   'contest': 'NYT Connections 330 - May 6th, 2024',
#   'words': ['COUPLE',
#    'JOIN',
#    'LINK',
#    'TIE',
#    'BOTHER',
#    'HANDFUL',
#    'PAIN',
#    'PEST',
#    'FEW',
#    'MANY',
#    'SEVERAL',
#    'SOME',
#    'FOOL',
#    'LOVERS',
#    'MAGICIAN',
#    'TOWER'],
#   'answers': [{'answerDescription': 'CONNECT',
#     'words': ['COUPLE', 'JOIN', 'LINK', 'TIE']},
#    {'answerDescription': 'NUISANCE',
#     'words': ['BOTHER', 'HANDFUL', 'PAIN', 'PEST']},
#    {'answerDescription': 'QUANTITY WORDS',
#     'words': ['FEW', 'MANY', 'SEVERAL', 'SOME']},
#    {'answerDescription': 'TAROT CARDS, WITH “THE”',
#     'words': ['FOOL', 'LOVERS', 'MAGICIAN', 'TOWER']}],
#   'difficulty': 2.8},
#  {'date': '2024/05/05',
#   'contest': 'NYT Connections 329 - May 5th, 2024',
#   'words': ['BENEFIT',
#    'FRUIT',
#    'RETURN',
#    'REWARD',
#    'EGG',
#    'EVERYTHING',
#    'PLAIN',
#    'POPPY',
#    'ACT',
#    'DIRECT',
#    'PRODUCE',
#    'WRITE',
#    'FRANK',
#    'MUM',
#    'VAMP',
#    'WERE'],
#   'answers': [{'answerDescription': 'SOMETHING GAINED FROM HARD WORK',
#     'words': ['BENEFIT', 'FRUIT', 'RETURN', 'REWARD']},
#    {'answerDescription': 'KINDS OF BAGELS',
#     'words': ['EGG', 'EVERYTHING', 'PLAIN', 'POPPY']},
#    {'answerDescription': 'CONTRIBUTE TO A MOVIE',
#     'words': ['ACT', 'DIRECT', 'PRODUCE', 'WRITE']},
#    {'answerDescription': 'STARTS OF MONSTERS',
#     'words': ['FRANK', 'MUM', 'VAMP', 'WERE']}],
#   'difficulty': 2.5},
#  {'date': '2024/05/04',
#   'contest': 'NYT Connections 328 - May 4th, 2024',
#   'words': ['FANCY',
#    'LOVE',
#    'RELISH',
#    'SAVOR',
#    'LIKE',
#    'LITERALLY',
#    'UM',
#    'WELL',
#    'CYLINDER',
#    'PIN',
#    'SPRING',
#    'TUMBLER',
#    'CARROT',
#    'HURTS',
#    'JEWEL',
#    'OM'],
#   'answers': [{'answerDescription': 'ENJOY',
#     'words': ['FANCY', 'LOVE', 'RELISH', 'SAVOR']},
#    {'answerDescription': 'FILLER WORDS',
#     'words': ['LIKE', 'LITERALLY', 'UM', 'WELL']},
#    {'answerDescription': 'COMPONENTS OF A LOCK',
#     'words': ['CYLINDER', 'PIN', 'SPRING', 'TUMBLER']},
#    {'answerDescription': 'HOMOPHONES OF UNITS OF MEASURE',
#     'words': ['CARROT', 'HURTS', 'JEWEL', 'OM']}],
#   'difficulty': 3.1},
#  {'date': '2024/05/03',
#   'contest': 'NYT Connections 327 - May 3rd, 2024',
#   'words': ['BAR',
#    'CLUB',
#    'DISCO',
#    'LOUNGE',
#    'DITCH',
#    'DROP',
#    'LOSE',
#    'SHED',
#    'FATHOM',
#    'FOOT',
#    'LEAGUE',
#    'YARD',
#    'BAKE',
#    'CLEARANCE',
#    'GARAGE',
#    'SAMPLE'],
#   'answers': [{'answerDescription': 'NIGHTSPOTS',
#     'words': ['BAR', 'CLUB', 'DISCO', 'LOUNGE']},
#    {'answerDescription': 'CAST OFF',
#     'words': ['DITCH', 'DROP', 'LOSE', 'SHED']},
#    {'answerDescription': 'UNITS OF LENGTH',
#     'words': ['FATHOM', 'FOOT', 'LEAGUE', 'YARD']},
#    {'answerDescription': '___ SALE',
#     'words': ['BAKE', 'CLEARANCE', 'GARAGE', 'SAMPLE']}],
#   'difficulty': 2.3},
#  {'date': '2024/05/02',
#   'contest': 'NYT Connections 326 - May 2nd, 2024',
#   'words': ['ACE',
#    'CRACKERJACK',
#    'EXPERT',
#    'HOTSHOT',
#    'CHOCK',
#    'JACK',
#    'TIRE',
#    'WRENCH',
#    'GLADIATOR',
#    'HER',
#    'JOKER',
#    'SIGNS',
#    'POPCORN',
#    'RAPTURE',
#    'ROCKETRY',
#    'SOULMATE'],
#   'answers': [{'answerDescription': 'HIGHLY SKILLED',
#     'words': ['ACE', 'CRACKERJACK', 'EXPERT', 'HOTSHOT']},
#    {'answerDescription': 'USED TO FIX A FLAT',
#     'words': ['CHOCK', 'JACK', 'TIRE', 'WRENCH']},
#    {'answerDescription': 'JOAQUIN PHOENIX MOVIES',
#     'words': ['GLADIATOR', 'HER', 'JOKER', 'SIGNS']},
#    {'answerDescription': 'WORDS STARTING WITH MUSIC GENRES',
#     'words': ['POPCORN', 'RAPTURE', 'ROCKETRY', 'SOULMATE']}],
#   'difficulty': 3.3},
#  {'date': '2024/05/01',
#   'contest': 'NYT Connections 325 - May 1st, 2024',
#   'words': ['BUTTON',
#    'FLY',
#    'POCKET',
#    'RIVET',
#    'LINE',
#    'PLANE',
#    'POINT',
#    'SOLID',
#    'FILE',
#    'HISTORY',
#    'VIEW',
#    'WINDOW',
#    'ANIMAL',
#    'DOOR',
#    'KINK',
#    'SUPREME'],
#   'answers': [{'answerDescription': 'FEATURES ON A PAIR OF JEANS',
#     'words': ['BUTTON', 'FLY', 'POCKET', 'RIVET']},
#    {'answerDescription': 'OBJECTS IN 0-, 1-, 2- AND 3-DIMENSIONAL SPACE',
#     'words': ['LINE', 'PLANE', 'POINT', 'SOLID']},
#    {'answerDescription': 'WEB BROWSER MENUS',
#     'words': ['FILE', 'HISTORY', 'VIEW', 'WINDOW']},
#    {'answerDescription': 'MEMBER OF A ’60S BAND',
#     'words': ['ANIMAL', 'DOOR', 'KINK', 'SUPREME']}],
#   'difficulty': 2.3},
#  {'date': '2024/04/30',
#   'contest': 'NYT Connections 324 - April 30th, 2024',
#   'words': ['AIOLI',
#    'BARBECUE',
#    'MARINARA',
#    'RANCH',
#    'EXAMINE',
#    'GRILL',
#    'PROBE',
#    'QUESTION',
#    'BILL',
#    'INVOICE',
#    'RECEIPT',
#    'STATEMENT',
#    'ANCESTRY',
#    'BROTH',
#    'CATTLE',
#    'MERCHANDISE'],
#   'answers': [{'answerDescription': 'DIPPING SAUCES',
#     'words': ['AIOLI', 'BARBECUE', 'MARINARA', 'RANCH']},
#    {'answerDescription': 'INTERROGATE',
#     'words': ['EXAMINE', 'GRILL', 'PROBE', 'QUESTION']},
#    {'answerDescription': 'TRANSACTION RECORD',
#     'words': ['BILL', 'INVOICE', 'RECEIPT', 'STATEMENT']},
#    {'answerDescription': 'WHAT “STOCK” MIGHT MEAN',
#     'words': ['ANCESTRY', 'BROTH', 'CATTLE', 'MERCHANDISE']}],
#   'difficulty': 2.5},
#  {'date': '2024/04/29',
#   'contest': 'NYT Connections 323 - April 29th, 2024',
#   'words': ['BRIDGE',
#    'CRUNCH',
#    'DIP',
#    'SQUAT',
#    'BOUNTY',
#    'COWBOY',
#    'DUEL',
#    'SALOON',
#    'CARTER',
#    'GORE',
#    'KING',
#    'TUTU',
#    'BUSY',
#    'HONEY',
#    'QUEEN',
#    'SPELLING'],
#   'answers': [{'answerDescription': 'EXERCISES',
#     'words': ['BRIDGE', 'CRUNCH', 'DIP', 'SQUAT']},
#    {'answerDescription': 'FEATURED IN WESTERNS',
#     'words': ['BOUNTY', 'COWBOY', 'DUEL', 'SALOON']},
#    {'answerDescription': 'LEADERS WHO RECEIVED THE NOBEL PEACE PRIZE',
#     'words': ['CARTER', 'GORE', 'KING', 'TUTU']},
#    {'answerDescription': '___ BEE',
#     'words': ['BUSY', 'HONEY', 'QUEEN', 'SPELLING']}],
#   'difficulty': 2.4},
#  {'date': '2024/04/28',
#   'contest': 'NYT Connections 322 - April 28th, 2024',
#   'words': ['DEEP',
#    'EXTREME',
#    'FIERCE',
#    'INTENSE',
#    'BUMP',
#    'BUTT',
#    'KNOCK',
#    'RAM',
#    'FUZZ',
#    'NOISE',
#    'SNOW',
#    'STATIC',
#    'BLOODY',
#    'HAIL',
#    'PROUD',
#    'VIRGIN'],
#   'answers': [{'answerDescription': 'PASSIONATE, AS A FEELING',
#     'words': ['DEEP', 'EXTREME', 'FIERCE', 'INTENSE']},
#    {'answerDescription': 'BANG INTO',
#     'words': ['BUMP', 'BUTT', 'KNOCK', 'RAM']},
#    {'answerDescription': 'ANALOG TV INTERFERENCE',
#     'words': ['FUZZ', 'NOISE', 'SNOW', 'STATIC']},
#    {'answerDescription': '___ MARY',
#     'words': ['BLOODY', 'HAIL', 'PROUD', 'VIRGIN']}],
#   'difficulty': 2.0},
#  {'date': '2024/04/27',
#   'contest': 'NYT Connections 321 - April 27th, 2024',
#   'words': ['ACCEPT',
#    'BELIEVE',
#    'BUY',
#    'SWALLOW',
#    'OUTAGE',
#    'SHORT',
#    'SPIKE',
#    'SURGE',
#    'ABSTRACT',
#    'BRIEF',
#    'DIGEST',
#    'OUTLINE',
#    'CURT',
#    'HAIRY',
#    'KNEEL',
#    'WANE'],
#   'answers': [{'answerDescription': 'TRUST AS REAL',
#     'words': ['ACCEPT', 'BELIEVE', 'BUY', 'SWALLOW']},
#    {'answerDescription': 'POWER ISSUES',
#     'words': ['OUTAGE', 'SHORT', 'SPIKE', 'SURGE']},
#    {'answerDescription': 'SUMMARY',
#     'words': ['ABSTRACT', 'BRIEF', 'DIGEST', 'OUTLINE']},
#    {'answerDescription': 'NAME HOMOPHONES',
#     'words': ['CURT', 'HAIRY', 'KNEEL', 'WANE']}],
#   'difficulty': 2.8},
#  {'date': '2024/04/26',
#   'contest': 'NYT Connections 320 - April 26th, 2024',
#   'words': ['ELEGANCE',
#    'GRACE',
#    'STYLE',
#    'TASTE',
#    'BAKE',
#    'BASK',
#    'SUN',
#    'TAN',
#    'AFFECT',
#    'IMPACT',
#    'MOVE',
#    'TOUCH',
#    'SEN',
#    'SIGHT',
#    'SINE',
#    'SOUR'],
#   'answers': [{'answerDescription': 'REFINED SENSIBILITY',
#     'words': ['ELEGANCE', 'GRACE', 'STYLE', 'TASTE']},
#    {'answerDescription': 'CATCH SOME RAYS',
#     'words': ['BAKE', 'BASK', 'SUN', 'TAN']},
#    {'answerDescription': 'EMOTIONALLY SWAY',
#     'words': ['AFFECT', 'IMPACT', 'MOVE', 'TOUCH']},
#    {'answerDescription': 'NUMBERS WITH FIRST LETTERS REPLACED BY “S”',
#     'words': ['SEN', 'SIGHT', 'SINE', 'SOUR']}],
#   'difficulty': 3.2},
#  {'date': '2024/04/25',
#   'contest': 'NYT Connections 319 - April 25th, 2024',
#   'words': ['BEAKER',
#    'DROPPER',
#    'GOGGLES',
#    'MICROSCOPE',
#    'CENTER',
#    'HEART',
#    'HUB',
#    'NUCLEUS',
#    'CELL',
#    'FORMULA',
#    'SHEET',
#    'SORT',
#    'BODY',
#    'LOVE',
#    'ROMANCE',
#    'SIGN'],
#   'answers': [{'answerDescription': 'LAB EQUIPMENT',
#     'words': ['BEAKER', 'DROPPER', 'GOGGLES', 'MICROSCOPE']},
#    {'answerDescription': 'NEXUS',
#     'words': ['CENTER', 'HEART', 'HUB', 'NUCLEUS']},
#    {'answerDescription': 'SPREADSHEET TERMS',
#     'words': ['CELL', 'FORMULA', 'SHEET', 'SORT']},
#    {'answerDescription': '___ LANGUAGE',
#     'words': ['BODY', 'LOVE', 'ROMANCE', 'SIGN']}],
#   'difficulty': 2.3},
#  {'date': '2024/04/24',
#   'contest': 'NYT Connections 318 - April 24th, 2024',
#   'words': ['CILANTRO',
#    'LIME',
#    'ONION',
#    'SALSA',
#    'KILO',
#    'MEGA',
#    'MICRO',
#    'PICO',
#    'MINI',
#    'PENCIL',
#    'POODLE',
#    'WRAP',
#    'CAPITOL',
#    'FAITH',
#    'FOOT',
#    'MOLE'],
#   'answers': [{'answerDescription': 'TACO TOPPINGS',
#     'words': ['CILANTRO', 'LIME', 'ONION', 'SALSA']},
#    {'answerDescription': 'METRIC PREFIXES',
#     'words': ['KILO', 'MEGA', 'MICRO', 'PICO']},
#    {'answerDescription': 'KINDS OF SKIRTS',
#     'words': ['MINI', 'PENCIL', 'POODLE', 'WRAP']},
#    {'answerDescription': 'WORDS WITH “HILL”',
#     'words': ['CAPITOL', 'FAITH', 'FOOT', 'MOLE']}],
#   'difficulty': 3.8},
#  {'date': '2024/04/23',
#   'contest': 'NYT Connections 317 - April 23rd, 2024',
#   'words': ['BOOT',
#    'BOUNCE',
#    'EJECT',
#    'TOSS',
#    'EARTH',
#    'GROUND',
#    'LAND',
#    'SOIL',
#    'BALTIC',
#    'BLACK',
#    'PHILIPPINE',
#    'RED',
#    'BIG',
#    'PHILADELPHIA',
#    'SPLASH',
#    'SULLY'],
#   'answers': [{'answerDescription': 'THROW OUT',
#     'words': ['BOOT', 'BOUNCE', 'EJECT', 'TOSS']},
#    {'answerDescription': 'TERRA FIRMA',
#     'words': ['EARTH', 'GROUND', 'LAND', 'SOIL']},
#    {'answerDescription': 'SEAS',
#     'words': ['BALTIC', 'BLACK', 'PHILIPPINE', 'RED']},
#    {'answerDescription': 'TOM HANKS MOVIES',
#     'words': ['BIG', 'PHILADELPHIA', 'SPLASH', 'SULLY']}],
#   'difficulty': 2.3},
#  {'date': '2024/04/22',
#   'contest': 'NYT Connections 316 - April 22nd, 2024',
#   'words': ['BUD',
#    'CHUM',
#    'MATE',
#    'PAL',
#    'COLD',
#    'DANK',
#    'DARK',
#    'MUSTY',
#    'FUZZ',
#    'SCRUFF',
#    'SHADOW',
#    'WHISKERS',
#    'FUND',
#    'KITTY',
#    'POOL',
#    'POT'],
#   'answers': [{'answerDescription': 'SLANG FOR FRIEND',
#     'words': ['BUD', 'CHUM', 'MATE', 'PAL']},
#    {'answerDescription': 'ADJECTIVES FOR A BASEMENT',
#     'words': ['COLD', 'DANK', 'DARK', 'MUSTY']},
#    {'answerDescription': 'STUBBLE',
#     'words': ['FUZZ', 'SCRUFF', 'SHADOW', 'WHISKERS']},
#    {'answerDescription': 'COLLECTION OF MONEY',
#     'words': ['FUND', 'KITTY', 'POOL', 'POT']}],
#   'difficulty': 1.8},
#  {'date': '2024/04/21',
#   'contest': 'NYT Connections 315 - April 21st, 2024',
#   'words': ['EXAMPLE',
#    'IDEAL',
#    'MODEL',
#    'SYMBOL',
#    'CAR',
#    'CONDUCTOR',
#    'STATION',
#    'TRACK',
#    'CYMBAL',
#    'SCIMITAR',
#    'SIMMER',
#    'SYMPHONY',
#    'DRUM',
#    'MARK',
#    'WAX',
#    'WIG'],
#   'answers': [{'answerDescription': 'EMBODIMENT',
#     'words': ['EXAMPLE', 'IDEAL', 'MODEL', 'SYMBOL']},
#    {'answerDescription': 'RELATED TO TRAINS',
#     'words': ['CAR', 'CONDUCTOR', 'STATION', 'TRACK']},
#    {'answerDescription': 'STARTING WITH THE SAME SOUND',
#     'words': ['CYMBAL', 'SCIMITAR', 'SIMMER', 'SYMPHONY']},
#    {'answerDescription': 'EAR___', 'words': ['DRUM', 'MARK', 'WAX', 'WIG']}],
#   'difficulty': 3.8},
#  {'date': '2024/04/20',
#   'contest': 'NYT Connections 314 - April 20th, 2024',
#   'words': ['BUNK',
#    'CROCK',
#    'HOGWASH',
#    'HORSEFEATHERS',
#    'BATON',
#    'HAMMER',
#    'HURDLE',
#    'POLE',
#    'GOATEE',
#    'HORNS',
#    'PITCHFORK',
#    'TAIL',
#    'BEND',
#    'BOWLINE',
#    'HITCH',
#    'SHEEPSHANK'],
#   'answers': [{'answerDescription': 'BALDERDASH',
#     'words': ['BUNK', 'CROCK', 'HOGWASH', 'HORSEFEATHERS']},
#    {'answerDescription': 'TRACK AND FIELD EQUIPMENT',
#     'words': ['BATON', 'HAMMER', 'HURDLE', 'POLE']},
#    {'answerDescription': 'PARTS OF A DEVIL COSTUME',
#     'words': ['GOATEE', 'HORNS', 'PITCHFORK', 'TAIL']},
#    {'answerDescription': 'TYPES OF KNOTS',
#     'words': ['BEND', 'BOWLINE', 'HITCH', 'SHEEPSHANK']}],
#   'difficulty': 4.0},
#  {'date': '2024/04/19',
#   'contest': 'NYT Connections 313 - April 19th, 2024',
#   'words': ['ADHERE',
#    'GLUE',
#    'PASTE',
#    'STICK',
#    'COPY',
#    'TEXT',
#    'WORDS',
#    'WRITING',
#    'CARAT',
#    'CLARITY',
#    'COLOR',
#    'CUT',
#    'LIST',
#    'OK',
#    'PLUS',
#    'ROD'],
#   'answers': [{'answerDescription': 'ATTACH WITH ADHESIVE',
#     'words': ['ADHERE', 'GLUE', 'PASTE', 'STICK']},
#    {'answerDescription': 'PUBLISHED LINES',
#     'words': ['COPY', 'TEXT', 'WORDS', 'WRITING']},
#    {'answerDescription': 'DIAMOND QUALITIES',
#     'words': ['CARAT', 'CLARITY', 'COLOR', 'CUT']},
#    {'answerDescription': 'A-___', 'words': ['LIST', 'OK', 'PLUS', 'ROD']}],
#   'difficulty': 2.6},
#  {'date': '2024/04/18',
#   'contest': 'NYT Connections 312 - April 18th, 2024',
#   'words': ['CURB',
#    'GRATE',
#    'GUTTER',
#    'MANHOLE',
#    'AIM',
#    'INTEND',
#    'MEAN',
#    'PLAN',
#    'CAL',
#    'GAL',
#    'IN',
#    'OZ',
#    'FLEECE',
#    'GIRLS',
#    'PARACHUTE',
#    'RULE'],
#   'answers': [{'answerDescription': 'SIDEWALK SIGHTS',
#     'words': ['CURB', 'GRATE', 'GUTTER', 'MANHOLE']},
#    {'answerDescription': 'HAVE IN MIND',
#     'words': ['AIM', 'INTEND', 'MEAN', 'PLAN']},
#    {'answerDescription': 'UNIT ABBREVIATIONS',
#     'words': ['CAL', 'GAL', 'IN', 'OZ']},
#    {'answerDescription': 'GOLDEN ___',
#     'words': ['FLEECE', 'GIRLS', 'PARACHUTE', 'RULE']}],
#   'difficulty': 2.6},
#  {'date': '2024/04/17',
#   'contest': 'NYT Connections 311 - April 17th, 2024',
#   'words': ['COLUMN',
#    'PILLAR',
#    'POLE',
#    'POST',
#    'FOLLOW',
#    'MIND',
#    'OBSERVE',
#    'REGARD',
#    'INTEREST',
#    'PERCENTAGE',
#    'SHARE',
#    'STAKE',
#    'DIRT',
#    'INFORMATION',
#    'INTELLIGENCE',
#    'SECRETS'],
#   'answers': [{'answerDescription': 'UPRIGHT SUPPORT',
#     'words': ['COLUMN', 'PILLAR', 'POLE', 'POST']},
#    {'answerDescription': 'HEED, AS RULES',
#     'words': ['FOLLOW', 'MIND', 'OBSERVE', 'REGARD']},
#    {'answerDescription': 'ALLOTMENT',
#     'words': ['INTEREST', 'PERCENTAGE', 'SHARE', 'STAKE']},
#    {'answerDescription': 'GATHERED BY SPIES',
#     'words': ['DIRT', 'INFORMATION', 'INTELLIGENCE', 'SECRETS']}],
#   'difficulty': 4.2},
#  {'date': '2024/04/16',
#   'contest': 'NYT Connections 310 - April 16th, 2024',
#   'words': ['FLOOR',
#    'ROCK',
#    'SHOCK',
#    'SURPRISE',
#    'ARTICLE',
#    'FEATURE',
#    'REPORT',
#    'STORY',
#    'EVEN',
#    'FLAT',
#    'FLUSH',
#    'LEVEL',
#    'BALCONY',
#    'BOX',
#    'ORCHESTRA',
#    'STAGE'],
#   'answers': [{'answerDescription': 'FLABBERGAST',
#     'words': ['FLOOR', 'ROCK', 'SHOCK', 'SURPRISE']},
#    {'answerDescription': 'BIT OF JOURNALISM',
#     'words': ['ARTICLE', 'FEATURE', 'REPORT', 'STORY']},
#    {'answerDescription': 'ON THE SAME PLANE',
#     'words': ['EVEN', 'FLAT', 'FLUSH', 'LEVEL']},
#    {'answerDescription': 'THEATER SECTIONS',
#     'words': ['BALCONY', 'BOX', 'ORCHESTRA', 'STAGE']}],
#   'difficulty': 2.6},
#  {'date': '2024/04/15',
#   'contest': 'NYT Connections 309 - April 15th, 2024',
#   'words': ['AD-LIB',
#    'FREESTYLE',
#    'IMPROV',
#    'MAKE UP',
#    'BABBLE',
#    'COO',
#    'CRAWL',
#    'NURSE',
#    'COSMETIC',
#    'EXTERNAL',
#    'SHALLOW',
#    'SURFACE',
#    'BUTTERFLY',
#    'DOMINO',
#    'PLACEBO',
#    'SIDE'],
#   'answers': [{'answerDescription': 'INVENT AS YOU GO',
#     'words': ['AD-LIB', 'FREESTYLE', 'IMPROV', 'MAKE UP']},
#    {'answerDescription': 'THINGS BABIES DO',
#     'words': ['BABBLE', 'COO', 'CRAWL', 'NURSE']},
#    {'answerDescription': 'SUPERFICIAL',
#     'words': ['COSMETIC', 'EXTERNAL', 'SHALLOW', 'SURFACE']},
#    {'answerDescription': '___ EFFECT',
#     'words': ['BUTTERFLY', 'DOMINO', 'PLACEBO', 'SIDE']}],
#   'difficulty': 2.6},
#  {'date': '2024/04/14',
#   'contest': 'NYT Connections 308 - April 14th, 2024',
#   'words': ['RIP',
#    'TEAR',
#    'WRENCH',
#    'YANK',
#    'DRILL',
#    'EXERCISE',
#    'PRACTICE',
#    'ROUTINE',
#    'AMERICAN',
#    'FRONTIER',
#    'SPIRIT',
#    'UNITED',
#    'FRIAR',
#    'MONKEY',
#    'SUNDRY',
#    'WEDDING'],
#   'answers': [{'answerDescription': 'PULL USING FORCE',
#     'words': ['RIP', 'TEAR', 'WRENCH', 'YANK']},
#    {'answerDescription': 'BIT OF REPETITIVE TRAINING',
#     'words': ['DRILL', 'EXERCISE', 'PRACTICE', 'ROUTINE']},
#    {'answerDescription': 'U.S.-BASED AIRLINES',
#     'words': ['AMERICAN', 'FRONTIER', 'SPIRIT', 'UNITED']},
#    {'answerDescription': 'BEGINNING WITH DAY ABBREVIATIONS',
#     'words': ['FRIAR', 'MONKEY', 'SUNDRY', 'WEDDING']}],
#   'difficulty': 2.3},
#  {'date': '2024/04/13',
#   'contest': 'NYT Connections 307 - April 13th, 2024',
#   'words': ['CLOWN',
#    'RING',
#    'TENT',
#    'TRAPEZE',
#    'LION',
#    'SCARECROW',
#    'WITCH',
#    'WIZARD',
#    'HAIR',
#    'MAKEUP',
#    'PROPS',
#    'WARDROBE',
#    'JOKER',
#    'LOVER',
#    'SINNER',
#    'SMOKER'],
#   'answers': [{'answerDescription': 'SEEN AT THE CIRCUS',
#     'words': ['CLOWN', 'RING', 'TENT', 'TRAPEZE']},
#    {'answerDescription': '“THE WIZARD OF OZ” FIGURES',
#     'words': ['LION', 'SCARECROW', 'WITCH', 'WIZARD']},
#    {'answerDescription': 'FILM DEPARTMENTS',
#     'words': ['HAIR', 'MAKEUP', 'PROPS', 'WARDROBE']},
#    {'answerDescription': '“I’M A ___” (LYRICS IN “THE JOKER”)',
#     'words': ['JOKER', 'LOVER', 'SINNER', 'SMOKER']}],
#   'difficulty': 2.0},
#  {'date': '2024/04/12',
#   'contest': 'NYT Connections 306 - April 12th, 2024',
#   'words': ['CLEAN',
#    'NEAT',
#    'TIDY',
#    'TRIM',
#    'HYPER',
#    'SUPER',
#    'UBER',
#    'ULTRA',
#    'BALLOON',
#    'MUSHROOM',
#    'SNOWBALL',
#    'SWELL',
#    'DOMINO',
#    'JACK',
#    'MARBLE',
#    'STICK'],
#   'answers': [{'answerDescription': 'ORDERLY',
#     'words': ['CLEAN', 'NEAT', 'TIDY', 'TRIM']},
#    {'answerDescription': 'AUGMENTATIVE PREFIXES',
#     'words': ['HYPER', 'SUPER', 'UBER', 'ULTRA']},
#    {'answerDescription': 'BECOME LARGER',
#     'words': ['BALLOON', 'MUSHROOM', 'SNOWBALL', 'SWELL']},
#    {'answerDescription': 'ITEMS IN CLASSIC KIDS’ GAMES',
#     'words': ['DOMINO', 'JACK', 'MARBLE', 'STICK']}],
#   'difficulty': 2.3},
#  {'date': '2024/04/11',
#   'contest': 'NYT Connections 305 - April 11th, 2024',
#   'words': ['BOWL',
#    'BUZZ',
#    'CREW',
#    'PIXIE',
#    'COMPASS',
#    'RULER',
#    'SCALE',
#    'WATCH',
#    'CHANNEL',
#    'LINE',
#    'MAIN',
#    'PIPE',
#    'CLOWN',
#    'COLONEL',
#    'KING',
#    'MERMAID'],
#   'answers': [{'answerDescription': 'HAIRCUTS, WITH “CUT”',
#     'words': ['BOWL', 'BUZZ', 'CREW', 'PIXIE']},
#    {'answerDescription': 'MEASURING INSTRUMENTS',
#     'words': ['COMPASS', 'RULER', 'SCALE', 'WATCH']},
#    {'answerDescription': 'WATER AND GAS CONDUITS',
#     'words': ['CHANNEL', 'LINE', 'MAIN', 'PIPE']},
#    {'answerDescription': 'FAST FOOD MASCOTS',
#     'words': ['CLOWN', 'COLONEL', 'KING', 'MERMAID']}],
#   'difficulty': 3.1},
#  {'date': '2024/04/10',
#   'contest': 'NYT Connections 304 - April 10th, 2024',
#   'words': ['CHAIR',
#    'CHIEF',
#    'DIRECTOR',
#    'HEAD',
#    'FIELD',
#    'GREEN',
#    'GROUNDS',
#    'LAWN',
#    'CHEST',
#    'COCO',
#    'HAZEL',
#    'PEA',
#    'BROWN',
#    'DOGS',
#    'FICTION',
#    'UNCHAINED'],
#   'answers': [{'answerDescription': 'PERSON IN CHARGE',
#     'words': ['CHAIR', 'CHIEF', 'DIRECTOR', 'HEAD']},
#    {'answerDescription': 'GRASSY AREA',
#     'words': ['FIELD', 'GREEN', 'GROUNDS', 'LAWN']},
#    {'answerDescription': 'WORDS BEFORE “NUT”',
#     'words': ['CHEST', 'COCO', 'HAZEL', 'PEA']},
#    {'answerDescription': 'SECOND WORDS IN TARANTINO MOVIES',
#     'words': ['BROWN', 'DOGS', 'FICTION', 'UNCHAINED']}],
#   'difficulty': 4.0},
#  {'date': '2024/04/09',
#   'contest': 'NYT Connections 303 - April 9th, 2024',
#   'words': ['EXTENT',
#    'RANGE',
#    'REACH',
#    'SCOPE',
#    'BRUSH',
#    'COMB',
#    'DRYER',
#    'IRON',
#    'ARMS',
#    'COAT',
#    'CREST',
#    'SHIELD',
#    'EAR',
#    'KETTLE',
#    'OIL',
#    'STEEL'],
#   'answers': [{'answerDescription': 'BREADTH',
#     'words': ['EXTENT', 'RANGE', 'REACH', 'SCOPE']},
#    {'answerDescription': 'HAIR TOOLS',
#     'words': ['BRUSH', 'COMB', 'DRYER', 'IRON']},
#    {'answerDescription': 'HERALDRY TERMS',
#     'words': ['ARMS', 'COAT', 'CREST', 'SHIELD']},
#    {'answerDescription': 'WORDS BEFORE “DRUM”',
#     'words': ['EAR', 'KETTLE', 'OIL', 'STEEL']}],
#   'difficulty': 2.2},
#  {'date': '2024/04/08',
#   'contest': 'NYT Connections 302 - April 8th, 2024',
#   'words': ['FLASH',
#    'HEARTBEAT',
#    'JIFF',
#    'WINK',
#    'CLASH',
#    'SCRAP',
#    'TANGLE',
#    'TIFF',
#    'JACK',
#    'LOVE',
#    'SQUAT',
#    'ZIP',
#    'CANE',
#    'MONOCLE',
#    'SPAT',
#    'TOP HAT'],
#   'answers': [{'answerDescription': 'BRIEF MOMENT',
#     'words': ['FLASH', 'HEARTBEAT', 'JIFF', 'WINK']},
#    {'answerDescription': 'DISPUTE',
#     'words': ['CLASH', 'SCRAP', 'TANGLE', 'TIFF']},
#    {'answerDescription': 'SLANG FOR ZERO',
#     'words': ['JACK', 'LOVE', 'SQUAT', 'ZIP']},
#    {'answerDescription': 'ACCESSORIES FOR MR. PEANUT',
#     'words': ['CANE', 'MONOCLE', 'SPAT', 'TOP HAT']}],
#   'difficulty': 3.3},
#  {'date': '2024/04/07',
#   'contest': 'NYT Connections 301 - April 7th, 2024',
#   'words': ['DUMP',
#    'MESS',
#    'PIGPEN',
#    'STY',
#    'FIRM',
#    'SOLID',
#    'SOUND',
#    'STABLE',
#    'CARAMEL',
#    'PEANUTS',
#    'POPCORN',
#    'PRIZE',
#    'CHARLEY',
#    'CRAZY',
#    'DARK',
#    'GIFT'],
#   'answers': [{'answerDescription': 'DISORDERLY PLACE',
#     'words': ['DUMP', 'MESS', 'PIGPEN', 'STY']},
#    {'answerDescription': 'STURDY',
#     'words': ['FIRM', 'SOLID', 'SOUND', 'STABLE']},
#    {'answerDescription': 'FOUND IN CRACKER JACKS',
#     'words': ['CARAMEL', 'PEANUTS', 'POPCORN', 'PRIZE']},
#    {'answerDescription': '___ HORSE',
#     'words': ['CHARLEY', 'CRAZY', 'DARK', 'GIFT']}],
#   'difficulty': 2.0},
#  {'date': '2024/04/06',
#   'contest': 'NYT Connections 300 - April 6th, 2024',
#   'words': ['DESIRE',
#    'DRIVE',
#    'RESOLVE',
#    'WILL',
#    'HAT',
#    'SHORTS',
#    'SUNGLASSES',
#    'TEE',
#    'ARRAY',
#    'BATTERY',
#    'SET',
#    'SERIES',
#    'FLY',
#    'POWER',
#    'RADISH',
#    'SHOE'],
#   'answers': [{'answerDescription': 'INTRINSIC MOTIVATORS',
#     'words': ['DESIRE', 'DRIVE', 'RESOLVE', 'WILL']},
#    {'answerDescription': 'SUMMER GEAR',
#     'words': ['HAT', 'SHORTS', 'SUNGLASSES', 'TEE']},
#    {'answerDescription': 'COLLECTION',
#     'words': ['ARRAY', 'BATTERY', 'SET', 'SERIES']},
#    {'answerDescription': 'HORSE___',
#     'words': ['FLY', 'POWER', 'RADISH', 'SHOE']}],
#   'difficulty': 2.5},
#  {'date': '2024/04/05',
#   'contest': 'NYT Connections 299 - April 5th, 2024',
#   'words': ['BED',
#    'CHAIR',
#    'COUCH',
#    'TABLE',
#    'BEAR',
#    'HARBOR',
#    'HOLD',
#    'MAINTAIN',
#    'BALANCED',
#    'DRY',
#    'FULL',
#    'SWEET',
#    'GOLDILOCKS',
#    'IRONIC',
#    'LEADERSHIP',
#    'TINDER'],
#   'answers': [{'answerDescription': 'PIECES OF FURNITURE',
#     'words': ['BED', 'CHAIR', 'COUCH', 'TABLE']},
#    {'answerDescription': 'CARRY, AS A FEELING',
#     'words': ['BEAR', 'HARBOR', 'HOLD', 'MAINTAIN']},
#    {'answerDescription': 'WINE TASTING DESCRIPTORS',
#     'words': ['BALANCED', 'DRY', 'FULL', 'SWEET']},
#    {'answerDescription': 'STARTING WITH METALS',
#     'words': ['GOLDILOCKS', 'IRONIC', 'LEADERSHIP', 'TINDER']}],
#   'difficulty': 3.2},
#  {'date': '2024/04/04',
#   'contest': 'NYT Connections 298 - April 4th, 2024',
#   'words': ['BOIL',
#    'FRY',
#    'POACH',
#    'SCRAMBLE',
#    'BUZZ',
#    'KICK',
#    'RUSH',
#    'THRILL',
#    'AXE',
#    'DART',
#    'HORSESHOE',
#    'RING',
#    'BODY',
#    'BUBBLE',
#    'GIFT',
#    'SHRINK'],
#   'answers': [{'answerDescription': 'WAYS TO PREPARE EGGS',
#     'words': ['BOIL', 'FRY', 'POACH', 'SCRAMBLE']},
#    {'answerDescription': 'EXHILARATION',
#     'words': ['BUZZ', 'KICK', 'RUSH', 'THRILL']},
#    {'answerDescription': 'THROWN IN TARGET GAMES',
#     'words': ['AXE', 'DART', 'HORSESHOE', 'RING']},
#    {'answerDescription': '___ WRAP',
#     'words': ['BODY', 'BUBBLE', 'GIFT', 'SHRINK']}],
#   'difficulty': 1.75},
#  {'date': '2024/04/03',
#   'contest': 'NYT Connections 297 - April 3rd, 2024',
#   'words': ['BENCHMARK',
#    'GAUGE',
#    'STANDARD',
#    'YARDSTICK',
#    'BET',
#    'CALL',
#    'CHECK',
#    'FOLD',
#    'COMBINATION',
#    'DRY',
#    'NORMAL',
#    'OILY',
#    'KENT',
#    'MARY',
#    'MASS',
#    'WASH'],
#   'answers': [{'answerDescription': 'BENCHMARK',
#     'words': ['BENCHMARK', 'GAUGE', 'STANDARD', 'YARDSTICK']},
#    {'answerDescription': 'POKER ACTIONS',
#     'words': ['BET', 'CALL', 'CHECK', 'FOLD']},
#    {'answerDescription': 'SKIN TYPES',
#     'words': ['COMBINATION', 'DRY', 'NORMAL', 'OILY']},
#    {'answerDescription': 'STARTS OF U.S. STATES',
#     'words': ['KENT', 'MARY', 'MASS', 'WASH']}],
#   'difficulty': 3.3},
#  {'date': '2024/04/02',
#   'contest': 'NYT Connections 296 - April 2nd, 2024',
#   'words': ['JAB',
#    'POKE',
#    'PROD',
#    'STICK',
#    'ADDER',
#    'BOA',
#    'MAMBA',
#    'MOCCASIN',
#    'BALL',
#    'PRINCE',
#    'PUMPKIN',
#    'SLIPPER',
#    'BOWTIE',
#    'ELBOW',
#    'TUBE',
#    'WHEEL'],
#   'answers': [{'answerDescription': 'THRUST',
#     'words': ['JAB', 'POKE', 'PROD', 'STICK']},
#    {'answerDescription': 'KINDS OF SNAKES',
#     'words': ['ADDER', 'BOA', 'MAMBA', 'MOCCASIN']},
#    {'answerDescription': 'SEEN IN “CINDERELLA”',
#     'words': ['BALL', 'PRINCE', 'PUMPKIN', 'SLIPPER']},
#    {'answerDescription': 'PASTA SHAPES',
#     'words': ['BOWTIE', 'ELBOW', 'TUBE', 'WHEEL']}],
#   'difficulty': 1.6},
#  {'date': '2024/04/01',
#   'contest': 'NYT Connections 295 - April 1st, 2024',
#   'words': ['🥓',
#    '🍞',
#    '🥬',
#    '🧀',
#    '🧠',
#    '✈️',
#    '🌧️',
#    '🚂',
#    '👽',
#    '🧛',
#    '🪚',
#    '😱',
#    '🐝',
#    '🐑',
#    '👁️',
#    '🫖'],
#   'answers': [{'answerDescription': 'FOOD SLANG FOR MONEY',
#     'words': ['🥓', '🍞', '🥬', '🧀']},
#    {'answerDescription': 'WORDS THAT RHYME', 'words': ['🧠', '✈️', '🌧️', '🚂']},
#    {'answerDescription': 'HORROR MOVIES', 'words': ['👽', '🧛', '🪚', '😱']},
#    {'answerDescription': 'LETTER HOMOPHONES', 'words': ['🐝', '🐑', '👁️', '🫖']}],
#   'difficulty': 3.3},
#  {'date': '2024/03/31',
#   'contest': 'NYT Connections 294 - March 31st, 2024',
#   'words': ['FALL',
#    'SLIP',
#    'SPILL',
#    'TRIP',
#    'MINERAL',
#    'SPRING',
#    'STILL',
#    'TAP',
#    'CORSET',
#    'DIABOLO',
#    'HOURGLASS',
#    'WASP',
#    'BOO-BOO',
#    'BROWN',
#    'HONEY',
#    'TEDDY'],
#   'answers': [{'answerDescription': 'TAKE A TUMBLE',
#     'words': ['FALL', 'SLIP', 'SPILL', 'TRIP']},
#    {'answerDescription': 'KINDS OF WATER',
#     'words': ['MINERAL', 'SPRING', 'STILL', 'TAP']},
#    {'answerDescription': 'THINGS THAT ARE CINCHED IN THE MIDDLE',
#     'words': ['CORSET', 'DIABOLO', 'HOURGLASS', 'WASP']},
#    {'answerDescription': '___ BEAR',
#     'words': ['BOO-BOO', 'BROWN', 'HONEY', 'TEDDY']}],
#   'difficulty': 3.4},
#  {'date': '2024/03/30',
#   'contest': 'NYT Connections 293 - March 30th, 2024',
#   'words': ['GASPS',
#    'HUFFS',
#    'PANTS',
#    'PUFFS',
#    'CANS',
#    'CURES',
#    'SALTS',
#    'SMOKES',
#    'BINDS',
#    'JAMS',
#    'PICKLES',
#    'SPOTS',
#    'KETTLES',
#    'MITTENS',
#    'RAINDROPS',
#    'WHISKERS'],
#   'answers': [{'answerDescription': 'BREATHES HEAVILY',
#     'words': ['GASPS', 'HUFFS', 'PANTS', 'PUFFS']},
#    {'answerDescription': 'PRESERVES, AS MEAT',
#     'words': ['CANS', 'CURES', 'SALTS', 'SMOKES']},
#    {'answerDescription': 'PREDICAMENTS',
#     'words': ['BINDS', 'JAMS', 'PICKLES', 'SPOTS']},
#    {'answerDescription': 'THINGS IN “MY FAVORITE THINGS”',
#     'words': ['KETTLES', 'MITTENS', 'RAINDROPS', 'WHISKERS']}],
#   'difficulty': 2.8},
#  {'date': '2024/03/29',
#   'contest': 'NYT Connections 292 - March 29th, 2024',
#   'words': ['MIGHTY',
#    'PRETTY',
#    'REALLY',
#    'VERY',
#    'DAISY',
#    'GOOFY',
#    'HAPPY',
#    'LADY',
#    'BABY',
#    'NAVY',
#    'SKY',
#    'TIFFANY',
#    'ARMY',
#    'COLONY',
#    'LIVERY',
#    'SHINY'],
#   'answers': [{'answerDescription': 'ESPECIALLY',
#     'words': ['MIGHTY', 'PRETTY', 'REALLY', 'VERY']},
#    {'answerDescription': 'DISNEY CHARACTERS',
#     'words': ['DAISY', 'GOOFY', 'HAPPY', 'LADY']},
#    {'answerDescription': 'KINDS OF BLUE',
#     'words': ['BABY', 'NAVY', 'SKY', 'TIFFANY']},
#    {'answerDescription': 'BODY PARTS PLUS "Y"',
#     'words': ['ARMY', 'COLONY', 'LIVERY', 'SHINY']}],
#   'difficulty': 2.3},
#  {'date': '2024/03/28',
#   'contest': 'NYT Connections 291 - March 28th, 2024',
#   'words': ['DEPARTED',
#    'LEFT',
#    'SPLIT',
#    'WENT',
#    'ACE',
#    'AVIATOR',
#    'FLIER',
#    'PILOT',
#    'BLUE',
#    'FIN',
#    'GRAY',
#    'RIGHT',
#    'ATM',
#    'CASINO',
#    'SCHEDULE',
#    'SPATULA'],
#   'answers': [{'answerDescription': 'EXITED',
#     'words': ['DEPARTED', 'LEFT', 'SPLIT', 'WENT']},
#    {'answerDescription': 'ONE FLYING AN AIRPLANE',
# ...
#   'words': ['EARN',
#    'LAND',
#    'SCORE',
#    'WIN',
#    'CROWD',
#    'FLOCK',
#    'HOST',
#    'SEA',
#    'ANCHOR',
#    'BOW',
#    'BRIDGE',
#    'DECK',
#    'EXPANSIVE',
#    'LIGHT',
#    'MASCULINE',
#    'YANG'],
#   'answers': [{'answerDescription': 'ATTAIN',
#     'words': ['EARN', 'LAND', 'SCORE', 'WIN']},
#    {'answerDescription': 'LARGE GROUP',
#     'words': ['CROWD', 'FLOCK', 'HOST', 'SEA']},
#    {'answerDescription': 'PARTS OF A SHIP',
#     'words': ['ANCHOR', 'BOW', 'BRIDGE', 'DECK']},
#    {'answerDescription': 'ASSOCIATED PRINCIPLES IN CHINESE PHILOSOPHY',
#     'words': ['EXPANSIVE', 'LIGHT', 'MASCULINE', 'YANG']}],
#   'difficulty': None},
#  {'date': '2024/11/26',
#   'contest': 'NYT Connections 534 - November 26th, 2024',
#   'words': ['BONUS',
#    'EQUITY',
#    'PROMOTION',
#    'RAISE',
#    'DISCOUNT',
#    'FORGET',
#    'IGNORE',
#    'OVERLOOK',
#    'ANIMAL',
#    'CLUB',
#    'GOLDFISH',
#    'RITZ',
#    'ELOISE',
#    'PLAZA',
#    'PUG',
#    'TURTLE'],
#   'answers': [{'answerDescription': 'GOOD THINGS TO GET AT WORK',
#     'words': ['BONUS', 'EQUITY', 'PROMOTION', 'RAISE']},
#    {'answerDescription': 'DISREGARD',
#     'words': ['DISCOUNT', 'FORGET', 'IGNORE', 'OVERLOOK']},
#    {'answerDescription': 'KINDS OF CRACKERS',
#     'words': ['ANIMAL', 'CLUB', 'GOLDFISH', 'RITZ']},
#    {'answerDescription': 'FEATURED IN “ELOISE”',
#     'words': ['ELOISE', 'PLAZA', 'PUG', 'TURTLE']}],
#   'difficulty': None},
#  {'date': '2024/11/27',
#   'contest': 'NYT Connections 535 - November 27th, 2024',
#   'words': ['BUGGY',
#    'ERRATIC',
#    'GLITCHY',
#    'SPOTTY',
#    'BUMPER',
#    'GRILLE',
#    'MIRROR',
#    'RIM',
#    'BABY',
#    'HOUSE',
#    'PET',
#    'PLANT',
#    'BOY',
#    'RUBBER',
#    'TRIBUTE',
#    'WEDDING'],
#   'answers': [{'answerDescription': 'NOT WORKING RELIABLY',
#     'words': ['BUGGY', 'ERRATIC', 'GLITCHY', 'SPOTTY']},
#    {'answerDescription': 'CAR PARTS',
#     'words': ['BUMPER', 'GRILLE', 'MIRROR', 'RIM']},
#    {'answerDescription': 'WHAT A SITTER MIGHT SIT',
#     'words': ['BABY', 'HOUSE', 'PET', 'PLANT']},
#    {'answerDescription': '___ BAND',
#     'words': ['BOY', 'RUBBER', 'TRIBUTE', 'WEDDING']}],
#   'difficulty': None},
#  {'date': '2024/11/28',
#   'contest': 'NYT Connections 536 - November 28th, 2024',
#   'words': ['CREDIT',
#    'PRAISE',
#    'RECOGNITION',
#    'THANKS',
#    'CHEAT',
#    'CON',
#    'FAKE',
#    'QUACK',
#    'BOLT',
#    'DOWN',
#    'GOBBLE',
#    'SCARF',
#    'FAT',
#    'GIVING',
#    'SUPER',
#    'TACO'],
#   'answers': [{'answerDescription': 'APPRECIATION',
#     'words': ['CREDIT', 'PRAISE', 'RECOGNITION', 'THANKS']},
#    {'answerDescription': 'FRAUDSTER',
#     'words': ['CHEAT', 'CON', 'FAKE', 'QUACK']},
#    {'answerDescription': 'EAT VORACIOUSLY',
#     'words': ['BOLT', 'DOWN', 'GOBBLE', 'SCARF']},
#    {'answerDescription': '___ TUESDAY',
#     'words': ['FAT', 'GIVING', 'SUPER', 'TACO']}],
#   'difficulty': None},
#  {'date': '2024/11/29',
#   'contest': 'NYT Connections 537 - November 29th, 2024',
#   'words': ['ENDEAVOR',
#    'ENTERPRISE',
#    'PROJECT',
#    'VENTURE',
#    'HERTZ',
#    'MOLE',
#    'SECOND',
#    'VOLT',
#    'NATIONAL',
#    'RAY',
#    'TIGER',
#    'TWIN',
#    'BOARDWALK',
#    'CURB',
#    'GAME',
#    'SILICON'],
#   'answers': [{'answerDescription': 'UNDERTAKING',
#     'words': ['ENDEAVOR', 'ENTERPRISE', 'PROJECT', 'VENTURE']},
#    {'answerDescription': 'UNITS',
#     'words': ['HERTZ', 'MOLE', 'SECOND', 'VOLT']},
#    {'answerDescription': 'M.L.B. TEAM MEMBER',
#     'words': ['NATIONAL', 'RAY', 'TIGER', 'TWIN']},
#    {'answerDescription': 'FIRST WORDS OF HBO SHOWS',
#     'words': ['BOARDWALK', 'CURB', 'GAME', 'SILICON']}],
#   'difficulty': None},
#  {'date': '2024/11/30',
#   'contest': 'NYT Connections 538 - November 30th, 2024',
#   'words': ['JAZZ',
#    'MODERN',
#    'SWING',
#    'TAP',
#    'LIFT',
#    'PALM',
#    'POCKET',
#    'SWIPE',
#    'ACE',
#    'CRUSH',
#    'NAIL',
#    'ROCK',
#    'CURVE',
#    'FAST',
#    'KNUCKLE',
#    'SCREW'],
#   'answers': [{'answerDescription': 'DANCE STYLES',
#     'words': ['JAZZ', 'MODERN', 'SWING', 'TAP']},
#    {'answerDescription': 'STEAL',
#     'words': ['LIFT', 'PALM', 'POCKET', 'SWIPE']},
#    {'answerDescription': 'PERFORM WELL ON',
#     'words': ['ACE', 'CRUSH', 'NAIL', 'ROCK']},
#    {'answerDescription': '___BALL PITCHES',
#     'words': ['CURVE', 'FAST', 'KNUCKLE', 'SCREW']}],
#   'difficulty': None},
#  {'date': '2024/12/01',
#   'contest': 'NYT Connections 539 - December 1st, 2024',
#   'words': ['HAVEN',
#    'PORT',
#    'RETREAT',
#    'SHELTER',
#    'CLEATS',
#    'HELMET',
#    'JERSEY',
#    'PADS',
#    'CHARMS',
#    'KINDER',
#    'WONKA',
#    'YORK',
#    'BIRD',
#    'FALLIN’',
#    'SOLO',
#    'WILLY'],
#   'answers': [{'answerDescription': 'SANCTUARY',
#     'words': ['HAVEN', 'PORT', 'RETREAT', 'SHELTER']},
#    {'answerDescription': 'FOOTBALL GEAR',
#     'words': ['CLEATS', 'HELMET', 'JERSEY', 'PADS']},
#    {'answerDescription': 'CANDY NAMES',
#     'words': ['CHARMS', 'KINDER', 'WONKA', 'YORK']},
#    {'answerDescription': '“FREE ___”',
#     'words': ['BIRD', 'FALLIN’', 'SOLO', 'WILLY']}],
#   'difficulty': None},
#  {'date': '2024/12/02',
#   'contest': 'NYT Connections 540 - December 2nd, 2024',
#   'words': ['BROADCAST',
#    'DECLARE',
#    'HERALD',
#    'TRUMPET',
#    'CARPENTRY',
#    'CROQUET',
#    'WHAC-A-MOLE',
#    'XYLOPHONE',
#    'CROCODILE',
#    'LAUREL',
#    'POLO PLAYER',
#    'SWOOSH',
#    'ALLIGATOR',
#    'HAIR',
#    'PAPER',
#    'VIDEO'],
#   'answers': [{'answerDescription': 'ANNOUNCE',
#     'words': ['BROADCAST', 'DECLARE', 'HERALD', 'TRUMPET']},
#    {'answerDescription': 'THINGS INVOLVING MALLETS',
#     'words': ['CARPENTRY', 'CROQUET', 'WHAC-A-MOLE', 'XYLOPHONE']},
#    {'answerDescription': 'ICON EMBROIDERED ON A POLO SHIRT',
#     'words': ['CROCODILE', 'LAUREL', 'POLO PLAYER', 'SWOOSH']},
#    {'answerDescription': '___ CLIP',
#     'words': ['ALLIGATOR', 'HAIR', 'PAPER', 'VIDEO']}],
#   'difficulty': None},
#  {'date': '2024/12/03',
#   'contest': 'NYT Connections 541 - December 3rd, 2024',
#   'words': ['CARMELA',
#    'JUNIOR',
#    'MEADOW',
#    'TONY',
#    'CUZ',
#    'GRAMMY',
#    'MUMMY',
#    'POP',
#    'COOKIE',
#    'COUNT',
#    'OSCAR',
#    'SNUFFY',
#    'CECE',
#    'EDIE',
#    'EMMY',
#    'KATIE'],
#   'answers': [{'answerDescription': 'SOPRANOS',
#     'words': ['CARMELA', 'JUNIOR', 'MEADOW', 'TONY']},
#    {'answerDescription': 'FAMILIAL NICKNAMES',
#     'words': ['CUZ', 'GRAMMY', 'MUMMY', 'POP']},
#    {'answerDescription': '“SESAME STREET” CHARACTERS',
#     'words': ['COOKIE', 'COUNT', 'OSCAR', 'SNUFFY']},
#    {'answerDescription': 'NAMES THAT SOUND LIKE TWO LETTERS',
#     'words': ['CECE', 'EDIE', 'EMMY', 'KATIE']}],
#   'difficulty': None},
#  {'date': '2024/12/04',
#   'contest': 'NYT Connections 542 - December 4th, 2024',
#   'words': ['DIRECT',
#    'GUIDE',
#    'LEAD',
#    'SHEPHERD',
#    'COMPASS',
#    'PINE TREE',
#    'SEWING KIT',
#    'TURNTABLE',
#    'ATLAS',
#    'ECHO',
#    'HELEN',
#    'PAN',
#    'CANDLE',
#    'LOOFAH',
#    'JOHNSON',
#    'TOILETRIES'],
#   'answers': [{'answerDescription': 'STEER',
#     'words': ['DIRECT', 'GUIDE', 'LEAD', 'SHEPHERD']},
#    {'answerDescription': 'THINGS WITH NEEDLE/S',
#     'words': ['COMPASS', 'PINE TREE', 'SEWING KIT', 'TURNTABLE']},
#    {'answerDescription': 'FIGURES IN GREEK MYTH',
#     'words': ['ATLAS', 'ECHO', 'HELEN', 'PAN']},
#    {'answerDescription': 'STARTING WITH SYNONYMS FOR LAVATORY',
#     'words': ['CANDLE', 'LOOFAH', 'JOHNSON', 'TOILETRIES']}],
#   'difficulty': None},
#  {'date': '2024/12/05',
#   'contest': 'NYT Connections 543 - December 5th, 2024',
#   'words': ['FLAIR',
#    'GIFT',
#    'INSTINCT',
#    'NOSE',
#    'FACE',
#    'FRONT',
#    'OUTSIDE',
#    'SURFACE',
#    'AMAZON',
#    'APPLE',
#    'INTUIT',
#    'ORACLE',
#    'BRIM',
#    'LIME',
#    'RHINE',
#    'YELLOW'],
#   'answers': [{'answerDescription': 'APTITUDE',
#     'words': ['FLAIR', 'GIFT', 'INSTINCT', 'NOSE']},
#    {'answerDescription': 'EXTERIOR',
#     'words': ['FACE', 'FRONT', 'OUTSIDE', 'SURFACE']},
#    {'answerDescription': 'TECH COMPANIES',
#     'words': ['AMAZON', 'APPLE', 'INTUIT', 'ORACLE']},
#    {'answerDescription': '___STONE',
#     'words': ['BRIM', 'LIME', 'RHINE', 'YELLOW']}],
#   'difficulty': None},
#  {'date': '2024/12/06',
#   'contest': 'NYT Connections 544 - December 6th, 2024',
#   'words': ['PERPLEX',
#    'PUZZLE',
#    'STUMP',
#    'VEX',
#    'HEX',
#    'JINX',
#    'POX',
#    'SPELL',
#    'BUZZ',
#    'HAMM',
#    'REX',
#    'SLINKY',
#    'CORE',
#    'GATE',
#    'MANIA',
#    'PILLED'],
#   'answers': [{'answerDescription': 'BAFFLE',
#     'words': ['PERPLEX', 'PUZZLE', 'STUMP', 'VEX']},
#    {'answerDescription': 'CURSE', 'words': ['HEX', 'JINX', 'POX', 'SPELL']},
#    {'answerDescription': '“TOY STORY” CHARACTERS, FAMILIARLY',
#     'words': ['BUZZ', 'HAMM', 'REX', 'SLINKY']},
#    {'answerDescription': 'COLLOQUIAL SUFFIXES',
#     'words': ['CORE', 'GATE', 'MANIA', 'PILLED']}],
#   'difficulty': None},
#  {'date': '2024/12/07',
#   'contest': 'NYT Connections 545 - December 7th, 2024',
#   'words': ['AFFILIATE',
#    'ASSOCIATE',
#    'EQUATE',
#    'RELATE',
#    'BAIT',
#    'CHUM',
#    'FLY',
#    'LURE',
#    'LIBERTY',
#    'STORM',
#    'SUN',
#    'WINGS',
#    'BOW',
#    'FELLOW',
#    'HORN',
#    'LEGS'],
#   'answers': [{'answerDescription': 'THINK OF TOGETHER',
#     'words': ['AFFILIATE', 'ASSOCIATE', 'EQUATE', 'RELATE']},
#    {'answerDescription': 'WAYS TO ATTRACT FISH',
#     'words': ['BAIT', 'CHUM', 'FLY', 'LURE']},
#    {'answerDescription': 'W.N.B.A. TEAMS',
#     'words': ['LIBERTY', 'STORM', 'SUN', 'WINGS']},
#    {'answerDescription': 'LONG___',
#     'words': ['BOW', 'FELLOW', 'HORN', 'LEGS']}],
#   'difficulty': None},
#  {'date': '2024/12/08',
#   'contest': 'NYT Connections 546 - December 8th, 2024',
#   'words': ['BELT',
#    'BLOW',
#    'SOCK',
#    'SLUG',
#    'SANDWICH',
#    'SHOEHORN',
#    'SQUEEZE',
#    'WEDGE',
#    'CATERPILLAR',
#    'DOVE',
#    'GREYHOUND',
#    'PUMA',
#    'INDY',
#    'METTLE',
#    'SEOUL',
#    'WRAP'],
#   'answers': [{'answerDescription': 'PUNCH',
#     'words': ['BELT', 'BLOW', 'SOCK', 'SLUG']},
#    {'answerDescription': 'CRAM',
#     'words': ['SANDWICH', 'SHOEHORN', 'SQUEEZE', 'WEDGE']},
#    {'answerDescription': 'COMPANIES NAMED AFTER ANIMALS',
#     'words': ['CATERPILLAR', 'DOVE', 'GREYHOUND', 'PUMA']},
#    {'answerDescription': 'HOMOPHONES OF MUSIC GENRES',
#     'words': ['INDY', 'METTLE', 'SEOUL', 'WRAP']}],
#   'difficulty': None},
#  {'date': '2024/12/09',
#   'contest': 'NYT Connections 547 - December 9th, 2024',
#   'words': ['CONSIDERATION',
#    'REFLECTION',
#    'SCRUTINY',
#    'THOUGHT',
#    'FLINT',
#    'LIGHTER',
#    'MAGNIFYING GLASS',
#    'MATCHES',
#    'MICROSCOPE',
#    'SLIDE',
#    'SPECIMEN',
#    'STAIN',
#    'FACTOR',
#    'FILES',
#    'GAMES',
#    'RAY'],
#   'answers': [{'answerDescription': 'DELIBERATION',
#     'words': ['CONSIDERATION', 'REFLECTION', 'SCRUTINY', 'THOUGHT']},
#    {'answerDescription': 'USED IN STARTING A FIRE',
#     'words': ['FLINT', 'LIGHTER', 'MAGNIFYING GLASS', 'MATCHES']},
#    {'answerDescription': 'USED TO VIEW A BIOLOGICAL SAMPLE',
#     'words': ['MICROSCOPE', 'SLIDE', 'SPECIMEN', 'STAIN']},
#    {'answerDescription': 'WORDS AFTER “X”',
#     'words': ['FACTOR', 'FILES', 'GAMES', 'RAY']}],
#   'difficulty': None},
#  {'date': '2024/12/10',
#   'contest': 'NYT Connections 548 - December 10th, 2024',
#   'words': ['CALL',
#    'DUB',
#    'LABEL',
#    'NAME',
#    'CRUISE',
#    'TAKEOFF',
#    'TAXI',
#    'TOUCHDOWN',
#    'FISH',
#    'FUMBLE',
#    'ROOT',
#    'RUMMAGE',
#    'INLAND',
#    'OLIVIA',
#    'RAN',
#    'WANDA'],
#   'answers': [{'answerDescription': 'GIVE A TITLE TO',
#     'words': ['CALL', 'DUB', 'LABEL', 'NAME']},
#    {'answerDescription': 'PARTS OF A FLIGHT',
#     'words': ['CRUISE', 'TAKEOFF', 'TAXI', 'TOUCHDOWN']},
#    {'answerDescription': 'FEEL AROUND (FOR)',
#     'words': ['FISH', 'FUMBLE', 'ROOT', 'RUMMAGE']},
#    {'answerDescription': 'COUNTRIES MINUS FIRST LETTER',
#     'words': ['INLAND', 'OLIVIA', 'RAN', 'WANDA']}],
#   'difficulty': None},
#  {'date': '2024/12/11',
#   'contest': 'NYT Connections 549 - December 11th, 2024',
#   'words': ['PARADISE',
#    'SEVENTH HEAVEN',
#    'SHANGRI-LA',
#    'XANADU',
#    'HAIRSPRAY',
#    'MAGIC 8 BALL',
#    'SALAD DRESSING',
#    'SNOWGLOBE',
#    'JAZZERCISE',
#    'PARALYMPICS',
#    'POKÉMON',
#    'WIKIPEDIA',
#    'KETCHUM',
#    'PAYPAL',
#    'PRIMATE',
#    'ROSEBUD'],
#   'answers': [{'answerDescription': 'UTOPIA',
#     'words': ['PARADISE', 'SEVENTH HEAVEN', 'SHANGRI-LA', 'XANADU']},
#    {'answerDescription': 'THINGS YOU SHAKE',
#     'words': ['HAIRSPRAY', 'MAGIC 8 BALL', 'SALAD DRESSING', 'SNOWGLOBE']},
#    {'answerDescription': 'PROPER NOUN PORTMANTEAUX',
#     'words': ['JAZZERCISE', 'PARALYMPICS', 'POKÉMON', 'WIKIPEDIA']},
#    {'answerDescription': 'ENDING IN SYNONYMS FOR “FRIEND”',
#     'words': ['KETCHUM', 'PAYPAL', 'PRIMATE', 'ROSEBUD']}],
#   'difficulty': None},
#  {'date': '2024/12/12',
#   'contest': 'NYT Connections 550 - December 12th, 2024',
#   'words': ['TEA',
#    'TEE (GOLF)',
#    'TEE (SHIRT)',
#    'TI (MUSICAL NOTE)',
#    'COMB',
#    'GEAR',
#    'SAW',
#    'ZIPPER',
#    'FUDGE',
#    'GEEZ',
#    'NUTS',
#    'RATS',
#    'BANK',
#    'BED',
#    'DELTA',
#    'MOUTH'],
#   'answers': [{'answerDescription': 'THINGS THAT SOUND LIKE "T"',
#     'words': ['TEA', 'TEE (GOLF)', 'TEE (SHIRT)', 'TI (MUSICAL NOTE)']},
#    {'answerDescription': 'OBJECTS WITH TEETH',
#     'words': ['COMB', 'GEAR', 'SAW', 'ZIPPER']},
#    {'answerDescription': 'MILD OATHS',
#     'words': ['FUDGE', 'GEEZ', 'NUTS', 'RATS']},
#    {'answerDescription': 'PARTS OF A RIVER',
#     'words': ['BANK', 'BED', 'DELTA', 'MOUTH']}],
#   'difficulty': None},
#  {'date': '2024/12/13',
#   'contest': 'NYT Connections 551 - December 13th, 2024',
#   'words': ['DRAGON',
#    'GIANT',
#    'PIXIE',
#    'TROLL',
#    'DRAFTS',
#    'SENT',
#    'SPAM',
#    'TRASH',
#    'CRUSH',
#    'SPRITE',
#    'SQUIRT',
#    'STARRY',
#    'BORE',
#    'LINKS',
#    'PHISH',
#    'TOWED'],
#   'answers': [{'answerDescription': 'FANTASY CREATURES',
#     'words': ['DRAGON', 'GIANT', 'PIXIE', 'TROLL']},
#    {'answerDescription': 'EMAIL FOLDERS',
#     'words': ['DRAFTS', 'SENT', 'SPAM', 'TRASH']},
#    {'answerDescription': 'CITRUS SODAS',
#     'words': ['CRUSH', 'SPRITE', 'SQUIRT', 'STARRY']},
#    {'answerDescription': 'ANIMAL HOMOPHONES',
#     'words': ['BORE', 'LINKS', 'PHISH', 'TOWED']}],
#   'difficulty': None},
#  {'date': '2024/12/14',
#   'contest': 'NYT Connections 552 - December 14th, 2024',
#   'words': ['FLUKE',
#    'MULLET',
#    'SOLE',
#    'TANG',
#    'GOING',
#    'ONCE',
#    'SOLD',
#    'TWICE',
#    'POUND',
#    'REAL',
#    'SOL',
#    'YUAN',
#    'BUTTER',
#    'DIVA',
#    'SOLO',
#    'WORLD'],
#   'answers': [{'answerDescription': 'FISH',
#     'words': ['FLUKE', 'MULLET', 'SOLE', 'TANG']},
#    {'answerDescription': 'WORDS IN AN AUCTION-ENDING PHRASE',
#     'words': ['GOING', 'ONCE', 'SOLD', 'TWICE']},
#    {'answerDescription': 'GLOBAL CURRENCIES',
#     'words': ['POUND', 'REAL', 'SOL', 'YUAN']},
#    {'answerDescription': 'WORDS BEFORE “CUP”',
#     'words': ['BUTTER', 'DIVA', 'SOLO', 'WORLD']}],
#   'difficulty': None},
#  {'date': '2024/12/15',
#   'contest': 'NYT Connections 553 - December 15th, 2024',
#   'words': ['CLOVE',
#    'MACE',
#    'NUTMEG',
#    'PEPPER',
#    'FLAIL',
#    'FLOP',
#    'FLOUNDER',
#    'TANK',
#    'FLIP',
#    'LEAF',
#    'RIFFLE',
#    'THUMB',
#    'KEY',
#    'MAR',
#    'SPEAR',
#    'STYLE'],
#   'answers': [{'answerDescription': 'SPICES',
#     'words': ['CLOVE', 'MACE', 'NUTMEG', 'PEPPER']},
#    {'answerDescription': 'PERFORM POORLY',
#     'words': ['FLAIL', 'FLOP', 'FLOUNDER', 'TANK']},
#    {'answerDescription': 'SKIM THROUGH, AS PAGES',
#     'words': ['FLIP', 'LEAF', 'RIFFLE', 'THUMB']},
#    {'answerDescription': 'POP SINGERS MINUS “S”',
#     'words': ['KEY', 'MAR', 'SPEAR', 'STYLE']}],
#   'difficulty': None},
#  {'date': '2024/12/16',
#   'contest': 'NYT Connections 554 - December 16th, 2024',
#   'words': ['AM',
#    'HAM',
#    'SATELLITE',
#    'WALKIE-TALKIE',
#    'FOOD',
#    'PILLOW',
#    'SNOWBALL',
#    'WATER BALLOON',
#    'DEVIL DOG',
#    'DING DONG',
#    'HOHO',
#    'YODEL',
#    'BAR',
#    'CHICKEN',
#    'KNOCK-KNOCK',
#    'LIGHT BULB'],
#   'answers': [{'answerDescription': 'TYPES OF RADIO',
#     'words': ['AM', 'HAM', 'SATELLITE', 'WALKIE-TALKIE']},
#    {'answerDescription': 'KINDS OF PLAY FIGHTS',
#     'words': ['FOOD', 'PILLOW', 'SNOWBALL', 'WATER BALLOON']},
#    {'answerDescription': 'SNACK CAKES',
#     'words': ['DEVIL DOG', 'DING DONG', 'HOHO', 'YODEL']},
#    {'answerDescription': 'CLASSIC JOKE STAPLES',
#     'words': ['BAR', 'CHICKEN', 'KNOCK-KNOCK', 'LIGHT BULB']}],
#   'difficulty': None}]
