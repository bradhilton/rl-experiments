# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %%html
# <style>
# .cell-output-ipywidget-background {
#     background-color: transparent !important;
# }
# :root {
#     --jp-widgets-color: var(--vscode-editor-foreground);
#     --jp-widgets-font-size: var(--vscode-editor-font-size);
# }
# </style>
# Out:
# <style>
# .cell-output-ipywidget-background {
#     background-color: transparent !important;
# }
# :root {
#     --jp-widgets-color: var(--vscode-editor-foreground);
#     --jp-widgets-font-size: var(--vscode-editor-font-size);
# }
# </style>

# %%
import asyncio
from lib.tasks import ChatCompletionParams, get_task_results
from lib.temporal_clue import get_temporal_clue_tasks
from lib.vllm import start_vllm, kill_vllm_workers
import random
import torch

tasks = list(get_temporal_clue_tasks())
val_tasks = tasks[:64]
test_tasks = tasks[64:128]
train_tasks = tasks[128:]
random.seed(42)
random.shuffle(train_tasks)
len(val_tasks), len(test_tasks), len(train_tasks)
# Out:
# (64, 64, 2860)

# %%
expected_tokens = 1000
model = "./models/044/0098"

# %%
vllm = await start_vllm(
    model,
    max_concurrent_requests=4096,
    env={"VLLM_ALLOW_LONG_MAX_MODEL_LEN": "1"},
    named_arguments=dict(
        block_size=32,
        disable_log_requests=True,
        enable_prefix_caching=True,
        enforce_eager=True,
        gpu_memory_utilization=0.95,
        max_model_len=16384,
        max_num_seqs=4096,
        max_num_batched_tokens=16384,
        num_scheduler_steps=16,
        preemption_mode="swap",
        return_tokens_as_token_ids=True,
        swap_space=80,
        tensor_parallel_size=torch.cuda.device_count(),
    ),
    timeout=360 + 15 * torch.cuda.device_count(),
)
# Out:
# $ vllm serve /home/gcpuser/sky_workdir/experiments/models/044/0098 --block-size=32 --disable-log-requests --enable-prefix-caching --enforce-eager --gpu-memory-utilization=0.95 --max-model-len=16384 --max-num-seqs=4096 --max-num-batched-tokens=16384 --num-scheduler-steps=16 --preemption-mode=swap --return-tokens-as-token-ids --swap-space=80 --tensor-parallel-size=2 --served-model-name=./models/044/0098 --port=8001 --api-key=default
# INFO 03-05 19:12:52 __init__.py:190] Automatically detected platform cuda.
# INFO 03-05 19:12:53 api_server.py:840] vLLM API server version 0.7.2
# INFO 03-05 19:12:53 api_server.py:841] args: Namespace(subparser='serve', model_tag='/home/gcpuser/sky_workdir/experiments/models/044/0098', config='', host=None, port=8001, uvicorn_log_level='info', allow_credentials=False, allowed_origins=['*'], allowed_methods=['*'], allowed_headers=['*'], api_key='default', lora_modules=None, prompt_adapters=None, chat_template=None, chat_template_content_format='auto', response_role='assistant', ssl_keyfile=None, ssl_certfile=None, ssl_ca_certs=None, ssl_cert_reqs=0, root_path=None, middleware=[], return_tokens_as_token_ids=True, disable_frontend_multiprocessing=False, enable_request_id_headers=False, enable_auto_tool_choice=False, enable_reasoning=False, reasoning_parser=None, tool_call_parser=None, tool_parser_plugin='', model='/home/gcpuser/sky_workdir/experiments/models/044/0098', task='auto', tokenizer=None, skip_tokenizer_init=False, revision=None, code_revision=None, tokenizer_revision=None, tokenizer_mode='auto', trust_remote_code=False, allowed_local_media_path=None, download_dir=None, load_format='auto', config_format=<ConfigFormat.AUTO: 'auto'>, dtype='auto', kv_cache_dtype='auto', max_model_len=16384, guided_decoding_backend='xgrammar', logits_processor_pattern=None, model_impl='auto', distributed_executor_backend=None, pipeline_parallel_size=1, tensor_parallel_size=2, max_parallel_loading_workers=None, ray_workers_use_nsight=False, block_size=32, enable_prefix_caching=True, disable_sliding_window=False, use_v2_block_manager=True, num_lookahead_slots=0, seed=0, swap_space=80.0, cpu_offload_gb=0, gpu_memory_utilization=0.95, num_gpu_blocks_override=None, max_num_batched_tokens=16384, max_num_seqs=4096, max_logprobs=20, disable_log_stats=False, quantization=None, rope_scaling=None, rope_theta=None, hf_overrides=None, enforce_eager=True, max_seq_len_to_capture=8192, disable_custom_all_reduce=False, tokenizer_pool_size=0, tokenizer_pool_type='ray', tokenizer_pool_extra_config=None, limit_mm_per_prompt=None, mm_processor_kwargs=None, disable_mm_preprocessor_cache=False, enable_lora=False, enable_lora_bias=False, max_loras=1, max_lora_rank=16, lora_extra_vocab_size=256, lora_dtype='auto', long_lora_scaling_factors=None, max_cpu_loras=None, fully_sharded_loras=False, enable_prompt_adapter=False, max_prompt_adapters=1, max_prompt_adapter_token=0, device='auto', num_scheduler_steps=16, multi_step_stream_outputs=True, scheduler_delay_factor=0.0, enable_chunked_prefill=None, speculative_model=None, speculative_model_quantization=None, num_speculative_tokens=None, speculative_disable_mqa_scorer=False, speculative_draft_tensor_parallel_size=None, speculative_max_model_len=None, speculative_disable_by_batch_size=None, ngram_prompt_lookup_max=None, ngram_prompt_lookup_min=None, spec_decoding_acceptance_method='rejection_sampler', typical_acceptance_sampler_posterior_threshold=None, typical_acceptance_sampler_posterior_alpha=None, disable_logprobs_during_spec_decoding=None, model_loader_extra_config=None, ignore_patterns=[], preemption_mode='swap', served_model_name=['./models/044/0098'], qlora_adapter_name_or_path=None, otlp_traces_endpoint=None, collect_detailed_traces=None, disable_async_output_proc=False, scheduling_policy='fcfs', override_neuron_config=None, override_pooler_config=None, compilation_config=None, kv_transfer_config=None, worker_cls='auto', generation_config=None, override_generation_config=None, enable_sleep_mode=False, calculate_kv_scales=False, disable_log_requests=True, max_log_len=None, disable_fastapi_docs=False, enable_prompt_tokens_details=False, dispatch_function=<function serve at 0x7542cbdd6fc0>)
# INFO 03-05 19:12:53 api_server.py:206] Started engine process with PID 27772
# INFO 03-05 19:12:56 __init__.py:190] Automatically detected platform cuda.
# INFO 03-05 19:12:58 config.py:542] This model supports multiple tasks: {'score', 'reward', 'generate', 'embed', 'classify'}. Defaulting to 'generate'.
# INFO 03-05 19:12:58 config.py:1401] Defaulting to use mp for distributed inference
# WARNING 03-05 19:12:58 cuda.py:95] To see benefits of async output processing, enable CUDA graph. Since, enforce-eager is enabled, async output processor cannot be used
# WARNING 03-05 19:12:58 config.py:678] Async output processing is not supported on the current platform type cuda.
# INFO 03-05 19:13:03 config.py:542] This model supports multiple tasks: {'embed', 'generate', 'reward', 'classify', 'score'}. Defaulting to 'generate'.
# INFO 03-05 19:13:03 config.py:1401] Defaulting to use mp for distributed inference
# WARNING 03-05 19:13:03 cuda.py:95] To see benefits of async output processing, enable CUDA graph. Since, enforce-eager is enabled, async output processor cannot be used
# WARNING 03-05 19:13:03 config.py:678] Async output processing is not supported on the current platform type cuda.
# INFO 03-05 19:13:03 llm_engine.py:234] Initializing a V0 LLM engine (v0.7.2) with config: model='/home/gcpuser/sky_workdir/experiments/models/044/0098', speculative_config=None, tokenizer='/home/gcpuser/sky_workdir/experiments/models/044/0098', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=16384, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=2, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=True, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='xgrammar'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=./models/044/0098, num_scheduler_steps=16, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=False, use_async_output_proc=False, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"splitting_ops":[],"compile_sizes":[],"cudagraph_capture_sizes":[],"max_capture_size":0}, use_cached_outputs=True,
# WARNING 03-05 19:13:03 multiproc_worker_utils.py:300] Reducing Torch parallelism from 26 threads to 1 to avoid unnecessary CPU contention. Set OMP_NUM_THREADS in the external environment to tune this value as needed.
# INFO 03-05 19:13:03 custom_cache_manager.py:19] Setting Triton cache manager to: vllm.triton_utils.custom_cache_manager:CustomCacheManager
# INFO 03-05 19:13:04 cuda.py:230] Using Flash Attention backend.
# WARNING 03-05 19:13:04 registry.py:340] `mm_limits` has already been set for model=/home/gcpuser/sky_workdir/experiments/models/044/0098, and will be overwritten by the new values.
# INFO 03-05 19:13:07 __init__.py:190] Automatically detected platform cuda.
# (VllmWorkerProcess pid=28161) INFO 03-05 19:13:08 multiproc_worker_utils.py:229] Worker ready; awaiting tasks
# (VllmWorkerProcess pid=28161) INFO 03-05 19:13:08 cuda.py:230] Using Flash Attention backend.
# (VllmWorkerProcess pid=28161) WARNING 03-05 19:13:08 registry.py:340] `mm_limits` has already been set for model=/home/gcpuser/sky_workdir/experiments/models/044/0098, and will be overwritten by the new values.
# (VllmWorkerProcess pid=28161) INFO 03-05 19:13:09 utils.py:950] Found nccl from library libnccl.so.2
# INFO 03-05 19:13:09 utils.py:950] Found nccl from library libnccl.so.2
# (VllmWorkerProcess pid=28161) INFO 03-05 19:13:09 pynccl.py:69] vLLM is using nccl==2.21.5
# INFO 03-05 19:13:09 pynccl.py:69] vLLM is using nccl==2.21.5
# (VllmWorkerProcess pid=28161) INFO 03-05 19:13:10 custom_all_reduce_utils.py:244] reading GPU P2P access cache from /home/gcpuser/.cache/vllm/gpu_p2p_access_cache_for_0,1.json
# INFO 03-05 19:13:10 custom_all_reduce_utils.py:244] reading GPU P2P access cache from /home/gcpuser/.cache/vllm/gpu_p2p_access_cache_for_0,1.json
# INFO 03-05 19:13:10 shm_broadcast.py:258] vLLM message queue communication handle: Handle(connect_ip='127.0.0.1', local_reader_ranks=[1], buffer_handle=(1, 4194304, 6, 'psm_b3d46cb4'), local_subscribe_port=59547, remote_subscribe_port=None)
# INFO 03-05 19:13:10 model_runner.py:1110] Starting to load model /home/gcpuser/sky_workdir/experiments/models/044/0098...
# (VllmWorkerProcess pid=28161) INFO 03-05 19:13:10 model_runner.py:1110] Starting to load model /home/gcpuser/sky_workdir/experiments/models/044/0098...
# Loading safetensors checkpoint shards:   0% Completed | 0/8 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards:  12% Completed | 1/8 [00:00<00:04,  1.54it/s]
# Loading safetensors checkpoint shards:  25% Completed | 2/8 [00:01<00:03,  1.58it/s]
# Loading safetensors checkpoint shards:  38% Completed | 3/8 [00:01<00:03,  1.59it/s]
# Loading safetensors checkpoint shards:  50% Completed | 4/8 [00:02<00:01,  2.19it/s]
# Loading safetensors checkpoint shards:  62% Completed | 5/8 [00:02<00:01,  2.16it/s]
# Loading safetensors checkpoint shards:  75% Completed | 6/8 [00:03<00:01,  1.95it/s]
# Loading safetensors checkpoint shards:  88% Completed | 7/8 [00:03<00:00,  1.81it/s]
# Loading safetensors checkpoint shards: 100% Completed | 8/8 [00:04<00:00,  1.75it/s]
# Loading safetensors checkpoint shards: 100% Completed | 8/8 [00:04<00:00,  1.81it/s]
# INFO 03-05 19:13:15 model_runner.py:1115] Loading model weights took 13.9281 GB
# (VllmWorkerProcess pid=28161) INFO 03-05 19:13:15 model_runner.py:1115] Loading model weights took 13.9281 GB
# (VllmWorkerProcess pid=28161) INFO 03-05 19:13:18 worker.py:267] Memory profiling takes 2.74 seconds
# (VllmWorkerProcess pid=28161) INFO 03-05 19:13:18 worker.py:267] the current vLLM instance can use total_gpu_memory (79.11GiB) x gpu_memory_utilization (0.95) = 75.15GiB
# (VllmWorkerProcess pid=28161) INFO 03-05 19:13:18 worker.py:267] model weights take 13.93GiB; non_torch_memory takes 1.57GiB; PyTorch activation peak memory takes 1.45GiB; the rest of the memory reserved for KV Cache is 58.21GiB.
# INFO 03-05 19:13:18 worker.py:267] Memory profiling takes 2.88 seconds
# INFO 03-05 19:13:18 worker.py:267] the current vLLM instance can use total_gpu_memory (79.11GiB) x gpu_memory_utilization (0.95) = 75.15GiB
# INFO 03-05 19:13:18 worker.py:267] model weights take 13.93GiB; non_torch_memory takes 1.82GiB; PyTorch activation peak memory takes 22.23GiB; the rest of the memory reserved for KV Cache is 37.17GiB.
# INFO 03-05 19:13:18 executor_base.py:110] # CUDA blocks: 12688, # CPU blocks: 27306
# INFO 03-05 19:13:18 executor_base.py:115] Maximum concurrency for 16384 tokens per request: 24.78x
# INFO 03-05 19:14:05 llm_engine.py:431] init engine (profile, create kv cache, warmup model) took 49.67 seconds
# INFO 03-05 19:14:05 api_server.py:756] Using supplied chat template:
# INFO 03-05 19:14:05 api_server.py:756] None
# INFO 03-05 19:14:05 launcher.py:21] Available routes are:
# INFO 03-05 19:14:05 launcher.py:29] Route: /openapi.json, Methods: HEAD, GET
# INFO 03-05 19:14:05 launcher.py:29] Route: /docs, Methods: HEAD, GET
# INFO 03-05 19:14:05 launcher.py:29] Route: /docs/oauth2-redirect, Methods: HEAD, GET
# INFO 03-05 19:14:05 launcher.py:29] Route: /redoc, Methods: HEAD, GET
# INFO 03-05 19:14:05 launcher.py:29] Route: /health, Methods: GET
# INFO 03-05 19:14:05 launcher.py:29] Route: /ping, Methods: POST, GET
# INFO 03-05 19:14:05 launcher.py:29] Route: /tokenize, Methods: POST
# INFO 03-05 19:14:05 launcher.py:29] Route: /detokenize, Methods: POST
# INFO 03-05 19:14:05 launcher.py:29] Route: /v1/models, Methods: GET
# INFO 03-05 19:14:05 launcher.py:29] Route: /version, Methods: GET
# INFO 03-05 19:14:05 launcher.py:29] Route: /v1/chat/completions, Methods: POST
# INFO 03-05 19:14:05 launcher.py:29] Route: /v1/completions, Methods: POST
# INFO 03-05 19:14:05 launcher.py:29] Route: /v1/embeddings, Methods: POST
# INFO 03-05 19:14:05 launcher.py:29] Route: /pooling, Methods: POST
# INFO 03-05 19:14:05 launcher.py:29] Route: /score, Methods: POST
# INFO 03-05 19:14:05 launcher.py:29] Route: /v1/score, Methods: POST
# INFO 03-05 19:14:05 launcher.py:29] Route: /rerank, Methods: POST
# INFO 03-05 19:14:05 launcher.py:29] Route: /v1/rerank, Methods: POST
# INFO 03-05 19:14:05 launcher.py:29] Route: /v2/rerank, Methods: POST
# INFO 03-05 19:14:05 launcher.py:29] Route: /invocations, Methods: POST
# INFO:     Started server process [27656]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8001 (Press CTRL+C to quit)
# INFO 03-05 19:14:06 chat_utils.py:332] Detected the chat template content format to be 'string'. You can set `--chat-template-content-format` to override this.
# INFO:     127.0.0.1:40084 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# vLLM server started succesfully. Logs can be found at ./logs/vllm.log

# %%
semaphore = asyncio.Semaphore(int(0.9 * vllm.max_concurrent_tokens / expected_tokens))
val_results = await get_task_results(
    tasks=val_tasks,
    client=vllm.client,
    model=vllm.model,
    cache=False,
    log_results=8,
    n=16,
    params=ChatCompletionParams(
        stream_options={
            "include_usage": True,
        }
    ),
    pbar_desc="val",
    semaphore=semaphore,
)
# Out:
# val:   0%|          | 0/1024 [00:00<?, ?it/s]
# val: 100%|██████████| 1024/1024 [06:56<00:00, 27.35s/it, completion_tokens=1363, prompt_tokens=1220, reward=0.594, acc=0.594, token_logprobs=1.4e+6]

# %%
from lib.tasks import TaskResult
from openai.types.chat.chat_completion import ChatCompletion


def get_likelihood(completion: ChatCompletion):
    logprobs = [
        token_logprob.logprob
        for token_logprob in completion.choices[0].logprobs.content
    ]
    return sum(logprobs)


def get_reward(result: TaskResult, completion: ChatCompletion):
    return result.rewards[(completion.id, 0)]


sum(
    get_reward(result, max(result.chat_completions, key=get_likelihood))
    for result in val_results
) / 64
# Out:
# 0.5946428571428571

# %%
sum(get_reward(result, chat_completion) for result in val_results for chat_completion in result.chat_completions) / 64 / 16
# Out:
# 0.5936918712797619

# %%
from lib.temporal_clue import get_temporal_clue_puzzles, TemporalCluePuzzle

puzzles = get_temporal_clue_puzzles()[:64]
puzzles
# Out:
# [{'num_clues': 72,
#   'prompt': 'On a dark winter night, wealthy and enigmatic Mr. John Q. Boddy hosted a small, but lavish, dinner party for some of his closest associates. However, the night ended in tragedy when Mr. Boddy was found dead in one of the rooms of Tudor Mansion in the early hours of the morning. The following persons of interest have been identified as suspects:\n\n• Miss Peach\n• Monsieur Brunette\n• Mr. Green\n• Professor Plum\n• Mrs. White\n• Colonel Mustard\n• Miss Scarlet\n• Mrs. Peacock\n• Sgt. Gray\n• Madame Rose\n\nAnd the following weapons were found on the premises:\n\n• Candlestick\n• Wrench\n• Lead Pipe\n• Revolver\n• Poison\n• Knife\n• Rope\n• Horseshoe\n\nThe murder could only have occured in one of the following rooms:\n\n01. Studio\n02. Gazebo\n03. Lounge\n04. Drawing Room\n05. Library\n06. Trophy Room\n07. Cloak Room\n08. Courtyard\n09. Kitchen\n10. Fountain\n11. Dining Room\n12. Carriage House\n13. Ballroom\n\nThe rooms are laid out as follows:\n\n  NN NN NN NN  \nW 01|02|03|04 E\nW 05|06|07|08 E\nW 09|10|11|12 E\nW 13|-|-|- E\n  SS SS SS SS  \n\nThe exact time of the murder is a bit uncertain, but it has been narrowed down to one of the following times:\n\n• 08:00 PM\n• 09:00 PM\n• 10:00 PM\n• 11:00 PM\n• 12:00 AM\n• 01:00 AM\n• 02:00 AM\n• 03:00 AM\n\nAt every time the suspects and Mr. Boddy either stayed in their current room or moved to an orthogonally adjacent room (north, south, east, or west). Weapons could be moved by suspects between rooms as well.\n\nEach suspect uniquely had one of the following possible motives for killing Mr. Boddy:\n\n• Jealousy\n• Ambition\n• Power\n• Betrayal\n• Anger\n• Fear\n• Greed\n• Hatred\n• Revenge\n• Pride\n\nFor the murder to occur, the murderer and Mr. Boddy must have been alone in a room with at least one weapon at some point in the night. Any clue about Mr. Boddy\'s whereabouts should be read as "Mr. Boddy (dead or alive) ..."\n\nThe available clues are as follows:\n\n- The murderer was in the Library at 12:00 AM\n- Mr. Green was at the Fountain at 12:00 AM\n- The Wrench was in the same room as Mr. Boddy at 10:00 PM\n- Mr. Boddy was in the Kitchen at 09:00 PM if and only if the suspect motivated by Fear was at the Fountain at 11:00 PM\n- Mr. Green was in the Trophy Room at 03:00 AM if and only if Mr. Boddy was in the Kitchen at 08:00 PM\n- Miss Scarlet was in the Library at 02:00 AM if and only if Mr. Green was in the Ballroom at 08:00 PM\n- Miss Scarlet was in the Ballroom at 08:00 PM if and only if Mr. Green was in the Trophy Room at 03:00 AM\n- Mrs. White moved from the Kitchen to the Library at 03:00 AM\n- Professor Plum and Madame Rose were in the Carriage House together at least once\n- The suspect motivated by Power moved the Poison from the Carriage House to the Courtyard at 11:00 PM\n- The suspect motivated by Hatred was in the Ballroom at 11:00 PM or the suspect motivated by Betrayal was in the Studio at 09:00 PM\n- Professor Plum was in the same room as Colonel Mustard at 08:00 PM\n- The suspect motivated by Pride was in the Trophy Room at 12:00 AM or the Horseshoe was in the Studio at 09:00 PM\n- Miss Scarlet was in the room just south of the Horseshoe at 12:00 AM\n- The Lead Pipe and Professor Plum were in the Courtyard together at least once\n- Mr. Boddy was murdered at 11:00 PM\n- The suspect motivated by Jealousy moved the Rope from the Trophy Room to the Library at 11:00 PM\n- Miss Scarlet was in the same room as Mrs. White at 08:00 PM\n- The murder weapon was in the same room as Miss Peach at 03:00 AM\n- The suspect motivated by Betrayal moved the Wrench from the Library to the Trophy Room at 03:00 AM\n- The suspect motivated by Ambition moved from the Lounge to the Gazebo at 11:00 PM\n- The suspect motivated by Anger moved from the Courtyard to the Cloak Room at 10:00 PM\n- The suspect motivated by Ambition moved from the Lounge to the Cloak Room at 03:00 AM\n- The suspect motivated by Greed was in the Kitchen at 01:00 AM\n- The Rope was in the room j ...
#   'solution': {'A': 'Monsieur Brunette',
#    'B': 'Horseshoe',
#    'C': 'Library',
#    'D': 'Jealousy',
#    'E': 'Courtyard',
#    'F': 'Drawing Room',
#    'G': 'Drawing Room',
#    'H': 'Fountain'}},
#  {'num_clues': 19,
#   'prompt': 'On a dark winter night, wealthy and enigmatic Mr. John Q. Boddy hosted a small, but lavish, dinner party for some of his closest associates. However, the night ended in tragedy when Mr. Boddy was found dead in one of the rooms of Tudor Mansion in the early hours of the morning. The following persons of interest have been identified as suspects:\n\n• Miss Scarlet\n• Sgt. Gray\n• Mrs. White\n• Mrs. Peacock\n• Mr. Green\n\nAnd the following weapons were found on the premises:\n\n• Rope\n• Knife\n• Lead Pipe\n• Poison\n\nThe murder could only have occured in one of the following rooms:\n\n1. Gazebo\n2. Ballroom\n3. Courtyard\n4. Hall\n5. Library\n6. Lounge\n\nThe rooms are laid out as follows:\n\n  N N N  \nW 1|2|3 E\nW 4|5|6 E\n  S S S  \n\nThe exact time of the murder is a bit uncertain, but it has been narrowed down to one of the following times:\n\n• 11:00 PM\n• 12:00 AM\n• 01:00 AM\n\nAt every time the suspects and Mr. Boddy either stayed in their current room or moved to an orthogonally adjacent room (north, south, east, or west). Weapons could be moved by suspects between rooms as well.\n\nEach suspect uniquely had one of the following possible motives for killing Mr. Boddy:\n\n• Jealousy\n• Betrayal\n• Ambition\n• Power\n• Fear\n\nFor the murder to occur, the murderer and Mr. Boddy must have been alone in a room with at least one weapon at some point in the night. Any clue about Mr. Boddy\'s whereabouts should be read as "Mr. Boddy (dead or alive) ..."\n\nThe available clues are as follows:\n\n- The suspect motivated by Power was in the Hall at 12:00 AM if and only if Sgt. Gray was in the Hall at 01:00 AM\n- Mrs. Peacock moved from the Hall to the Library at 12:00 AM\n- Miss Scarlet was in the same room as Sgt. Gray at 01:00 AM\n- Miss Scarlet was in the Hall at 11:00 PM\n- Mrs. White moved the murder weapon from the Library to the Ballroom at 01:00 AM\n- The Poison was in the room just east of the Lead Pipe at 12:00 AM\n- Mrs. White is motivated by Fear\n- Miss Scarlet was in the Hall at 12:00 AM if and only if the murderer was in the Hall at 01:00 AM\n- Mrs. White was in the Lounge at 11:00 PM\n- Miss Scarlet was in the room just west of Mr. Boddy at 12:00 AM\n- The Poison was in the Ballroom at 01:00 AM if and only if the murderer was in the Library at 11:00 PM\n- Mr. Green was in the room just west of the Knife at 01:00 AM\n- The suspect motivated by Ambition moved from the Gazebo to the Ballroom at 12:00 AM\n- The Rope and Mrs. Peacock were in the Ballroom together at least once\n- The murderer was in the Library at 12:00 AM or the suspect motivated by Ambition was in the Gazebo at 12:00 AM\n- The Rope was in the Library at 11:00 PM\n- The suspect motivated by Betrayal moved from the Library to the Ballroom at 01:00 AM\n- The Knife was in the Courtyard at 01:00 AM\n- Mr. Boddy was killed with the Poison\n\nPlease answer the following question(s):\n\nA. Who murdered Mr. Boddy?\nB. Where was the murder committed?\nC. When did the murder occur?\nD. Why did the murderer do it?\n\nAnd the following bonus question(s):\n\nE. What motivates Sgt. Gray?\nF. Who is motivated by Betrayal?\nG. Where was the suspect motivated by Jealousy at 01:00 AM?\nH. Where was the suspect motivated by Ambition at 12:00 AM?\n\nFill out your final answers in the following format:\n\nA. SUSPECT\nB. ROOM\nC. TIME\nD. MOTIVE\nE. MOTIVE\nF. SUSPECT\nG. ROOM\nH. ROOM\n\nBest of luck, detective.',
#   'solution': {'A': 'Sgt. Gray',
#    'B': 'Library',
#    'C': '11:00 PM',
#    'D': 'Jealousy',
#    'E': 'Jealousy',
#    'F': 'Mrs. Peacock',
#    'G': 'Hall',
#    'H': 'Ballroom'}},
#  {'num_clues': 20,
#   'prompt': 'On a dark winter night, wealthy and enigmatic Mr. John Q. Boddy hosted a small, but lavish, dinner party for some of his closest associates. However, the night ended in tragedy when Mr. Boddy was found dead in one of the rooms of Tudor Mansion in the early hours of the morning. The following persons of interest have been identified as suspects:\n\n• Mrs. White\n• Colonel Mustard\n• Miss Scarlet\n• Madame Rose\n• Mrs. Peacock\n\nAnd the following weapons were found on the premises:\n\n• Poison\n• Horseshoe\n• Revolver\n• Knife\n\nThe murder could only have occured in one of the following rooms:\n\n1. Studio\n2. Carriage House\n3. Conservatory\n4. Drawing Room\n5. Cloak Room\n\nThe rooms are laid out as follows:\n\n  N N  \nW 1|2 E\nW 3|4 E\nW 5|- E\n  S S  \n\nThe exact time of the murder is a bit uncertain, but it has been narrowed down to one of the following times:\n\n• 11:00 PM\n• 11:30 PM\n• 12:00 AM\n\nAt every time the suspects and Mr. Boddy either stayed in their current room or moved to an orthogonally adjacent room (north, south, east, or west). Weapons could be moved by suspects between rooms as well.\n\nEach suspect had one of the following possible motives for killing Mr. Boddy:\n\n• Betrayal (2 suspects)\n• Power (3 suspects)\n\nFor the murder to occur, the murderer and Mr. Boddy must have been alone in a room with at least one weapon at some point in the night. Any clue about Mr. Boddy\'s whereabouts should be read as "Mr. Boddy (dead or alive) ..."\n\nThe available clues are as follows:\n\n- Mrs. Peacock is motivated by Betrayal\n- The Revolver was in the room just west of Colonel Mustard at 12:00 AM\n- Mrs. White moved from the Carriage House to the Drawing Room at 11:30 PM\n- The Knife was in the same room as Madame Rose at 12:00 AM\n- Madame Rose moved from the Carriage House to the Drawing Room at 12:00 AM\n- A suspect motivated by Power was in the same room as the Horseshoe at 11:30 PM\n- The murder weapon was in the Studio at 11:00 PM or Mrs. Peacock was in the Carriage House at 11:00 PM\n- The Revolver was in the room just south of Mr. Boddy at 11:30 PM\n- Madame Rose was in the Carriage House at 11:00 PM\n- Mrs. White was in the Drawing Room at 12:00 AM\n- The Poison was in the room just north of the Revolver at 11:00 PM\n- The Knife was in the Conservatory at 11:00 PM or Colonel Mustard was in the Drawing Room at 11:30 PM\n- A suspect motivated by Betrayal moved from the Conservatory to the Drawing Room at 12:00 AM\n- The Horseshoe and Mrs. Peacock were in the Drawing Room together at least once\n- The Revolver was in the room just south of Mrs. Peacock at 12:00 AM\n- The murderer moved from the Drawing Room to the Conservatory at 11:30 PM\n- Mr. Boddy was in the Studio at 11:00 PM\n- A suspect motivated by Betrayal moved from the Cloak Room to the Conservatory at 11:30 PM\n- The Horseshoe was in the Studio at 12:00 AM or Colonel Mustard was in the Drawing Room at 11:00 PM\n- The Knife was in the same room as Madame Rose at 11:30 PM\n\nPlease answer the following question(s):\n\nA. Who murdered Mr. Boddy?\nB. What weapon did the murderer use?\nC. Where was the murder committed?\nD. When did the murder occur?\nE. Why did the murderer do it?\n\nAnd the following bonus question(s):\n\nF. Where was Madame Rose at 12:00 AM?\nG. Where was the Poison at 11:30 PM?\n\nFill out your final answers in the following format:\n\nA. SUSPECT\nB. WEAPON\nC. ROOM\nD. TIME\nE. MOTIVE\nF. ROOM\nG. ROOM\n\nBest of luck, detective.',
#   'solution': {'A': 'Mrs. Peacock',
#    'B': 'Poison',
#    'C': 'Studio',
#    'D': '12:00 AM',
#    'E': 'Betrayal',
#    'F': 'Drawing Room',
#    'G': 'Studio'}},
#  {'num_clues': 66,
#   'prompt': 'On a dark winter night, wealthy and enigmatic Mr. John Q. Boddy hosted a small, but lavish, dinner party for some of his closest associates. However, the night ended in tragedy when Mr. Boddy was found dead in one of the rooms of Tudor Mansion in the early hours of the morning. The following persons of interest have been identified as suspects:\n\n• Sgt. Gray\n• Madame Rose\n• Colonel Mustard\n• Mrs. Peacock\n• Mr. Green\n• Professor Plum\n• Miss Peach\n• Monsieur Brunette\n• Miss Scarlet\n• Mrs. White\n\nAnd the following weapons were found on the premises:\n\n• Candlestick\n• Horseshoe\n• Poison\n• Wrench\n• Revolver\n• Lead Pipe\n• Knife\n• Rope\n\nThe murder could only have occured in one of the following rooms:\n\n01. Studio\n02. Billiard Room\n03. Dining Room\n04. Cloak Room\n05. Drawing Room\n06. Courtyard\n07. Ballroom\n08. Kitchen\n09. Library\n10. Gazebo\n11. Trophy Room\n\nThe rooms are laid out as follows:\n\n  NN NN NN NN  \nW 01|02|03|04 E\nW 05|06|07|08 E\nW 09|10|11|- E\n  SS SS SS SS  \n\nThe exact time of the murder is a bit uncertain, but it has been narrowed down to one of the following times:\n\n• 10:00 PM\n• 10:30 PM\n• 11:00 PM\n• 11:30 PM\n• 12:00 AM\n• 12:30 AM\n• 01:00 AM\n\nAt every time the suspects and Mr. Boddy either stayed in their current room or moved to an orthogonally adjacent room (north, south, east, or west). Weapons could be moved by suspects between rooms as well.\n\nEach suspect uniquely had one of the following possible motives for killing Mr. Boddy:\n\n• Greed\n• Anger\n• Fear\n• Hatred\n• Power\n• Ambition\n• Jealousy\n• Betrayal\n• Revenge\n• Pride\n\nFor the murder to occur, the murderer and Mr. Boddy must have been alone in a room with at least one weapon at some point in the night. Any clue about Mr. Boddy\'s whereabouts should be read as "Mr. Boddy (dead or alive) ..."\n\nThe available clues are as follows:\n\n- The Candlestick was in the same room as the Horseshoe at 10:30 PM\n- The suspect motivated by Pride was in the Kitchen at 12:00 AM or the murder weapon was in the Gazebo at 11:30 PM\n- Monsieur Brunette was in the room just north of Colonel Mustard at 11:30 PM\n- Madame Rose moved the murder weapon from the Drawing Room to the Courtyard at 01:00 AM\n- Professor Plum was in the Studio at 10:30 PM if and only if the Candlestick was in the Billiard Room at 01:00 AM\n- The Revolver was in the same room as Monsieur Brunette at 10:00 PM\n- Monsieur Brunette was in the same room as Mr. Boddy at 12:30 AM\n- Mrs. White was in the room just west of Miss Peach at 10:00 PM\n- The suspect motivated by Anger moved from the Dining Room to the Cloak Room at 10:30 PM\n- The suspect motivated by Pride moved from the Ballroom to the Kitchen at 11:30 PM\n- The suspect motivated by Revenge moved the Lead Pipe from the Drawing Room to the Library at 01:00 AM\n- Sgt. Gray was in the same room as the Horseshoe at 10:00 PM\n- Mrs. White was in the Gazebo at 12:30 AM if and only if the suspect motivated by Jealousy was in the Cloak Room at 10:00 PM\n- Colonel Mustard moved the Poison from the Drawing Room to the Library at 01:00 AM\n- Mr. Boddy was in the same room as Colonel Mustard at 10:00 PM\n- Miss Scarlet moved from the Cloak Room to the Kitchen at 11:30 PM\n- The suspect motivated by Jealousy moved the Knife from the Cloak Room to the Dining Room at 12:00 AM\n- The suspect motivated by Revenge moved from the Library to the Drawing Room at 12:30 AM\n- Mr. Green was in the same room as Miss Scarlet at 10:30 PM\n- Professor Plum and the Rope were in the Studio together at least once\n- The suspect motivated by Fear was in the Cloak Room at 01:00 AM\n- Mrs. Peacock was in the Cloak Room at 12:00 AM\n- Monsieur Brunette was in the same room as Sgt. Gray at 01:00 AM\n- Madame Rose and Sgt. Gray were in the Drawing Room together at least once\n- The Wrench was in the same room as Mrs. White at 10:30 PM\n- The suspect motivated by Pride moved from the Cloak Room to the Kitchen at 01: ...
#   'solution': {'A': 'Monsieur Brunette',
#    'B': 'Revolver',
#    'C': 'Library',
#    'D': '10:30 PM',
#    'E': 'Betrayal',
#    'F': 'Gazebo',
#    'G': 'Library',
#    'H': 'Drawing Room'}},
#  {'num_clues': 5,
#   'prompt': 'On a dark winter night, wealthy and enigmatic Mr. John Q. Boddy hosted a small, but lavish, dinner party for some of his closest associates. However, the night ended in tragedy when Mr. Boddy was found dead in one of the rooms of Tudor Mansion in the early hours of the morning. The following persons of interest have been identified as suspects:\n\n• Monsieur Brunette\n• Mr. Green\n\nAnd the following weapons were found on the premises:\n\n• Lead Pipe\n• Rope\n\nThe murder could only have occured in one of the following rooms:\n\n1. Study\n2. Lounge\n\nThe rooms are laid out as follows:\n\n  N N  \nW 1|2 E\n  S S  \n\nThe exact time of the murder is a bit uncertain, but it has been narrowed down to one of the following times:\n\n• 11:45 PM\n• 12:00 AM\n\nAt every time the suspects and Mr. Boddy either stayed in their current room or moved to an orthogonally adjacent room (north, south, east, or west). Weapons could be moved by suspects between rooms as well.\n\nFor the murder to occur, the murderer and Mr. Boddy must have been alone in a room with at least one weapon at some point in the night. Any clue about Mr. Boddy\'s whereabouts should be read as "Mr. Boddy (dead or alive) ..."\n\nThe available clues are as follows:\n\n- The Lead Pipe was in the Study at 12:00 AM if and only if the murderer was in the Lounge at 12:00 AM\n- The Rope was in the room just west of Mr. Green at 11:45 PM\n- Mr. Boddy was killed with the Rope\n- The Rope was in the room just west of Mr. Green at 12:00 AM\n- The Lead Pipe was in the room just west of Mr. Green at 12:00 AM\n\nPlease answer the following question(s):\n\nA. Who murdered Mr. Boddy?\nB. Where was the murder committed?\nC. When did the murder occur?\n\nAnd the following bonus question(s):\n\nD. Where was Monsieur Brunette at 11:45 PM?\n\nFill out your final answers in the following format:\n\nA. SUSPECT\nB. ROOM\nC. TIME\nD. ROOM\n\nBest of luck, detective.',
#   'solution': {'A': 'Monsieur Brunette',
#    'B': 'Study',
#    'C': '11:45 PM',
#    'D': 'Study'}},
#  {'num_clues': 41,
#   'prompt': 'On a dark winter night, wealthy and enigmatic Mr. John Q. Boddy hosted a small, but lavish, dinner party for some of his closest associates. However, the night ended in tragedy when Mr. Boddy was found dead in one of the rooms of Tudor Mansion in the early hours of the morning. The following persons of interest have been identified as suspects:\n\n• Colonel Mustard\n• Mrs. White\n• Mrs. Peacock\n• Madame Rose\n• Miss Scarlet\n• Monsieur Brunette\n• Miss Peach\n\nAnd the following weapons were found on the premises:\n\n• Poison\n• Horseshoe\n• Knife\n• Lead Pipe\n• Candlestick\n• Wrench\n\nThe murder could only have occured in one of the following rooms:\n\n1. Cloak Room\n2. Conservatory\n3. Billiard Room\n4. Ballroom\n5. Drawing Room\n6. Dining Room\n7. Trophy Room\n8. Gazebo\n9. Kitchen\n\nThe rooms are laid out as follows:\n\n  N N N  \nW 1|2|3 E\nW 4|5|6 E\nW 7|8|9 E\n  S S S  \n\nThe exact time of the murder is a bit uncertain, but it has been narrowed down to one of the following times:\n\n• 10:00 PM\n• 10:30 PM\n• 11:00 PM\n• 11:30 PM\n• 12:00 AM\n• 12:30 AM\n\nAt every time the suspects and Mr. Boddy either stayed in their current room or moved to an orthogonally adjacent room (north, south, east, or west). Weapons could be moved by suspects between rooms as well.\n\nEach suspect uniquely had one of the following possible motives for killing Mr. Boddy:\n\n• Hatred\n• Ambition\n• Betrayal\n• Pride\n• Anger\n• Power\n• Greed\n\nFor the murder to occur, the murderer and Mr. Boddy must have been alone in a room with at least one weapon at some point in the night. Any clue about Mr. Boddy\'s whereabouts should be read as "Mr. Boddy (dead or alive) ..."\n\nThe available clues are as follows:\n\n- The Horseshoe was in the Gazebo at 10:00 PM\n- The suspect motivated by Anger moved from the Kitchen to the Gazebo at 12:00 AM\n- Mrs. White moved from the Conservatory to the Billiard Room at 10:30 PM\n- Monsieur Brunette was in the room just south of the Wrench at 10:00 PM\n- The suspect motivated by Anger moved from the Dining Room to the Kitchen at 11:00 PM\n- Mrs. White was in the room just north of the Lead Pipe at 12:00 AM\n- The suspect motivated by Greed moved the Poison from the Conservatory to the Cloak Room at 11:30 PM\n- The Lead Pipe was in the room just south of Monsieur Brunette at 10:30 PM\n- The suspect motivated by Power was in the same room as the Knife at 11:00 PM\n- The Candlestick and Colonel Mustard were in the Billiard Room together at least once\n- Mr. Boddy was in the room just west of the Horseshoe at 11:00 PM\n- The suspect motivated by Pride moved the Poison from the Billiard Room to the Conservatory at 11:00 PM\n- The suspect motivated by Greed moved the Knife from the Cloak Room to the Conservatory at 12:30 AM\n- Mrs. Peacock was in the Trophy Room at 10:00 PM\n- The Wrench was in the Ballroom at 10:30 PM or the Candlestick was in the Cloak Room at 10:00 PM\n- Monsieur Brunette was in the same room as Mr. Boddy at 12:30 AM\n- Miss Scarlet and Colonel Mustard were in the Gazebo together at least once\n- The Candlestick was in the room just east of Madame Rose at 10:30 PM\n- The suspect motivated by Ambition and Mr. Boddy were in the Gazebo together at least once\n- Miss Scarlet was in the Gazebo at 11:30 PM if and only if Mrs. White was in the Conservatory at 11:00 PM\n- Madame Rose moved the Wrench from the Cloak Room to the Conservatory at 12:30 AM\n- The suspect motivated by Hatred was in the same room as the Lead Pipe at 12:00 AM\n- Miss Scarlet was in the Gazebo at 12:00 AM if and only if Miss Peach was in the Trophy Room at 12:00 AM\n- The murderer was in the same room as the Lead Pipe at 11:00 PM\n- Miss Scarlet was in the Gazebo at 11:00 PM\n- Miss Peach was in the Trophy Room at 12:30 AM\n- Miss Scarlet was in the same room as Miss Peach at 10:30 PM\n- The murder weapon and Miss Scarlet were in the Trophy Room together at least once\n- Miss Peach moved the Horseshoe from the Gazebo ...
#   'solution': {'A': 'Mrs. Peacock',
#    'B': 'Lead Pipe',
#    'C': 'Trophy Room',
#    'D': '10:30 PM',
#    'E': 'Hatred',
#    'F': 'Dining Room',
#    'G': 'Drawing Room',
#    'H': 'Trophy Room'}},
#  {'num_clues': 54,
#   'prompt': 'On a dark winter night, wealthy and enigmatic Mr. John Q. Boddy hosted a small, but lavish, dinner party for some of his closest associates. However, the night ended in tragedy when Mr. Boddy was found dead in one of the rooms of Tudor Mansion in the early hours of the morning. The following persons of interest have been identified as suspects:\n\n• Colonel Mustard\n• Miss Peach\n• Professor Plum\n• Mrs. Peacock\n• Monsieur Brunette\n• Miss Scarlet\n• Sgt. Gray\n\nAnd the following weapons were found on the premises:\n\n• Lead Pipe\n• Revolver\n• Knife\n• Poison\n• Candlestick\n• Horseshoe\n\nThe murder could only have occured in one of the following rooms:\n\n01. Dining Room\n02. Lounge\n03. Drawing Room\n04. Carriage House\n05. Ballroom\n06. Gazebo\n07. Study\n08. Library\n09. Hall\n10. Courtyard\n11. Trophy Room\n\nThe rooms are laid out as follows:\n\n  NN NN NN  \nW 01|02|03 E\nW 04|05|06 E\nW 07|08|09 E\nW 10|11|- E\n  SS SS SS  \n\nThe exact time of the murder is a bit uncertain, but it has been narrowed down to one of the following times:\n\n• 11:00 PM\n• 11:30 PM\n• 12:00 AM\n• 12:30 AM\n• 01:00 AM\n• 01:30 AM\n• 02:00 AM\n• 02:30 AM\n• 03:00 AM\n\nAt every time the suspects and Mr. Boddy either stayed in their current room or moved to an orthogonally adjacent room (north, south, east, or west). Weapons could be moved by suspects between rooms as well.\n\nEach suspect had one of the following possible motives for killing Mr. Boddy:\n\n• Hatred (1 suspect)\n• Ambition (2 suspects)\n• Jealousy (2 suspects)\n• Fear (2 suspects)\n\nFor the murder to occur, the murderer and Mr. Boddy must have been alone in a room with at least one weapon at some point in the night. Any clue about Mr. Boddy\'s whereabouts should be read as "Mr. Boddy (dead or alive) ..."\n\nThe available clues are as follows:\n\n- The murder weapon was in the Carriage House at 03:00 AM or the Horseshoe was in the Library at 12:00 AM\n- A suspect motivated by Ambition was in the Library at 03:00 AM\n- Colonel Mustard was in the room just west of the Horseshoe at 01:30 AM\n- A suspect motivated by Fear was in the Carriage House at 12:00 AM\n- Colonel Mustard moved the Lead Pipe from the Study to the Library at 03:00 AM\n- The murderer was in the Drawing Room at 12:30 AM if and only if Mr. Boddy was in the Drawing Room at 11:00 PM\n- The Knife was in the Dining Room at 12:00 AM or Monsieur Brunette was in the Dining Room at 01:30 AM\n- Colonel Mustard was in the Carriage House at 11:30 PM\n- The Lead Pipe was in the Carriage House at 11:00 PM if and only if the Knife was in the Library at 02:30 AM\n- Miss Peach was in the room just south of the Poison at 11:30 PM\n- A suspect motivated by Fear was in the Carriage House at 11:00 PM\n- Sgt. Gray was in the Carriage House at 03:00 AM\n- Sgt. Gray was in the Dining Room at 11:00 PM\n- The murder weapon and Mr. Boddy were in the Drawing Room together at least once\n- Mr. Boddy was murdered at 11:00 PM\n- Miss Peach moved the Lead Pipe from the Study to the Library at 01:30 AM\n- A suspect motivated by Fear moved the Horseshoe from the Study to the Library at 03:00 AM\n- The murder weapon was in the Trophy Room at 02:00 AM or a suspect motivated by Jealousy was in the Gazebo at 11:00 PM\n- The Lead Pipe was in the same room as Colonel Mustard at 02:00 AM\n- A suspect motivated by Fear moved the Lead Pipe from the Carriage House to the Study at 01:00 AM\n- Sgt. Gray moved the Candlestick from the Carriage House to the Dining Room at 01:30 AM\n- Mr. Boddy was in the room just north of Miss Scarlet at 03:00 AM\n- Sgt. Gray moved from the Dining Room to the Carriage House at 02:30 AM\n- A suspect motivated by Jealousy was in the Carriage House at 12:30 AM\n- The Knife was in the room just south of Mrs. Peacock at 02:00 AM\n- A suspect motivated by Jealousy moved from the Gazebo to the Hall at 03:00 AM\n- The Horseshoe was in the room just west of Miss Scarlet at 11:00 PM\n- Sgt. Gray moved the Candlestick  ...
#   'solution': {'A': 'Mrs. Peacock',
#    'B': 'Revolver',
#    'C': 'Drawing Room',
#    'D': 'Fear',
#    'E': 'Drawing Room',
#    'F': 'Library',
#    'G': 'Lounge',
#    'H': 'Study'}},
#  {'num_clues': 48,
#   'prompt': 'On a dark winter night, wealthy and enigmatic Mr. John Q. Boddy hosted a small, but lavish, dinner party for some of his closest associates. However, the night ended in tragedy when Mr. Boddy was found dead in one of the rooms of Tudor Mansion in the early hours of the morning. The following persons of interest have been identified as suspects:\n\n• Monsieur Brunette\n• Mr. Green\n• Madame Rose\n• Mrs. Peacock\n• Colonel Mustard\n• Sgt. Gray\n• Miss Scarlet\n• Professor Plum\n• Mrs. White\n• Miss Peach\n\nAnd the following weapons were found on the premises:\n\n• Horseshoe\n• Rope\n• Lead Pipe\n• Wrench\n• Knife\n• Revolver\n• Candlestick\n• Poison\n\nThe murder could only have occured in one of the following rooms:\n\n01. Library\n02. Conservatory\n03. Drawing Room\n04. Study\n05. Lounge\n06. Kitchen\n07. Fountain\n08. Dining Room\n09. Cloak Room\n10. Ballroom\n11. Trophy Room\n12. Gazebo\n13. Billiard Room\n14. Carriage House\n\nThe rooms are laid out as follows:\n\n  NN NN NN NN  \nW 01|02|03|04 E\nW 05|06|07|08 E\nW 09|10|11|12 E\nW 13|14|-|- E\n  SS SS SS SS  \n\nThe exact time of the murder is a bit uncertain, but it has been narrowed down to one of the following times:\n\n• 10:00 PM\n• 11:00 PM\n• 12:00 AM\n• 01:00 AM\n\nAt every time the suspects and Mr. Boddy either stayed in their current room or moved to an orthogonally adjacent room (north, south, east, or west). Weapons could be moved by suspects between rooms as well.\n\nEach suspect had one of the following possible motives for killing Mr. Boddy:\n\n• Power (1 suspect)\n• Ambition (3 suspects)\n• Revenge (1 suspect)\n• Greed (4 suspects)\n• Pride (1 suspect)\n\nFor the murder to occur, the murderer and Mr. Boddy must have been alone in a room with at least one weapon at some point in the night. Any clue about Mr. Boddy\'s whereabouts should be read as "Mr. Boddy (dead or alive) ..."\n\nThe available clues are as follows:\n\n- Mr. Boddy was in the same room as the Knife at 10:00 PM\n- A suspect motivated by Greed moved the Candlestick from the Fountain to the Dining Room at 12:00 AM\n- The murderer was in the same room as the Revolver at 11:00 PM\n- Miss Peach was in the room just north of the Poison at 12:00 AM\n- Miss Peach was in the room just east of the Revolver at 01:00 AM\n- A suspect motivated by Ambition was in the Gazebo at 10:00 PM or Monsieur Brunette was in the Carriage House at 12:00 AM\n- Mrs. White was at the Fountain at 10:00 PM if and only if the suspect motivated by Revenge was in the Drawing Room at 10:00 PM\n- Mrs. Peacock was in the Carriage House at 11:00 PM\n- The Candlestick was at the Fountain at 10:00 PM\n- Miss Scarlet was in the Library at 01:00 AM\n- Mr. Green was in the Carriage House at 10:00 PM\n- The suspect motivated by Power was in the same room as the Poison at 01:00 AM\n- Miss Peach was in the same room as the Wrench at 01:00 AM\n- The suspect motivated by Pride was in the Cloak Room at 01:00 AM if and only if the Wrench was at the Fountain at 10:00 PM\n- A suspect motivated by Ambition was in the Carriage House at 12:00 AM\n- Monsieur Brunette was in the room just east of the Poison at 11:00 PM\n- The Horseshoe was in the room just north of Mrs. White at 11:00 PM\n- The Rope was in the same room as Mrs. White at 10:00 PM\n- The Candlestick and Colonel Mustard were in the Study together at least once\n- A suspect motivated by Greed moved from the Dining Room to the Fountain at 11:00 PM\n- Mr. Boddy and Miss Peach were at the Fountain together at least once\n- A suspect motivated by Ambition was in the Conservatory at 11:00 PM\n- Professor Plum was in the Cloak Room at 01:00 AM if and only if the Wrench was at the Fountain at 01:00 AM\n- Colonel Mustard was at the Fountain at 10:00 PM\n- Mrs. Peacock was in the Carriage House at 10:00 PM\n- Professor Plum was in the same room as Mr. Green at 12:00 AM\n- Mrs. White was in the same room as Monsieur Brunette at 12:00 AM\n- Colonel Mustard moved the Rope from the Dini ...
#   'solution': {'A': 'Madame Rose',
#    'B': 'Knife',
#    'C': 'Kitchen',
#    'D': '01:00 AM',
#    'E': 'Revenge',
#    'F': 'Fountain',
#    'G': 'Carriage House',
#    'H': 'Conservatory'}},
#  {'num_clues': 20,
#   'prompt': 'On a dark winter night, wealthy and enigmatic Mr. John Q. Boddy hosted a small, but lavish, dinner party for some of his closest associates. However, the night ended in tragedy when Mr. Boddy was found dead in one of the rooms of Tudor Mansion in the early hours of the morning. The following persons of interest have been identified as suspects:\n\n• Colonel Mustard\n• Miss Scarlet\n• Sgt. Gray\n• Monsieur Brunette\n• Mr. Green\n• Professor Plum\n• Mrs. White\n• Miss Peach\n• Madame Rose\n\nAnd the following weapons were found on the premises:\n\n• Rope\n• Knife\n• Lead Pipe\n• Poison\n• Revolver\n\nThe murder could only have occured in one of the following rooms:\n\n01. Carriage House\n02. Fountain\n03. Cloak Room\n04. Study\n05. Kitchen\n06. Courtyard\n07. Billiard Room\n08. Dining Room\n09. Conservatory\n10. Library\n11. Studio\n12. Lounge\n\nThe rooms are laid out as follows:\n\n  NN NN NN  \nW 01|02|03 E\nW 04|05|06 E\nW 07|08|09 E\nW 10|11|12 E\n  SS SS SS  \n\nEach suspect uniquely had one of the following possible motives for killing Mr. Boddy:\n\n• Fear\n• Jealousy\n• Power\n• Anger\n• Betrayal\n• Ambition\n• Greed\n• Hatred\n• Revenge\n\nFor the murder to occur, the murderer and Mr. Boddy must have been alone in a room with at least one weapon.\n\nThe available clues are as follows:\n\n- Madame Rose was in the room just west of Mrs. White\n- The Knife was in the room just east of the Revolver\n- The Lead Pipe was in the same room as Miss Peach\n- Mrs. White is motivated by Power\n- Colonel Mustard is motivated by Hatred\n- The murder weapon was in the Library if and only if the suspect motivated by Betrayal was in the Study\n- Madame Rose is motivated by Greed\n- Miss Scarlet is motivated by Revenge\n- The Knife was in the room just west of Mrs. White\n- Mr. Green is motivated by Ambition\n- Sgt. Gray is motivated by Fear\n- The suspect motivated by Betrayal was in the Study or the Revolver was in the Conservatory\n- The suspect motivated by Betrayal was in the Library or Monsieur Brunette was in the Lounge\n- The suspect motivated by Revenge was in the Lounge or the suspect motivated by Anger was in the Lounge\n- Miss Scarlet was in the room just south of the Rope\n- Mr. Green was in the Dining Room\n- Miss Scarlet was in the Lounge or Mr. Green was in the Conservatory\n- Mrs. White was in the Cloak Room\n- Professor Plum was in the Conservatory\n- The suspect motivated by Hatred was at the Fountain\n\nPlease answer the following question(s):\n\nA. Who murdered Mr. Boddy?\nB. What weapon did the murderer use?\nC. Where was the murder committed?\nD. Why did the murderer do it?\n\nAnd the following bonus question(s):\n\nE. Where was the Revolver?\nF. Where was Madame Rose?\n\nFill out your final answers in the following format:\n\nA. SUSPECT\nB. WEAPON\nC. ROOM\nD. MOTIVE\nE. ROOM\nF. ROOM\n\nBest of luck, detective.',
#   'solution': {'A': 'Sgt. Gray',
#    'B': 'Poison',
#    'C': 'Library',
#    'D': 'Fear',
#    'E': 'Carriage House',
#    'F': 'Fountain'}},
#  {'num_clues': 18,
#   'prompt': 'On a dark winter night, wealthy and enigmatic Mr. John Q. Boddy hosted a small, but lavish, dinner party for some of his closest associates. However, the night ended in tragedy when Mr. Boddy was found dead in one of the rooms of Tudor Mansion in the early hours of the morning. The following persons of interest have been identified as suspects:\n\n• Colonel Mustard\n• Mrs. White\n• Sgt. Gray\n• Miss Peach\n• Madame Rose\n• Mr. Green\n• Professor Plum\n\nAnd the following weapons were found on the premises:\n\n• Rope\n• Horseshoe\n• Poison\n• Candlestick\n• Wrench\n• Revolver\n\nThe murder could only have occured in one of the following rooms:\n\n1. Kitchen\n2. Dining Room\n3. Ballroom\n4. Drawing Room\n5. Study\n6. Conservatory\n7. Carriage House\n8. Courtyard\n9. Lounge\n\nThe rooms are laid out as follows:\n\n  N N N  \nW 1|2|3 E\nW 4|5|6 E\nW 7|8|9 E\n  S S S  \n\nThe exact time of the murder is a bit uncertain, but it has been narrowed down to one of the following times:\n\n• 11:30 PM\n• 12:00 AM\n\nAt every time the suspects and Mr. Boddy either stayed in their current room or moved to an orthogonally adjacent room (north, south, east, or west). Weapons could be moved by suspects between rooms as well.\n\nEach suspect had one of the following possible motives for killing Mr. Boddy:\n\n• Power (1 suspect)\n• Anger (6 suspects)\n\nFor the murder to occur, the murderer and Mr. Boddy must have been alone in a room with at least one weapon at some point in the night. Any clue about Mr. Boddy\'s whereabouts should be read as "Mr. Boddy (dead or alive) ..."\n\nThe available clues are as follows:\n\n- Mr. Boddy was in the same room as Mr. Green at 11:30 PM\n- Colonel Mustard moved from the Kitchen to the Dining Room at 12:00 AM\n- A suspect motivated by Anger was in the Drawing Room at 12:00 AM\n- The Revolver was in the room just west of Miss Peach at 12:00 AM\n- The Horseshoe was in the Lounge at 11:30 PM\n- A suspect motivated by Anger was in the Conservatory at 11:30 PM\n- The Poison and the Wrench were in the Drawing Room together at least once\n- The Revolver was in the Study at 11:30 PM\n- Miss Peach and the Candlestick were in the Conservatory together at least once\n- Mr. Green moved from the Dining Room to the Ballroom at 12:00 AM\n- Sgt. Gray moved from the Drawing Room to the Study at 12:00 AM\n- The murderer was in the Study at 12:00 AM or the Poison was in the Study at 12:00 AM\n- Professor Plum was in the Ballroom at 11:30 PM if and only if Colonel Mustard was in the Dining Room at 12:00 AM\n- Professor Plum was in the same room as Mr. Green at 12:00 AM\n- The suspect motivated by Power moved from the Courtyard to the Carriage House at 12:00 AM\n- Madame Rose was in the Drawing Room at 11:30 PM or the Poison was in the Lounge at 11:30 PM\n- The Wrench was in the Drawing Room at 12:00 AM\n- The Rope was in the same room as the Poison at 12:00 AM\n\nPlease answer the following question(s):\n\nA. Who murdered Mr. Boddy?\nB. What weapon did the murderer use?\nC. Where was the murder committed?\nD. When did the murder occur?\nE. Why did the murderer do it?\n\nAnd the following bonus question(s):\n\nF. Where was the Wrench at 11:30 PM?\nG. What motivates Mrs. White?\nH. What motivates Colonel Mustard?\n\nFill out your final answers in the following format:\n\nA. SUSPECT\nB. WEAPON\nC. ROOM\nD. TIME\nE. MOTIVE\nF. ROOM\nG. MOTIVE\nH. MOTIVE\n\nBest of luck, detective.',
#   'solution': {'A': 'Sgt. Gray',
#    'B': 'Revolver',
#    'C': 'Study',
#    'D': '12:00 AM',
#    'E': 'Anger',
#    'F': 'Drawing Room',
#    'G': 'Power',
#    'H': 'Anger'}},
#  {'num_clues': 25,
#   'prompt': 'On a dark winter night, wealthy and enigmatic Mr. John Q. Boddy hosted a small, but lavish, dinner party for some of his closest associates. However, the night ended in tragedy when Mr. Boddy was found dead in one of the rooms of Tudor Mansion in the early hours of the morning. The following persons of interest have been identified as suspects:\n\n• Miss Peach\n• Mrs. White\n• Miss Scarlet\n• Colonel Mustard\n• Mrs. Peacock\n\nAnd the following weapons were found on the premises:\n\n• Revolver\n• Rope\n• Horseshoe\n• Wrench\n• Poison\n\nThe murder could only have occured in one of the following rooms:\n\n1. Library\n2. Drawing Room\n3. Studio\n4. Ballroom\n5. Dining Room\n6. Study\n7. Kitchen\n\nThe rooms are laid out as follows:\n\n  N N N  \nW 1|2|3 E\nW 4|5|6 E\nW 7|-|- E\n  S S S  \n\nThe exact time of the murder is a bit uncertain, but it has been narrowed down to one of the following times:\n\n• 11:00 PM\n• 11:30 PM\n• 12:00 AM\n• 12:30 AM\n• 01:00 AM\n\nAt every time the suspects and Mr. Boddy either stayed in their current room or moved to an orthogonally adjacent room (north, south, east, or west). Weapons could be moved by suspects between rooms as well.\n\nEach suspect had one of the following possible motives for killing Mr. Boddy:\n\n• Pride (2 suspects)\n• Fear (1 suspect)\n• Ambition (2 suspects)\n\nFor the murder to occur, the murderer and Mr. Boddy must have been alone in a room with at least one weapon at some point in the night. Any clue about Mr. Boddy\'s whereabouts should be read as "Mr. Boddy (dead or alive) ..."\n\nThe available clues are as follows:\n\n- The Horseshoe was in the room just north of the Rope at 12:00 AM\n- Miss Peach moved from the Ballroom to the Dining Room at 01:00 AM\n- Mrs. White was in the Drawing Room at 11:00 PM\n- The suspect motivated by Fear was in the Ballroom at 12:00 AM\n- Mrs. Peacock was in the Library at 11:30 PM or a suspect motivated by Pride was in the Ballroom at 12:00 AM\n- The Wrench was in the Studio at 01:00 AM or a suspect motivated by Pride was in the Drawing Room at 11:30 PM\n- A suspect motivated by Ambition was in the Ballroom at 11:00 PM\n- A suspect motivated by Ambition was in the same room as Mr. Boddy at 01:00 AM\n- Mrs. White was in the Dining Room at 01:00 AM or Miss Peach was in the Ballroom at 01:00 AM\n- The Wrench was in the Ballroom at 01:00 AM if and only if the Horseshoe was in the Studio at 12:00 AM\n- Miss Peach moved from the Drawing Room to the Library at 11:30 PM\n- A suspect motivated by Pride moved the Revolver from the Drawing Room to the Dining Room at 12:30 AM\n- Mrs. Peacock moved from the Ballroom to the Kitchen at 12:30 AM\n- The Wrench was in the Kitchen at 11:30 PM if and only if the Rope was in the Study at 12:00 AM\n- Mrs. Peacock was in the room just south of the Wrench at 01:00 AM\n- Miss Scarlet was in the same room as Colonel Mustard at 11:30 PM\n- A suspect motivated by Pride was in the Ballroom at 01:00 AM\n- Mrs. Peacock moved the Wrench from the Kitchen to the Ballroom at 12:00 AM\n- A suspect motivated by Ambition was in the same room as the Wrench at 01:00 AM\n- The murderer and Mr. Boddy were in the Kitchen together at least once\n- Miss Scarlet moved from the Kitchen to the Ballroom at 12:30 AM\n- The Poison was in the Drawing Room at 12:30 AM\n- Colonel Mustard was in the Ballroom at 12:30 AM\n- A suspect motivated by Pride was in the same room as Mr. Boddy at 11:00 PM\n- Mrs. Peacock was in the room just south of Colonel Mustard at 11:00 PM\n\nPlease answer the following question(s):\n\nA. Who murdered Mr. Boddy?\nB. What weapon did the murderer use?\nC. Where was the murder committed?\nD. When did the murder occur?\nE. Why did the murderer do it?\n\nAnd the following bonus question(s):\n\nF. Where was Miss Peach at 12:30 AM?\n\nFill out your final answers in the following format:\n\nA. SUSPECT\nB. WEAPON\nC. ROOM\nD. TIME\nE. MOTIVE\nF. ROOM\n\nBest of luck, detective.',
#   'solution': {'A': 'Mrs. Peacock',
#    'B': 'Wrench',
#    'C': 'Kitchen',
#    'D': '11:30 PM',
#    'E': 'Ambition',
#    'F': 'Ballroom'}},
#  {'num_clues': 47,
#   'prompt': 'On a dark winter night, wealthy and enigmatic Mr. John Q. Boddy hosted a small, but lavish, dinner party for some of his closest associates. However, the night ended in tragedy when Mr. Boddy was found dead in one of the rooms of Tudor Mansion in the early hours of the morning. The following persons of interest have been identified as suspects:\n\n• Mrs. White\n• Miss Scarlet\n• Madame Rose\n• Sgt. Gray\n• Mrs. Peacock\n• Colonel Mustard\n• Miss Peach\n• Professor Plum\n\nAnd the following weapons were found on the premises:\n\n• Poison\n• Rope\n• Candlestick\n• Lead Pipe\n• Wrench\n• Revolver\n• Horseshoe\n• Knife\n\nThe murder could only have occured in one of the following rooms:\n\n1. Carriage House\n2. Study\n3. Gazebo\n4. Fountain\n5. Ballroom\n6. Trophy Room\n7. Lounge\n8. Hall\n9. Billiard Room\n\nThe rooms are laid out as follows:\n\n  N N N  \nW 1|2|3 E\nW 4|5|6 E\nW 7|8|9 E\n  S S S  \n\nThe exact time of the murder is a bit uncertain, but it has been narrowed down to one of the following times:\n\n• 10:30 PM\n• 11:00 PM\n• 11:30 PM\n• 12:00 AM\n• 12:30 AM\n\nAt every time the suspects and Mr. Boddy either stayed in their current room or moved to an orthogonally adjacent room (north, south, east, or west). Weapons could be moved by suspects between rooms as well.\n\nEach suspect uniquely had one of the following possible motives for killing Mr. Boddy:\n\n• Power\n• Greed\n• Jealousy\n• Betrayal\n• Fear\n• Pride\n• Ambition\n• Anger\n\nFor the murder to occur, the murderer and Mr. Boddy must have been alone in a room with at least one weapon at some point in the night. Any clue about Mr. Boddy\'s whereabouts should be read as "Mr. Boddy (dead or alive) ..."\n\nThe available clues are as follows:\n\n- Sgt. Gray was in the Carriage House at 11:30 PM\n- Mr. Boddy was murdered at 11:30 PM\n- The suspect motivated by Jealousy was in the Lounge at 12:30 AM if and only if Professor Plum was in the Lounge at 12:30 AM\n- Sgt. Gray moved from the Study to the Carriage House at 11:00 PM\n- Miss Peach was in the Study at 12:30 AM\n- Madame Rose was in the Lounge at 10:30 PM if and only if the Rope was at the Fountain at 11:00 PM\n- Mrs. White was in the room just north of the Poison at 12:30 AM\n- Madame Rose was in the Lounge at 12:30 AM if and only if the suspect motivated by Ambition was in the Billiard Room at 11:00 PM\n- Mr. Boddy was in the same room as Professor Plum at 12:00 AM\n- Mr. Boddy was in the Hall at 11:00 PM\n- Colonel Mustard and Mrs. White were in the Billiard Room together at least once\n- The Rope was in the Study at 12:30 AM\n- The suspect motivated by Power was in the Gazebo at 12:00 AM or the suspect motivated by Betrayal was in the Study at 12:00 AM\n- The Wrench was in the room just west of Miss Scarlet at 11:00 PM\n- The suspect motivated by Pride moved the Horseshoe from the Ballroom to the Trophy Room at 12:00 AM\n- The Lead Pipe was in the same room as Mrs. White at 12:30 AM\n- The Knife was at the Fountain at 11:30 PM or the Revolver was at the Fountain at 11:30 PM\n- Mrs. Peacock was in the room just north of the Wrench at 10:30 PM\n- The murder weapon and Colonel Mustard were in the Trophy Room together at least once\n- Mr. Boddy was in the Ballroom at 10:30 PM\n- Mrs. Peacock moved the Revolver from the Fountain to the Lounge at 12:30 AM\n- The suspect motivated by Jealousy was in the Lounge at 11:30 PM if and only if Professor Plum was in the Hall at 12:00 AM\n- The Knife was in the Study at 12:30 AM\n- Miss Scarlet was in the same room as Mr. Boddy at 10:30 PM\n- The Revolver was at the Fountain at 10:30 PM\n- The Knife was in the same room as the Lead Pipe at 10:30 PM\n- The suspect motivated by Anger moved the Wrench from the Carriage House to the Fountain at 12:00 AM\n- The murder weapon was in the Hall at 10:30 PM\n- The suspect motivated by Anger moved the Rope from the Fountain to the Carriage House at 11:30 PM\n- Mr. Boddy was in the room just east of Madame Rose at 12:00  ...
#   'solution': {'A': 'Colonel Mustard',
#    'B': 'Candlestick',
#    'C': 'Hall',
#    'D': 'Greed',
#    'E': 'Study',
#    'F': 'Ballroom',
#    'G': 'Lounge'}},
#  {'num_clues': 30,
# ...
#   'solution': {'A': 'Miss Scarlet',
#    'B': 'Poison',
#    'C': 'Fountain',
#    'D': 'Power',
#    'E': 'Hall',
#    'F': 'Hall'}},
#  {'num_clues': 23,
#   'prompt': 'On a dark winter night, wealthy and enigmatic Mr. John Q. Boddy hosted a small, but lavish, dinner party for some of his closest associates. However, the night ended in tragedy when Mr. Boddy was found dead in one of the rooms of Tudor Mansion in the early hours of the morning. The following persons of interest have been identified as suspects:\n\n• Madame Rose\n• Miss Scarlet\n• Colonel Mustard\n• Mrs. White\n• Mr. Green\n• Mrs. Peacock\n• Sgt. Gray\n\nAnd the following weapons were found on the premises:\n\n• Lead Pipe\n• Poison\n• Knife\n• Rope\n• Candlestick\n\nThe murder could only have occured in one of the following rooms:\n\n01. Trophy Room\n02. Studio\n03. Courtyard\n04. Dining Room\n05. Conservatory\n06. Ballroom\n07. Lounge\n08. Billiard Room\n09. Carriage House\n10. Gazebo\n11. Fountain\n\nThe rooms are laid out as follows:\n\n  NN NN NN NN  \nW 01|02|03|04 E\nW 05|06|07|08 E\nW 09|10|11|- E\n  SS SS SS SS  \n\nThe exact time of the murder is a bit uncertain, but it has been narrowed down to one of the following times:\n\n• 11:30 PM\n• 11:45 PM\n• 12:00 AM\n\nAt every time the suspects and Mr. Boddy either stayed in their current room or moved to an orthogonally adjacent room (north, south, east, or west). Weapons could be moved by suspects between rooms as well.\n\nFor the murder to occur, the murderer and Mr. Boddy must have been alone in a room with at least one weapon at some point in the night. Any clue about Mr. Boddy\'s whereabouts should be read as "Mr. Boddy (dead or alive) ..."\n\nThe available clues are as follows:\n\n- Mrs. Peacock was in the Dining Room at 12:00 AM\n- The Rope was in the same room as Miss Scarlet at 11:30 PM\n- Mr. Green and Miss Scarlet were in the Courtyard together at least once\n- The Candlestick was in the room just east of the Knife at 11:30 PM\n- Mr. Green was in the room just north of Mrs. Peacock at 11:30 PM\n- Mr. Boddy was murdered at 11:30 PM\n- Madame Rose moved from the Lounge to the Fountain at 12:00 AM\n- Colonel Mustard moved from the Courtyard to the Studio at 11:45 PM\n- Mr. Green moved from the Dining Room to the Courtyard at 11:45 PM\n- Miss Scarlet was in the Studio at 11:30 PM\n- The Lead Pipe was in the Gazebo at 12:00 AM if and only if Miss Scarlet was in the Studio at 11:45 PM\n- Mr. Green was at the Fountain at 11:45 PM or the Rope was in the Studio at 12:00 AM\n- Madame Rose was in the Lounge at 11:30 PM\n- Mrs. White was in the Conservatory at 11:45 PM\n- The Lead Pipe and the Candlestick were in the Gazebo together at least once\n- The murderer was in the Carriage House at 12:00 AM\n- Mrs. Peacock was in the Billiard Room at 11:45 PM\n- Mr. Green was in the room just east of Colonel Mustard at 12:00 AM\n- The Poison was in the Billiard Room at 11:30 PM or Mrs. White was in the Conservatory at 12:00 AM\n- Mrs. White was in the Conservatory at 11:30 PM or the murderer was in the Courtyard at 11:45 PM\n- Sgt. Gray was in the Carriage House at 11:45 PM\n- Mrs. White and the Poison were in the Conservatory together at least once\n- Mr. Boddy was in the same room as the Knife at 11:30 PM\n\nPlease answer the following question(s):\n\nA. Who murdered Mr. Boddy?\nB. What weapon did the murderer use?\nC. Where was the murder committed?\n\nAnd the following bonus question(s):\n\nD. Where was Miss Scarlet at 11:45 PM?\nE. Where was the Rope at 11:30 PM?\nF. Where was Mrs. Peacock at 11:30 PM?\nG. Where was Mr. Green at 12:00 AM?\n\nFill out your final answers in the following format:\n\nA. SUSPECT\nB. WEAPON\nC. ROOM\nD. ROOM\nE. ROOM\nF. ROOM\nG. ROOM\n\nBest of luck, detective.',
#   'solution': {'A': 'Sgt. Gray',
#    'B': 'Knife',
#    'C': 'Carriage House',
#    'D': 'Studio',
#    'E': 'Studio',
#    'F': 'Billiard Room',
#    'G': 'Courtyard'}},
#  {'num_clues': 4,
#   'prompt': 'On a dark winter night, wealthy and enigmatic Mr. John Q. Boddy hosted a small, but lavish, dinner party for some of his closest associates. However, the night ended in tragedy when Mr. Boddy was found dead in one of the rooms of Tudor Mansion in the early hours of the morning. The following persons of interest have been identified as suspects:\n\n• Madame Rose\n• Sgt. Gray\n\nAnd the following weapons were found on the premises:\n\n• Revolver\n• Lead Pipe\n\nThe murder could only have occured in one of the following rooms:\n\n1. Studio\n2. Study\n\nThe rooms are laid out as follows:\n\n  N  \nW 1 E\nW 2 E\n  S  \n\nEach suspect uniquely had one of the following possible motives for killing Mr. Boddy:\n\n• Hatred\n• Power\n\nFor the murder to occur, the murderer and Mr. Boddy must have been alone in a room with at least one weapon.\n\nThe available clues are as follows:\n\n- The Revolver was in the same room as Sgt. Gray\n- The suspect motivated by Power was in the Studio\n- The murderer was in the Study if and only if the Revolver was in the Studio\n- The murder weapon was in the Study\n\nPlease answer the following question(s):\n\nA. Who murdered Mr. Boddy?\nB. What weapon did the murderer use?\nC. Where was the murder committed?\nD. Why did the murderer do it?\n\nAnd the following bonus question(s):\n\nE. Who is motivated by Power?\nF. Where was the Lead Pipe?\n\nFill out your final answers in the following format:\n\nA. SUSPECT\nB. WEAPON\nC. ROOM\nD. MOTIVE\nE. SUSPECT\nF. ROOM\n\nBest of luck, detective.',
#   'solution': {'A': 'Madame Rose',
#    'B': 'Lead Pipe',
#    'C': 'Study',
#    'D': 'Hatred',
#    'E': 'Sgt. Gray',
#    'F': 'Study'}},
#  {'num_clues': 31,
#   'prompt': 'On a dark winter night, wealthy and enigmatic Mr. John Q. Boddy hosted a small, but lavish, dinner party for some of his closest associates. However, the night ended in tragedy when Mr. Boddy was found dead in one of the rooms of Tudor Mansion in the early hours of the morning. The following persons of interest have been identified as suspects:\n\n• Mrs. Peacock\n• Miss Peach\n• Madame Rose\n• Professor Plum\n• Colonel Mustard\n• Monsieur Brunette\n• Sgt. Gray\n\nAnd the following weapons were found on the premises:\n\n• Horseshoe\n• Lead Pipe\n• Candlestick\n• Knife\n• Poison\n\nThe murder could only have occured in one of the following rooms:\n\n1. Study\n2. Studio\n3. Fountain\n4. Billiard Room\n5. Drawing Room\n6. Library\n7. Ballroom\n8. Gazebo\n9. Conservatory\n\nThe rooms are laid out as follows:\n\n  N N N  \nW 1|2|3 E\nW 4|5|6 E\nW 7|8|9 E\n  S S S  \n\nThe exact time of the murder is a bit uncertain, but it has been narrowed down to one of the following times:\n\n• 11:15 PM\n• 11:30 PM\n• 11:45 PM\n• 12:00 AM\n\nAt every time the suspects and Mr. Boddy either stayed in their current room or moved to an orthogonally adjacent room (north, south, east, or west). Weapons could be moved by suspects between rooms as well.\n\nEach suspect uniquely had one of the following possible motives for killing Mr. Boddy:\n\n• Hatred\n• Betrayal\n• Revenge\n• Power\n• Pride\n• Ambition\n• Greed\n\nFor the murder to occur, the murderer and Mr. Boddy must have been alone in a room with at least one weapon at some point in the night. Any clue about Mr. Boddy\'s whereabouts should be read as "Mr. Boddy (dead or alive) ..."\n\nThe available clues are as follows:\n\n- The suspect motivated by Hatred moved from the Library to the Conservatory at 12:00 AM\n- The Lead Pipe was in the same room as Monsieur Brunette at 11:45 PM\n- Professor Plum and Miss Peach were in the Gazebo together at least once\n- The suspect motivated by Pride moved from the Conservatory to the Gazebo at 11:45 PM\n- Miss Peach and the Lead Pipe were in the Gazebo together at least once\n- Colonel Mustard was in the room just east of the Candlestick at 12:00 AM\n- The suspect motivated by Ambition moved from the Studio to the Drawing Room at 11:30 PM\n- The suspect motivated by Revenge moved from the Ballroom to the Gazebo at 11:30 PM\n- Mr. Boddy was at the Fountain at 11:15 PM if and only if the Knife was in the Drawing Room at 11:15 PM\n- The suspect motivated by Revenge was in the Gazebo at 11:45 PM\n- Mr. Boddy was in the same room as the Horseshoe at 12:00 AM\n- Mrs. Peacock moved the Horseshoe from the Drawing Room to the Studio at 11:45 PM\n- Mrs. Peacock was in the room just west of Madame Rose at 12:00 AM\n- Professor Plum was in the Conservatory at 11:15 PM\n- Mr. Boddy was in the same room as Mrs. Peacock at 11:45 PM\n- The suspect motivated by Greed was at the Fountain at 11:45 PM\n- Mr. Boddy was killed with the Knife\n- Colonel Mustard moved from the Library to the Drawing Room at 12:00 AM\n- The suspect motivated by Ambition was in the Studio at 12:00 AM or the suspect motivated by Pride was in the Studio at 11:45 PM\n- The Poison was in the Study at 11:45 PM\n- The suspect motivated by Hatred moved from the Conservatory to the Library at 11:30 PM\n- The Lead Pipe was in the Conservatory at 11:30 PM\n- Madame Rose moved from the Library to the Fountain at 11:30 PM\n- The Horseshoe and Colonel Mustard were in the Drawing Room together at least once\n- Madame Rose was in the Library at 11:15 PM if and only if Colonel Mustard was in the Library at 11:30 PM\n- The suspect motivated by Pride was in the Gazebo at 12:00 AM\n- Mr. Boddy was in the same room as Madame Rose at 11:30 PM\n- Monsieur Brunette moved from the Conservatory to the Gazebo at 11:30 PM\n- Mr. Boddy was murdered at 12:00 AM\n- The suspect motivated by Power moved from the Gazebo to the Conservatory at 11:45 PM\n- Mr. Boddy was at the Fountain at 11:30 PM if and only if the murder  ...
#   'solution': {'A': 'Mrs. Peacock',
#    'B': 'Studio',
#    'C': 'Ambition',
#    'D': 'Library',
#    'E': 'Gazebo',
#    'F': 'Library',
#    'G': 'Drawing Room'}},
#  {'num_clues': 9,
#   'prompt': 'On a dark winter night, wealthy and enigmatic Mr. John Q. Boddy hosted a small, but lavish, dinner party for some of his closest associates. However, the night ended in tragedy when Mr. Boddy was found dead in one of the rooms of Tudor Mansion in the early hours of the morning. The following persons of interest have been identified as suspects:\n\n• Mr. Green\n• Colonel Mustard\n\nAnd the following weapons were found on the premises:\n\n• Rope\n• Lead Pipe\n\nThe murder could only have occured in one of the following rooms:\n\n1. Carriage House\n2. Library\n\nThe rooms are laid out as follows:\n\n  N N  \nW 1|2 E\n  S S  \n\nThe exact time of the murder is a bit uncertain, but it has been narrowed down to one of the following times:\n\n• 10:00 PM\n• 11:00 PM\n• 12:00 AM\n\nAt every time the suspects and Mr. Boddy either stayed in their current room or moved to an orthogonally adjacent room (north, south, east, or west). Weapons could be moved by suspects between rooms as well.\n\nFor the murder to occur, the murderer and Mr. Boddy must have been alone in a room with at least one weapon at some point in the night. Any clue about Mr. Boddy\'s whereabouts should be read as "Mr. Boddy (dead or alive) ..."\n\nThe available clues are as follows:\n\n- Colonel Mustard was in the Library at 11:00 PM if and only if the murder weapon was in the Library at 10:00 PM\n- The Lead Pipe was in the room just east of the Rope at 10:00 PM\n- The Rope was in the Library at 10:00 PM or Mr. Green was in the Library at 11:00 PM\n- Mr. Boddy was in the same room as the Lead Pipe at 11:00 PM\n- The murderer was in the Carriage House at 10:00 PM\n- Mr. Boddy was in the Library at 10:00 PM\n- The murderer was in the Carriage House at 10:00 PM if and only if Mr. Green was in the Library at 10:00 PM\n- Mr. Green and the Rope were in the Carriage House together at least once\n- The Rope was in the Carriage House at 10:00 PM or the Rope was in the Library at 11:00 PM\n\nPlease answer the following question(s):\n\nA. Who murdered Mr. Boddy?\nB. What weapon did the murderer use?\nC. Where was the murder committed?\nD. When did the murder occur?\n\nAnd the following bonus question(s):\n\nE. Where was the Rope at 11:00 PM?\nF. Where was the Lead Pipe at 12:00 AM?\n\nFill out your final answers in the following format:\n\nA. SUSPECT\nB. WEAPON\nC. ROOM\nD. TIME\nE. ROOM\nF. ROOM\n\nBest of luck, detective.',
#   'solution': {'A': 'Colonel Mustard',
#    'B': 'Lead Pipe',
#    'C': 'Library',
#    'D': '12:00 AM',
#    'E': 'Carriage House',
#    'F': 'Library'}}]

# %%
from collections import Counter
import math
import re


def get_consensus(result: TaskResult, puzzle: TemporalCluePuzzle):
    consensus = {key: Counter() for key in puzzle["solution"]}
    for completion in result.chat_completions:
        for choice in completion.choices:
            content = choice.message.content
            assert isinstance(content, str)
            for key in puzzle["solution"]:
                if matches := re.findall(rf"{key}\. ([A-Za-z \.:-]+)", content):
                    match = matches[-1]
                    consensus[key][match.strip().lower()] += 1
                    # consensus[key][match.strip().lower()] += -math.log(
                    #     1
                    #     - math.exp(
                    #         sum(
                    #             token_logprob.logprob
                    #             for token_logprob in choice.logprobs.content
                    #         ) / len(choice.logprobs.content)
                    #     )
                    # )
    num_correct = 0
    for key in puzzle["solution"]:
        try:
            consensus_answer = max(consensus[key], key=consensus[key].get)
        except ValueError:
            consensus_answer = None
        if consensus_answer == puzzle["solution"][key].lower():
            num_correct += 1
    return num_correct / len(puzzle["solution"])


sum(get_consensus(result, puzzle) for result, puzzle in zip(val_results, puzzles)) / 64
# Out:
# 0.6143043154761905
