# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %%html
# <style>
# .cell-output-ipywidget-background {
#     background-color: transparent !important;
# }
# :root {
#     --jp-widgets-color: var(--vscode-editor-foreground);
#     --jp-widgets-font-size: var(--vscode-editor-font-size);
# }
# </style>
# Out:
# <style>
# .cell-output-ipywidget-background {
#     background-color: transparent !important;
# }
# :root {
#     --jp-widgets-color: var(--vscode-editor-foreground);
#     --jp-widgets-font-size: var(--vscode-editor-font-size);
# }
# </style>

# %%
import asyncio
from itertools import islice
from lib.nyt_connections import get_connections_games, get_connections_tasks
from lib.tasks import ChatCompletionParams, get_task_results
import openai
import os


games = get_connections_games()
benchmark_tasks = list(
    islice(get_connections_tasks(games, parse_answers_liberally=True), 200)
)
benchmark_tasks
# Out:
# [Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nsnow\nlevel\nshift\nkayak\nheat\ntab\nbucks\nreturn\njazz\nhail\noption\nrain\nsleet\nracecar\nmom\nnets'}], grader=<function get_grader.<locals>.grader at 0x132876de0>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nPUMP\nFOOT\nTIME\nSEA\nLEAGUE\nLOAFER\nWHY\nUS\nBOOT\nYARD\nPEOPLE\nARE\nMILE\nSNEAKER\nQUEUE\nESSENCE'}], grader=<function get_grader.<locals>.grader at 0x132876d40>),
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\namigo\nmouth\nlab\nstooge\nwolf\nking\nnose\nchow\ntenor\npom\nscarf\neye\npit\ngobble\npeke\ncheek'}], grader=<function get_grader.<locals>.grader at 0x1328771a0>),
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nDUST\nCATS\nSPIDER\nCAROUSEL\nPUMA\nIRON\nNIKE\nMOP\nCHICAGO\nSWEEP\nSUPER\nBAT\nREEBOK\nCABARET\nVACUUM\nADIDAS'}], grader=<function get_grader.<locals>.grader at 0x1328772e0>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nmustard\ntartar\nplum\nblue\ngreen\nprime\nglum\nrelish\ndown\npeacock\nketchup\nlow\nhulu\nscarlet\nmayo\nnetflix'}], grader=<function get_grader.<locals>.grader at 0x16a192ac0>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nWONDER\nFUTURE\nBABY\nGO\nSIN\nCHANCE\nROYAL\nICE CUBE\nMIDNIGHT\nJAIL\nSEA\nPOWDER\nQ-TIP\nSISTER\nBOARDWALK\nCOMMON'}], grader=<function get_grader.<locals>.grader at 0x16a192f20>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\njohn\ncub\nstar\nsilver\nknee\nthrone\njoey\njelly\ncalf\nankle\ncray\nhead\nshin\ncan\nkid\nthigh'}], grader=<function get_grader.<locals>.grader at 0x107e396c0>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nLOCKSMITH\nFIRE TRUCK\nKING\nPIANO\nCHESS\nRUBY\nFLORIDA\nTWIN\nCHERRY\nQUEEN\nSTOP SIGN\nGO\nCHECKERS\nCRYPTOGRAPHY\nFULL\nBACKGAMMON'}], grader=<function get_grader.<locals>.grader at 0x16a192de0>),
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nsquash\ntee\ncarrot\nant\ntank\ncorn\ncricket\nmantis\npolo\nonion\nbeetle\nbeet\ncami\ntermite\nhalter\nfencing'}], grader=<function get_grader.<locals>.grader at 0x16a191ee0>),
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nTWINS\nTURKEY\nGOAT\nKIWI\nSCALES\nFISH\nJORDAN\nJAY\nORANGE\nGEORGIA\nDATE\nCRANE\nTOGO\nSWALLOW\nLEMON\nCHAD'}], grader=<function get_grader.<locals>.grader at 0x16a1932e0>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nsugar\nangel\nginger\nbird\nbaby\ncumin\nboo\nscary\nsweetie\ncoriander\nairplane\nclove\npegasus\nhoney\ncardamom\nposh'}], grader=<function get_grader.<locals>.grader at 0x16a193ec0>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nLUST\nPRIDE\nTAN\nSCHOOL\nSLOTH\nSEC\nPACK\nCOT\nSNAIL\nGREED\nSIN\nFLOCK\nPOD\nLORIS\nENVY\nTORTOISE'}], grader=<function get_grader.<locals>.grader at 0x16a1936a0>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nknew\ngnome\niota\nfrontier\ndelta\nchi\ngnocchi\nnew\nspirit\nbeta\nvirgin\ngnaw\nnu\ngnat\nunited\ngnu'}], grader=<function get_grader.<locals>.grader at 0x16a191080>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nCANOPY\nLINK\nPASSPORT\nMARX\nPILOT\nSONIC\nWRIGHT\nACCORD\nMURPHY\nCRASH\nCIVIC\nBUNK\nMARIO\nJONAS\nTRUNDLE\nWARNER'}], grader=<function get_grader.<locals>.grader at 0x16a1939c0>),
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nsilver\ntweet\nrod\nsparrow\nbrown\ntackle\nhook\npink\ncaw\njones\nviolet\nreel\nturquoise\nchirp\nlure\ncluck'}], grader=<function get_grader.<locals>.grader at 0x16a193ba0>),
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nBEAN\nESPRESSO\nALMOND\nFOREST\nPECAN\nCLEAN\nKELLY\nLATTE\nPEANUT\nEMERALD\nAMERICANO\nFOX\nOLIVE\nWALNUT\nCAPPUCCINO\nCASHEW'}], grader=<function get_grader.<locals>.grader at 0x16a191300>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\ntide\nbermuda\nstern\nscarf\nlove\nascot\ngain\nbow\nright\nera\nport\nbolo\nacute\ntie\nall\nstarboard'}], grader=<function get_grader.<locals>.grader at 0x16a1927a0>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nGREY\nCUP\nBILL\nRIBBON\nQUAD\nBEAR\nHOUSE\nLAT\nQUINN\nTRI\nMEDAL\nCOMMANDER\nBROWN\nTROPHY\nPEC\nHOWSER'}], grader=<function get_grader.<locals>.grader at 0x16a190900>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\ncream\ngarlic\npork\nrow\nmirror\nbeef\nspat\neggshell\npoultry\nstake\ntiff\nvanilla\nivory\nquarrel\nvenison\ncrucifix'}], grader=<function get_grader.<locals>.grader at 0x16a193b00>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nKING\nOAT\nSTONE\nRICE\nBARLEY\nBONG\nDUKE\nFORD\nBROWN\nSPELT\nLEE\nEARL\nHOWARD\nBARON\nRYE\nPRINCE'}], grader=<function get_grader.<locals>.grader at 0x16a191800>),
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nopera\nbaby\nwayne\njo\npop\nmeg\nsafari\nkim\nrap\nchrome\nbeth\njazz\npunk\njon\namy\nedge'}], grader=<function get_grader.<locals>.grader at 0x16a193380>),
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nBITE\nSTOP\nTRUNK\nBOXER\nWAVE\nYIELD\nMUZZLE\nBARRIER\nDETOUR\nHUSKY\nSNOUT\nASLEEP\nDALMATIAN\nBEAK\nSLOW\nPOODLE'}], grader=<function get_grader.<locals>.grader at 0x16a191bc0>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nbeach boy\ntwist\nchain\nrolling stone\nmashed potato\nwired\nwebsite\nbeatle\nsausage\nbyrd\ndougie\nfortune\nmacarena\nvogue\ngolf course\nmonkee'}], grader=<function get_grader.<locals>.grader at 0x16a191620>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nMILKY WAY\nGENESIS\nHAMMER\nSUM\nSWITCH\nMAROON\nBOUNTY\nU\nANVIL\nCRUNCH\nBLINK\nSTIRRUP\nHEATH\nWII\nCOCHLEA\nDREAMCAST'}], grader=<function get_grader.<locals>.grader at 0x16a192840>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nmousse\nwalrus\nfudge\nhorseshoe\nshoot\npencil\nelephant\nflan\nnarwhal\nhippo\nheck\nhandlebar\ntiramisu\ndarn\nwarthog\ncheesecake'}], grader=<function get_grader.<locals>.grader at 0x16a193240>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nPETTY\nPARROT\nPOLAND\nCRUISE\nMIX\nMIMIC\nHOLLAND\nGREECE\nECHO\nMILD\nLIVID\nCOPY\nPORTUGAL\nWAITS\nDENMARK\nDILL'}], grader=<function get_grader.<locals>.grader at 0x16a190720>),
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nheart\nberet\nspine\npot\nass\nkidney\nfez\njacket\nbowler\nrabbit\nliver\ncover\nlung\npage\nfedora\nknife'}], grader=<function get_grader.<locals>.grader at 0x16a192ca0>),
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nCOCONUT\nZIP\nPENGUIN\nDOC\nKIWI\nHAPPY\nTIFF\nBANANA\nEMU\nGRUMPY\nMANGO\nGIF\nPDF\nOSTRICH\nBASHFUL\nPINEAPPLE'}], grader=<function get_grader.<locals>.grader at 0x16a193060>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nskate\nadd\ncopy\nfly\nalley\ntang\nmoth\ncool\ndivide\nsole\nlap\nsubtract\ntetra\ngnat\nmultiply\nwasp'}], grader=<function get_grader.<locals>.grader at 0x16a190ae0>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nSPIRAL\nHIP\nMOTHER\nRAVEN\nELBOW\nAIRPLANE\nKNEE\nSHELL\nCOWBOY\nSHOULDER\nOKLAHOMA\nBOWTIE\nTHEM\nPACKER\nWRIST\nBRONCO'}], grader=<function get_grader.<locals>.grader at 0x16a193ce0>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\npad\nlima\ncone\ntomato\npolish\npepper\nphone\npyramid\ncube\nmobile\njob\ncucumber\neggplant\nmac\nsphere\npod'}], grader=<function get_grader.<locals>.grader at 0x16a190040>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nSOLE\nTROUBLE\nHUNT\nCEMENT\nSMART\nTONGUE\nSOUL\nBOND\nLACE\nBAND\nSORRY\nRYAN\nCLUE\nHEEL\nDUCKIE\nRISK'}], grader=<function get_grader.<locals>.grader at 0x16a1937e0>),
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\ntug\nchuck\njunk\nclub\nshank\nrob\nsub\nflank\ncuban\nferry\nloin\nsue\njosh\nround\nmelt\nyacht'}], grader=<function get_grader.<locals>.grader at 0x16a192d40>),
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nROCK\nFUNK\nBUCK\nBOUQUET\nSHOOT\nBULL\nCOUNTRY\nJACK\nSOUL\nSCENT\nSCISSORS\nBOAR\nFRAGRANCE\nPAPER\nBLUES\nAROMA'}], grader=<function get_grader.<locals>.grader at 0x16a193920>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nnickel\nhalf\nhorseshoe\ntin\nrainbow\nquarter\nneck\nlead\npenny\nclover\niron\nso\nzinc\nagain\ndime\nmoon'}], grader=<function get_grader.<locals>.grader at 0x107749620>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nEYE\nMARS\nPAPER\nTRUTH\nWOMBAT\nGUN\nMOLE RAT\nCHUNKY\nCHEDDAR\nCRUNCH\nKANGAROO\nDOUGH\nKOALA\nSTACKS\nMOUNDS\nWALLABY'}], grader=<function get_grader.<locals>.grader at 0x107bd3380>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nspoke\nmove\ncub\nseal\nhawk\nchain\ndolphin\nchin\nsaddle\npeddle\nmalt\notter\nmanatee\nbrake\nvend\ntong'}], grader=<function get_grader.<locals>.grader at 0x107bd3ce0>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nMOUNTAIN\nELM\nONION\nJUMP\nPLAIN\nVALLEY\nMAPLE\nPOPPY\nPINE\nSESAME\nHILL\nFEAR\nPLATEAU\nASH\nEVERYTHING\nCEDAR'}], grader=<function get_grader.<locals>.grader at 0x169845080>),
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\npepper\nmole\nwatch\nbob\nsecond\nevil\ncrop\nclock\nno\nnewton\nsundial\npixie\nhertz\nhourglass\nshag\nj'}], grader=<function get_grader.<locals>.grader at 0x169844cc0>),
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nAVIATOR\nFLUTE\nMONK\nLID\nHARBOR\nHARP\nCLARINET\nCAT EYE\nTOP\nHOODED\nBASSOON\nCOVER\nOBOE\nWAYFARER\nCAP\nWRAPAROUND'}], grader=<function get_grader.<locals>.grader at 0x169f687c0>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nfiji\nmud\npop\npalau\njoe\nsam\njapan\nbrew\ncuba\nvoss\ntony\njava\ndasani\nmalta\nevian\nlucky'}], grader=<function get_grader.<locals>.grader at 0x169f6ad40>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nDASH\nMASK\nJUNGLE\nPERIOD\nHOUSE\nHYPHEN\nSNORKEL\nBOLT\nFAT\nTANK\nCOLON\nRACE\nFINS\nSPRINT\nDOJA\nCOMMA'}], grader=<function get_grader.<locals>.grader at 0x169f6b420>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\ncanary\nirate\nlost\nschool bus\nbeach\ngull\nfurious\nbooby\nbanana\nbeastie\nsunflower\nlivid\nhardy\npelican\nincensed\npuffin'}], grader=<function get_grader.<locals>.grader at 0x169f6be20>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nSOLID\nPASTE\nSLATE\nTRASH\nTESLA\nCUT\nPLASMA\nCRUSH\nGAS\nSHELLAC\nSTALE\nUNDO\nCOPY\nLIQUID\nROUT\nLEAST'}], grader=<function get_grader.<locals>.grader at 0x169f6b6a0>),
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nplane\nsun\nday\nthunder\nsonic\nboat\nstripes\ncheckers\ncar\nsubway\nfloyd\ntrain\noutback\nking\nsabbath\nmagic'}], grader=<function get_grader.<locals>.grader at 0x169f68720>),
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nHURRICANE\nCYCLONE\nCHICAGO\nW\nMANHATTAN\nGLAMOUR\nTORNADO\nPHILADELPHIA\nCOSMOPOLITAN\nSQUALL\nALLURE\nSCREWDRIVER\nRIO\nBLIZZARD\nMUNICH\nELLE'}], grader=<function get_grader.<locals>.grader at 0x169f69bc0>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\ntree\ngecko\nforest\ngo\nmonitor\ndesert\nlotus\ncan\niguana\ncha\ntundra\ncobra\ngrassland\nwarrior\nnae\nchameleon'}], grader=<function get_grader.<locals>.grader at 0x169f69080>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nRIB\nSPECTER\nTWEED\nSCAR\nSPIRIT\nBEAST\nNEEDLE\nLINEN\nSTITCH\nPOKE\nDENIM\nGENIE\nCORDUROY\nGHOST\nTEASE\nPHANTOM'}], grader=<function get_grader.<locals>.grader at 0x169f6b600>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\ndaisy\naunt\nalarm\nquirky\nscrooge\ngrandfather\nkooky\nbiological\nnephew\ndaffy\ncuckoo\nmother\ndewey\nwacky\ncousin\ndonald'}], grader=<function get_grader.<locals>.grader at 0x169f6a7a0>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nOIL\nFOOT\nSAMOSA\nDIM\nQUART\nKATSU\nMILE\nWATERCOLOR\nPEN\nINCH\nACRYLIC\nFALAFEL\nYARD\nNICK\nSCHNITZEL\nTEMPERA'}], grader=<function get_grader.<locals>.grader at 0x169f6b100>),
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nmatch\nhero\nblade\ndriver\ngrinder\nscott\nhinge\ntwilight\nwest\ntinder\nant\nsub\nbumble\nlost boys\nhoagie\nnear dark'}], grader=<function get_grader.<locals>.grader at 0x169f6bd80>),
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nRAT\nHORN\nSPEAKER\nTRIANGLE\nCARP\nHARP\nORGAN\nVOLE\nGROUSE\nHAMSTER\nMOUSE\nMONITOR\nKEYBOARD\nMOAN\nGERBIL\nGRIPE'}], grader=<function get_grader.<locals>.grader at 0x169f68180>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nhigh\npride\nclass\ngov\norder\nchem\nlit\nfamily\nswarm\ndomain\nbio\ncolony\nbaked\nstats\nherd\nblazed'}], grader=<function get_grader.<locals>.grader at 0x169f6a700>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nTOM\nROCKY\nTEMPLE\nHARRY\nHIGH\nALTAR\nSYLVESTER\nGROVER\nSILK\nCALVIN\nABBEY\nGARFIELD\nCHESTER\nRELIQUARY\nFELIX\nSHRINE'}], grader=<function get_grader.<locals>.grader at 0x169f69760>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nviola\ntop\ngiggle\nmemory\neggnog\nblocks\nselfie\npuck\ndoll\nhockey\nduncan\nleggings\njuliet\nbaggage\nyo-yo\nfish'}], grader=<function get_grader.<locals>.grader at 0x169f69300>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nPINCH\nSALSA\nSAVAGE\nBREAKOUT\nCENT\nSWIPE\nSWING\nTAP\nASTEROIDS\nPAC\nPONG\nHUSTLE\nTANGO\nSPREAD\nCHAINZ\nFROGGER'}], grader=<function get_grader.<locals>.grader at 0x169f696c0>),
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nkiss\nromance\nstripes\nfiction\npaisley\nhorror\ndot\nlie\nmusical\nwhopper\nplaid\nfib\ngoober\ntale\nwestern\nhoundstooth'}], grader=<function get_grader.<locals>.grader at 0x169f6a160>),
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nBLADE\nCATFISH\nTICK\nCHAR\nSTATE\nEEL\nSTORM\nFLASH\nBLACK WIDOW\nJACKASS\nPERCH\nSCORPION\nMITE\nSHARK\nSPIDER\nCRIBS'}], grader=<function get_grader.<locals>.grader at 0x169f6a340>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nmoon\nglobe\nsome\nlyme\nfew\npair\npost\ncomet\nplumb\nhandful\nsun\nplanet\njournal\nmellon\nasteroid\nseveral'}], grader=<function get_grader.<locals>.grader at 0x169f693a0>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nDIAMOND\nPENDANT\nCHARM\nSAW\nPLEASE\nCOURT\nSCREAM\nTICKLE\nBANGLE\nRING\nFIELD\nDELIGHT\nPURGE\nANKLET\nRINK\nBROOCH'}], grader=<function get_grader.<locals>.grader at 0x169f68040>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nbarbie\noppenheimer\nmatch\ngenius\nwest\nbush\nselling\nhawking\nfaculty\neinstein\nmate\nmoot\ncrikey\ngift\nfeynman\nflair'}], grader=<function get_grader.<locals>.grader at 0x169f6a8e0>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nMA\nLA\nNA\nNU\nPI\nNI\nTI\nHE\nFA\nXI\nPA\nFE\nDO\nCO\nMU\nME'}], grader=<function get_grader.<locals>.grader at 0x169f69f80>),
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\njack\npress\nplanet\nbutton\nplank\nsquat\nsnap\nobvious\ncrunch\nbuckle\nnothing\ncurl\nzip\nkangaroo\nlunge\nnada'}], grader=<function get_grader.<locals>.grader at 0x169f69e40>),
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nCATCH\nSPOT\nBONE\nLUCKY\nSEE\nSHIRT\nFLY\nSTORM\nCHUM\nNOTICE\nREX\nBAIT\nFIDO\nSINKER\nOBSERVE\nROVER'}], grader=<function get_grader.<locals>.grader at 0x169f6a200>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\njuice\nwater\ntree\nearth\ngas\ncircus\nsteam\nliquid\nsaturn\nfire\nsolid\nspirit\nplasma\nvigor\nair\nwedding'}], grader=<function get_grader.<locals>.grader at 0x169f6b9c0>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nROSE\nCLOSE\nBACON\nYEAR\nPANCAKE\nMONTH\nMUNCH\nEGG\nDECADE\nCEREAL\nCENTURY\nOMELET\nWHISTLER\nMILLENNIUM\nJUROR\nWAFFLE'}], grader=<function get_grader.<locals>.grader at 0x169f6a3e0>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nfudge\nmeal\ncobbler\nsmith\npie\ndoctor\nroot\ntwist\ndance\none\nfisher\ntart\nmason\ncake\ndistort\nmiller'}], grader=<function get_grader.<locals>.grader at 0x169f6a5c0>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nPINT\nREAL\nCARROT\nAWFUL\nSPONGE\nCUP\nWON\nSUPER\nGALLON\nCOFFEE\nVERY\nPOUND\nRAND\nQUITE\nQUART\nSTERLING'}], grader=<function get_grader.<locals>.grader at 0x169f6a520>),
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nbud\npump\ncrock\nherb\npot\nmate\nwedge\ngrass\nwok\nmary jane\nchum\nslide\nclog\npal\nskillet\nweed'}], grader=<function get_grader.<locals>.grader at 0x169f6ba60>),
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nMINUTE\nDIG\nMEAL\nCOOLER\nHOUR\nTENT\nSLIGHT\nMEDIUM\nSMALL\nBARB\nCAMPER\nLANTERN\nJAB\nSLEEPING BAG\nDISS\nWEE'}], grader=<function get_grader.<locals>.grader at 0x169f6b060>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\ncrush\nutah\nrush\nhawk\nmontana\nmug\narizona\ngenesis\nsquirt\nstark\nyes\ncolorado\nkansas\nsprite\nnevada\nsoprano'}], grader=<function get_grader.<locals>.grader at 0x169dea980>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nHEART\nCOMET\nTASTE\nSINGER\nSANTA\nCUPID\nCARD\nDANCER\nROSE\nBOYS\nSTAND-UP\nVIXEN\nLIEUTENANT\nACTOR\nDASHER\nCHOCOLATE'}], grader=<function get_grader.<locals>.grader at 0x169de8c20>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nshadow\ngear\ndog\nbeard\nhandlebar\ntrack\ngoatee\nvote\ntail\nmovie\nwheel\ndoubt\nmustache\npedal\nfollow\nstubble'}], grader=<function get_grader.<locals>.grader at 0x169de80e0>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nMASTODON\nX\nSMACK\nTHREADS\nBUSTS\nPECK\nDODO\nDUDS\nSMOOCH\nMAMMOTH\nOUTFIT\nFLOPS\nMISSES\nGETUP\nTURKEYS\nTRILOBITE'}], grader=<function get_grader.<locals>.grader at 0x169deb060>),
# ...
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nconstruction\npaper\ngreat\nglee\nbig\nfelicity\npoetry\ngiant\nhumor\nwhooping\ncheers\nfiction\ntravel\neuphoria\nhuge\nfrasier'}], grader=<function get_grader.<locals>.grader at 0x16a11be20>),
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nTAU\nISLAND\nNOTE\nGEM\nSTAFF\nSCALES\nBULL\nCAN\nCAPITOL\nCRAB\nREST\nVIRGIN\nLIB\nCOLUMBIA\nTWINS\nCLEF'}], grader=<function get_grader.<locals>.grader at 0x16a118180>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nalpha\nbet\npom\nma\nusa\nyo\nla\ntango\nbravo\nok\nboo\ne\nhi\ntom\nhallmark\nromeo'}], grader=<function get_grader.<locals>.grader at 0x16a1187c0>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nSTATE\nFLAG\nPURE\nAIR\nPRINCE\nBANNER\nUTTER\nFADE\nSPEAK\nSHEER\nSTARK\nTOTAL\nEBB\nVOICE\nWANE\nWAYNE'}], grader=<function get_grader.<locals>.grader at 0x16a1185e0>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nnail\nshake\nrice\npeanut\nnote\nfloat\npalm\nscrew\nfingers\nolive\nbolt\nsplit\ncorn\nrivet\nwicket\nsundae'}], grader=<function get_grader.<locals>.grader at 0x16a118f40>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nSPRING\nBREEZE\nSPIRAL\nBANK\nWIND\nVAULT\nMOUTH\nSNAP\nLEAP\nBED\nTWIST\nCINCH\nPICNIC\nCOIL\nBOUND\nDELTA'}], grader=<function get_grader.<locals>.grader at 0x16a118b80>),
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nsilk\nblow\nlace\nland\nsole\nbaby\nvelvet\ntongue\nperch\npackage\nsettle\nspeech\nsatin\neyelet\nroost\nchiffon'}], grader=<function get_grader.<locals>.grader at 0x16a118cc0>),
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nBALL\nTAIL\nCLOUD\nFIN\nSHADOW\nICE\nFLIPPER\nFOG\nBUMPER\nTRACK\nHAZE\nIRE\nNETHER\nPLUNGER\nTRAIL\nMIST'}], grader=<function get_grader.<locals>.grader at 0x16a1189a0>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\ntough\nstop\nrough\nblue\ngreen\ndough\ncoarse\nenough\ncough\nuncle\nbough\nbawdy\nbunker\nrisque\nmercy\nfairway'}], grader=<function get_grader.<locals>.grader at 0x16a118ae0>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nSPOON\nBUG\nSCREEN\nFORK\nBOWL\nPART\nHOUND\nFOX\nFIELD\nBADGER\nSPLIT\nDOME\nNAG\nLINING\nARENA\nDIVIDE'}], grader=<function get_grader.<locals>.grader at 0x16a11a480>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nshark\nmotto\ncrab\nseal\nduck\nquack\nflag\ncrank\ncrook\nstoop\ngrump\nanthem\ncrouch\ngrouch\ncheat\nsquat'}], grader=<function get_grader.<locals>.grader at 0x16a11b880>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nPLOT\nPLOP\nPLOW\nPLOY\nTICKLE\nSICKLE\nTRICK\nBANG\nRUSE\nAMUSE\nSPLASH\nRAKE\nPLEASE\nTHUD\nHOE\nDELIGHT'}], grader=<function get_grader.<locals>.grader at 0x16a119620>),
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\npages\nsticks\nbank\nstones\ncoal\nbone\nnerve\nsave\nguts\ncarrot\nstore\nbusiness\nsnow\nstash\ngirl\ngall'}], grader=<function get_grader.<locals>.grader at 0x16a119580>),
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nFIRST\nAMATEUR\nBROADWAY\nJIFFY\nHAPPY\nSECOND\nRUSH\nPARK\nCHIEF\nFIFTH\nFLASH\nPRINCIPAL\nMADISON\nWINK\nMAIN\nELEVENTH'}], grader=<function get_grader.<locals>.grader at 0x16a118e00>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\ndraw\nsketch\nwatch\ncharm\ntie\nfreight\nroutine\nbracelet\noften\ncanine\nbelt\nbit\npull\nstone\njoke\nappeal'}], grader=<function get_grader.<locals>.grader at 0x16a119440>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nDINKY\nITCHY\nINDEX\nBUZZ\nPINKY\nRING\nSLIGHT\nMINUTE\nSPEEDY\nLITTLE\nAPPENDIX\nCALL\nCHAPTER\nDIAL\nJERRY\nPREFACE'}], grader=<function get_grader.<locals>.grader at 0x16a118d60>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nlead\nhidden\nhamper\nmyself\none\niron\ndirect\nsilicon\niodine\nuncanny\nguide\ndryer\nsteer\nwasher\niota\ndeath'}], grader=<function get_grader.<locals>.grader at 0x16a1193a0>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nANGEL\nHAIR\nSPELL\nCOMB\nWAIL\nWITCH\nWHILE\nWAX\nDEAR\nHONEY\nCLOWN\nPERIOD\nPIRATE\nHOARSE\nSTRETCH\nHIVE'}], grader=<function get_grader.<locals>.grader at 0x16a118400>),
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\ncar\ngame\nblue\ndash\nstraw\nsplash\nin\nboat\ndrop\ndown\ngoose\non board\npinch\ntrain\nrasp\nplane'}], grader=<function get_grader.<locals>.grader at 0x16a11a8e0>),
#  Task(messages=[{'role': 'user', 'content': 'Group words that share a common thread. There are four words for each common thread. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nCROWN\nSOFT\nDICE\nSHOULDER\nCHOP\nCANDLE\nROBE\nLIGHT\nEYELASH\nTORCH\nMELLOW\nBELLY\nMILD\nHOCK\nDANDELION\nTABLET'}], grader=<function get_grader.<locals>.grader at 0x16a11a840>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nsanta\nbaby\nzip\nline\nlove\nsauce\npoint\nenergy\nboo\nray\njuice\ndear\nfire\ncode\nsegment\nagent'}], grader=<function get_grader.<locals>.grader at 0x16a118360>),
#  Task(messages=[{'role': 'user', 'content': 'This is a puzzle. Create four groups of four. Words in each group fit under a specific category. Some categories might be defined by their use of wordplay (palindromes, homophones, adding or dropping letters and words) rather than the literal meanings of the words on the cards. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nLEAF\nTHUMB\nDRIVE\nPAGE\nSTEM\nPICK\nBLOW\nCHECK\nSTREET\nCURB\nSHEET\nALLEY\nLIMIT\nLANE\nHOLD\nFOLIO'}], grader=<function get_grader.<locals>.grader at 0x16a118220>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nms\npaint\nghost\nbell\npastel\nsign\nblack\nink\nrev\nwarning\nmessage\ngen\ndr\nprof\ncharcoal\nomen'}], grader=<function get_grader.<locals>.grader at 0x16a118720>),
#  Task(messages=[{'role': 'user', 'content': 'Find groups of four items that share something in common. Output them in the following format: four total lines. On each line, there should be four comma-separated items. No additional text (like group titles or descriptions) should be in the output. Also, there should not be anything in your output before or after the solution.\nWords:\n\nSWIFT\nHOLIDAY\nCARDINAL\nHOOD\nZIP\nMONK\nTRUNK\nDASH\nPARKER\nLARK\nDART\nTIRE\nBOLT\nBUMPER\nJAY\nHANCOCK'}], grader=<function get_grader.<locals>.grader at 0x16a119bc0>)]

# %%
fireworks = openai.AsyncOpenAI(
    base_url="https://api.fireworks.ai/inference/v1",
    api_key=os.getenv("FIREWORKS_API_KEY"),
)
openrouter = openai.AsyncOpenAI(
    base_url="https://openrouter.ai/api/v1", api_key=os.getenv("OPENROUTER_API_KEY")
)
together = openai.AsyncOpenAI(
    base_url="https://api.together.xyz/v1", api_key=os.getenv("TOGETHER_API_KEY")
)

results = await asyncio.gather(
    get_task_results(
        tasks=benchmark_tasks,
        client=fireworks,
        model="accounts/fireworks/models/deepseek-r1",
        params=ChatCompletionParams(
            max_tokens=2**17,
            logprobs=True,
            top_logprobs=5,
        ),
        pbar_desc="deepseek-r1",
        prices=(8.0, 8.0),
    ),
    # get_task_results(
    #     tasks=benchmark_tasks,
    #     client=fireworks,
    #     model="accounts/fireworks/models/deepseek-r1",
    #     params=ChatCompletionParams(
    #         logit_bias={128799: -4},  # type: ignore
    #         max_tokens=2**17,
    #         logprobs=True,
    #         temperature=0.6,
    #         top_logprobs=5,
    #     ),
    #     pbar_desc="deepseek-r1:high:0.6",
    #     prices=(8.0, 8.0),
    # ),
    # get_task_results(
    #     tasks=benchmark_tasks,
    #     client=fireworks,
    #     model="accounts/fireworks/models/deepseek-r1",
    #     params=ChatCompletionParams(
    #         max_tokens=2**17,
    #         logprobs=True,
    #         temperature=0.6,
    #         top_logprobs=5,
    #     ),
    #     pbar_desc="deepseek-r1:0.6",
    #     prices=(8.0, 8.0),
    # ),
    # get_task_results(
    #     tasks=benchmark_tasks,
    #     client=fireworks,
    #     model="accounts/fireworks/models/deepseek-r1",
    #     params=ChatCompletionParams(
    #         max_tokens=2**17,
    #         logprobs=True,
    #         temperature=0.85,
    #         top_logprobs=5,
    #     ),
    #     pbar_desc="deepseek-r1:0.85",
    #     prices=(8.0, 8.0),
    # ),
    get_task_results(
        tasks=benchmark_tasks,
        client=openrouter,
        model="deepseek/deepseek-r1-distill-qwen-1.5b",
        pbar_desc="r1-qwen-1.5b",
        prices=(0.18, 0.18),
    ),
    get_task_results(
        tasks=benchmark_tasks,
        client=openrouter,
        model="qwen/qwen-2.5-7b-instruct",
        pbar_desc="qwen-2.5-7b",
        params=ChatCompletionParams(
            extra_body={"provider": {"order": ["DeepInfra"], "allow_fallbacks": False}},
        ),
        prices=(0.0025, 0.005),
    ),
    get_task_results(
        tasks=benchmark_tasks,
        client=openrouter,
        model="deepseek/deepseek-r1-distill-qwen-14b",
        pbar_desc="r1-qwen-14b",
        prices=(1.6, 1.6),
    ),
    # get_task_results(
    #     tasks=benchmark_tasks,
    #     client=openrouter,
    #     model="deepseek/deepseek-r1-distill-qwen-14b",
    #     params=ChatCompletionParams(
    #         temperature=0.6,
    #     ),
    #     pbar_desc="r1-qwen-14b:0.6",
    #     prices=(1.6, 1.6),
    # ),
    get_task_results(
        tasks=benchmark_tasks,
        client=openrouter,
        model="deepseek/deepseek-r1-distill-qwen-32b",
        params=ChatCompletionParams(
            extra_body={"provider": {"order": ["DeepInfra"], "allow_fallbacks": False}},
        ),
        pbar_desc="r1-qwen-32b",
        prices=(0.12, 0.18),
    ),
    # get_task_results(
    #     tasks=benchmark_tasks,
    #     client=openrouter,
    #     model="deepseek/deepseek-r1-distill-qwen-32b",
    #     params=ChatCompletionParams(
    #         temperature=0.6,
    #         extra_body={"provider": {"order": ["DeepInfra"], "allow_fallbacks": False}},
    #     ),
    #     pbar_desc="r1-qwen-32b:0.6",
    #     prices=(0.12, 0.18),
    # ),
    get_task_results(
        tasks=benchmark_tasks,
        client=openrouter,
        model="deepseek/deepseek-r1-distill-llama-70b:free",
        params=ChatCompletionParams(
            extra_body={"provider": {"order": ["Targon"], "allow_fallbacks": False}},
        ),
        pbar_desc="r1-llama-70b:targon",
        prices=(0.0, 0.0),
    ),
    # get_task_results(
    #     tasks=benchmark_tasks,
    #     client=openrouter,
    #     model="deepseek/deepseek-r1-distill-llama-70b:free",
    #     params=ChatCompletionParams(
    #         logit_bias={"</think>": 10},
    #         extra_body={"provider": {"order": ["Targon"], "allow_fallbacks": False}},
    #     ),
    #     pbar_desc="r1-llama-70b:low",
    #     prices=(0.0, 0.0),
    # ),
    # get_task_results(
    #     tasks=benchmark_tasks,
    #     client=openrouter,
    #     model="deepseek/deepseek-r1-distill-llama-70b:free",
    #     params=ChatCompletionParams(
    #         logit_bias={"</think>": -2},
    #         extra_body={"provider": {"order": ["Targon"], "allow_fallbacks": False}},
    #     ),
    #     pbar_desc="r1-llama-70b:high",
    #     prices=(0.0, 0.0),
    # ),
    get_task_results(
        tasks=benchmark_tasks,
        client=openrouter,
        model="deepseek/deepseek-r1-distill-llama-70b",
        params=ChatCompletionParams(
            extra_body={"provider": {"order": ["SambaNova"], "allow_fallbacks": False}},
        ),
        pbar_desc="r1-llama-70b:samba",
        prices=(0.7, 1.4),
    ),
    # get_task_results(
    #     tasks=benchmark_tasks,
    #     client=openrouter,
    #     model="deepseek/deepseek-r1-distill-llama-70b",
    #     params=ChatCompletionParams(
    #         temperature=0.6,
    #         extra_body={"provider": {"order": ["SambaNova"], "allow_fallbacks": False}},
    #     ),
    #     pbar_desc="r1-llama-70b:samba:0.6",
    #     prices=(0.7, 1.4),
    # ),
)
# Out:
# deepseek-r1:   0%|          | 0/100 [00:00<?, ?it/s]
# r1-qwen-1.5b:   0%|          | 0/100 [00:00<?, ?it/s]
# qwen-2.5-7b:   0%|          | 0/100 [00:00<?, ?it/s]
# r1-qwen-14b:   0%|          | 0/100 [00:00<?, ?it/s]
# r1-qwen-32b:   0%|          | 0/100 [00:00<?, ?it/s]
# r1-llama-70b:targon:   0%|          | 0/100 [00:00<?, ?it/s]
# r1-llama-70b:samba:   0%|          | 0/100 [00:00<?, ?it/s]
# r1-qwen-14b: 100%|██████████| 100/100 [00:21<00:00,  4.55it/s, completion_tokens=3930, prompt_tokens=136, reward=0.237, spend=$0.00]
# r1-qwen-1.5b: 100%|██████████| 100/100 [00:21<00:00,  3.56it/s, completion_tokens=3917, prompt_tokens=136, reward=0, spend=$0.00]
# qwen-2.5-7b: 100%|██████████| 100/100 [00:21<00:00,  6.17it/s, completion_tokens=43, prompt_tokens=140, reward=0.0425, spend=$0.00]
# r1-qwen-32b: 100%|██████████| 100/100 [00:21<00:00,  8.39it/s, completion_tokens=3258, prompt_tokens=136, reward=0.292, spend=$0.00]
# r1-llama-70b:samba: 100%|██████████| 100/100 [00:21<00:00,  9.52it/s, completion_tokens=3013, prompt_tokens=135, reward=0.398, spend=$0.00]
# r1-llama-70b:targon: 100%|██████████| 100/100 [00:21<00:00,  8.98it/s, completion_tokens=2772, prompt_tokens=137, reward=0.41, spend=$0.00]
# deepseek-r1: 100%|██████████| 100/100 [00:22<00:00,  6.52it/s, completion_tokens=4857, prompt_tokens=139, reward=0.667, spend=$0.00]

# %%
raise [exception for result in results[1] for exception in result.exceptions][0]
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 raise [exception for result in results[1] for exception in result.exceptions][0]
#
# File ~/github/bradhilton/openpipe-rl/experiments/lib/tasks.py:85, in get_task_results.<locals>.get_task_result(task, client, model, log_results)
#      68 for chat_completion_future in asyncio.as_completed(
#      69     get_chat_completion(
#      70         client,
#    (...)
#      82     for _ in range(n)
#      83 ):
#      84     try:
# ---> 85         chat_completion = await chat_completion_future
#      86         chat_completions.append(chat_completion)
#      87         stats.update(id=chat_completion.id, usage=chat_completion.usage)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/tasks.py:631, in as_completed.<locals>._wait_for_one()
#     628 if f is None:
#     629     # Dummy value from _on_timeout().
#     630     raise exceptions.TimeoutError
# --> 631 return f.result()
#
# File ~/github/bradhilton/openpipe-rl/experiments/lib/chat_completions.py:98, in get_chat_completion(client, cache, log_results, on_chunk, **create_params)
#      96             return chat_completion
#      97 if log_results or on_chunk:
# ---> 98     stream = await client.chat.completions.create(**create_params, stream=True)
#      99     log_file = os.path.join(
#     100         chat_completion_logs_dir, f"{datetime.now().isoformat()}.log"
#     101     )
#     102     if log_results:
#
# File ~/github/bradhilton/openpipe-rl/.venv/lib/python3.12/site-packages/openai/resources/chat/completions.py:1727, in AsyncCompletions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#    1685 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1686 async def create(
#    1687     self,
#    (...)
#    1724     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    1725 ) -> ChatCompletion | AsyncStream[ChatCompletionChunk]:
#    1726     validate_response_format(response_format)
# -> 1727     return await self._post(
#    1728         "/chat/completions",
#    1729         body=await async_maybe_transform(
#    1730             {
#    1731                 "messages": messages,
#    1732                 "model": model,
#    1733                 "audio": audio,
#    1734                 "frequency_penalty": frequency_penalty,
#    1735                 "function_call": function_call,
#    1736                 "functions": functions,
#    1737                 "logit_bias": logit_bias,
#    1738                 "logprobs": logprobs,
#    1739                 "max_completion_tokens": max_completion_tokens,
#    1740                 "max_tokens": max_tokens,
#    1741                 "metadata": metadata,
#    1742                 "modalities": modalities,
#    1743                 "n": n,
#    1744                 "parallel_tool_calls": parallel_tool_calls,
#    1745                 "prediction": prediction,
#    1746                 "presence_penalty": presence_penalty,
#    1747                 "reasoning_effort": reasoning_effort,
#    1748                 "response_format": response_format,
#    1749                 "seed": seed,
#    1750                 "service_tier": service_tier,
#    1751                 "stop": stop,
#    1752                 "store": store,
#    1753                 "stream": stream,
#    1754                 "stream_options": stream_options,
#    1755                 "temperature": temperature,
#    1756                 "tool_choice": tool_choice,
#    1757                 "tools": tools,
#    1758                 "top_logprobs": top_logprobs,
#    1759                 "top_p": top_p,
#    1760                 "user": user,
#    1761             },
#    1762             completion_create_params.CompletionCreateParams,
#    1763         ),
#    1764         options=make_request_options(
#    1765             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1766         ),
#    1767         cast_to=ChatCompletion,
#    1768         stream=stream or False,
#    1769         stream_cls=AsyncStream[ChatCompletionChunk],
#    1770     )
#
# File ~/github/bradhilton/openpipe-rl/.venv/lib/python3.12/site-packages/openai/_base_client.py:1849, in AsyncAPIClient.post(self, path, cast_to, body, files, options, stream, stream_cls)
#    1835 async def post(
#    1836     self,
#    1837     path: str,
#    (...)
#    1844     stream_cls: type[_AsyncStreamT] | None = None,
#    1845 ) -> ResponseT | _AsyncStreamT:
#    1846     opts = FinalRequestOptions.construct(
#    1847         method="post", url=path, json_data=body, files=await async_to_httpx_files(files), **options
#    1848     )
# -> 1849     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File ~/github/bradhilton/openpipe-rl/.venv/lib/python3.12/site-packages/openai/_base_client.py:1543, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1540 else:
#    1541     retries_taken = 0
# -> 1543 return await self._request(
#    1544     cast_to=cast_to,
#    1545     options=options,
#    1546     stream=stream,
#    1547     stream_cls=stream_cls,
#    1548     retries_taken=retries_taken,
#    1549 )
#
# File ~/github/bradhilton/openpipe-rl/.venv/lib/python3.12/site-packages/openai/_base_client.py:1644, in AsyncAPIClient._request(self, cast_to, options, stream, stream_cls, retries_taken)
#    1641         await err.response.aread()
#    1643     log.debug("Re-raising status error")
# -> 1644     raise self._make_status_error_from_response(err.response) from None
#    1646 return await self._process_response(
#    1647     cast_to=cast_to,
#    1648     options=options,
#    (...)
#    1652     retries_taken=retries_taken,
#    1653 )
#
# BadRequestError: Error code: 400 - {'error': {'object': 'error', 'type': 'invalid_request_error', 'message': "Input should be a valid integer, unable to parse string as an integer, field: 'logit_bias.</think>.[key]', value: '</think>'"}}

# %%
from typing import Any, Callable


def wrap_bound_method(method, wrapper):
    # Get the bound instance and the original function
    bound_instance = method.__self__
    original_func = method.__func__
    
    # Create a new wrapped method
    wrapped = wrapper(original_func)
    
    # Bind the wrapped function to the instance
    import types
    bound_method = types.MethodType(wrapped, bound_instance)
    
    # For the OpenAI client, we need to look at the instance's __dict__ directly
    instance_dict = vars(bound_instance)
    for attr_name, attr_value in instance_dict.items():
        if getattr(attr_value, '__func__', None) is original_func:
            setattr(bound_instance, attr_name, bound_method)
            break
    else:
        # If not found in instance dict, try class dict
        for attr_name, attr_value in bound_instance.__class__.__dict__.items():
            if getattr(attr_value, '__func__', None) is original_func:
                setattr(bound_instance, attr_name, bound_method)
                break
        else:
            # If still not found, just monkey patch the create attribute directly
            if hasattr(bound_instance, 'create'):
                bound_instance.create = bound_method
            else:
                raise ValueError("Method not found and cannot patch directly")
    
    return bound_method


def wrapper(f: Callable) -> Callable:
    async def wrapped(*args: Any, **kwargs: Any) -> Any:
        print(f"Calling {f.__name__} with args: {args} and kwargs: {kwargs}")
        return await f(*args, **kwargs)

    return wrapped


wrap_bound_method(together.chat.completions.create, wrapper)
await together.chat.completions.create(messages=[], model="")
# Out:
# Calling create with args: (<openai.resources.chat.completions.AsyncCompletions object at 0x14d273560>,) and kwargs: {'messages': [], 'model': ''}
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[15], line 47
#      43     return wrapped
#      46 wrap_bound_method(together.chat.completions.create, wrapper)
# ---> 47 await together.chat.completions.create(messages=[], model="")
#
# Cell In[15], line 41, in wrapper.<locals>.wrapped(*args, **kwargs)
#      39 async def wrapped(*args: Any, **kwargs: Any) -> Any:
#      40     print(f"Calling {f.__name__} with args: {args} and kwargs: {kwargs}")
# ---> 41     return await f(*args, **kwargs)
#
# File ~/github/bradhilton/openpipe-rl/.venv/lib/python3.12/site-packages/openai/resources/chat/completions.py:1727, in AsyncCompletions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#    1685 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1686 async def create(
#    1687     self,
#    (...)
#    1724     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    1725 ) -> ChatCompletion | AsyncStream[ChatCompletionChunk]:
#    1726     validate_response_format(response_format)
# -> 1727     return await self._post(
#    1728         "/chat/completions",
#    1729         body=await async_maybe_transform(
#    1730             {
#    1731                 "messages": messages,
#    1732                 "model": model,
#    1733                 "audio": audio,
#    1734                 "frequency_penalty": frequency_penalty,
#    1735                 "function_call": function_call,
#    1736                 "functions": functions,
#    1737                 "logit_bias": logit_bias,
#    1738                 "logprobs": logprobs,
#    1739                 "max_completion_tokens": max_completion_tokens,
#    1740                 "max_tokens": max_tokens,
#    1741                 "metadata": metadata,
#    1742                 "modalities": modalities,
#    1743                 "n": n,
#    1744                 "parallel_tool_calls": parallel_tool_calls,
#    1745                 "prediction": prediction,
#    1746                 "presence_penalty": presence_penalty,
#    1747                 "reasoning_effort": reasoning_effort,
#    1748                 "response_format": response_format,
#    1749                 "seed": seed,
#    1750                 "service_tier": service_tier,
#    1751                 "stop": stop,
#    1752                 "store": store,
#    1753                 "stream": stream,
#    1754                 "stream_options": stream_options,
#    1755                 "temperature": temperature,
#    1756                 "tool_choice": tool_choice,
#    1757                 "tools": tools,
#    1758                 "top_logprobs": top_logprobs,
#    1759                 "top_p": top_p,
#    1760                 "user": user,
#    1761             },
#    1762             completion_create_params.CompletionCreateParams,
#    1763         ),
#    1764         options=make_request_options(
#    1765             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1766         ),
#    1767         cast_to=ChatCompletion,
#    1768         stream=stream or False,
#    1769         stream_cls=AsyncStream[ChatCompletionChunk],
#    1770     )
#
# File ~/github/bradhilton/openpipe-rl/.venv/lib/python3.12/site-packages/openai/_base_client.py:1849, in AsyncAPIClient.post(self, path, cast_to, body, files, options, stream, stream_cls)
#    1835 async def post(
#    1836     self,
#    1837     path: str,
#    (...)
#    1844     stream_cls: type[_AsyncStreamT] | None = None,
#    1845 ) -> ResponseT | _AsyncStreamT:
#    1846     opts = FinalRequestOptions.construct(
#    1847         method="post", url=path, json_data=body, files=await async_to_httpx_files(files), **options
#    1848     )
# -> 1849     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File ~/github/bradhilton/openpipe-rl/.venv/lib/python3.12/site-packages/openai/_base_client.py:1543, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1540 else:
#    1541     retries_taken = 0
# -> 1543 return await self._request(
#    1544     cast_to=cast_to,
#    1545     options=options,
#    1546     stream=stream,
#    1547     stream_cls=stream_cls,
#    1548     retries_taken=retries_taken,
#    1549 )
#
# File ~/github/bradhilton/openpipe-rl/.venv/lib/python3.12/site-packages/openai/_base_client.py:1644, in AsyncAPIClient._request(self, cast_to, options, stream, stream_cls, retries_taken)
#    1641         await err.response.aread()
#    1643     log.debug("Re-raising status error")
# -> 1644     raise self._make_status_error_from_response(err.response) from None
#    1646 return await self._process_response(
#    1647     cast_to=cast_to,
#    1648     options=options,
#    (...)
#    1652     retries_taken=retries_taken,
#    1653 )
#
# NotFoundError: Error code: 404 - {'id': '91278fde2f885306', 'error': {'message': 'Unable to access model . Please visit https://api.together.ai/models to view the list of supported models.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_available'}}
