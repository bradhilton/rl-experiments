# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %%html
# <style>
# .cell-output-ipywidget-background {
#     background-color: transparent !important;
# }
# :root {
#     --jp-widgets-color: var(--vscode-editor-foreground);
#     --jp-widgets-font-size: var(--vscode-editor-font-size);
# }
# </style>
# Out:
# <style>
# .cell-output-ipywidget-background {
#     background-color: transparent !important;
# }
# :root {
#     --jp-widgets-color: var(--vscode-editor-foreground);
#     --jp-widgets-font-size: var(--vscode-editor-font-size);
# }
# </style>

# %%
from unsloth import FastLanguageModel
import torch

max_seq_length = 4096  # Can increase for longer reasoning traces
lora_rank = 32  # Larger rank = smarter, but slower

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name="meta-llama/meta-Llama-3.1-8B-Instruct",
    max_seq_length=max_seq_length,
    load_in_4bit=True,  # False for LoRA 16bit
    fast_inference=True,  # Enable vLLM fast inference
    max_lora_rank=lora_rank,
    gpu_memory_utilization=0.6,  # Reduce if out of memory
)

model = FastLanguageModel.get_peft_model(
    model,
    r=lora_rank,  # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules=[
        "q_proj",
        "k_proj",
        "v_proj",
        "o_proj",
        "gate_proj",
        "up_proj",
        "down_proj",
    ],  # Remove QKVO if out of memory
    lora_alpha=lora_rank,
    use_gradient_checkpointing="unsloth",  # Enable long context finetuning
    random_state=3407,
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# INFO 03-13 21:21:22 __init__.py:190] Automatically detected platform cuda.
# ==((====))==  Unsloth 2025.3.10: Fast Llama patching. Transformers: 4.48.3. vLLM: 0.7.2.
#    \\   /|    NVIDIA H100 80GB HBM3. Num GPUs = 1. Max memory: 79.109 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 9.0. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: vLLM loading unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit with actual GPU utilization = 59.54%
# Unsloth: Your GPU has CUDA compute capability 9.0 with VRAM = 79.11 GB.
# Unsloth: Using conservativeness = 1.0. Chunked prefill tokens = 4096. Num Sequences = 226.
# Unsloth: vLLM's KV Cache can use up to 40.93 GB. Also swap space = 6 GB.
# INFO 03-13 21:21:33 config.py:542] This model supports multiple tasks: {'generate', 'classify', 'reward', 'score', 'embed'}. Defaulting to 'generate'.
# Unsloth: vLLM Bitsandbytes config using kwargs = {'load_in_8bit': False, 'load_in_4bit': True, 'bnb_4bit_compute_dtype': 'bfloat16', 'bnb_4bit_quant_storage': 'uint8', 'bnb_4bit_quant_type': 'nf4', 'bnb_4bit_use_double_quant': True, 'llm_int8_enable_fp32_cpu_offload': False, 'llm_int8_has_fp16_weight': False, 'llm_int8_skip_modules': ['lm_head', 'multi_modal_projector', 'merger', 'modality_projection', 'model.layers.1.mlp'], 'llm_int8_threshold': 6.0}
# INFO 03-13 21:21:33 llm_engine.py:234] Initializing a V0 LLM engine (v0.7.2) with config: model='unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit', speculative_config=None, tokenizer='unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=4096, download_dir=None, load_format=LoadFormat.BITSANDBYTES, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=bitsandbytes, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda:0, decoding_config=DecodingConfig(guided_decoding_backend='xgrammar'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=False, use_async_output_proc=True, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"level":0,"splitting_ops":[],"compile_sizes":[],"cudagraph_capture_sizes":[232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"max_capture_size":232}, use_cached_outputs=False,
# INFO 03-13 21:21:34 cuda.py:230] Using Flash Attention backend.
# INFO 03-13 21:21:34 model_runner.py:1110] Starting to load model unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit...
# INFO 03-13 21:21:34 loader.py:1102] Loading weights with BitsAndBytes quantization.  May take a while ...
# [W313 21:21:34.186654765 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# INFO 03-13 21:21:35 weight_utils.py:252] Using model weights format ['*.safetensors']
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# INFO 03-13 21:21:38 model_runner.py:1115] Loading model weights took 5.5976 GB
# INFO 03-13 21:21:38 punica_selector.py:18] Using PunicaWrapperGPU.
# INFO 03-13 21:21:39 worker.py:267] Memory profiling takes 1.37 seconds
# INFO 03-13 21:21:39 worker.py:267] the current vLLM instance can use total_gpu_memory (79.11GiB) x gpu_memory_utilization (0.60) = 47.11GiB
# INFO 03-13 21:21:39 worker.py:267] model weights take 5.60GiB; non_torch_memory takes 0.15GiB; PyTorch activation peak memory takes 1.09GiB; the rest of the memory reserved for KV Cache is 40.26GiB.
# INFO 03-13 21:21:40 executor_base.py:110] # CUDA blocks: 20613, # CPU blocks: 3072
# INFO 03-13 21:21:40 executor_base.py:115] Maximum concurrency for 4096 tokens per request: 80.52x
# INFO 03-13 21:21:43 model_runner.py:1434] Capturing cudagraphs for decoding. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI. If out-of-memory error occurs during cudagraph capture, consider decreasing `gpu_memory_utilization` or switching to eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# Capturing CUDA graph shapes: 100%|██████████| 32/32 [00:24<00:00,  1.31it/s]
# INFO 03-13 21:22:07 model_runner.py:1562] Graph capturing finished in 24 secs, took 4.17 GiB
# INFO 03-13 21:22:07 llm_engine.py:431] init engine (profile, create kv cache, warmup model) took 29.48 seconds
# Unsloth 2025.3.10 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %%
from datasets import Dataset
from lib.temporal_clue import get_temporal_clue_puzzles
import random


puzzles = get_temporal_clue_puzzles()[128:]
random.seed(42)
random.shuffle(puzzles)

dataset = Dataset.from_list(puzzles).map(
    lambda x: {
        "prompt": [
            {"role": "user", "content": x["prompt"]},
        ],
        "answer": x["solution"],
    }
)
# Out:
# Map:   0%|          | 0/2860 [00:00<?, ? examples/s]

# %%
import re


def _reward_func(response, answer) -> float:
    num_correct = 0
    for key, value in answer.items():
        if matches := re.findall(rf"{key}\. ([A-Za-z \.:-]+)", response):
            match = matches[-1]
            if match is not None and match.strip().lower() == value.lower():
                num_correct += 1
    return num_correct / len(answer)


def reward_func(prompts, completions, answer, **kwargs) -> list[float]:
    responses = [completion[0]["content"] for completion in completions]
    q = prompts[0][-1]["content"]
    print(
        "-" * 20,
        f"Question:\n{q}",
        f"\nAnswer:\n{answer[0]}",
        f"\nResponse:\n{responses[0]}",
    )
    return [_reward_func(r, a) for r, a in zip(responses, answer)]

# %%
max_prompt_length = 256

from trl import GRPOConfig, GRPOTrainer

training_args = GRPOConfig(
    learning_rate=5e-6,
    adam_beta1=0.9,
    adam_beta2=0.99,
    weight_decay=0.1,
    warmup_ratio=0.1,
    lr_scheduler_type="cosine",
    optim="paged_adamw_8bit",
    logging_steps=1,
    per_device_train_batch_size=1,
    gradient_accumulation_steps=1,  # Increase to 4 for smoother training
    num_generations=6,  # Decrease if out of memory
    max_prompt_length=max_prompt_length,
    max_completion_length=max_seq_length - max_prompt_length,
    # num_train_epochs = 1, # Set to 1 for a full training run
    max_steps=250,
    save_steps=250,
    max_grad_norm=0.1,
    report_to="none",  # Can use Weights & Biases
    output_dir="outputs",
)
# Out:
# Unsloth: We now expect `per_device_train_batch_size` to be a multiple of `num_generations`.
# We will change the batch size of 1 to the `num_generations` of 6

# %%
trainer = GRPOTrainer(
    model=model,
    processing_class=tokenizer,
    reward_funcs=reward_func,  # type: ignore
    args=training_args,
    train_dataset=dataset,
)
trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 2,860 | Num Epochs = 1 | Total steps = 250
# O^O/ \_/ \    Batch size per device = 6 | Gradient accumulation steps = 1
# \        /    Data Parallel GPUs = 1 | Total batch size (6 x 1 x 1) = 6
#  "-____-"     Trainable parameters = 83,886,080/4,712,566,784 (1.78% trained)
# -------------------- Question:
# On a dark winter night, wealthy and enigmatic Mr. John Q. Boddy hosted a small, but lavish, dinner party for some of his closest associates. However, the night ended in tragedy when Mr. Boddy was found dead in one of the rooms of Tudor Mansion in the early hours of the morning. The following persons of interest have been identified as suspects:
#
# • Sgt. Gray
# • Monsieur Brunette
# • Madame Rose
# • Professor Plum
# • Miss Scarlet
# • Mrs. White
# • Miss Peach
# • Colonel Mustard
# • Mr. Green
#
# And the following weapons were found on the premises:
#
# • Revolver
# • Rope
# • Lead Pipe
# • Wrench
# • Horseshoe
# • Candlestick
#
# The murder could only have occured in one of the following rooms:
#
# 01. Courtyard
# 02. Library
# 03. Conservatory
# 04. Studio
# 05. Lounge
# 06. Drawing Room
# 07. Cloak Room
# 08. Hall
# 09. Kitchen
# 10. Dining Room
# 11. Gazebo
# 12. Ballroom
# 13. Fountain
# 14. Trophy Room
# 15. Carriage House
#
# The rooms are laid out as follows:
#
#   NN NN NN NN
# W 01|02|03|04 E
# W 05|06|07|08 E
# W 09|10|11|12 E
# W 13|14|15|- E
#   SS SS SS SS
#
# The exact time of the murder is a bit uncertain, but it has been narrowed down to one of the following times:
#
# • 10:00 PM
# • 10:30 PM
# • 11:00 PM
# • 11:30 PM
# • 12:00 AM
# • 12:30 AM
# • 01:00 AM
#
# At every time the suspects and Mr. Boddy either stayed in their current room or moved to an orthogonally adjacent room (north, south, east, or west). Weapons could be moved by suspects between rooms as well.
#
# Each suspect uniquely had one of the following possible motives for killing Mr. Boddy:
#
# • Power
# • Fear
# • Jealousy
# • Revenge
# • Betrayal
# • Pride
# • Anger
# • Ambition
# • Greed
#
# For the murder to occur, the murderer and Mr. Boddy must have been alone in a room with at least one weapon at some point in the night. Any clue about Mr. Boddy's whereabouts should be read as "Mr. Boddy (dead or alive) ..."
#
# The available clues are as follows:
#
# - The suspect motivated by Power was in the Cloak Room at 11:30 PM
# - The Rope was in the room just south of Professor Plum at 12:00 AM
# - Sgt. Gray was in the room just west of Monsieur Brunette at 12:00 AM
# - The murderer was in the Library at 11:30 PM
# - The suspect motivated by Betrayal was in the Lounge at 12:00 AM if and only if Colonel Mustard was in the Drawing Room at 12:30 AM
# - The suspect motivated by Pride was in the same room as Mr. Boddy at 10:30 PM
# - The Wrench was in the same room as the Lead Pipe at 10:00 PM
# - Sgt. Gray was in the Carriage House at 10:00 PM
# - Mr. Boddy was in the Library at 12:00 AM
# - Mr. Boddy was in the same room as Miss Peach at 10:00 PM
# - Monsieur Brunette was in the same room as Sgt. Gray at 11:00 PM
# - The Lead Pipe was in the Gazebo at 01:00 AM if and only if the suspect motivated by Jealousy was in the Ballroom at 10:00 PM
# - Colonel Mustard was in the Kitchen at 10:30 PM if and only if the suspect motivated by Pride was in the Conservatory at 01:00 AM
# - The suspect motivated by Power moved from the Cloak Room to the Hall at 12:30 AM
# - Madame Rose was in the Lounge at 10:30 PM
# - The suspect motivated by Fear was in the Kitchen at 11:00 PM or the suspect motivated by Revenge was in the Carriage House at 01:00 AM
# - The suspect motivated by Betrayal was in the Drawing Room at 12:30 AM or the suspect motivated by Power was in the Hall at 10:30 PM
# - Professor Plum was in the room just east of Mr. Boddy at 11:00 PM
# - Colonel Mustard was in the same room as Miss Scarlet at 01:00 AM
# - The Lead Pipe was in the room just north of Monsieur Brunette at 12:30 AM
# - The suspect motivated by Pride moved the Revolver from the Library to the Conservatory at 12:00 AM
# - Sgt. Gray was in the same room as Monsieur Brunette at 10:30 PM
# - The suspect motivated by Ambition moved from the Gazebo to the Cloak Room at 10:30 PM
# - Sgt. Gray was in the same room as Monsieur Brunette at 10:00 PM
# - Sgt. Gray moved from the Trophy Room to the Fountain at 01:00 AM
# - The suspect motivated by Jealousy moved from the Ballroom to the Hall at 11:00 PM
# - Colonel Mustard and Madame Rose were in the Lounge together at least once
# - Miss Scarlet moved from the Conservatory to the Library at 11:00 PM
# - The suspect motivated by Anger moved from the Library to the Drawing Room at 11:30 PM
# - The suspect motivated by Revenge was in the Carriage House at 10:30 PM
# - The Revolver was in the Conservatory at 10:00 PM
# - The suspect motivated by Revenge was in the Carriage House at 11:30 PM or Madame Rose was in the Carriage House at 12:30 AM
# - Mr. Boddy was murdered at 12:30 AM
# - Mr. Boddy was in the Library at 11:30 PM
# - The suspect motivated by Jealousy moved from the Hall to the Ballroom at 11:30 PM
# - The suspect motivated by Ambition was in the same room as the Wrench at 12:30 AM
# - Mr. Green was in the Ballroom at 01:00 AM
# - The suspect motivated by Greed moved from the Carriage House to the Trophy Room at 11:30 PM
# - The suspect motivated by Pride was in the Courtyard at 10:00 PM
# - Mr. Boddy and Professor Plum were in the Library together at least once
# - The Wrench was in the Ballroom at 12:30 AM
# - The suspect motivated by Ambition moved from the Gazebo to the Ballroom at 12:00 AM
# - The suspect motivated by Fear moved from the Cloak Room to the Conservatory at 10:30 PM
# - The Horseshoe was in the Drawing Room at 10:00 PM
# - The suspect motivated by Betrayal was in the Kitchen at 10:30 PM if and only if Miss Peach was in the Conservatory at 12:30 AM
# - Mr. Green moved the Wrench from the Cloak Room to the Gazebo at 11:00 PM
# - The Candlestick was in the Studio at 11:30 PM
# - The suspect motivated by Revenge was in the Carriage House at 12:00 AM or Madame Rose was in the Dining Room at 01:00 AM
# - Professor Plum moved from the Lounge to the Drawing Room at 10:30 PM
# - The suspect motivated by Betrayal moved from the Kitchen to the Lounge at 11:30 PM
# - The Wrench was in the Gazebo at 11:30 PM if and only if the suspect motivated by Jealousy was in the Gazebo at 01:00 AM
# - The Rope was in the Dining Room at 12:30 AM or the suspect motivated by Pride was at the Fountain at 10:30 PM
# - The suspect motivated by Pride moved from the Courtyard to the Library at 11:00 PM
# - Colonel Mustard moved from the Lounge to the Kitchen at 10:30 PM
# - Miss Scarlet moved the Horseshoe from the Library to the Drawing Room at 01:00 AM
# - The Lead Pipe was in the Ballroom at 12:00 AM if and only if the suspect motivated by Jealousy was in the Ballroom at 10:30 PM
# - The Wrench was in the Cloak Room at 10:00 PM if and only if Mrs. White was in the Gazebo at 12:30 AM
# - Miss Scarlet was in the Library at 12:00 AM
# - Madame Rose was in the Hall at 01:00 AM
#
# Please answer the following question(s):
#
# A. Who murdered Mr. Boddy?
# B. What weapon did the murderer use?
# C. Where was the murder committed?
# D. Why did the murderer do it?
#
# And the following bonus question(s):
#
# E. Where was Monsieur Brunette at 12:00 AM?
# F. What motivates Mr. Green?
# G. Where was the suspect motivated by Greed at 12:30 AM?
# H. Where was Mrs. White at 01:00 AM?
#
# Fill out your final answers in the following format:
#
# A. SUSPECT
# B. WEAPON
# C. ROOM
# D. MOTIVE
# E. ROOM
# F. MOTIVE
# G. ROOM
# H. ROOM
#
# Best of luck, detective.
# Answer:
# {'A': 'Miss Scarlet', 'B': 'Horseshoe', 'C': 'Library', 'D': 'Fear', 'E': 'Carriage House', 'F': 'Ambition', 'G': 'Trophy Room', 'H': 'Gazebo'}
# Response:
# A. Mrs. White
# B. Lead Pipe
# C. Drawing Room
# D. Jealousy
# E. Room just west of Monsieur Brunette
# F. Greed
# G. Carriage House
# H. Gazebo
#
# Explanation:
# From the clues, we can start by narrowing down the suspect who moved the Lead Pipe from the Cloak Room to the Gazebo (at 11:00 PM) and then to the Drawing Room (at 12:00 AM). Since only Mr. Green was in the Gazebo at 11:00 PM, the Lead Pipe in the Drawing Room at 12:00 AM must have been moved by Mr. Green.
#
# The suspect motivated by Jealousy was in the Ballroom at 10:00 PM. As the Lead Pipe was in the Ballroom at this time (or the suspect motivated by Jealousy was in the Ballroom if the Lead Pipe was in the Ballroom), the suspect motivated by Jealousy must have moved the Lead Pipe from the Gazebo to the Ballroom at 10:00 PM.
#
# Since the Lead Pipe was in the Ballroom at 12:00 AM, the suspect motivated by Jealousy must have stayed in the Ballroom from 10:00 PM to 12:00 AM. Then, the suspect moved the Lead Pipe to the Drawing Room at 12:00 AM and it was moved again to the Gazebo at 01:00 AM. Thus, the Lead Pipe was in the Gazebo at 01:00 AM for sure.
#
# Since the Candlestick was in the Studio at 11:30 PM, it must have been there all the time. The suspect motivated by Fear was in the Kitchen at 11:00 PM or the suspect motivated by Revenge was in the Carriage House at 01:00 AM. The suspect motivated by Greed moved from the Carriage House to the Trophy Room at 11:30 PM (previously established that the Greed and the Greed suspect "played a game together" at 10:30 PM) then to the room several spaces away from the Trophy Room (at 12:30 AM, given that the Greed suspect was not in the same room as the suspect motivated by Pride).
#
# Therefore, the Greed suspect must be someone who could be in a hall at 12:30 AM (not Colonel Mustard as he was with Madame Rose). Therefore, the Greed suspect is Mrs. White. As the Greed suspect was in the Carriage House at 11:30 PM and in the Hall at 12:30 AM, she was in the same room as the murderer at the estimated time. The Lead Pipe in the Drawing Room at 12:00 AM must have been moved by the Greed suspect. Since the Lead Pipe must have been moved at some point, the Greed suspect can be associated with this moving.
#
# Now, from the clues, the suspect motivated by Jealousy was in the Hall at 11:30 PM. The suspect motivated by Power moved from the Cloak Room to the Hall at 12:30 AM, so the suspect motivated by Jealousy must have moved from the Hall to the Ballroom at 11:30 PM.
#
# Here, we can associate 2 suspects (Mrs. White and the suspect motivated by Jealousy) to the 2 clues (the Lead Pipe in the Gazebo and the Lead Pipe in the Drawing Room). If they hadn't stayed in their current rooms, the murder wouldn't happen. Since Mrs. White was in the Gazebo at 12:30 AM, she can't move to the Drawing Room at 12:00 AM. Since the murder wouldn't be able to happen in case the Greed and the Jealousy suspects stay, both of them must be in the same room at 12:30 AM. Since the Greed and the Jealousy suspects were in the Carriage House and Hall at the same time, each of them can only be in the rooms adjacent to the Carriage House and the Hall, thus they have to be in the same room at 12:30 AM.
#
# The Greed suspect must be Mrs. White (explained earlier). The Greed suspect was in the Hall at 12:30 AM. Since the murder must happen between the Greed and Jealousy suspects in the same room, the Hall is the only place the murder would occur.
#     <div>
#
#       <progress value='6' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  6/250 04:42 < 4:47:40, 0.01 it/s, Epoch 0.00/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completion_length</th>
#       <th>kl</th>
#       <th>rewards / reward_func</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>0.083333</td>
#       <td>0.064550</td>
#       <td>850.833374</td>
#       <td>0.000000</td>
#       <td>0.083333</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>-0.000000</td>
#       <td>0.062500</td>
#       <td>0.104583</td>
#       <td>949.500000</td>
#       <td>0.000000</td>
#       <td>0.062500</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>0.145833</td>
#       <td>0.122899</td>
#       <td>534.500000</td>
#       <td>0.000547</td>
#       <td>0.145833</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000000</td>
#       <td>0.083333</td>
#       <td>0.151383</td>
#       <td>1535.000000</td>
#       <td>0.000520</td>
#       <td>0.083333</td>
#     </tr>
#   </tbody>
# </table><p>
# -------------------- Question:
# On a dark winter night, wealthy and enigmatic Mr. John Q. Boddy hosted a small, but lavish, dinner party for some of his closest associates. However, the night ended in tragedy when Mr. Boddy was found dead in one of the rooms of Tudor Mansion in the early hours of the morning. The following persons of interest have been identified as suspects:
#
# • Mr. Green
# • Miss Scarlet
# • Madame Rose
# • Mrs. Peacock
# • Sgt. Gray
# • Mrs. White
# • Monsieur Brunette
# • Colonel Mustard
# • Professor Plum
# • Miss Peach
#
# And the following weapons were found on the premises:
#
# • Revolver
# • Rope
# • Poison
# • Knife
# • Candlestick
# • Wrench
# • Lead Pipe
#
# The murder could only have occured in one of the following rooms:
#
# 01. Library
# 02. Ballroom
# 03. Cloak Room
# 04. Study
# 05. Carriage House
# 06. Lounge
# 07. Conservatory
# 08. Hall
# 09. Drawing Room
# 10. Kitchen
# 11. Trophy Room
#
# The rooms are laid out as follows:
#
#   NN NN NN NN
# W 01|02|03|04 E
# W 05|06|07|08 E
# W 09|10|11|- E
#   SS SS SS SS
#
# The exact time of the murder is a bit uncertain, but it has been narrowed down to one of the following times:
#
# • 11:30 PM
# • 12:00 AM
#
# At every time the suspects and Mr. Boddy either stayed in their current room or moved to an orthogonally adjacent room (north, south, east, or west). Weapons could be moved by suspects between rooms as well.
#
# Each suspect uniquely had one of the following possible motives for killing Mr. Boddy:
#
# • Anger
# • Greed
# • Pride
# • Jealousy
# • Fear
# • Power
# • Ambition
# • Hatred
# • Revenge
# • Betrayal
#
# For the murder to occur, the murderer and Mr. Boddy must have been alone in a room with at least one weapon at some point in the night. Any clue about Mr. Boddy's whereabouts should be read as "Mr. Boddy (dead or alive) ..."
#
# The available clues are as follows:
#
# - The Poison was in the Hall at 12:00 AM
# - The suspect motivated by Fear was in the Lounge at 12:00 AM if and only if the suspect motivated by Jealousy was in the Conservatory at 12:00 AM
# - Madame Rose was in the same room as Miss Peach at 12:00 AM
# - Professor Plum was in the same room as the Knife at 12:00 AM
# - Monsieur Brunette was in the same room as Colonel Mustard at 11:30 PM
# - The suspect motivated by Betrayal was in the Conservatory at 11:30 PM
# - Sgt. Gray and the Wrench were in the Lounge together at least once
# - Professor Plum was in the Cloak Room at 12:00 AM
# - Madame Rose and the Wrench were in the Lounge together at least once
# - Monsieur Brunette was in the Kitchen at 11:30 PM or the suspect motivated by Power was in the Carriage House at 11:30 PM
# - The murderer and Mr. Boddy were in the Study together at least once
# - Madame Rose was in the Kitchen at 12:00 AM or the suspect motivated by Revenge was in the Hall at 11:30 PM
# - Mrs. White is motivated by Betrayal
# - Mr. Boddy was in the Library at 11:30 PM or the suspect motivated by Greed was in the Conservatory at 11:30 PM
# - The suspect motivated by Ambition moved from the Study to the Cloak Room at 12:00 AM
# - Mr. Green was in the Library at 11:30 PM
# - Monsieur Brunette was in the Carriage House at 11:30 PM if and only if the Rope was in the Ballroom at 12:00 AM
# - The Lead Pipe and the Candlestick were in the Kitchen together at least once
# - Mr. Green was in the Library at 12:00 AM
# - The suspect motivated by Fear was in the Ballroom at 11:30 PM if and only if the Wrench was in the Lounge at 11:30 PM
# - The suspect motivated by Pride was in the same room as the Knife at 11:30 PM
# - Mr. Boddy was in the Ballroom at 12:00 AM or Sgt. Gray was in the Ballroom at 11:30 PM
# - Colonel Mustard moved from the Carriage House to the Drawing Room at 12:00 AM
# - Mrs. White was in the Conservatory at 12:00 AM
# - Sgt. Gray was in the Lounge at 12:00 AM if and only if Madame Rose was in the Conservatory at 12:00 AM
# - The Poison was in the same room as Miss Scarlet at 12:00 AM
# - Miss Scarlet was in the Hall at 11:30 PM
# - The suspect motivated by Jealousy was in the Cloak Room at 11:30 PM or the murder weapon was in the Study at 12:00 AM
# - Professor Plum was in the Cloak Room at 11:30 PM
# - The suspect motivated by Hatred was in the Carriage House at 12:00 AM if and only if Mr. Boddy was in the Study at 11:30 PM
#
# Please answer the following question(s):
#
# A. Who murdered Mr. Boddy?
# B. What weapon did the murderer use?
# C. Where was the murder committed?
# D. When did the murder occur?
# E. Why did the murderer do it?
#
# And the following bonus question(s):
#
# F. Where was the suspect motivated by Revenge at 12:00 AM?
#
# Fill out your final answers in the following format:
#
# A. SUSPECT
# B. WEAPON
# C. ROOM
# D. TIME
# E. MOTIVE
# F. ROOM
#
# Best of luck, detective.
# Answer:
# {'A': 'Mrs. Peacock', 'B': 'Revolver', 'C': 'Study', 'D': '11:30 PM', 'E': 'Ambition', 'F': 'Hall', 'G': None, 'H': None}
# Response:
# A. Mrs. Peacock
# B. Poison
# C. Hall
# D. 12:00 AM
# E. Ambition
# F. Either the Kitchen or the Lounge
#
# Deductions:
# 1. Mrs. Peacock was in the same room as the Poison at 12:00 AM because the poison was in the Hall at 12:00 AM.
# 2. As Mrs. Peacock was in the same room as the poison, Mrs. Peacock, who was motivated by Ambition, is the killer because one of the rooms has a unique empty space in the 3rd column, implying that at least one person can move at a certain time. Since at 11:30 PM, Mrs. Peacock must move into the first room in the first column to make room for the movement of others, Mrs. Peacock must not be in the first column at 11:30 PM. Mrs. Peacock can move to the 3rd room in the second column, which implies that the suspect motivated by Ambition is not Mr. Green. Mrs. Peacock can move to the 3rd room in the 2nd column or the 1st room in the 3rd column, implying that Mrs. Peacock cannot be the suspect motivated by Power. Mrs. Peacock can move to the 3rd room in the 1st column, implying that Mrs. Peacock is not the suspect motivated by Hatred. Hence, the killer must be Mrs. Peacock who is motivated by Ambition.
# 3. The killer was in the same room as the Knife at some point in the night, (because Professor Plum was in the same room as the Knife at 12:00 AM), but the killer and the knife must not be in the same room at 11:30 PM, because the killer must not be in the first room in the 1st column at 11:30 PM (since Mrs. Peacock cannot be in the first column and the suspect motivated by Hatred cannot kill), and there is no place for the suspect motivated by Hatred to move. Hence, the killer was in the Hall.
# 4. Since the killer was in the Hall at some point in the night, the killer must be in the Hall at 11:30 or 12:00 AM. At 11:30, the Hall is occupied by Mr. Boddy, so the killer must be in the Hall at 12:00 AM.
# 5. Since the suspect motivated by Desire was in the Hall at 12:00 AM if and only if the suspect motivated by Jealousy was in the Conservatory at 12:00 AM, the suspect motivated by Jealousy was in the Conservatory at 12:00 AM.
# 16. Since Mrs. Peacock and the Rope were in the first room in the first column at 11:30 and 12:00 AM, and Mrs. Peacock was in the Hall at 12:00 AM, Mrs. Peacock moved from the first room in the first column at 11:30 PM to the Hall at 12:00 AM.
# 17. Since the suspect motivated by Power was in the carriages house at 11:30 PM or the suspect motivated by Power was in the carriages house, Mr. Boddy must be in the Ballroom at 11:30 PM, the suspect motivated by Revenge must not be in the Ballroom at 11:30 PM, the suspect motivated by Ambition must not be in the Ballroom at 11:30 PM, the suspect motivated by Hatred must not be in the Ballroom at 11:30 PM, the suspect motivated by Hate was in the carriages house at 11:30 PM, and the killer was in the Hall at 12:00 AM and in the carriages house at 11:30 PM. Since
# Unsloth: Will smartly offload gradients to save VRAM!
# -------------------- Question:
# On a dark winter night, wealthy and enigmatic Mr. John Q. Boddy hosted a small, but lavish, dinner party for some of his closest associates. However, the night ended in tragedy when Mr. Boddy was found dead in one of the rooms of Tudor Mansion in the early hours of the morning. The following persons of interest have been identified as suspects:
#
# • Mr. Green
# • Madame Rose
# • Sgt. Gray
# • Mrs. White
# • Colonel Mustard
#
# And the following weapons were found on the premises:
#
# • Candlestick
# • Revolver
# • Poison
#
# The murder could only have occured in one of the following rooms:
#
# 1. Courtyard
# 2. Fountain
# 3. Hall
# 4. Carriage House
# 5. Drawing Room
#
# The rooms are laid out as follows:
#
#   N N
# W 1|2 E
# W 3|4 E
# W 5|- E
#   S S
#
# For the murder to occur, the murderer and Mr. Boddy must have been alone in a room with at least one weapon.
#
# The available clues are as follows:
#
# - Sgt. Gray was in the room just north of the Poison
# - The Candlestick was in the Hall
# - Mrs. White was at the Fountain
# - Colonel Mustard was in the Drawing Room or the Candlestick was in the Drawing Room
# - Mr. Boddy was killed with the Poison
# - The murder weapon was in the Hall
# - Madame Rose was in the Drawing Room
# - The Revolver was in the Carriage House
#
# Please answer the following question(s):
#
# A. Who murdered Mr. Boddy?
# B. Where was the murder committed?
#
# And the following bonus question(s):
#
# C. Where was Mr. Green?
# D. Where was Colonel Mustard?
# E. Where was Sgt. Gray?
#
# Fill out your final answers in the following format:
#
# A. SUSPECT
# B. ROOM
# C. ROOM
# D. ROOM
# E. ROOM
#
# Best of luck, detective.
# Answer:
# {'A': 'Mr. Green', 'B': 'Hall', 'C': 'Hall', 'D': 'Drawing Room', 'E': 'Courtyard', 'F': None, 'G': None, 'H': None}
# Response:
# A. Mrs. White
# B. Fountain
# C. Carriage House
# D. Drawing Room
# E. Courtyard
# -------------------- Question:
# On a dark winter night, wealthy and enigmatic Mr. John Q. Boddy hosted a small, but lavish, dinner party for some of his closest associates. However, the night ended in tragedy when Mr. Boddy was found dead in one of the rooms of Tudor Mansion in the early hours of the morning. The following persons of interest have been identified as suspects:
#
# • Colonel Mustard
# • Monsieur Brunette
# • Mrs. White
# • Mr. Green
# • Miss Scarlet
#
# And the following weapons were found on the premises:
#
# • Lead Pipe
# • Candlestick
# • Wrench
# • Knife
#
# The murder could only have occured in one of the following rooms:
#
# 1. Courtyard
# 2. Kitchen
# 3. Dining Room
# 4. Cloak Room
# 5. Fountain
# 6. Hall
#
# The rooms are laid out as follows:
#
#   N N N
# W 1|2|3 E
# W 4|5|6 E
#   S S S
#
# Each suspect had one of the following possible motives for killing Mr. Boddy:
#
# • Ambition (1 suspect)
# • Power (2 suspects)
# • Betrayal (2 suspects)
#
# For the murder to occur, the murderer and Mr. Boddy must have been alone in a room with at least one weapon.
#
# The available clues are as follows:
#
# - Mr. Boddy was in the Courtyard
# - The Knife was in the room just east of Miss Scarlet
# - Monsieur Brunette was in the room just west of the Knife
# - Monsieur Brunette is motivated by Ambition
# - The Lead Pipe was in the room just east of Mr. Boddy
# - Colonel Mustard was in the room just east of the Knife
# - A suspect motivated by Power was in the same room as Mr. Boddy
# - The murder weapon was in the Courtyard if and only if the Wrench was in the Hall
# - Mrs. White is motivated by Power
# - Mrs. White was in the Hall
#
# Please answer the following question(s):
#
# A. Who murdered Mr. Boddy?
# B. What weapon did the murderer use?
# C. Where was the murder committed?
# D. Why did the murderer do it?
#
# And the following bonus question(s):
#
# E. Where was Mr. Green?
# F. Where was Monsieur Brunette?
# G. What motivates Colonel Mustard?
#
# Fill out your final answers in the following format:
#
# A. SUSPECT
# B. WEAPON
# C. ROOM
# D. MOTIVE
# E. ROOM
# F. ROOM
# G. MOTIVE
#
# Best of luck, detective.
# Answer:
# {'A': 'Mr. Green', 'B': 'Candlestick', 'C': 'Courtyard', 'D': 'Power', 'E': 'Courtyard', 'F': 'Cloak Room', 'G': 'Betrayal', 'H': None}
# Response:
# Let's break down the information given to solve the puzzle.
#
# From the given information:
# - Mr. Boddy was in the Courtyard (given)
# - The Lead Pipe was in the room just east of Mr. Boddy (given)
# - A suspect motivated by Power was in the same room as Mr. Boddy (given)
# - Mrs. White is motivated by Power (given)
# - Mrs. White was in the Hall (given)
# - The Wrench cannot be in the Hall if the murder was in the Courtyard (given)
# - The murder weapon was in the Courtyard if and only if the Wrench was in the Hall (given)
# - The Lead Pipe cannot be in the Courtyard because if the murder weapon was the Lead Pipe, the Wrench would need to be in the Hall, which means the murder occurred in the room that was east of the Lead Pipe, but we already know that the Lead Pipe is east of the Courtyard, so it would mean that the murder occurred in the Courtyard, which is a contradiction.
# Given this, the Lead Pipe must not be the murder weapon. The Lead Pipe must be in the room just east of the Courtyard.
# - The Lead Pipe is east of Mr. Boddy, so Mr. Boddy is either in the Courtyard or the room just east of the Courtyard, but we already know Mr. Boddy was in the Courtyard, so the room just east of Mr. Boddy is the room just east of the Courtyard (which is the room with number 3).
# - The Knife was in the room just east of Miss Scarlet, which must be the room with number 3 as well (since Colonel Mustard was in the room just east of the Knife, which means the room just east of the Knife is the room with number 6), the room with number 3 must be to the left of the room with number 6.
# - The room to the west of the Knife (which is the room with number 6), must be the room with number 2.
# - The room to the east of the Knife (which is the room with number 3), must be the room with number 5.
# - Monsieur Brunette was in the room just west of the Knife (given), so Monsieur Brunette was in the room with number 2.
# - Since the room with number 2 is west of the room with number 3, Monsieur Brunette (in the room with number 2) cannot be to the east of the Lead Pipe, so Monsieur Brunette is not the suspect motivated by Power.
# - Since the Lead Pipe is in the room with number 3 and Mrs. White is in the Hall, Mrs. White cannot be in the room with number 3 and since the Power motive is tied to Mrs. White, Mrs. White cannot be motivated by Power.
# - If a Power motive is tied to someone that is in the same room as Mr. Boddy (who is in the Courtyard), then the Power motive must be tied to one of the people that are in the room with the Lead Pipe (which is the room with number 3).
# - A suspect that was in the room just east of the Courtyard cannot be in the same room as Mr. Boddy, so that room (with number 3) is either the room with the Knife or the room with the Wrench. However, since we know that Monsieur Brunette was in the room with number 2, the room with number 3 cannot be the room with the Knife because if the Knife was in the room with number 3, Monsieur Brunette would need to be in the room with the Wrench.
# - The Lead Pipe was in the room with number 3 as previously stated, Mr. Boddy was in the room with number 2, the room with number 2 was to the east of the room with the number 1, the room with number 5 was to the east of the Lead Pipe, and the room with number 6 was the room with the Lead Pipe (which was incorrect, since it cannot be to the east of the Lead Pipe), so the room with number 6 must be the room with the Knife.
# - The room to the east of the Lead Pipe is the room with the number 6 and the room with the number 6 is the room with the Knife, but we've also concluded the room with the number 6 was to the east of the Lead Pipe, so we have two conclusions: the Lead Pipe is in the room with the number 6 or the Lead Pipe is in the room with the number 4 or the Lead Pipe is in the room to the west of the room with the number 6, this was a contradiction so the room with the number 6 must be to the west of the Lead Pipe. That would mean the room with the number 5 (which is the room with the Lead Pipe) is the room to the west of the room with the Lead Pipe.
# - Mr. Boddy was in the room with the number 2, Colonel Mustard was in the room with the number 6, and Colonel Mustard was the Power motive (because he was in the room with Mr. Boddy), so Miss Scarlet was the Ambition suspect because she was the only one left.
# - The room to the west of the Lead Pipe is the room to the west of the room with the number 3 (which is the room to the south of the room with the number 1), the room just west of the room with the number 3 would then be the room to the south of the room with the number 1, which was the room with the Lead Pipe and Miss Scarlet was in the room to the west of the Lead Pipe.
# - We've concluded the room with the Lead Pipe must be to the west of the room with the number 6 (which is the room with the Knife because it's where the Colonel is) since the Lead Pipe cannot be the room with number 6 because it was Colonel Mustard.
# - If the Lead Pipe
# -------------------- Question:
# On a dark winter night, wealthy and enigmatic Mr. John Q. Boddy hosted a small, but lavish, dinner party for some of his closest associates. However, the night ended in tragedy when Mr. Boddy was found dead in one of the rooms of Tudor Mansion in the early hours of the morning. The following persons of interest have been identified as suspects:
#
# • Mr. Green
# • Sgt. Gray
# • Colonel Mustard
# • Mrs. White
# • Miss Peach
# • Mrs. Peacock
#
# And the following weapons were found on the premises:
#
# • Poison
# • Horseshoe
# • Revolver
# • Wrench
# • Knife
# • Lead Pipe
#
# The murder could only have occured in one of the following rooms:
#
# 1. Study
# 2. Courtyard
# 3. Carriage House
# 4. Gazebo
# 5. Trophy Room
# 6. Kitchen
# 7. Lounge
#
# The rooms are laid out as follows:
#
#   N N N
# W 1|2|3 E
# W 4|5|6 E
# W 7|-|- E
#   S S S
#
# The exact time of the murder is a bit uncertain, but it has been narrowed down to one of the following times:
#
# • 11:00 PM
# • 11:30 PM
# • 12:00 AM
#
# At every time the suspects and Mr. Boddy either stayed in their current room or moved to an orthogonally adjacent room (north, south, east, or west). Weapons could be moved by suspects between rooms as well.
#
# Each suspect had one of the following possible motives for killing Mr. Boddy:
#
# • Pride (2 suspects)
# • Betrayal (2 suspects)
# • Ambition (1 suspect)
# • Greed (1 suspect)
#
# For the murder to occur, the murderer and Mr. Boddy must have been alone in a room with at least one weapon at some point in the night. Any clue about Mr. Boddy's whereabouts should be read as "Mr. Boddy (dead or alive) ..."
#
# The available clues are as follows:
#
# - The suspect motivated by Ambition was in the Study at 12:00 AM
# - The Poison was in the Carriage House at 11:30 PM if and only if the Lead Pipe was in the Study at 11:30 PM
# - Miss Peach and Mrs. White were in the Trophy Room together at least once
# - Mrs. White was in the Trophy Room at 11:30 PM if and only if Mr. Green was in the Gazebo at 11:00 PM
# - The suspect motivated by Ambition was in the Trophy Room at 11:00 PM
# - Sgt. Gray was in the Lounge at 11:00 PM
# - Mr. Boddy was in the Trophy Room at 11:30 PM
# - The Revolver was in the Lounge at 12:00 AM or Miss Peach was in the Kitchen at 11:00 PM
# - Mrs. Peacock moved from the Kitchen to the Carriage House at 11:30 PM
# - The suspect motivated by Greed was in the Trophy Room at 11:00 PM if and only if a suspect motivated by Betrayal was in the Trophy Room at 11:30 PM
# - The murder weapon was in the Carriage House at 11:00 PM
# - The Horseshoe was in the Lounge at 11:30 PM if and only if Mrs. Peacock was in the Kitchen at 12:00 AM
# - Colonel Mustard was in the room just east of Mr. Green at 11:00 PM
# - A suspect motivated by Betrayal moved from the Trophy Room to the Gazebo at 12:00 AM
# - The Lead Pipe was in the same room as the Wrench at 11:00 PM
# - A suspect motivated by Pride moved from the Gazebo to the Study at 12:00 AM
# - Miss Peach moved from the Kitchen to the Trophy Room at 12:00 AM
# - Mr. Boddy was in the Trophy Room at 11:00 PM
# - Sgt. Gray and Colonel Mustard were in the Gazebo together at least once
# - Miss Peach was in the same room as the Poison at 11:00 PM
# - The Horseshoe was in the same room as the Revolver at 12:00 AM
# - Mr. Boddy was in the room just south of the Poison at 12:00 AM
# - A suspect motivated by Pride moved the Knife from the Carriage House to the Kitchen at 12:00 AM
#
# Please answer the following question(s):
#
# A. Who murdered Mr. Boddy?
# B. What weapon did the murderer use?
# C. Where was the murder committed?
# D. When did the murder occur?
# E. Why did the murderer do it?
#
# And the following bonus question(s):
#
# F. Where was the Revolver at 12:00 AM?
# G. Where was the Poison at 11:00 PM?
#
# Fill out your final answers in the following format:
#
# A. SUSPECT
# B. WEAPON
# C. ROOM
# D. TIME
# E. MOTIVE
# F. ROOM
# G. ROOM
#
# Best of luck, detective.
# Answer:
# {'A': 'Mrs. Peacock', 'B': 'Knife', 'C': 'Kitchen', 'D': '12:00 AM', 'E': 'Pride', 'F': 'Lounge', 'G': 'Carriage House', 'H': None}
# Response:
# A. Colonel Mustard
# B. Lead Pipe
# C. Study
# D. 11:30 PM
# E. Betrayal
# F. Lounge
# G. Study
#
# To determine the answer to A, we start by analyzing the clues that involve Colonel Mustard.
#
# The significant clue about Colonel Mustard is "Colonel Mustard was in the room just east of Mr. Green at 11:00 PM." Since the grid is as follows:
#
#   N N N
# W 1|2|3 E
# W 4|5|6 E
# W 7|-|- E
#   S S S
#
# The only possible rooms that are east of Room 2 are Room 3, Room 6, and Room 0 (which does not exist in this grid). This means that at 11:00 PM, at least one of the following must be true: (Mr. Green is in Room 1 and Colonel Mustard is in Room 3), (Mr. Green is in Room 2 and Colonel Mustard is in Room 6), or (Mr. Green is in Room 2 and Colonel Mustard is in a non-existent Room 0). Therefore, considering the options, (Mr. Green is in Room 2 and Colonel Mustard is in Room 6) is the only one that makes sense because all the other options lead to a contradiction.
#
# Another clue that relates to Colonel Mustard is "A suspect motivated by Betrayal moved from the Trophy Room to the Gazebo at 12:00 AM." This indicates that Colonel Mustard could be the suspect motivated by Betrayal.
#
# Now looking at clue E, "The murder could only have occured in one of the following rooms: 1. Study 2. Courtyard 3. Carriage House 4. Gazebo 5. Trophy Room 6. Kitchen 7. Lounge." "The murder weapon was in the Carriage House at 11:00 PM" means the murder must have occurred in the Carriage House, the Kitchen, the Lounge, the Study, or the Trophy Room.
#
# Now looking at clue D, "The Revolver was in the Lounge at 12:00 AM or Miss Peach was in the Kitchen at 11:00 PM." The Revolver cannot be in the Lounge at 12:00 AM if the murder was in the Lounge (this is because the murderer must have at least one of the weapons at some point before the murder, and the only possible time suggested that the Revolver could have been in the Lounge and one of the rooms that the murder could have been in is if it was in the Lounge at 11:30 PM, but that leads to a contradiction because the Revolver would have been in the Lounge and the Lounge is not the same room as the murder weapon Carriage House. Thus the murder must not be in the Lounge), so if the Revolver is not in the Lounge, then Miss Peach was in the Kitchen at 11:00 PM. As a result, the murder must have occurred in the Kitchen, the Lounge, the Carriage House, the Study, or the Trophy Room.
#
# Combining the results of the previous two paragraphs, the murder must have occurred in the Kitchen, the Lounge, the Carriage House, the Study, or the Trophy Room. From clue E, "Mr. Boddy was in the room just south of the Poison at 12:00 AM" and clue F, "The Poison was in the Carriage House at 11:30 PM if and only if the Lead Pipe was in the Study at 11:30 PM," we know the Poison was in the Carriage House at 11:30 PM. This places Mr. Boddy in Room 4 at 12:00 AM, and since the Carriage House must be the bathroom, it also places the murder in the Kitchen at 11:30 PM.
#
# Now that we know the murder time and room, we can determine whether the murderer has a Betrayal motive (that is, the suspect that moved from the Trophy Room to the Gazebo at 12:00 AM). The only time when the suspect that moved from the Trophy Room to the Gazebo at 12:00 AM and was in the study is when Colonel Mustard was in the Study at 12:00 AM. Since Mr. Boddy was in the room just south of the lead pipe (which was in the Study at some point), it means he was not moved to the study at 12:00 AM.
#
# Based on the available information, the only time when there was a suspect with a Betrayal motive in the study is when the suspect was in the study at 12:00 AM. So the possible times and places that the murderer could be the suspect with the Betrayal motive are the study at 12:00 AM, and the study was not the murder location. Thus, no suspect with a Betrayal motive was involved in the murder. This leaves Colonel Mustard to be the murderer, because one of the motives for Colonel Mustard is Betrayal.
#
# Before we can confirm whether we solved the murder, we need to check our results against the given information. Clue E, "The suspect motivated by Ambition was in the Study at 12:00 AM," does not conflict with our results because the suspect with a Betrayal motive is not the one motivated by Ambition, and our suspect Colonel Mustard is not the suspect with a Betrayal motive.
#
# Clue C, "Miss Peach and Mrs. White were in the Trophy Room together at least once," does not conflict with our results because at least one possible solution to this puzzle is that Miss Peach and Mrs. White visit the study, the Carriage House, the Kitchen, the Lounge, or the Study. At least one of these rooms is the possible murder location.
#
# Clue G, "The Horseshoe was in the same room as the Revolver at 12:00 AM," does not conflict with our results because the Horseshoe was in the Gazebo at 11:00 PM, meaning at 12:00 AM Horseshoe that was in the same room as the Revolver was in the Lounge. Clue A, "The suspect motivated by Greed was in the Trophy Room at 11:00 PM if and only if a suspect motivated by Betrayal was in the Trophy Room at 11:30 PM," does not conflict with our results because the suspect with a Greed motive cannot be the suspect with a Betrayal motive. Clue E, "A suspect motivated by Pride moved the Knife from the Carriage House to the Kitchen at 12:00 AM," does not conflict with our results because a suspect with a Pride motive does not move the Knife at 12:00 AM.
#
# Clue F, "Mrs. Peacock moved from the Kitchen to the Carriage House at 11:30 PM," and Clue H, "Mr. Boddy was in the Trophy Room at 11:00 PM," do not conflict with our results.
#
# Clue H, "The Lead Pipe was in the same room as the Wrench at 11:00 PM," does not conflict with our results.
#
# After checking against the available information, we can confirm that the murder was indeed committed by Colonel Mustard with the Lead Pipe in the Study at 11:30 PM, where the Poison was in the Carriage House.
