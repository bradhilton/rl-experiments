# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %%html
# <style>
# .cell-output-ipywidget-background {
#     background-color: transparent !important;
# }
# :root {
#     --jp-widgets-color: var(--vscode-editor-foreground);
#     --jp-widgets-font-size: var(--vscode-editor-font-size);
# }
# </style>
# Out:
# <style>
# .cell-output-ipywidget-background {
#     background-color: transparent !important;
# }
# :root {
#     --jp-widgets-color: var(--vscode-editor-foreground);
#     --jp-widgets-font-size: var(--vscode-editor-font-size);
# }
# </style>

# %%
from unsloth import FastLanguageModel
import torch

max_seq_length = 4096  # Can increase for longer reasoning traces
lora_rank = 32  # Larger rank = smarter, but slower

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name="meta-llama/meta-Llama-3.1-8B-Instruct",
    max_seq_length=max_seq_length,
    load_in_4bit=True,  # False for LoRA 16bit
    fast_inference=True,  # Enable vLLM fast inference
    max_lora_rank=lora_rank,
    gpu_memory_utilization=0.6,  # Reduce if out of memory
)

model = FastLanguageModel.get_peft_model(
    model,
    r=lora_rank,  # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules=[
        "q_proj",
        "k_proj",
        "v_proj",
        "o_proj",
        "gate_proj",
        "up_proj",
        "down_proj",
    ],  # Remove QKVO if out of memory
    lora_alpha=lora_rank,
    use_gradient_checkpointing="unsloth",  # Enable long context finetuning
    random_state=3407,
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# INFO 03-13 23:06:48 __init__.py:190] Automatically detected platform cuda.
# ==((====))==  Unsloth 2025.3.10: Fast Llama patching. Transformers: 4.48.3. vLLM: 0.7.2.
#    \\   /|    NVIDIA H100 80GB HBM3. Num GPUs = 1. Max memory: 79.109 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 9.0. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: vLLM loading unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit with actual GPU utilization = 59.54%
# Unsloth: Your GPU has CUDA compute capability 9.0 with VRAM = 79.11 GB.
# Unsloth: Using conservativeness = 1.0. Chunked prefill tokens = 4096. Num Sequences = 226.
# Unsloth: vLLM's KV Cache can use up to 40.93 GB. Also swap space = 6 GB.
# INFO 03-13 23:06:58 config.py:542] This model supports multiple tasks: {'classify', 'score', 'reward', 'generate', 'embed'}. Defaulting to 'generate'.
# Unsloth: vLLM Bitsandbytes config using kwargs = {'load_in_8bit': False, 'load_in_4bit': True, 'bnb_4bit_compute_dtype': 'bfloat16', 'bnb_4bit_quant_storage': 'uint8', 'bnb_4bit_quant_type': 'nf4', 'bnb_4bit_use_double_quant': True, 'llm_int8_enable_fp32_cpu_offload': False, 'llm_int8_has_fp16_weight': False, 'llm_int8_skip_modules': ['lm_head', 'multi_modal_projector', 'merger', 'modality_projection', 'model.layers.1.mlp'], 'llm_int8_threshold': 6.0}
# INFO 03-13 23:06:58 llm_engine.py:234] Initializing a V0 LLM engine (v0.7.2) with config: model='unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit', speculative_config=None, tokenizer='unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=4096, download_dir=None, load_format=LoadFormat.BITSANDBYTES, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=bitsandbytes, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda:0, decoding_config=DecodingConfig(guided_decoding_backend='xgrammar'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=False, use_async_output_proc=True, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"level":0,"splitting_ops":[],"compile_sizes":[],"cudagraph_capture_sizes":[232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"max_capture_size":232}, use_cached_outputs=False,
# INFO 03-13 23:07:06 cuda.py:230] Using Flash Attention backend.
# INFO 03-13 23:07:07 model_runner.py:1110] Starting to load model unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit...
# INFO 03-13 23:07:07 loader.py:1102] Loading weights with BitsAndBytes quantization.  May take a while ...
# [W313 23:07:07.551828945 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# INFO 03-13 23:07:08 weight_utils.py:252] Using model weights format ['*.safetensors']
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# INFO 03-13 23:07:10 model_runner.py:1115] Loading model weights took 5.5976 GB
# INFO 03-13 23:07:10 punica_selector.py:18] Using PunicaWrapperGPU.
# INFO 03-13 23:07:12 worker.py:267] Memory profiling takes 1.43 seconds
# INFO 03-13 23:07:12 worker.py:267] the current vLLM instance can use total_gpu_memory (79.11GiB) x gpu_memory_utilization (0.60) = 47.11GiB
# INFO 03-13 23:07:12 worker.py:267] model weights take 5.60GiB; non_torch_memory takes 0.15GiB; PyTorch activation peak memory takes 1.09GiB; the rest of the memory reserved for KV Cache is 40.26GiB.
# INFO 03-13 23:07:12 executor_base.py:110] # CUDA blocks: 20613, # CPU blocks: 3072
# INFO 03-13 23:07:12 executor_base.py:115] Maximum concurrency for 4096 tokens per request: 80.52x
# INFO 03-13 23:07:15 model_runner.py:1434] Capturing cudagraphs for decoding. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI. If out-of-memory error occurs during cudagraph capture, consider decreasing `gpu_memory_utilization` or switching to eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# Capturing CUDA graph shapes: 100%|██████████| 32/32 [00:25<00:00,  1.28it/s]
# INFO 03-13 23:07:40 model_runner.py:1562] Graph capturing finished in 25 secs, took 4.17 GiB
# INFO 03-13 23:07:40 llm_engine.py:431] init engine (profile, create kv cache, warmup model) took 30.20 seconds
# Unsloth 2025.3.10 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %%
from datasets import Dataset
from lib.temporal_clue import get_temporal_clue_puzzles
import random


puzzles = get_temporal_clue_puzzles()[128:]
random.seed(42)
random.shuffle(puzzles)

dataset = Dataset.from_list(puzzles).map(
    lambda x: {
        "prompt": [
            {"role": "user", "content": x["prompt"]},
        ],
        "answer": x["solution"],
    }
)
# Out:
# Map:   0%|          | 0/2860 [00:00<?, ? examples/s]

# %%
import re


def _reward_func(response, answer) -> float:
    num_correct = 0
    for key, value in answer.items():
        if matches := re.findall(rf"{key}\. ([A-Za-z \.:-]+)", response):
            match = matches[-1]
            if (
                match is not None
                and value is not None
                and match.strip().lower() == value.lower()
            ):
                num_correct += 1
    return num_correct / len(answer)


def reward_func(prompts, completions, answer, **kwargs) -> list[float]:
    responses = [completion[0]["content"] for completion in completions]
    q = prompts[0][-1]["content"]
    print(
        "-" * 20,
        f"Question:\n{q}",
        f"\nAnswer:\n{answer[0]}",
        f"\nResponse:\n{responses[0]}",
    )
    return [_reward_func(r, a) for r, a in zip(responses, answer)]

# %%
max_prompt_length = 2048

from trl import GRPOConfig, GRPOTrainer

training_args = GRPOConfig(
    learning_rate=5e-6,
    adam_beta1=0.9,
    adam_beta2=0.99,
    weight_decay=0.1,
    warmup_ratio=0.1,
    lr_scheduler_type="cosine",
    optim="paged_adamw_8bit",
    beta=0.0,
    logging_steps=1,
    per_device_train_batch_size=1,
    gradient_accumulation_steps=1,  # Increase to 4 for smoother training
    num_generations=15,  # Decrease if out of memory
    max_prompt_length=max_prompt_length,
    max_completion_length=max_seq_length - max_prompt_length,
    # num_train_epochs = 1, # Set to 1 for a full training run
    max_steps=250,
    save_steps=250,
    max_grad_norm=0.1,
    report_to="none",  # Can use Weights & Biases
    output_dir="outputs",
)
# Out:
# Unsloth: We now expect `per_device_train_batch_size` to be a multiple of `num_generations`.
# We will change the batch size of 1 to the `num_generations` of 15

# %%
trainer = GRPOTrainer(
    model=model,
    processing_class=tokenizer,
    reward_funcs=reward_func,  # type: ignore
    args=training_args,
    train_dataset=dataset,
    
)
trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 2,860 | Num Epochs = 1 | Total steps = 250
# O^O/ \_/ \    Batch size per device = 15 | Gradient accumulation steps = 1
# \        /    Data Parallel GPUs = 1 | Total batch size (15 x 1 x 1) = 15
#  "-____-"     Trainable parameters = 83,886,080/4,712,566,784 (1.78% trained)
# -------------------- Question:
# On a dark winter night, wealthy and enigmatic Mr. John Q. Boddy hosted a small, but lavish, dinner party for some of his closest associates. However, the night ended in tragedy when Mr. Boddy was found dead in one of the rooms of Tudor Mansion in the early hours of the morning. The following persons of interest have been identified as suspects:
#
# • Sgt. Gray
# • Monsieur Brunette
# • Madame Rose
# • Professor Plum
# • Miss Scarlet
# • Mrs. White
# • Miss Peach
# • Colonel Mustard
# • Mr. Green
#
# And the following weapons were found on the premises:
#
# • Revolver
# • Rope
# • Lead Pipe
# • Wrench
# • Horseshoe
# • Candlestick
#
# The murder could only have occured in one of the following rooms:
#
# 01. Courtyard
# 02. Library
# 03. Conservatory
# 04. Studio
# 05. Lounge
# 06. Drawing Room
# 07. Cloak Room
# 08. Hall
# 09. Kitchen
# 10. Dining Room
# 11. Gazebo
# 12. Ballroom
# 13. Fountain
# 14. Trophy Room
# 15. Carriage House
#
# The rooms are laid out as follows:
#
#   NN NN NN NN
# W 01|02|03|04 E
# W 05|06|07|08 E
# W 09|10|11|12 E
# W 13|14|15|- E
#   SS SS SS SS
#
# The exact time of the murder is a bit uncertain, but it has been narrowed down to one of the following times:
#
# • 10:00 PM
# • 10:30 PM
# • 11:00 PM
# • 11:30 PM
# • 12:00 AM
# • 12:30 AM
# • 01:00 AM
#
# At every time the suspects and Mr. Boddy either stayed in their current room or moved to an orthogonally adjacent room (north, south, east, or west). Weapons could be moved by suspects between rooms as well.
#
# Each suspect uniquely had one of the following possible motives for killing Mr. Boddy:
#
# • Power
# • Fear
# • Jealousy
# • Revenge
# • Betrayal
# • Pride
# • Anger
# • Ambition
# • Greed
#
# For the murder to occur, the murderer and Mr. Boddy must have been alone in a room with at least one weapon at some point in the night. Any clue about Mr. Boddy's whereabouts should be read as "Mr. Boddy (dead or alive) ..."
#
# The available clues are as follows:
#
# - The suspect motivated by Power was in the Cloak Room at 11:30 PM
# - The Rope was in the room just south of Professor Plum at 12:00 AM
# - Sgt. Gray was in the room just west of Monsieur Brunette at 12:00 AM
# - The murderer was in the Library at 11:30 PM
# - The suspect motivated by Betrayal was in the Lounge at 12:00 AM if and only if Colonel Mustard was in the Drawing Room at 12:30 AM
# - The suspect motivated by Pride was in the same room as Mr. Boddy at 10:30 PM
# - The Wrench was in the same room as the Lead Pipe at 10:00 PM
# - Sgt. Gray was in the Carriage House at 10:00 PM
# - Mr. Boddy was in the Library at 12:00 AM
# - Mr. Boddy was in the same room as Miss Peach at 10:00 PM
# - Monsieur Brunette was in the same room as Sgt. Gray at 11:00 PM
# - The Lead Pipe was in the Gazebo at 01:00 AM if and only if the suspect motivated by Jealousy was in the Ballroom at 10:00 PM
# - Colonel Mustard was in the Kitchen at 10:30 PM if and only if the suspect motivated by Pride was in the Conservatory at 01:00 AM
# - The suspect motivated by Power moved from the Cloak Room to the Hall at 12:30 AM
# - Madame Rose was in the Lounge at 10:30 PM
# - The suspect motivated by Fear was in the Kitchen at 11:00 PM or the suspect motivated by Revenge was in the Carriage House at 01:00 AM
# - The suspect motivated by Betrayal was in the Drawing Room at 12:30 AM or the suspect motivated by Power was in the Hall at 10:30 PM
# - Professor Plum was in the room just east of Mr. Boddy at 11:00 PM
# - Colonel Mustard was in the same room as Miss Scarlet at 01:00 AM
# - The Lead Pipe was in the room just north of Monsieur Brunette at 12:30 AM
# - The suspect motivated by Pride moved the Revolver from the Library to the Conservatory at 12:00 AM
# - Sgt. Gray was in the same room as Monsieur Brunette at 10:30 PM
# - The suspect motivated by Ambition moved from the Gazebo to the Cloak Room at 10:30 PM
# - Sgt. Gray was in the same room as Monsieur Brunette at 10:00 PM
# - Sgt. Gray moved from the Trophy Room to the Fountain at 01:00 AM
# - The suspect motivated by Jealousy moved from the Ballroom to the Hall at 11:00 PM

#
# Fill out your final answers in the following format:
#
# A. SUSPECT
# B. WEAPON
# C. ROOM
# D. MOTIVE
# E. ROOM
# F. MOTIVE
# G. ROOM
# H. ROOM
#
# Best of luck, detective.
# Answer:
# {'A': 'Miss Scarlet', 'B': 'Horseshoe', 'C': 'Library', 'D': 'Fear', 'E': 'Carriage House', 'F': 'Ambition', 'G': 'Trophy Room', 'H': 'Gazebo'}
# Response:
# A. Monsieur Brunette
# B. Candlestick
# C. Drawing Room
# D. Jealousy
#
# Explanation:
#
# Since Mr. Boddy was in the Library at 11:30 PM and the suspect motivated by Power was in the Library at that time, the Library cannot be the location of the murder.
#
# The murderer was in the Library at 11:30 PM, so the suspect motivated by Anger was in the Library at 11:30 PM. Further, the suspect motivated by Power moved from the Hall to the Lounge at 11:30 PM, so the Power motive had to be in the Lounge at 10:30 PM, and then moved to the Hall at 11:30 PM.
#
# Since the Wrench was in the Ballroom at 12:30 AM, the suspect motivated by Jealousy was in the Ballroom at 12:30 AM. Further, this means the Jealousy motive had to be in the Gazebo at 11:30 PM and in the Ballroom at 10:30 PM.
#
# Since the Lead Pipe was in the Ballroom at 12:00 AM and was in the Gazebo at 01:00 AM, the Lead Pipe must have been in the Gazebo at 01:00 AM. And, since the Lead Pipe was originally in the same room as the Wrench, the Wrench was in the Gazebo at 01:00 AM.
#
# Since the Wrench was in the WOC room at 10:00 PM, it was in room W (01, 02, 03 or 04).
#
# As the Wrench was in the Gazebo at 11:30 PM and was moved from the WOC room to the Gazebo at 11:00 PM, the person who moved the Wrench must have done so at 11:00 PM.
#
# The suspect motivated by Ambition moved from the Gazebo to the Ballroom at 12:00 AM. Since this person had to move from the WOC room to the Gazebo at 11:00 PM, the person had to be in the Ballroom at 11:00 PM or 11:30 PM. Since the Ballroom was empty before 10:30 PM, the WOC room is 03.
#
# Since the suspect motivated by Power was in the Hall at 10:30 PM, the Hall is not the N or S room of 03 (as the Power would have had to stay in the Hall when he moved from the Cloak Room to the Hall).
#
# Therefore, the other three rooms not yet ruled out are W (03), W (02), and N (04). To place the suspects, consider the contradiction that would occur if each of them was in those rooms.
#
# Consider Mr. Boddy moving from the Courtyard to the Library at 11:00 PM (and all other suspects staying in 03 W, 02 W, or 04 N). Then Mr. Boddy would have been in 04 N at 11:00 PM and 03 W or 02 W at 11:30 PM. If Mr. Boddy was in the Drawing Room or the Hall, he could not have been in the Library at 12:00 AM.
#
# Assume Mr. Boddy was in the room W (02) at 11:00 PM and in the room W (03) at 11:30 PM. Since Professor Plum was in the room E of Mr. Boddy at 11:00 PM and in the room E of the suspect motivated by Pride at 11:00 PM, Professor Plum was in the room N of the suspect motivated by Pride at 11:00 PM. This means Professor Plum was in the Hall at 10:30 PM, but he could not have been in the Hall at 10:30 PM as the suspect motivated by Pride was in the Hall then.
#
# Consider the case that the Hall is W (02). With this, Professor Plum could not be in the Hall at 11:00 PM, meaning he was in the room N of the suspect motivated by Pride at 11:00 PM, which is the room W (03). Since the suspect motivated by Anger was in the Library at 11:30 PM, Professor Plum moved to the Drawing Room at 11:00 PM.
#
# Considering the suspect motivated by Power moved from the Cloak Room to the Hall at 12:30 AM, if the Hall was W (02), then Power could be in one of S (02), N (02), W (02), or E (02).
#
# Since the Power was in the Hall at 10:30 PM, he was in the Hall that is W (02) since he could not be in the Hall that is S (02), N (02), or E (02).
#
# Since Madame Rose was in the Lounge at 10:30 PM, Monsieur Brunette was in the Hall at 10:30 PM.
act time of the murder is a bit uncertain, but it has been narrowed down to one of the following times:
#
# • 11:30 PM
# • 12:00 AM
#
# At every time the suspects and Mr. Boddy either stayed in their current room or moved to an orthogonally adjacent room (north, south, east, or west). Weapons could be moved by suspects between rooms as well.
#
# Each suspect uniquely had one of the following possible motives for killing Mr. Boddy:
#
# • Anger
# • Greed
# • Pride
# • Jealousy
# • Fear
# • Power
# • Ambition
# • Hatred
# • Revenge
# • Betrayal
#
# For the murder to occur, the murderer and Mr. Boddy must have been alone in a room with at least one weapon at some point in the night. Any clue about Mr. Boddy's whereabouts should be read as "Mr. Boddy (dead or alive) ..."
#
# The available clues are as follows:
#
# - The Poison was in the Hall at 12:00 AM
# - The suspect motivated by Fear was in the Lounge at 12:00 AM if and only if the suspect motivated by Jealousy was in the Conservatory at 12:00 AM
# - Madame Rose was in the same room as Miss Peach at 12:00 AM
# - Professor Plum was in the same room as the Knife at 12:00 AM
# - Monsieur Brunette was in the same room as Colonel Mustard at 11:30 PM
# - The suspect motivated by Betrayal was in the Conservatory at 11:30 PM
# - Sgt. Gray and the Wrench were in the Lounge together at least once
# - Professor Plum was in the Cloak Room at 12:00 AM
# - Madame Rose and the Wrench were in the Lounge together at least once
# - Monsieur Brunette was in the Kitchen at 11:30 PM or the suspect motivated by Power was in the Carriage House at 11:30 PM
# - The murderer and Mr. Boddy were in the Study together at least once
# - Madame Rose was in the Kitchen at 12:00 AM or the suspect motivated by Revenge was in the Hall at 11:30 PM
# - Mrs. White is motivated by Betrayal
# - Mr. Boddy was in the Library at 11:30 PM or the suspect motivated by Greed was in the Conservatory at 11:30 PM
# - The suspect motivated by Ambition moved from the Study to the Cloak Room at 12:00 AM
# - Mr. Green was in the Library at 11:30 PM
# - Monsieur Brunette was in the Carriage House at 11:30 PM if and only if the Rope was in the Ballroom at 12:00 AM
# - The Lead Pipe and the Candlestick were in the Kitchen together at least once
# - Mr. Green was in the Library at 12:00 AM
# - The suspect motivated by Fear was in the Ballroom at 11:30 PM if and only if the Wrench was in the Lounge at 11:30 PM
# - The suspect motivated by Pride was in the same room as the Knife at 11:30 PM
# - Mr. Boddy was in the Ballroom at 12:00 AM or Sgt. Gray was in the Ballroom at 11:30 PM
# - Colonel Mustard moved from the Carriage House to the Drawing Room at 12:00 AM
# - Mrs. White was in the Conservatory at 12:00 AM
# - Sgt. Gray was in the Lounge at 12:00 AM if and only if Madame Rose was in the Conservatory at 12:00 AM
# - The Poison was in the same room as Miss Scarlet at 12:00 AM
# - Miss Scarlet was in the Hall at 11:30 PM
# - The suspect motivated by Jealousy was in the Cloak Room at 11:30 PM or the murder weapon was in the Study at 12:00 AM
# - Professor Plum was in the Cloak Room at 11:30 PM
# - The suspect motivated by Hatred was in the Carriage House at 12:00 AM if and only if Mr. Boddy was in the Study at 11:30 PM
#
# Please answer the following question(s):
#
# A. Who murdered Mr. Boddy?
# B. What weapon did the murderer use?
# C. Where was the murder committed?
# D. When did the murder occur?
# E. Why did the murderer do it?
#
# And the following bonus question(s):
#
# F. Where was the suspect motivated by Revenge at 12:00 AM?
#
# Fill out your final answers in the following format:
#
# A. SUSPECT
# B. WEAPON
# C. ROOM
# D. TIME
# E. MOTIVE
# F. ROOM
#
# Best of luck, detective.
# Answer:
# {'A': 'Mrs. Peacock', 'B': 'Revolver', 'C': 'Study', 'D': '11:30 PM', 'E': 'Ambition', 'F': 'Hall', 'G': None, 'H': None}
# Response:
# Based on the given information, the solution is as follows:
#
# A. COLONEL MUSTARD
# B. CANDLESTICK
# C. TROPHY ROOM
# D. 11:30 PM
# E. HATRED
# F. CARRIAGE HOUSE
#
# Here is the reasoning and the explanation for each step:
#
# 1. **The suspect motivated by Revenge was in the Hall at 11:30 PM**: From the clue "Madame Rose was in the Kitchen at 12:00 AM or the suspect motivated by Revenge was in the Hall at 11:30 PM", we can narrow down the location of the suspect motivated by Revenge to the Hall at 11:30 PM. **(11:30 PM)**
#
# 2. **Mrs. White is motivated by Betrayal**: It is given in the clues that Mrs. White is motivated by Betrayal.
#
# 3. **The suspect motivated by Fear was in the Lounge at 12:00 AM**: Since "The suspect motivated by Fear was in the Lounge at 12:00 AM if and only if the suspect motivated by Jealousy was in the Conservatory at 12:00 AM", the suspect motivated by Jealousy must be in the Conservatory at 12:00 AM. Since "The suspect motivated by Fear was in the Ballroom at 11:30 PM if and only if the Wrench was in the Lounge at 11:30 PM", and the Wrench is in the Lounge at some point, the suspect motivated by Fear must be in the Lounge at 12:00 AM. **(12:00 AM)**
#
# 4. **The suspect motivated by Betrayal was in the Conservatory at 11:30 PM**: Since "The suspect motivated by Betrayal was in the Conservatory at 11:30 PM", Mrs. White must be in the Ballroom at 11:30 PM.
#
# 5. **Sgt. Gray was in the Lounge at 11:30 PM**: Since "Sgt. Gray was in the Lounge at 12:00 AM if and only if Madame Rose was in the Conservatory at 12:00 AM", and Madame Rose is in the Kitchen at 12:00 AM, Sgt. Gray must be in the Lounge at 11:30 PM.
#
# 6. **Sgt. Gray and the Wrench were in the Lounge together at least once**: Since Sgt. Gray is in the Lounge at 11:30 PM, the Wrench must be in the Lounge at 11:30 PM.
#
# 7. **Sgt. Gray was in the Ballroom at 11:30 PM**: Since "Mr. Boddy was in the Ballroom at 12:00 AM or Sgt. Gray was in the Ballroom at 11:30 PM", Sgt. Gray must be in the Ballroom at 11:30 PM.
#
# 8. **Mr. Green was in the Library at 11:30 PM or the suspect motivated by Greed was in the Conservatory at 11:30 PM**: Since "Mr. Boddy was in the Library at 11:30 PM or the suspect motivated by Greed was in the Conservatory at 11:30 PM", the suspect motivated by Greed must be in the Conservatory at 11:30 PM.
#
# 9. **Monsieur Brunette was in the Carriage House at 11:30 PM or the suspect motivated by Power was in the Carriage House at 11:30 PM**: Since "Monsieur Brunette was in the Carriage House at 11:30 PM or the suspect motivated by Power was in the Carriage House at 11:30 PM", the suspect motivated by Power was in the Carriage House at 11:30 PM.
#
# 10. **The Lead Pipe and the Candlestick were in the Kitchen together at least once**: Since the Lead Pipe and the Candlestick were in the Kitchen together at least once, the suspect motivated by Hatred must be in the Kitchen.
#
# 11. **The suspect motivated by Ambition moved from the Study to the Cloak Room at 12:00 AM**: Since "The suspect motivated by Ambition moved from the Study to the Cloak Room at 12:00 AM", Mr. Boddy must be in the Study at 11:30 PM.
#
# 12. **The suspense murder**: The location of the murder weapon and the murderer must be considered one by one. There are five suspects remaining: Colonel Mustard, Colonel Mustard was in the Study at 11:30 PM. **(11:30 PM)**
a dark winter night, wealthy and enigmatic Mr. John Q. Boddy hosted a small, but lavish, dinner party for some of his closest associates. However, the night ended in tragedy when Mr. Boddy was found dead in one of the rooms of Tudor Mansion in the early hours of the morning. The following persons of interest have been identified as suspects:
#
# • Mr. Green
# • Madame Rose
# • Sgt. Gray
# • Mrs. White
# • Colonel Mustard
#
# And the following weapons were found on the premises:
#
# • Candlestick
# • Revolver
# • Poison
#
# The murder could only have occured in one of the following rooms:
#
# 1. Courtyard
# 2. Fountain
# 3. Hall
# 4. Carriage House
# 5. Drawing Room
#
# The rooms are laid out as follows:
#
#   N N
# W 1|2 E
# W 3|4 E
# W 5|- E
#   S S
#
# For the murder to occur, the murderer and Mr. Boddy must have been alone in a room with at least one weapon.
#
# The available clues are as follows:
#
# - Sgt. Gray was in the room just north of the Poison
# - The Candlestick was in the Hall
# - Mrs. White was at the Fountain
# - Colonel Mustard was in the Drawing Room or the Candlestick was in the Drawing Room
# - Mr. Boddy was killed with the Poison
# - The murder weapon was in the Hall
# - Madame Rose was in the Drawing Room
# - The Revolver was in the Carriage House
#
# Please answer the following question(s):
#
# A. Who murdered Mr. Boddy?
# B. Where was the murder committed?
#
# And the following bonus question(s):
#
# C. Where was Mr. Green?
# D. Where was Colonel Mustard?
# E. Where was Sgt. Gray?
#
# Fill out your final answers in the following format:
#
# A. SUSPECT
# B. ROOM
# C. ROOM
# D. ROOM
# E. ROOM
#
# Best of luck, detective.
# Answer:
# {'A': 'Mr. Green', 'B': 'Hall', 'C': 'Hall', 'D': 'Drawing Room', 'E': 'Courtyard', 'F': None, 'G': None, 'H': None}
# Response:
# A. COLONEL MUSTARD
# B. FOUNTAIN
# C. HALL
# D. DRAWING ROOM
# E. POISON ROOM
# -------------------- Question:
# On a dark winter night, wealthy and enigmatic Mr. John Q. Boddy hosted a small, but lavish, dinner party for some of his closest associates. However, the night ended in tragedy when Mr. Boddy was found dead in one of the rooms of Tudor Mansion in the early hours of the morning. The following persons of interest have been identified as suspects:
#
# • Colonel Mustard
# • Monsieur Brunette
# • Mrs. White
# • Mr. Green
# • Miss Scarlet
#
# And the following weapons were found on the premises:
#
# • Lead Pipe
# • Candlestick
# • Wrench
# • Knife
#
# The murder could only have occured in one of the following rooms:
#
# 1. Courtyard
# 2. Kitchen
# 3. Dining Room
# 4. Cloak Room
# 5. Fountain
# 6. Hall
#
# The rooms are laid out as follows:
#
#   N N N
# W 1|2|3 E
# W 4|5|6 E
#   S S S
#
# Each suspect had one of the following possible motives for killing Mr. Boddy:
#
# • Ambition (1 suspect)
# • Power (2 suspects)
# • Betrayal (2 suspects)
#
# For the murder to occur, the murderer and Mr. Boddy must have been alone in a room with at least one weapon.
#
# The available clues are as follows:
#
# - Mr. Boddy was in the Courtyard
# - The Knife was in the room just east of Miss Scarlet
# - Monsieur Brunette was in the room just west of the Knife
# - Monsieur Brunette is motivated by Ambition
# - The Lead Pipe was in the room just east of Mr. Boddy
# - Colonel Mustard was in the room just east of the Knife
# - A suspect motivated by Power was in the same room as Mr. Boddy
# - The murder weapon was in the Courtyard if and only if the Wrench was in the Hall
# - Mrs. White is motivated by Power
# - Mrs. White was in the Hall
#
# Please answer the following question(s):
#
# A. Who murdered Mr. Boddy?
# B. What weapon did the murderer use?
# C. Where was the murder committed?
# D. Why did the murderer do it?
#
# And the following bonus question(s):
#
# E. Where was Mr. Green?
# F. Where was Monsieur Brunette?
# G. What motivates Colonel Mustard?
#
# Fill out your final answers in the following format:
#
# A. SUSPECT
# B. WEAPON
# C. ROOM
# D. MOTIVE
# E. ROOM
# F. ROOM
# G. MOTIVE
#
# Best of luck, detective.
# Answer:
# {'A': 'Mr. Green', 'B': 'Candlestick', 'C': 'Courtyard', 'D': 'Power', 'E': 'Courtyard', 'F': 'Cloak Room', 'G': 'Betrayal', 'H': None}
# Response:
# A. Colonel Mustard
#
# B. Lead Pipe
#
# C. Courtyard
#
# D. Betrayal
#
# Since the Bloc layout shows that the room just east of the Courtyard must be room 5, we know the Lead Pipe must be in room 5 (because the Lead Pipe is just east of Mr. Boddy, and Mr. Boddy is in the Courtyard), which implies the Wrench is in the Hall. The murder weapon thus cannot be the Wrench.
#
# Since a Power-seeker is in the same room as Mr Boddy, and Mrs. White is in the Hall, we conclude Mrs. White and the Wrench cannot be in the Courtyard.
#
# The Knife is just east of Miss Scarlet, and since Monsieur Brunette is west of the Knife, the Knife must be in room 2. Colonel Mustard cannot be in room 2 because Monsieur Brunette is in the room west of the Knife, meaning the Knife must be in room 2, thus Monsieur Brunette is in room 1, which would place the Lead Pipe in room 6.
#
# The Wrench, therefore, is in the room where the Lead Pipe is, which is the Hall. The Lead Pipe is in room 5, which means that Mr. Boddy is in room 6. Since there is only one Power-seeker, Mrs. White, it means the Power-seeker (Mrs. White) must be in room 4 to be alone with the Wrench, while the room east of room 4 must be the Courtyard (where Mr. Boddy was found) so the Lead Pipe is there too, in room 6. Mr. Boddy must be in room 5 so the Lead Pipe isn't in the Courtyard, thus killing the Lead Pipe possibility (if it were in 5 or 6, we would have the sentence: Mr. Boddy murder in Courtyard). Mrs. White can't be in room 5 because then the Power-seeker would be on the same east-west line as the Courtyard (the room must be in the "lower" part of the map), thus Mr. Boddy must be in room 4. This means the Power-seeker must be in room 6.
#
# Colonel Mustard is now a suspect because he has been placed on the same row as room 5 and we know the Knife must be in room 2 so he isn't in room 2. The only possible scenario left for him is the room directly above room 5 (room 6), except Mrs. White must be there (the power-seeker), so that leaves him in the room above room 4 where the Wrench isn't (because it's in room 5), which must then be room 3. Therefore, Colonel Mustard must be in room 3.
#
# We later deduce that Colonel Mustard must be in the room where the murder occurred because if he were in room 3, he would be in the same horizontal line as the Lead Pipe and the Power-seeker, so he must be in room 3 which is the same horizontal line as the Courtyard.
#
# Since we deduce Colonel Mustard's room to be 3 (same line as room 5) and he can't be in room 2 (as the Knife is in room 2), he must be in the room where the Lead Pipe and Wrench aren't, which would be the room above the Courtyard, thus making room 3 his possible location.
#
# We also deduce that Colonel Mustard must use the Lead Pipe as the murder weapon because it's the only logical option left, and he must kill in the Courtyard.
#
# Monsieur Brunette must be above the room with the Knife (2), so he must be in room 1.
#
# We find that Mr. Green can't be in room 1 or 2 because Monsieur Brunette is in room 1. The only option for the only person left who wasn't mentioned is room 4, however we can eliminate this option because then Mr. Boddy would be in room 5 and the Lead Pipe wouldn't be in room 5, we can also eliminate room 6 because then Power-seeker Mrs. White would be able to be the room above the Courtyard; both of these eliminate two more options so only one is left: room 3 (since that's where Mr. Boddy cannot be in, so it must be the other room of its row, and Mr. Boddy is either in 4 or 5 or 6 as deduced earlier, making the only choice to be in room 3).
#
# Deduction E and all other remaining deductions determine he must be in room 3 as well.
#
# Hence, Mr Green must be in room 4.
#
# Monsieur Brunette is motivated by Ambition, Monsieur Brunette was in room 1 and we have concluded that Monsieur Brunette was in the room just west of the knife, thus Monsieur Brunette must be motivated by Ambition, which therefore must be (E) in room 1.
#
# G. Ambassador
# -------------------- Question:
# On a dark winter night, wealthy and enigmatic Mr. John Q. Boddy hosted a small, but lavish, dinner party for some of his closest associates. However, the night ended in tragedy when Mr. Boddy was found dead in one of the rooms of Tudor Mansion in the early hours of the morning. The following persons of interest have been identified as suspects:
#
# • Mr. Green
# • Sgt. Gray
# • Colonel Mustard
# • Mrs. White
# • Miss Peach
# • Mrs. Peacock
#
# And the following weapons were found on the premises:
#
# • Poison
# • Horseshoe
# • Revolver
# • Wrench
# • Knife
# • Lead Pipe
#
# The murder could only have occured in one of the following rooms:
#
# 1. Study
# 2. Courtyard
# 3. Carriage House
# 4. Gazebo
# 5. Trophy Room
# 6. Kitchen
# 7. Lounge
#
# The rooms are laid out as follows:
#
#   N N N
# W 1|2|3 E
# W 4|5|6 E
# W 7|-|- E
#   S S S
#
# The exact time of the murder is a bit uncertain, but it has been narrowed down to one of the following times:
#
# • 11:00 PM
# • 11:30 PM
# • 12:00 AM
#
# At every time the suspects and Mr. Boddy either stayed in their current room or moved to an orthogonally adjacent room (north, south, east, or west). Weapons could be moved by suspects between rooms as well.
#
# Each suspect had one of the following possible motives for killing Mr. Boddy:
#
# • Pride (2 suspects)
# • Betrayal (2 suspects)
# • Ambition (1 suspect)
# • Greed (1 suspect)
#
# For the murder to occur, the murderer and Mr. Boddy must have been alone in a room with at least one weapon at some point in the night. Any clue about Mr. Boddy's whereabouts should be read as "Mr. Boddy (dead or alive) ..."
#
# The available clues are as follows:
#
# - The suspect motivated by Ambition was in the Study at 12:00 AM
# - The Poison was in the Carriage House at 11:30 PM if and only if the Lead Pipe was in the Study at 11:30 PM
# - Miss Peach and Mrs. White were in the Trophy Room together at least once
# - Mrs. White was in the Trophy Room at 11:30 PM if and only if Mr. Green was in the Gazebo at 11:00 PM
# - The suspect motivated by Ambition was in the Trophy Room at 11:00 PM
# - Sgt. Gray was in the Lounge at 11:00 PM
# - Mr. Boddy was in the Trophy Room at 11:30 PM
# - The Revolver was in the Lounge at 12:00 AM or Miss Peach was in the Kitchen at 11:00 PM
# - Mrs. Peacock moved from the Kitchen to the Carriage House at 11:30 PM
# - The suspect motivated by Greed was in the Trophy Room at 11:00 PM if and only if a suspect motivated by Betrayal was in the Trophy Room at 11:30 PM
# - The murder weapon was in the Carriage House at 11:00 PM
# - The Horseshoe was in the Lounge at 11:30 PM if and only if Mrs. Peacock was in the Kitchen at 12:00 AM
# - Colonel Mustard was in the room just east of Mr. Green at 11:00 PM
# - A suspect motivated by Betrayal moved from the Trophy Room to the Gazebo at 12:00 AM
# - The Lead Pipe was in the same room as the Wrench at 11:00 PM
# - A suspect motivated by Pride moved from the Gazebo to the Study at 12:00 AM
# - Miss Peach moved from the Kitchen to the Trophy Room at 12:00 AM
# - Mr. Boddy was in the Trophy Room at 11:00 PM
# - Sgt. Gray and Colonel Mustard were in the Gazebo together at least once
# - Miss Peach was in the same room as the Poison at 11:00 PM
# - The Horseshoe was in the same room as the Revolver at 12:00 AM
# - Mr. Boddy was in the room just south of the Poison at 12:00 AM
# - A suspect motivated by Pride moved the Knife from the Carriage House to the Kitchen at 12:00 AM
#
# Please answer the following question(s):
#
# A. Who murdered Mr. Boddy?
# B. What weapon did the murderer use?
# C. Where was the murder committed?
# D. When did the murder occur?
# E. Why did the murderer do it?
#
# And the following bonus question(s):
#
# F. Where was the Revolver at 12:00 AM?
# G. Where was the Poison at 11:00 PM?
#
# Fill out your final answers in the following format:
#
# A. SUSPECT
# B. WEAPON
# C. ROOM
# D. TIME
# E. MOTIVE
# F. ROOM
# G. ROOM
#
# Best of luck, detective.
# Answer:
# {'A': 'Mrs. Peacock', 'B': 'Knife', 'C': 'Kitchen', 'D': '12:00 AM', 'E': 'Pride', 'F': 'Lounge', 'G': 'Carriage House', 'H': None}
# Response:
# A. Colonel Mustard
# B. Horseshoe
# C. Lounge
# D. 11:00 PM
# E. Betrayal
# F. Lounge
# G. Kitchen
#
# The steps to solve the murder include:
#
# 1. The Horseshoe was in the Lounge at 11:30 PM if and only if Mrs. Peacock was in the Kitchen at 12:00 AM. As the Horseshoe is in the Lounge at 11:30 PM if and only if the Revolver was present in the Lounge and Mrs. Peacock was in the Kitchen, and the Revolver was in the Lounge at 12:00 AM if and only if Miss Peach was in the Kitchen at 11:00 PM. Since the Revolver was in the Lounge at 12:00 AM and the Horseshoe was in the Lounge at 11:30 PM, we know that Mrs. Peacock must have been in the Kitchen at 11:00 PM and the Poison must have been in the Carriage House at 11:30 PM, which, by the Poison in the Carriage House condition, means Lead Pipe was already in the Study at 11:30 PM.
#
# 2. Since Miss Peach was in the Kitchen at 11:00 PM, the Revolver must have been in the Lounge at 12:00 AM and the Horseshoe in the Lounge at 11:30 PM. So the Horseshoe is the Horseshoe weapon.
#
# 3. Miss Peach was in the same room as the Poison at 11:00 PM, and the Poison was in the Carriage House at 11:30 PM.
#
# 4. The suspect motivated by Ambition was in the Study at 12:00 AM. So a suspect motivated by Betrayal was in the Gazebo at 11:00 PM, and a suspect motivated by Pride moved from the Gazebo to the Study at 12:00 AM.
#
# 5. A suspect motivated by Pride moved the Knife from the Carriage House to the Kitchen at 12:00 AM.
#
# ...
# - Professor Plum was in the Drawing Room at 11:30 PM
# - Mrs. White was in the room just south of the Lead Pipe at 12:00 AM
# - Mr. Boddy and the Lead Pipe were in the Trophy Room together at least once
# - Mrs. White is motivated by Betrayal
# - Miss Scarlet was in the Drawing Room at 11:30 PM
# - The suspect motivated by Betrayal moved from the Drawing Room to the Library at 12:00 AM
# - Mrs. Peacock was in the room just east of Mr. Boddy at 12:00 AM
# - The murder weapon was in the same room as Colonel Mustard at 11:30 PM
# - The suspect motivated by Pride moved from the Lounge to the Kitchen at 11:45 PM
# - Miss Scarlet is motivated by Power
# - Mr. Green moved from the Lounge to the Ballroom at 12:00 AM
# - Mrs. White was in the Drawing Room at 11:30 PM
# - The Horseshoe was in the Lounge at 11:30 PM or the suspect motivated by Anger was in the Drawing Room at 11:30 PM
# - The suspect motivated by Anger was in the Drawing Room at 11:45 PM or the suspect motivated by Hatred was in the Lounge at 11:30 PM
# - Professor Plum and Mrs. White were in the Library together at least once
# - The Horseshoe was in the Dining Room at 12:00 AM if and only if the Lead Pipe was in the Trophy Room at 11:45 PM
# - The suspect motivated by Pride was in the Kitchen at 12:00 AM
# - Mr. Boddy was murdered at 11:30 PM
# - The Knife and the Revolver were in the Gazebo together at least once
# - The suspect motivated by Greed and the Candlestick were in the Ballroom together at least once
# - The Wrench was in the Study at 11:30 PM or the Wrench was in the Carriage House at 11:45 PM
# - The Knife was in the room just north of Sgt. Gray at 11:45 PM
# - The suspect motivated by Power moved the Rope from the Drawing Room to the Library at 12:00 AM
# - The Rope was in the Dining Room at 12:00 AM or the Revolver was in the Gazebo at 11:45 PM
# - Mrs. Peacock was in the same room as the Wrench at 11:45 PM
# - The Horseshoe was in the Kitchen at 11:45 PM if and only if the murder weapon was in the Trophy Room at 11:45 PM
# - Mrs. Peacock was in the room just west of the Knife at 11:30 PM
# - Miss Peach and Monsieur Brunette were in the Lounge together at least once
# - Monsieur Brunette is motivated by Revenge
# - The suspect motivated by Jealousy moved the Candlestick from the Ballroom to the Dining Room at 12:00 AM
# - The suspect motivated by Ambition moved from the Trophy Room to the Fountain at 12:00 AM
# - Miss Peach moved from the Ballroom to the Dining Room at 12:00 AM
#
# Please answer the following question(s):
#
# A. Who murdered Mr. Boddy?
# B. What weapon did the murderer use?
# C. Where was the murder committed?
# D. Why did the murderer do it?
#
# And the following bonus question(s):
#
# E. Where was Miss Scarlet at 12:00 AM?
# F. Where was the Horseshoe at 11:30 PM?
# G. Where was Miss Peach at 11:45 PM?
# H. Where was the suspect motivated by Betrayal at 11:45 PM?
#
# Fill out your final answers in the following format:
#
# A. SUSPECT
# B. WEAPON
# C. ROOM
# D. MOTIVE
# E. ROOM
# F. ROOM
# G. ROOM
# H. ROOM
#
# Best of luck, detective.
# Answer:
# {'A': 'Colonel Mustard', 'B': 'Lead Pipe', 'C': 'Trophy Room', 'D': 'Ambition', 'E': 'Library', 'F': 'Kitchen', 'G': 'Ballroom', 'H': 'Drawing Room'}
# Response:
# A. Colonel Mustard
# B. Lead Pipe
# C. Trophy Room
# D. Power
# E. Lounge
# F. Lounge
# G. Dining Room
# H. Drawing Room
# -------------------- Question:
# On a dark winter night, wealthy and enigmatic Mr. John Q. Boddy hosted a small, but lavish, dinner party for some of his closest associates. However, the night ended in tragedy when Mr. Boddy was found dead in one of the rooms of Tudor Mansion in the early hours of the morning. The following persons of interest have been identified as suspects:
#
# • Mr. Green
# • Mrs. Peacock
#
# And the following weapons were found on the premises:
#
# • Horseshoe
# • Candlestick
#
# The murder could only have occured in one of the following rooms:
#
# 1. Study
# 2. Fountain
#
# The rooms are laid out as follows:
#
#   N
# W 1 E
# W 2 E
#   S
#
# The exact time of the murder is a bit uncertain, but it has been narrowed down to one of the following times:
#
# • 11:45 PM
# • 12:00 AM
#
# At every time the suspects and Mr. Boddy either stayed in their current room or moved to an orthogonally adjacent room (north, south, east, or west). Weapons could be moved by suspects between rooms as well.
#
# Each suspect uniquely had one of the following possible motives for killing Mr. Boddy:
#
# • Ambition
# • Power
#
# For the murder to occur, the murderer and Mr. Boddy must have been alone in a room with at least one weapon at some point in the night. Any clue about Mr. Boddy's whereabouts should be read as "Mr. Boddy (dead or alive) ..."
#
# The available clues are as follows:
#
# - The murder weapon was in the Study at 11:45 PM if and only if Mr. Green was at the Fountain at 12:00 AM
# - The Candlestick was in the room just north of Mr. Green at 12:00 AM
# - The suspect motivated by Ambition moved from the Fountain to the Study at 12:00 AM
# - Mr. Boddy was killed with the Horseshoe
# - Mr. Boddy was in the Study at 11:45 PM
# - Mr. Green was in the room just south of the Candlestick at 11:45 PM
#
# Please answer the following question(s):
#
# A. Who murdered Mr. Boddy?
# B. Where was the murder committed?
# C. When did the murder occur?
# D. Why did the murderer do it?
#
# And the following bonus question(s):
#
# E. Where was Mrs. Peacock at 12:00 AM?
# F. Where was the suspect motivated by Ambition at 12:00 AM?
# G. Where was the Candlestick at 12:00 AM?
#
# Fill out your final answers in the following format:
#
# A. SUSPECT
# B. ROOM
# C. TIME
# D. MOTIVE
# E. ROOM
# F. ROOM
# G. ROOM
#
# Best of luck, detective.
# Answer:
# {'A': 'Mrs. Peacock', 'B': 'Study', 'C': '12:00 AM', 'D': 'Ambition', 'E': 'Study', 'F': 'Study', 'G': 'Study', 'H': None}
# Response:
# A. Mrs. Peacock
# B. Study
# C. 11:45 PM
# D. Ambition
# E. W 2
# F. Fountain
# G. N
# -------------------- Question:
# On a dark winter night, wealthy and enigmatic Mr. John Q. Boddy hosted a small, but lavish, dinner party for some of his closest associates. However, the night ended in tragedy when Mr. Boddy was found dead in one of the rooms of Tudor Mansion in the early hours of the morning. The following persons of interest have been identified as suspects:
#
# • Miss Peach
# • Mr. Green
# • Professor Plum
# • Madame Rose
# • Monsieur Brunette
# • Mrs. White
# • Colonel Mustard
# • Sgt. Gray
#
# And the following weapons were found on the premises:
#
# • Wrench
# • Candlestick
# • Revolver
# • Poison
# • Rope
#
# The murder could only have occured in one of the following rooms:
#
# 01. Billiard Room
# 02. Study
# 03. Library
# 04. Fountain
# 05. Kitchen
# 06. Hall
# 07. Conservatory
# 08. Studio
# 09. Lounge
# 10. Cloak Room
# 11. Dining Room
#
# The rooms are laid out as follows:
#
#   NN NN NN
# W 01|02|03 E
# W 04|05|06 E
# W 07|08|09 E
# W 10|11|- E
#   SS SS SS
#
# The exact time of the murder is a bit uncertain, but it has been narrowed down to one of the following times:
#
# • 09:30 PM
# • 10:00 PM
# • 10:30 PM
# • 11:00 PM
# • 11:30 PM
# • 12:00 AM
# • 12:30 AM
# • 01:00 AM
#
# At every time the suspects and Mr. Boddy either stayed in their current room or moved to an orthogonally adjacent room (north, south, east, or west). Weapons could be moved by suspects between rooms as well.
#
# Each suspect uniquely had one of the following possible motives for killing Mr. Boddy:
#
# • Ambition
# • Betrayal
# • Pride
# • Fear
# • Hatred
# • Revenge
# • Power
# • Greed
#
# For the murder to occur, the murderer and Mr. Boddy must have been alone in a room with at least one weapon at some point in the night. Any clue about Mr. Boddy's whereabouts should be read as "Mr. Boddy (dead or alive) ..."
#
# The available clues are as follows:
#
# - The suspect motivated by Betrayal was in the Conservatory at 09:30 PM or Professor Plum was in the Hall at 11:30 PM
# - Monsieur Brunette moved from the Cloak Room to the Dining Room at 01:00 AM
# - The suspect motivated by Fear moved from the Dining Room to the Cloak Room at 10:30 PM
# - The suspect motivated by Power was in the Billiard Room at 10:00 PM
# - Monsieur Brunette was in the Cloak Room at 11:30 PM
# - Mrs. White was in the Cloak Room at 12:00 AM
# - Colonel Mustard was in the room just south of Professor Plum at 09:30 PM
# - Madame Rose was in the Studio at 12:30 AM or Miss Peach was in the Cloak Room at 09:30 PM
# - The Rope was in the room just east of Colonel Mustard at 12:00 AM
# - The murderer moved from the Studio to the Conservatory at 10:30 PM
# - The Wrench was in the room just north of the Rope at 11:30 PM
# - The suspect motivated by Hatred was in the Dining Room at 01:00 AM
# - The suspect motivated by Greed was in the Cloak Room at 01:00 AM
# - Professor Plum moved from the Conservatory to the Cloak Room at 12:00 AM
# - Mr. Boddy was in the Billiard Room at 09:30 PM or Colonel Mustard was in the Billiard Room at 10:30 PM
# - Miss Peach moved the Candlestick from the Cloak Room to the Dining Room at 12:30 AM
# - Miss Peach was in the same room as Sgt. Gray at 10:30 PM
# - The Poison was in the Conservatory at 11:30 PM or Madame Rose was in the Hall at 10:00 PM
# - Mr. Boddy was in the Cloak Room at 11:30 PM or Miss Peach was in the Cloak Room at 10:00 PM
# - The suspect motivated by Revenge moved from the Billiard Room to the Study at 11:30 PM
# - The murderer moved from the Lounge to the Studio at 10:00 PM
# - The suspect motivated by Pride was in the Study at 12:00 AM or Monsieur Brunette was in the Cloak Room at 10:00 PM
# - The suspect motivated by Greed was in the Conservatory at 11:00 PM if and only if the suspect motivated by Ambition was in the Cloak Room at 12:30 AM
# - The murderer was in the Conservatory at 11:30 PM if and only if Mr. Green was in the Cloak Room at 01:00 AM
# - The suspect motivated by Pride was in the Conservatory at 11:00 PM if and only if the Poison was in the Studio at 09:30 PM
# - Monsieur Brunette was in the Cloak Room at 12:00 AM
# - The suspect motivated by Fear moved from the Cloak Room to the Conservatory at 01:00 AM
# - Mrs. White was in the same room as Madame Rose at 11:00 PM
# - The suspect motivated by Pride was in the Hall at 11:30 PM or the suspect motivated by Revenge was in the Study at 01:00 AM
# - The murder weapon was in the Cloak Room at 11:00 PM
# - The suspect motivated by Hatred was in the Cloak Room at 11:30 PM
# - The suspect motivated by Greed moved from the Conservatory to the Fountain at 10:30 PM
# - Miss Peach was in the same room as Monsieur Brunette at 09:30 PM
# - Mrs. White was in the room just east of Miss Peach at 09:30 PM
# - The suspect motivated by Betrayal moved from the Cloak Room to the Conservatory at 12:00 AM
# - Mr. Boddy was in the room just east of Sgt. Gray at 12:00 AM
# - Professor Plum was in the Dining Room at 12:30 AM
# - Sgt. Gray was in the Conservatory at 11:00 PM
# - The Revolver was in the room just east of Mr. Boddy at 10:30 PM
# - The murderer was in the Studio at 10:00 PM if and only if the suspect motivated by Greed was in the Conservatory at 12:30 AM
# - Madame Rose moved from the Dining Room to the Cloak Room at 11:00 PM
# - Mr. Green was in the Conservatory at 11:30 PM if and only if Monsieur Brunette was in the Dining Room at 11:00 PM
# - Mr. Boddy was in the Studio at 09:30 PM
# - Sgt. Gray was in the same room as Mr. Green at 12:00 AM
# - Madame Rose moved from the Fountain to the Billiard Room at 01:00 AM
# - The suspect motivated by Revenge moved from the Fountain to the Billiard Room at 10:00 PM
# - The murder weapon was in the Studio at 09:30 PM
# - The suspect motivated by Ambition moved from the Cloak Room to the Dining Room at 11:00 PM
# - Professor Plum was in the same room as Miss Peach at 01:00 AM
# - Sgt. Gray moved the Poison from the Fountain to the Conservatory at 01:00 AM
# - Professor Plum moved from the Billiard Room to the Fountain at 11:00 PM
# - The Rope was in the room just east of Colonel Mustard at 12:30 AM
# - Mrs. White was in the Cloak Room at 11:30 PM
# - Colonel Mustard was in the same room as Mr. Green at 09:30 PM
#
# Please answer the following question(s):
#
# A. Who murdered Mr. Boddy?
# B. What weapon did the murderer use?
# C. Where was the murder committed?
# D. When did the murder occur?
# E. Why did the murderer do it?
#
# And the following bonus question(s):
#
# F. Where was the suspect motivated by Greed at 11:30 PM?
# G. Where was the suspect motivated by Ambition at 01:00 AM?
#
# Fill out your final answers in the following format:
#
# A. SUSPECT
# B. WEAPON
# C. ROOM
# D. TIME
# E. MOTIVE
# F. ROOM
# G. ROOM
#
# Best of luck, detective.
# Answer:
# {'A': 'Sgt. Gray', 'B': 'Candlestick', 'C': 'Studio', 'D': '10:00 PM', 'E': 'Pride', 'F': 'Conservatory', 'G': 'Dining Room', 'H': None}
# Response:
# A. Sgt. Gray
# B. Revolver
# C. Studio
# D. 11:00 PM
# E. Revenge
# F. Conservatory
# G. Dining Room
# -------------------- Question:
# On a dark winter night, wealthy and enigmatic Mr. John Q. Boddy hosted a small, but lavish, dinner party for some of his closest associates. However, the night ended in tragedy when Mr. Boddy was found dead in one of the rooms of Tudor Mansion in the early hours of the morning. The following persons of interest have been identified as suspects:
#
# • Miss Scarlet
# • Sgt. Gray
# • Colonel Mustard
#
# And the following weapons were found on the premises:
#
# • Wrench
# • Knife
# • Lead Pipe
#
# The murder could only have occured in one of the following rooms:
#
# 1. Lounge
# 2. Trophy Room
# 3. Hall
# 4. Courtyard
#
# The rooms are laid out as follows:
#
#   N N
# W 1|2 E
# W 3|4 E
#   S S
#
# The exact time of the murder is a bit uncertain, but it has been narrowed down to one of the following times:
#
# • 11:45 PM
# • 12:00 AM
# • 12:15 AM
# • 12:30 AM
#
# At every time the suspects and Mr. Boddy either stayed in their current room or moved to an orthogonally adjacent room (north, south, east, or west). Weapons could be moved by suspects between rooms as well.
#
# For the murder to occur, the murderer and Mr. Boddy must have been alone in a room with at least one weapon at some point in the night. Any clue about Mr. Boddy's whereabouts should be read as "Mr. Boddy (dead or alive) ..."
#
# The available clues are as follows:
#
# - Colonel Mustard was in the room just north of Sgt. Gray at 12:15 AM
# - The murder weapon was in the Courtyard at 12:00 AM
# - Mr. Boddy was in the same room as the Wrench at 12:15 AM
# - The murder weapon was in the Trophy Room at 12:15 AM if and only if Colonel Mustard was in the Hall at 12:00 AM
# - Mr. Boddy was murdered at 12:30 AM
# - The Knife was in the same room as Sgt. Gray at 12:30 AM
# - Mr. Boddy was in the Courtyard at 12:00 AM
# - Mr. Boddy was in the room just south of the Lead Pipe at 12:15 AM
# - Miss Scarlet moved from the Courtyard to the Hall at 12:00 AM
# - Mr. Boddy was in the Courtyard at 11:45 PM or the Knife was in the Trophy Room at 12:30 AM
# - Sgt. Gray was in the Hall at 12:00 AM
# - The Knife was in the Hall at 12:30 AM if and only if Sgt. Gray was in the Hall at 12:00 AM
# - Sgt. Gray was in the Lounge at 11:45 PM if and only if Colonel Mustard was in the Lounge at 12:30 AM
# - Miss Scarlet moved from the Hall to the Courtyard at 12:15 AM
# - Mr. Boddy was in the Courtyard at 12:30 AM or the murder weapon was in the Lounge at 12:15 AM
# - The Wrench was in the Hall at 12:30 AM if and only if Colonel Mustard was in the Trophy Room at 12:15 AM
# - Colonel Mustard and the Knife were in the Hall together at least once
# - Sgt. Gray was in the Lounge at 11:45 PM or the Wrench was in the Lounge at 12:30 AM
#
# Please answer the following question(s):
#
# A. Who murdered Mr. Boddy?
# B. What weapon did the murderer use?
# C. Where was the murder committed?
#
# And the following bonus question(s):
#
# D. Where was the Knife at 11:45 PM?
# E. Where was Sgt. Gray at 12:30 AM?
#
# Fill out your final answers in the following format:
#
# A. SUSPECT
# B. WEAPON
# C. ROOM
# D. ROOM
# E. ROOM
#
# Best of luck, detective.
# Answer:
# {'A': 'Miss Scarlet', 'B': 'Wrench', 'C': 'Courtyard', 'D': 'Hall', 'E': 'Hall', 'F': None, 'G': None, 'H': None}
# Response:
# A. Colonel Mustard
# B. Lead Pipe
# C. Courtyard
# D. Hall
# E. Hall
# TrainOutput(global_step=250, training_loss=1.0140968795405159e-07, metrics={'train_runtime': 8543.5364, 'train_samples_per_second': 0.439, 'train_steps_per_second': 0.029, 'total_flos': 0.0, 'train_loss': 1.0140968795405159e-07})

# %%
160_000/60/60/60
# Out:
# 0.7407407407407407
